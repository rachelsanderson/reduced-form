# %% [markdown]
# ## I'm going to remove 1603 and Doe Loan guarantee program projects and see what happens.  I think there will be a more pronounced spike in what remains

# %%
import pandas as pd

# %%
# list of operating projects in 2018
gen = pd.read_csv('/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/eia_data/eia8602018/merged_new.csv')
gen = gen[~gen['utility_name'].isna()]
gen['nameplate_cap'] = pd.to_numeric(gen['nameplate_capacity_mw'].astype(str).str.replace(',',''))
# Out:
# /Users/rachelanderson/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (17,40,44,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#list of funded capacity 
grant_recips = pd.read_excel('../../../Data for Tax Equity Project/treasury_data/grant_awards.xlsx',header=1)

# %%
#create variables for receiving 1603 loan grant or 1705 

#DoE 1705 utility-scale recipients
searchfor = ['Agua Caliente', 'California Valley Solar', 
             'Desert Sun','Mesquite Solar 1', 'AV Solar']

gen['1603_grant'] = gen['plant_name'].isin(grant_recips['Business Name']) | gen['utility_name'].isin(grant_recips['Business Name'])
gen['1705_grant'] = gen['plant_name'].str.contains('|'.join(searchfor))

# %%
# Out:
# array(['Dolet Hills', 'Charles E Monty', 'Charles E Monty',
#        'Coughlin Power Station', 'Coughlin Power Station',
#        'Coughlin Power Station', 'Coughlin Power Station',
#        'Coughlin Power Station', 'Teche', 'Teche', 'Androscoggin 3',
#        'Bar Mills', 'Bar Mills', 'Bonny Eagle', 'Bonny Eagle',
#        'Bonny Eagle', 'Bonny Eagle', 'Bonny Eagle', 'Bonny Eagle',
#        'Brunswick Hydro', 'Brunswick Hydro', 'Brunswick Hydro',
#        'Cataract Hydro', 'Deer Rips', 'Deer Rips', 'Deer Rips',
#        'Deer Rips', 'Deer Rips', 'Deer Rips', 'Deer Rips', 'Gulf Island',
#        'Gulf Island', 'Gulf Island', 'Harris Hydro', 'Harris Hydro',
#        'Harris Hydro', 'Harris Hydro', 'Hiram', 'Hiram', 'North Gorham',
#        'North Gorham', 'Shawmut', 'Shawmut', 'Shawmut', 'Shawmut',
#        'Shawmut', 'Shawmut', 'Shawmut', 'Shawmut', 'Skelton', 'Skelton',
#        'West Buxton', 'West Buxton', 'West Buxton', 'West Buxton',
#        'West Buxton', 'West Buxton', 'Weston Hydro', 'Weston Hydro',
#        'Weston Hydro', 'Weston Hydro', 'Williams Hydro', 'Williams Hydro',
#        'Wyman Hydro', 'Wyman Hydro', 'Wyman Hydro', 'Colfax', 'Colfax',
#        'Colfax', 'Colfax', 'Colfax', 'Delray', 'Delray', 'Fermi', 'Fermi',
#        'Fermi', 'Fermi', 'Fermi', 'Hancock', 'Hancock', 'Hancock',
#        'Hancock', 'Hancock', 'Hancock', 'Monroe (MI)', 'Monroe (MI)',
#        'Monroe (MI)', 'Monroe (MI)', 'Monroe (MI)', 'Monroe (MI)',
#        'Monroe (MI)', 'Monroe (MI)', 'Monroe (MI)', 'Northeast (MI)',
#        'Northeast (MI)', 'Northeast (MI)', 'Northeast (MI)',
#        'Northeast (MI)', 'Northeast (MI)', 'Northeast (MI)', 'Oliver',
#        'Oliver', 'Oliver', 'Oliver', 'Oliver', 'Placid 12', 'Placid 12',
#        'Placid 12', 'Placid 12', 'Placid 12', 'Putnam (MI)',
#        'Putnam (MI)', 'Putnam (MI)', 'Putnam (MI)', 'Putnam (MI)',
#        'River Rouge', 'River Rouge', 'River Rouge', 'River Rouge',
#        'River Rouge', 'Slocum', 'Slocum', 'Slocum', 'Slocum', 'Slocum',
#        'St Clair', 'St Clair', 'St Clair', 'St Clair', 'St Clair',
#        'St Clair', 'St Clair', 'St Clair', 'Superior', 'Superior',
#        'Superior', 'Superior', 'Trenton Channel', 'Wilmot', 'Wilmot',
#        'Wilmot', 'Wilmot', 'Wilmot', 'John H Warden', 'G G Allen',
#        'G G Allen', 'G G Allen', 'G G Allen', 'G G Allen', 'Bridgewater',
#        'Bridgewater', 'Bridgewater', 'Buck', 'Buck', 'Buck',
#        'James E. Rogers Energy Complex', 'James E. Rogers Energy Complex',
#        'Cowans Ford', 'Cowans Ford', 'Cowans Ford', 'Cowans Ford',
#        'Dan River', 'Dan River', 'Dan River', 'Lookout Shoals',
#        'Lookout Shoals', 'Lookout Shoals', 'Marshall (NC)',
#        'Marshall (NC)', 'Marshall (NC)', 'Marshall (NC)',
#        'Mountain Island', 'Mountain Island', 'Mountain Island',
#        'Mountain Island', 'Oxford Dam', 'Oxford Dam', 'Rhodhiss',
#        'Rhodhiss', 'Rhodhiss', 'Tuxedo', 'Tuxedo', 'Bear Creek Dam',
#        'Cedar Cliff', 'Franklin (NC)', 'Franklin (NC)', 'Mission',
#        'Mission', 'Mission', 'Nantahala', 'Tennessee Creek', 'Thorpe',
#        'Tuckasegee', 'Cedar Creek', 'Cedar Creek', 'Cedar Creek',
#        'Dearborn', 'Dearborn', 'Dearborn', 'Fishing Creek',
#        'Fishing Creek', 'Fishing Creek', 'Fishing Creek', 'Fishing Creek',
#        'Gaston Shoals', 'Gaston Shoals', 'Gaston Shoals', 'Gaston Shoals',
#        'Great Falls (SC)', 'Great Falls (SC)', 'Great Falls (SC)',
#        'Great Falls (SC)', 'Jocassee', 'Jocassee', 'Jocassee', 'Jocassee',
#        'W S Lee', 'W S Lee', 'W S Lee', 'W S Lee', 'W S Lee', 'W S Lee',
#        'Oconee', 'Oconee', 'Oconee', 'Wateree Hydro', 'Wateree Hydro',
#        'Wateree Hydro', 'Wateree Hydro', 'Wateree Hydro', 'Wylie',
#        'Wylie', 'Wylie', 'Wylie', '99 Islands', '99 Islands',
#        '99 Islands', '99 Islands', 'Belle River', 'Belle River',
#        'Belle River', 'Belle River', 'Belle River', 'Belle River',
#        'Belle River', 'Belle River', 'Belle River', 'Belle River',
#        'Greenwood (MI)', 'Greenwood (MI)', 'Greenwood (MI)',
#        'Greenwood (MI)', 'Catawba', 'Catawba', 'McGuire', 'McGuire',
#        'Brame Energy Center', 'Brame Energy Center',
#        'Brame Energy Center', 'Queens Creek', 'Keowee', 'Keowee',
#        'Bad Creek', 'Bad Creek', 'Bad Creek', 'Bad Creek',
#        'Lincoln Combustion', 'Lincoln Combustion', 'Lincoln Combustion',
#        'Lincoln Combustion', 'Lincoln Combustion', 'Lincoln Combustion',
#        'Lincoln Combustion', 'Lincoln Combustion', 'Lincoln Combustion',
#        'Lincoln Combustion', 'Lincoln Combustion', 'Lincoln Combustion',
#        'Lincoln Combustion', 'Lincoln Combustion', 'Lincoln Combustion',
#        'Lincoln Combustion', 'State Farm', 'State Farm', 'State Farm',
#        'Springview', 'Springview', 'Mill Creek (SC)', 'Mill Creek (SC)',
#        'Mill Creek (SC)', 'Mill Creek (SC)', 'Mill Creek (SC)',
#        'Mill Creek (SC)', 'Mill Creek (SC)', 'Mill Creek (SC)',
#        'Belews Creek', 'Belews Creek', 'Benton Falls Associates',
#        'Benton Falls Associates', 'Gilman Mill', 'Gilman Mill',
#        'Gilman Mill', 'Gilman Mill', 'Glen Ferris Hydro',
#        'Glen Ferris Hydro', 'Glen Ferris Hydro', 'Glen Ferris Hydro',
#        'Glen Ferris Hydro', 'Glen Ferris Hydro', 'Glen Ferris Hydro',
#        'Glen Ferris Hydro', 'Hawks Nest Hydro', 'Hawks Nest Hydro',
#        'Hawks Nest Hydro', 'Hawks Nest Hydro',
#        'Cosmo Specialty Fibers Plant', 'Cosmo Specialty Fibers Plant',
#        'Multitrade Rabun Gap, LLC', 'Aziscohos Hydroelectric Project',
#        'Puna Geothermal Venture I', 'Puna Geothermal Venture I',
#        'Puna Geothermal Venture I', 'Puna Geothermal Venture I',
#        'Puna Geothermal Venture I', 'Puna Geothermal Venture I',
#        'Puna Geothermal Venture I', 'Puna Geothermal Venture I',
#        'Puna Geothermal Venture I', 'Puna Geothermal Venture I',
#        'Puna Geothermal Venture I', 'Puna Geothermal Venture I',
#        'Otay Landfill Gas, LLC', 'Otay Landfill Gas, LLC',
#        'Otay Landfill Gas, LLC', 'Otay Landfill Gas, LLC',
#        'Otay Landfill Gas, LLC', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Great Lakes Hydro America - ME', 'Great Lakes Hydro America - ME',
#        'Interstate Paper LLC Riceboro', 'Rio Grande Valley Sugar Growers',
#        'Rio Grande Valley Sugar Growers',
#        'Rio Grande Valley Sugar Growers',
#        'Rio Grande Valley Sugar Growers',
#        'Rio Grande Valley Sugar Growers', 'Hewlett Packard Enterprise',
#        'Hewlett Packard Enterprise', 'Hewlett Packard Enterprise',
#        'Hewlett Packard Enterprise', 'Hewlett Packard Enterprise',
#        'Hewlett Packard Enterprise', 'Hewlett Packard Enterprise',
#        'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham',
#        'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham',
#        'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham',
#        'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham',
#        'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham', 'Berlin Gorham',
#        'Berlin Gorham', 'Santeetlah', 'Santeetlah', 'Cheoah', 'Cheoah',
#        'Cheoah', 'Cheoah', 'Cheoah', 'Calderwood', 'Calderwood',
#        'Calderwood', 'Chilhowee', 'Chilhowee', 'Chilhowee',
#        'MM Taunton Energy', 'MM Taunton Energy', 'MM Taunton Energy',
#        'MM Taunton Energy', 'Rockingham County CT Station',
#        'Rockingham County CT Station', 'Rockingham County CT Station',
#        'Rockingham County CT Station', 'Rockingham County CT Station',
#        'Acadia Energy Center', 'Acadia Energy Center',
#        'Acadia Energy Center', 'Acadia Energy Center',
#        'Acadia Energy Center', 'Acadia Energy Center',
#        'Renaissance Power Plant', 'Renaissance Power Plant',
#        'Renaissance Power Plant', 'Renaissance Power Plant', 'Dean',
#        'Dean', 'Dean', 'Dean', 'Mountain Home',
#        'Ampersand Chowchilla Biomass LLC', 'Barton Windpower LLC',
#        'Barton Windpower LLC', 'Pebble Springs Wind LLC',
#        'Penascal Wind Power LLC', 'South Chestnut LLC',
#        'EcoGrove Wind LLC', 'Solana Generating Station',
#        'Solana Generating Station', 'Plainfield Renewable Energy LLC',
#        'Wheat Field Wind Power Project', 'Marble River Wind Farm',
#        'Sagebrush Power Partners', 'Atlantic City Convention Center',
#        'Atlantic City Convention Center',
#        'Atlantic City Convention Center',
#        'Atlantic City Convention Center', 'Threemile Canyon',
#        'NRG Solar Blythe LLC', 'Bull Creek Wind',
#        'NGP Blue Mountain I LLC', 'NGP Blue Mountain I LLC',
#        'NGP Blue Mountain I LLC', 'Penascal II Wind Project LLC',
#        'Star Point Wind Project LLC', 'Meadow Lake Wind Farm LLC',
#        'Lost Lakes Wind Farm LLC', 'Meadow Lake Wind Farm II LLC',
#        'Blackstone Wind Farm II LLC', 'Meadow Lake Wind Farm III LLC',
#        'Tuana Springs', 'Eurus Combine Hills Turbine Ranch 2',
#        'Beech Ridge Energy LLC', 'Meadow Lake Wind Farm IV',
#        'Vantage Wind Energy LLC', 'Blue Wing Solar Energy Generation',
#        'Lubbock Wind Ranch', 'Lubbock Wind Ranch', 'Lubbock Wind Ranch',
#        'Flat Water Wind Farm LLC', 'Hardscrabble Wind Power LLC',
#        'Criterion', 'Garnet Wind Energy Center',
#        'Copper Crossing Solar LLC', 'Mayberry Solar LLC',
#        'Mojave Solar Project', 'Mojave Solar Project',
#        'DE Solar 10240 Old Dowd Rd', 'DE Solar 657 Brigham Rd',
#        'DE Solar 1725 Drywall Dr', 'Sun City Project LLC',
#        'Sand Drag LLC', 'Lakefield Wind Project LLC', 'Gratiot Wind Park',
#        'Buffalo Ridge II LLC', 'San Emidio',
#        'Martins Creek Solar NC, LLC', 'Bishop Hill Energy LLC',
#        'Ralls Wind Farm', 'John L. Featherstone Plant',
#        'Manzana Wind LLC', 'Masser Farms Realty Solar',
#        'Ocotillo Express LLC', 'Kapaa Photovoltaic Project',
#        'Sunset Reservoir North Basin', 'RP-Orlando, LLC',
#        'Record Hill Wind', 'PaTu Wind Farm LLC',
#        'Long Island Solar Farm LLC', 'Hatch Solar Energy Center I, LLC',
#        'New Harvest Wind Project LLC', 'Paulding Wind Farm II',
#        'Wolverine', 'Bulldog', "City & County of Denver at Denver Int'l",
#        'McCormick & Co. Inc. at Belcamp',
#        'Toys R Us- DE, Inc. at Mt. Olive, NJ', 'Temescal Canyon RV, LLC',
#        'SAF Hydroelectric LLC', 'SAF Hydroelectric LLC',
#        'SAF Hydroelectric LLC', 'SAF Hydroelectric LLC',
#        'SAF Hydroelectric LLC', 'SAF Hydroelectric LLC',
#        'SAF Hydroelectric LLC', 'SAF Hydroelectric LLC',
#        'SAF Hydroelectric LLC', 'SAF Hydroelectric LLC',
#        'SAF Hydroelectric LLC', 'SAF Hydroelectric LLC',
#        'SAF Hydroelectric LLC', 'SAF Hydroelectric LLC',
#        'SAF Hydroelectric LLC', 'SAF Hydroelectric LLC',
#        'SMUD at Grundman', 'SMUD at Van Conett', 'SMUD at Fleshman',
#        'Murphy Farm Power, LLC', 'CS Murphy Point, LLC', 'Turnbull Hydro',
#        'Turnbull Hydro', 'Vasco Winds', 'Johnson Matthey, Inc. Solar',
#        'Benjamin Moore & Co. Solar', 'Suzlon Project VIII LLC',
#        'Suzlon Project VIII LLC', 'The City of Vineland at West Vineland',
#        'The City of Vineland at North Vineland',
#        'FedEx Field Solar Facility', 'Gordon Butte Wind LLC',
#        'Sawtooth Wind Project', 'SMUD at Lawrence',
#        'Power County Wind Park South', 'Power County Wind Park North',
#        'RE Bagdad Solar I LLC', 'RE Ajo 1 LLC', 'ISH Solar Central, LLC',
#        'GL Wind', 'GL Wind', 'Sigel Wind Park', 'Minden Wind Park',
#        'McKinley Wind Park', 'Santa Cruz Energy', 'Concord Energy',
#        'Concord Energy', 'Richmond Energy', 'Richmond Energy',
#        'Richmond Energy', 'Richmond Energy', 'Auwahi Wind Energy',
#        'Auwahi Wind Energy', 'California Ridge Wind Energy LLC',
#        'Buffalo Center Wind LLC', 'Roeder Family Wind Farm LLC',
#        'Keystone Solar', 'Brookside Newark', 'Echo Wind Park',
#        'Echo Wind Park', 'Echo Wind Park',
#        'Oberlin Spear Point Solar One', 'RE Kansas South LLC',
#        'TA-High Desert LLC', '180 Raritan Solar',
#        'RE Victor Phelan Solar One LLC', 'NFM Solar Power LLC',
#        'GL Dairy Biogas', 'GL Dairy Biogas', 'Newberry Solar 1 LLC',
#        'Lincoln Financial Field', 'Leicester One MA Solar LLC',
#        'Chadbourn Farm', 'Belwood Farm', 'Railroad Farm', 'Watts Farm',
#        'Farrington Farm', 'Haynes Farm', 'Moorings Farm',
#        'White Cross Farm', 'Wilson Farm 1', 'Rochelle Energy Center',
#        'Rochelle Energy Center', 'Rochelle Energy Center',
#        'Threemile Digester', 'Threemile Digester', 'Threemile Digester',
#        'CES Sterling LLC', 'Red Lion Energy Center',
#        'Red Lion Energy Center', 'Red Lion Energy Center',
#        'Red Lion Energy Center', 'Red Lion Energy Center',
#        'Red Lion Energy Center', 'Swauk Wind LLC', 'Cumberland Rose',
#        'Fontanelle', 'Meadow Ridge', 'McCoy Solar Energy Project',
#        'McCoy Solar Energy Project', 'McCoy Solar Energy Project',
#        'McCoy Solar Energy Project', 'McCoy Solar Energy Project',
#        'McCoy Solar Energy Project', 'McCoy Solar Energy Project',
#        'McCoy Solar Energy Project', 'Herbert Farm Solar', 'Alethea I',
#        'PCSP3 Airport', 'Silver City WWTP PV Project',
#        'Gilbert Solar Facility I, LLC', 'Community Solar 1',
#        'Halifax County Biomass', 'Paradise Solar Energy Center',
#        'Lightning Dock Geothermal HI-01, LLC',
#        'Lightning Dock Geothermal HI-01, LLC',
#        'Lightning Dock Geothermal HI-01, LLC',
#        'Lightning Dock Geothermal HI-01, LLC',
#        'Lightning Dock Geothermal HI-01, LLC',
#        'Celina Solar Project #1, LLC', 'Gratiot County Wind LLC',
#        'ABEC Bidart-Old River LLC', 'ABEC Bidart-Old River LLC',
#        'Brookfield', 'JMB Mcguire-Dix-Lakehurst Solar Project',
#        'Richland Center Renewable Energy LLC',
#        'Richland Center Renewable Energy LLC', 'Oakboro Farm',
#        'Berkley East Solar LLC', 'Stuyvesant Falls', 'Stuyvesant Falls',
#        'Story City Wind Project', 'Camelot Wind LLC',
#        'West Davisville Solar', 'AgriReNew', 'Eagle Springs Solar LLC',
#        'WED NK Green', 'Plainfield One Solar LLC',
#        '24 Applegate Solar LLC', 'Engelhard Solar LLC',
#        'Westborough Solar LLC', 'Lakewood Seven Solar LLC',
#        '4 Applegate Solar LLC', '12 Applegate Solar LLC',
#        'Adelanto Solar II, LLC', 'Adelanto Solar, LLC', 'Cranbury',
#        'Valencia Solar', 'Tech Park Solar',
#        'Antares-GRE 314 East Lyme LLC', 'Parlin Solar LLC',
#        'Springfield Solar LLC', 'Beaver Solar LLC', 'Mocksville Solar',
#        'CII Methane Management IV, LLC', 'Fairhaven Wind',
#        'Leominster (MA)-South Street-R&D', 'Adams Farm Solar',
#        'Fremont Community Digester, LLC',
#        'Fremont Community Digester, LLC', 'Hunt Farm Solar',
#        '205 Sturbridge A', '201 Sturbridge B',
#        'General Motors Corp at White Marsh MD',
#        'FCPC Renewable Generation', 'FCPC Renewable Generation',
#        'Domino Farms Solar', 'Ford World Headquarters',
#        'Greenwood Solar Farm', 'Demille Solar Farm', 'Turrill Solar Farm',
#        "O'Shea Solar Farm", 'NHA at Mansfield NJ',
#        'Monroe Solar Facility', 'Pfizer Peapack Solar',
#        'Royal Wine Corp Solar Power Plant',
#        'Summit Water Nexus Mt. Holly, LLC Solar', 'Sabert Solar',
#        '126 Grove Solar LLC', 'Nexamp Peak CSG', 'Dublin Solar I',
#        'Green Island Hydroelectric Station',
#        'Green Island Hydroelectric Station',
#        'Green Island Hydroelectric Station',
#        'Green Island Hydroelectric Station', '433 Purchase Solar NG, LLC',
#        'Grafton PV', 'Barrett PV', 'Cedar Creek PV',
#        'Amazon - Patterson PV', 'Lichtenthal', 'Call Farms 1',
#        'Call Farms 3', 'Monroe County Sites A & B',
#        'Monroe County Sites A & B', 'Monroe County Sites C, D, & E',
#        'Monroe County Sites C, D, & E', 'Monroe County Sites C, D, & E',
#        'Eagle Point Solar', 'Anheuser-Busch Baldwinsville',
#        'Columbia University - Johnson Farms',
#        'Time Warner Cable Enterprises - Martino',
#        'Columbia University - Minisink',
#        'St. Lawerence University - Sutton', 'City of Rochester Solar',
#        'Broadalbin-Perth Solar', 'Richmond NMCA', 'Mattas Farms',
#        'Woodleaf Solar Facility', 'Dynamic - Walpole', 'Rantoul Solar',
#        'Connell East LLC', 'RC Energy AA LLC Solar Facility',
#        'Nextsun Energy Littleton'], dtype=object)

# %%
arra_names = gen[gen['plant_name'].isin(grant_recips['Business Name']) | gen['utility_name'].isin(grant_recips['Business Name'])]['plant_name'].values
doe_names = gen[gen['plant_name'].str.contains('|'.join(searchfor))]['plant_name'].values
loan_dict = dict.fromkeys(arra_names, '1603 grant')
loan_dict.update(dict.fromkeys(doe_names, '1705 program'))

# %%
gen['grant_program'] = gen['plant_name'].map(loan_dict)
gen['grant_program'] = gen['grant_program'].fillna("none")
# Out:
#        Unnamed: 0  Unnamed: 0.1  utility_id                     utility_name  \
# 107           107           107        3265                  Cleco Power LLC
# 1388         1388          1388       39006  Brookfield White Pine Hydro LLC
# 1389         1389          1389       39006  Brookfield White Pine Hydro LLC
# 2462         2462          2462        3265                  Cleco Power LLC
# 2463         2463          2463        3265                  Cleco Power LLC
# ...           ...           ...         ...                              ...
# 21867       21867         21867       61012           AES Distributed Energy
# 21934       21934         21934       61969                    Altorfer Inc.
# 21983       21983         21983       62095                Connell East LLC.
# 22080       22080         22080       62655                 RC Energy AA LLC
# 22093       22093         22093       62727     Nextsun Energy Littleton LLC
#
#        plant_code                       plant_name plant_state        county  \
# 107          51.0                      Dolet Hills          LA        DeSoto
# 1388        805.0                  Charles E Monty          ME  Androscoggin
# 1389        805.0                  Charles E Monty          ME  Androscoggin
# 2462       1396.0           Coughlin Power Station          LA    Evangeline
# 2463       1396.0           Coughlin Power Station          LA    Evangeline
# ...           ...                              ...         ...           ...
# 21867     62324.0                Dynamic - Walpole          MA       Norfolk
# 21934     62451.0                    Rantoul Solar          IL     Champaign
# 21983     62598.0                 Connell East LLC          NJ         Union
# 22080     62756.0  RC Energy AA LLC Solar Facility          NM    Bernalillo
# 22093     62842.0         Nextsun Energy Littleton          MA     Middlesex
#
#       generator_id                        technology  ... entity_type  \
# 107              1           Conventional Steam Coal  ...           I
# 1388           M-1        Conventional Hydroelectric  ...           Q
# 1389            M2        Conventional Hydroelectric  ...           Q
# 2462             6  Natural Gas Fired Combined Cycle  ...           I
# 2463             7  Natural Gas Fired Combined Cycle  ...           I
# ...            ...                               ...  ...         ...
# 21867        WAL01                Solar Photovoltaic  ...           Q
# 21934        RANTL                Solar Photovoltaic  ...         IND
# 21983        LOREA                Solar Photovoltaic  ...         COM
# 22080        AA001                Solar Photovoltaic  ...           Q
# 22093        1-003                Solar Photovoltaic  ...           Q
#
#       other_owner     region    regulated                       period  \
# 107          True       MISO    Regulated  2009-2011: Loan grant + ITC
# 1388        False     ISO-NE  Deregulated  2009-2011: Loan grant + ITC
# 1389        False     ISO-NE  Deregulated  2009-2011: Loan grant + ITC
# 2462         True       MISO    Regulated  2009-2011: Loan grant + ITC
# 2463         True       MISO    Regulated  2009-2011: Loan grant + ITC
# ...           ...        ...          ...                          ...
# 21867       False     ISO-NE  Deregulated       2017-2023: ITC Round 2
# 21934       False       MISO  Deregulated       2012-2016: ITC Round 1
# 21983       False        PJM  Deregulated       2012-2016: ITC Round 1
# 22080       False  Southwest    Regulated  2009-2011: Loan grant + ITC
# 22093       False     ISO-NE  Deregulated       2012-2016: ITC Round 1
#
#       nameplate_cap loan_grant 1603_grant 1705_grant grant_program
# 107           720.7       True       True      False    1603 grant
# 1388           14.2       True       True      False    1603 grant
# 1389           14.2       True       True      False    1603 grant
# 2462          113.6       True       True      False    1603 grant
# 2463          243.1       True       True      False    1603 grant
# ...             ...        ...        ...        ...           ...
# 21867           2.0       True       True      False    1603 grant
# 21934           1.0       True       True      False    1603 grant
# 21983           1.4      False       True      False    1603 grant
# 22080           1.0       True       True      False    1603 grant
# 22093           5.0       True       True      False    1603 grant
#
# [771 rows x 93 columns]

# %%
gen.to_csv('/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/eia_data/eia8602018/merged_new.csv')

# %%
# finds exact matches from generators to loan grants

gen_grants = gen[gen['Utility Name'].isin(grant_recips['Business Name'])]
gen_grants[['Utility Name','nameplate_cap', 'Plant Name', 'Technology']].sort_values(by=['nameplate_cap'],ascending=False)
gen_grants[gen_grants['Technology'].str.contains("Solar")]
# Out:
#        Unnamed: 0 Utility ID                         Utility Name  Plant Code  \
# 15342       15342      56023                Arizona Solar One LLC     56812.0
# 15343       15343      56023                Arizona Solar One LLC     56812.0
# 15523       15523      57044  Constellation Solar New Jersey, LLC     56900.0
# 15524       15524      57044  Constellation Solar New Jersey, LLC     56900.0
# 15525       15525      57044  Constellation Solar New Jersey, LLC     56900.0
# ...           ...        ...                                  ...         ...
# 21861       21861       5416           Duke Energy Carolinas, LLC     62304.0
# 21867       21867      61012               AES Distributed Energy     62324.0
# 21934       21934      61969                        Altorfer Inc.     62451.0
# 22080       22080      62655                     RC Energy AA LLC     62756.0
# 22093       22093      62727         Nextsun Energy Littleton LLC     62842.0
#
#                             Plant Name State      County Generator ID  \
# 15342        Solana Generating Station    AZ    Maricopa        GEN 1
# 15343        Solana Generating Station    AZ    Maricopa         GEN2
# 15523  Atlantic City Convention Center    NJ    Atlantic            1
# 15524  Atlantic City Convention Center    NJ    Atlantic            2
# 15525  Atlantic City Convention Center    NJ    Atlantic            3
# ...                                ...   ...         ...          ...
# 21861          Woodleaf Solar Facility    NC       Rowan          PV1
# 21867                Dynamic - Walpole    MA     Norfolk        WAL01
# 21934                    Rantoul Solar    IL   Champaign        RANTL
# 22080  RC Energy AA LLC Solar Facility    NM  Bernalillo        AA001
# 22093         Nextsun Energy Littleton    MA   Middlesex        1-003
#
#                               Technology Prime Mover  ...  \
# 15342  Solar Thermal with Energy Storage          CP  ...
# 15343  Solar Thermal with Energy Storage          CP  ...
# 15523                 Solar Photovoltaic          PV  ...
# 15524                 Solar Photovoltaic          PV  ...
# 15525                 Solar Photovoltaic          PV  ...
# ...                                  ...         ...  ...
# 21861                 Solar Photovoltaic          PV  ...
# 21867                 Solar Photovoltaic          PV  ...
# 21934                 Solar Photovoltaic          PV  ...
# 22080                 Solar Photovoltaic          PV  ...
# 22093                 Solar Photovoltaic          PV  ...
#
#       Planned New Nameplate Capacity (MW) Planned Repower Month  \
# 15342
# 15343
# 15523
# 15524
# 15525
# ...                                   ...                   ...
# 21861
# 21867
# 21934
# 22080
# 22093
#
#       Planned Repower Year Other Planned Modifications?  \
# 15342                                                 N
# 15343                                                 N
# 15523                                               NaN
# 15524                                               NaN
# 15525                                               NaN
# ...                    ...                          ...
# 21861                                               NaN
# 21867                                               NaN
# 21934                                               NaN
# 22080                                               NaN
# 22093                                               NaN
#
#       Other Modifications Month Other Modifications Year Multiple Fuels?  \
# 15342                                                                  N
# 15343                                                                  N
# 15523                                                                NaN
# 15524                                                                NaN
# 15525                                                                NaN
# ...                         ...                      ...             ...
# 21861                                                                NaN
# 21867                                                                NaN
# 21934                                                                NaN
# 22080                                                                NaN
# 22093                                                                NaN
#
#       Cofire Fuels? Switch Between Oil and Natural Gas? nameplate_cap
# 15342             N                                   N         140.0
# 15343             N                                   N         140.0
# 15523           NaN                                 NaN           0.5
# 15524           NaN                                 NaN           0.5
# 15525           NaN                                 NaN           0.5
# ...             ...                                 ...           ...
# 21861           NaN                                 NaN           6.0
# 21867           NaN                                 NaN           2.0
# 21934           NaN                                 NaN           1.0
# 22080           NaN                                 NaN           1.0
# 22093           NaN                                 NaN           5.0
#
# [128 rows x 75 columns]

# %%
# finds matches from loan grant recips to utilities 

grant_recips[grant_recips['Business Name'].isin(gen['Utility Name'])]
# Out:
#                               Business Name State  \
# 55                    Arizona Solar One LLC    AZ
# 158           Gilbert Solar Facility I, LLC    AZ
# 268                            RE Ajo 1 LLC    AZ
# 269                   RE Bagdad Solar 1 LLC    AZ
# 346                    Tech Park Solar, LLC    AZ
# ...                                     ...   ...
# 9780          Sagebrush Power Partners, LLC    WA
# 9792                    GL Dairy Biogas LLC    WI
# 9993         FCPC Renewable Generation, LLC    WI
# 9996   Richland Center Renewable Energy LLC    WI
# 10002                  Hawks Nest Hydro LLC    WV
#
#                            Technology       Funded           Award Date
# 55                  Solar Electricity  513753359.0  2014-03-04 00:00:00
# 158                 Solar Electricity    2505195.0  2012-07-10 00:00:00
# 268                 Solar Electricity    6605741.0  2012-12-31 00:00:00
# 269                 Solar Electricity   22909331.0  2012-12-31 00:00:00
# 346                 Solar Electricity    4464795.0  2014-03-26 00:00:00
# ...                               ...          ...                  ...
# 9780                             Wind   53420192.0  2011-01-28 00:00:00
# 9792   Biomass (open loop, livestock)    2231830.0  2014-05-29 00:00:00
# 9993                   Trash Facility    5178221.0  2014-09-10 00:00:00
# 9996                   Trash Facility    7346948.0  2013-05-10 00:00:00
# 10002        Hydropower (incremental)    6429574.0  2014-05-30 00:00:00
#
# [160 rows x 5 columns]

# %%
desertSun = gen[gen['Utility Name'].str.contains("NextEra Energy Desert Sunlight")]

# %%
desertSun['Nameplate Capacity (MW)'].sum()
# Out:
# 563.4000000000001

# %%
desertSun[['Plant Name', 'Utility Name', 'Generator ID', 'Nameplate Capacity (MW)','Operating Month', 'Operating Year']]
# Out:
#                      Plant Name                             Utility Name  \
# 17177  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17178  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17179  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17180  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17181  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17182  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17183  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17184  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17185  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17186  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 17187  Desert Sunlight 300, LLC  NextEra Energy Desert Sunlight 300, LLC
# 18005  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
# 18006  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
# 18007  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
# 18008  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
# 18009  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
# 18010  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
# 18011  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
# 18012  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
# 18013  Desert Sunlight 250, LLC  NextEra Energy Desert Sunlight 250, LLC
#
#       Generator ID Nameplate Capacity (MW)  Operating Month  Operating Year
# 17177         DSL1                    40.3             11.0          2013.0
# 17178        DSL10                    30.2             11.0          2013.0
# 17179        DSL11                    20.2             11.0          2013.0
# 17180         DSL2                    40.3             11.0          2013.0
# 17181         DSL3                    40.3             11.0          2013.0
# 17182         DSL4                    30.2             11.0          2013.0
# 17183         DSL5                    25.2              6.0          2014.0
# 17184         DSL6                    25.2              8.0          2014.0
# 17185         DSL7                    20.2              8.0          2014.0
# 17186         DSL8                    18.9             10.0          2014.0
# 17187         DSL9                    22.7             10.0          2014.0
# 18005        DSL12                    39.1             12.0          2013.0
# 18006        DSL13                    39.1              1.0          2014.0
# 18007        DSL14                    26.5              4.0          2014.0
# 18008        DSL15                    13.9              6.0          2014.0
# 18009        DSL16                    22.7             11.0          2013.0
# 18010        DSL17                      29             11.0          2013.0
# 18011        DSL18                      29              6.0          2014.0
# 18012        DSL19                    25.2             10.0          2014.0
# 18013        DSL20                    25.2             11.0          2013.0

# %%
# Out:
# 347.7
