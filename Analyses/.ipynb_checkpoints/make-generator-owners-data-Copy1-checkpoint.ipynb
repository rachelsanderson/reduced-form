# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import json
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

pd.options.display.max_rows = 999
pd.options.display.max_columns=100
plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = [15, 10]

dataDir = '/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/'
jsonDir = '/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/JSONFiles/'

# %% [markdown]
# ## Read and fix data

# %%
utils = pd.read_csv(dataDir + 'eia_data/eia8602018/utility_2018.csv',header=1).fillna(0)
utils.columns = [x.lower().replace(" ","_").replace("?","") for x in utils.columns]

# %%
utils['owner_of_plants_reported_on_form'].value_counts()
# Out:
# Y    4400
# 0     639
# Name: owner_of_plants_reported_on_form, dtype: int64

# %%
utils[utils['owner_of_plants_reported_on_form']==0];

# %%
gen_data = pd.read_csv(dataDir + 'eia_data/eia8602018/gen_2018.csv')
gen_data.drop(['Unnamed: 0'],axis=1,inplace=True)
gen_data = gen_data[~gen_data['Utility ID'].str.contains('NOTE', na=False)]
gen_data['Utility ID'] = pd.to_numeric(gen_data['Utility ID'])
gen_data.columns = gen_data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace('?','')
# Out:
# /Users/rachelanderson/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (1,16,39,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Now I want to merge the utility data with the generator data so I can do some sick analyses bro
#
# I'll start by merging the utility list with the list of generators (all in 2018), so I'll see if any columns will conflict

# %%
[print(x) for x in gen_data.columns if x in utils.columns]
# Out:
# utility_id
# utility_name
# state
# [None, None, None]

# %% [markdown]
# I'm merging by utility_id so let's fix the state variable

# %%
gen_data = gen_data.rename(columns={'state': 'plant_state'})

# %%
merged = gen_data.merge(utils, how='left', on=['utility_id','utility_name'])

# %% [markdown]
# Various checks assures me that the merge was successful. So now I want to merge in ownership data in a clever way

# %% [markdown]
# ## Now merge in the owner variable in a creative way
# ### solution is to add owner_1 owner_1_perc, owner_2 ... etc.  for each plant

# %%
# S Single ownership by respondent 
# J Jointly owned with another entity
# W Wholly owned by an entity other than respondent
df = merged.join(pd.get_dummies(merged['ownership']))
df.rename(columns={'S': 'single_owner', 'W': 'other_owner', 'J':'joint_owner'},inplace=True)

# %%
owners = pd.read_csv(dataDir + 'eia_data/eia8602018/owner_2018.csv',header=1)
owners.columns = owners.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace('?','')

owners['perc_owned'] = pd.to_numeric(owners['percent_owned'].str.replace("%",""))

num_owners = owners.groupby(['plant_name', 'generator_id']).apply(lambda grp: len(grp.owner_name.unique())).reset_index()
num_owners.rename(columns={0: 'num_owners'},inplace=True)
owners = owners.merge(num_owners, how='outer', on=['plant_name','generator_id'])

# %%
owners['idx'] = owners['plant_code'].astype(str) + '_' + owners['generator_id']

# %%
# owner_dict with key = generator; value = owners 
owner_dict = owners.groupby(['idx']).owner_name.apply(lambda grp: list(grp.value_counts().index)).to_dict()

perc_dict = owners.groupby(['idx']).perc_owned.apply(lambda grp: list(grp)).to_dict()

# dictionary may be useful for other stuff 
perc_owned_dict = {}
for x in owner_dict:
    temp_dict = {}
    for i,y in enumerate(owner_dict[x]):
        temp_dict.update({y : perc_dict[x][i]})
    perc_owned_dict[x] = temp_dict

# %%
owners = owners.join(owners['idx'].map(owner_dict).apply(pd.Series).iloc[:,0:4].rename(columns={0: 'owner_1', 1: 'owner_2', 2: 'owner_3', 3: 'owner_4'}))

owners = owners.join(owners['idx'].map(perc_dict).apply(pd.Series).iloc[:,0:4].rename(columns={0: 'perc_owner_1', 1: 'perc_owner_2', 2: 'perc_owner_3', 3: 'perc_owner_4'}))

# %% [markdown]
# ## Apply parent dict to the list of owners

# %%
with open(jsonDir + 'final_parent_dict.json') as outfile:
    parent_map = json.load(outfile)

# %%
owners['parent_1'] = owners.owner_1.str.lower().map(parent_map)
owners['parent_2'] = owners.owner_2.str.lower().map(parent_map)
owners['parent_3'] = owners.owner_3.str.lower().map(parent_map)
owners['parent_4'] = owners.owner_4.str.lower().map(parent_map)

# %%
owners['diff_parent'] = owners['parent_1'] != owners['owner_1']

# %% [markdown]
# ## Drop duplicates before merging

# %%
# list of cols to ignore to avoid _x and _y 
cols_to_ignore = ['utility_id',
 'utility_name',
 'plant_name',
 'state',
 'status'] 

owners_to_merge = owners.drop_duplicates('idx')
owners_to_merge = owners_to_merge.drop([x for x in df.columns if x in owners.columns if x in cols_to_ignore],axis=1)
df = df.merge(owners_to_merge, how='left', on=['plant_code','generator_id'])

# %%
df.to_csv(dataDir + 'master_gen_by_owner_2028.csv')

# %% [markdown]
# ## Merge owners back into generator data

# %% [markdown]
# ### Now do the parent utility stuff

# %%
# fill na of parent 1 with parent map on the utility name

df['parent_1'] = df['parent_1'].fillna(df.utility_name.str.lower().map(parent_map))

# %%
df['nameplate_cap']=pd.to_numeric(df['nameplate_capacity_mw'].astype(str).str.replace(",",""))

# %%
solar = df[df['energy_source_1']=='SUN']
wind=df[df['energy_source_1']=='WND']

# %%
solar.groupby('plant_state').nameplate_cap.sum().sort_values(ascending=False).reset_index()
# Out:
#    plant_state  nameplate_cap
# 0           CA        11837.6
# 1           NC         4007.9
# 2           AZ         2067.3
# 3           TX         1943.1
# 4           NV         1926.0
# 5           FL         1401.6
# 6           GA         1026.2
# 7           UT          859.1
# 8           NJ          771.9
# 9           MA          744.9
# 10          MN          741.5
# 11          NM          562.2
# 12          CO          532.6
# 13          VA          462.0
# 14          MD          355.2
# 15          SC          353.0
# 16          OR          312.8
# 17          NY          268.6
# 18          ID          240.0
# 19          IN          216.3
# 20          AL          196.9
# 21          TN          180.6
# 22          MS          160.6
# 23          HI          124.1
# 24          VT          100.6
# 25          AR          100.0
# 26          MI           99.3
# 27          WY           92.0
# 28          CT           86.1
# 29          OH           84.8
# 30          MO           62.1
# 31          PA           59.7
# 32          IL           40.9
# 33          DE           33.4
# 34          RI           31.6
# 35          OK           30.5
# 36          KY           26.3
# 37          WI           23.9
# 38          WA           19.7
# 39          NE           17.9
# 40          MT           17.0
# 41          IA            9.2
# 42          ME            5.6
# 43          KS            4.0
# 44          LA            1.1
# 45          SD            1.0

# %%
solar[solar['plant_state']=='TX'].groupby('parent_1').nameplate_cap.sum().sort_values(ascending=False).reset_index()
# Out:
#                                      parent_1  nameplate_cap
# 0        consolidated edison development inc.          355.5
# 1                            southern company          218.5
# 2                             clearway energy          202.0
# 3                      174 power global corp.          182.0
# 4                    upton county solar 2 llc          180.0
# 5                                 re roserock          160.0
# 6                          berkshire hathaway          155.0
# 7                    cypress creek renewables          110.8
# 8                        solaireholman 1, llc           50.0
# 9                     lamesa solar ii, l.l.c.           50.0
# 10                            oci solar power           45.1
# 11                      fremont energy center           39.6
# 12               first solar asset management           30.2
# 13                        bluebell solar, llc           30.0
# 14                           frv ae solar llc           30.0
# 15                         phantom solar, llc           15.4
# 16                                duke energy           13.9
# 17                              sune cps3 llc           10.6
# 18                           newman solar llc           10.5
# 19           macquarie infrastructure company           10.0
# 20                              sune cps1 llc           10.0
# 21                              sune cps2 llc           10.0
# 22                           pgc plano i, llc            7.7
# 23                        el paso electric co            3.0
# 24                        powerfin asl 1, llc            2.6
# 25                          ikea property inc            2.6
# 26         renewable energy alternatives, llc            2.0
# 27                 ameresco federal solutions            2.0
# 28  harvest moon renewable energy company llc            1.6
# 29                         socore bandera llc            1.5
# 30                clean energy collective llc            1.0

# %%
wind
# Out:
#        utility_id                                utility_name  plant_code  \
# 195         13642                  Nome Joint Utility Systems        90.0
# 196         13642                  Nome Joint Utility Systems        90.0
# 197         13642                  Nome Joint Utility Systems        90.0
# 887         10633                        City of Lamar - (CO)       508.0
# 888         10633                        City of Lamar - (CO)       508.0
# ...           ...                                         ...         ...
# 22006       58270                          GE Wind Energy LLC     62642.0
# 22007       58270                          GE Wind Energy LLC     62642.0
# 22076       62657                               Harbec Energy     62736.0
# 22077       62657                               Harbec Energy     62736.0
# 22087       62645  General Services Administration - Region 8     62782.0
#
#                                     plant_name plant_state   county  \
# 195                                Snake River          AK     Nome
# 196                                Snake River          AK     Nome
# 197                                Snake River          AK     Nome
# 887                                Lamar Plant          CO  Prowers
# 888                                Lamar Plant          CO  Prowers
# ...                                        ...         ...      ...
# 22006                               GE-Lubbock          TX  Lubbock
# 22007                               GE-Lubbock          TX  Lubbock
# 22076                            Harbec Energy          NY  Ontario
# 22077                            Harbec Energy          NY  Ontario
# 22087  Pembina Land Port of Entry Wind Turbine          ND  Pembina
#
#       generator_id            technology prime_mover unit_code ownership  \
# 195            ENT  Onshore Wind Turbine          WT       NaN         S
# 196          EWT 1  Onshore Wind Turbine          WT       NaN         S
# 197          EWT 2  Onshore Wind Turbine          WT       NaN         S
# 887          T1-T3  Onshore Wind Turbine          WT       NaN         S
# 888             T4  Onshore Wind Turbine          WT       NaN         W
# ...            ...                   ...         ...       ...       ...
# 22006        GE-P2  Onshore Wind Turbine          WT       NaN         S
# 22007        GE-P3  Onshore Wind Turbine          WT       NaN         S
# 22076        250KW  Onshore Wind Turbine          WT       NaN         S
# 22077        850KW  Onshore Wind Turbine          WT       NaN         S
# 22087        PEMWT  Onshore Wind Turbine          WT       NaN         S
#
#       duct_burners can_bypass_heat_recovery_steam_generator  \
# 195              X                                        X
# 196              X                                        X
# 197              X                                        X
# 887              X                                        X
# 888              X                                        X
# ...            ...                                      ...
# 22006            X                                        X
# 22007            X                                        X
# 22076            X                                        X
# 22077            X                                        X
# 22087            X                                        X
#
#       rto/iso_lmp_node_designation  \
# 195                            NaN
# 196                            NaN
# 197                            NaN
# 887                            NaN
# 888                            NaN
# ...                            ...
# 22006                          NaN
# 22007                          NaN
# 22076                          NaN
# 22077                          NaN
# 22087                          NaN
#
#       rto/iso_location_designation_for_reporting_wholesale_sales_data_to_ferc  \
# 195                                                  NaN
# 196                                                  NaN
# 197                                                  NaN
# 887                                                  NaN
# 888                                                  NaN
# ...                                                  ...
# 22006                                                NaN
# 22007                                                NaN
# 22076                                                NaN
# 22077                                                NaN
# 22087                                                NaN
#
#       nameplate_capacity_mw nameplate_power_factor summer_capacity_mw  \
# 195                     0.8                                       0.8
# 196                     0.9                                       0.9
# 197                     0.9                                       0.9
# 887                     4.5                                       4.0
# 888                     1.5                                       1.5
# ...                     ...                    ...                ...
# 22006                   2.5                                       3.0
# 22007                   2.8                                       3.1
# 22076                   0.3                                       0.3
# 22077                   0.9                                       0.9
# 22087                     1                                       0.8
#
#       winter_capacity_mw minimum_load_mw  \
# 195                  0.8             0.1
# 196                  0.9             0.1
# 197                  0.9             0.1
# 887                  4.0             1.0
# 888                  1.5             1.0
# ...                  ...             ...
# 22006                3.0             0.1
# 22007                3.1             0.1
# 22076                0.3             0.0
# 22077                0.9             0.0
# 22087                1.0             0.0
#
#       uprate_or_derate_completed_during_year month_uprate_or_derate_completed  \
# 195                                        N
# 196                                        N
# 197                                        N
# 887                                        N
# 888                                        N
# ...                                      ...                              ...
# 22006                                      N
# 22007                                      Y                               11
# 22076                                      N
# 22077                                      N
# 22087                                      N
#
#       year_uprate_or_derate_completed status  \
# 195                                       OA
# 196                                       OP
# 197                                       OP
# 887                                       OP
# 888                                       OP
# ...                               ...    ...
# 22006                                     OP
# 22007                            2018     OP
# 22076                                     OP
# 22077                                     OP
# 22087                                     OP
#
#       synchronized_to_transmission_grid  operating_month  operating_year  \
# 195                                   X              1.0          2015.0
# 196                                   X              7.0          2013.0
# 197                                   X              7.0          2013.0
# 887                                   X              2.0          2004.0
# 888                                   X              2.0          2004.0
# ...                                 ...              ...             ...
# 22006                                 X              4.0          2014.0
# 22007                                 X              2.0          2015.0
# 22076                                 X             12.0          2001.0
# 22077                                 X             12.0          2011.0
# 22087                                 X              6.0          2012.0
#
#       planned_retirement_month planned_retirement_year  \
# 195
# 196
# 197
# 887
# 888
# ...                        ...                     ...
# 22006
# 22007
# 22076
# 22077
# 22087
#
#       associated_with_combined_heat_and_power_system         sector_name  \
# 195                                                N    Electric Utility
# 196                                                N    Electric Utility
# 197                                                N    Electric Utility
# 887                                                N    Electric Utility
# 888                                                N    Electric Utility
# ...                                              ...                 ...
# 22006                                              N         IPP Non-CHP
# 22007                                              N         IPP Non-CHP
# 22076                                              N      Industrial CHP
# 22077                                              N      Industrial CHP
# 22087                                              N  Commercial Non-CHP
#
#        sector topping_or_bottoming energy_source_1 energy_source_2  \
# 195       1.0                    X             WND             NaN
# 196       1.0                    X             WND             NaN
# 197       1.0                    X             WND             NaN
# 887       1.0                    X             WND             NaN
# 888       1.0                    X             WND             NaN
# ...       ...                  ...             ...             ...
# 22006     2.0                    X             WND             NaN
# 22007     2.0                    X             WND             NaN
# 22076     7.0                    X             WND             NaN
# 22077     7.0                    X             WND             NaN
# 22087     4.0                    X             WND             NaN
#
#       energy_source_3 energy_source_4 energy_source_5 energy_source_6  \
# 195               NaN             NaN             NaN             NaN
# 196               NaN             NaN             NaN             NaN
# 197               NaN             NaN             NaN             NaN
# 887               NaN             NaN             NaN             NaN
# 888               NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 22006             NaN             NaN             NaN             NaN
# 22007             NaN             NaN             NaN             NaN
# 22076             NaN             NaN             NaN             NaN
# 22077             NaN             NaN             NaN             NaN
# 22087             NaN             NaN             NaN             NaN
#
#       startup_source_1 startup_source_2 startup_source_3 startup_source_4  \
# 195                NaN              NaN              NaN              NaN
# 196                NaN              NaN              NaN              NaN
# 197                NaN              NaN              NaN              NaN
# 887                NaN              NaN              NaN              NaN
# 888                NaN              NaN              NaN              NaN
# ...                ...              ...              ...              ...
# 22006              NaN              NaN              NaN              NaN
# 22007              NaN              NaN              NaN              NaN
# 22076              NaN              NaN              NaN              NaN
# 22077              NaN              NaN              NaN              NaN
# 22087              NaN              NaN              NaN              NaN
#
#       solid_fuel_gasification_system carbon_capture_technology  \
# 195                              NaN                         N
# 196                                N                         N
# 197                                N                         N
# 887                                N                       NaN
# 888                                N                       NaN
# ...                              ...                       ...
# 22006                            NaN                       NaN
# 22007                            NaN                       NaN
# 22076                              N                         N
# 22077                              N                         N
# 22087                              N                       NaN
#
#       turbines_or_hydrokinetic_buoys time_from_cold_shutdown_to_full_load  \
# 195                               15                                  NaN
# 196                                1                                  NaN
# 197                                1                                  NaN
# 887                                3                                  NaN
# 888                                1                                  NaN
# ...                              ...                                  ...
# 22006                              1                                  NaN
# 22007                              1                                  NaN
# 22076                              1                                  NaN
# 22077                              1                                  NaN
# 22087                              1                                  NaN
#
#       fluidized_bed_technology pulverized_coal_technology stoker_technology  \
# 195                        NaN                        NaN               NaN
# 196                        NaN                        NaN               NaN
# 197                        NaN                        NaN               NaN
# 887                        NaN                        NaN               NaN
# 888                        NaN                        NaN               NaN
# ...                        ...                        ...               ...
# 22006                      NaN                        NaN               NaN
# 22007                      NaN                        NaN               NaN
# 22076                      NaN                        NaN               NaN
# 22077                      NaN                        NaN               NaN
# 22087                      NaN                        NaN               NaN
#
#        ... planned_net_winter_capacity_derate_mw planned_derate_month  \
# 195    ...
# 196    ...
# 197    ...
# 887    ...
# 888    ...
# ...    ...                                   ...                  ...
# 22006  ...
# 22007  ...
# 22076  ...
# 22077  ...
# 22087  ...
#
#       planned_derate_year planned_new_prime_mover planned_energy_source_1  \
# 195                                           NaN                     NaN
# 196                                           NaN                     NaN
# 197                                           NaN                     NaN
# 887                                           NaN                     NaN
# 888                                           NaN                     NaN
# ...                   ...                     ...                     ...
# 22006                                         NaN                     NaN
# 22007                                         NaN                     NaN
# 22076                                         NaN                     NaN
# 22077                                         NaN                     NaN
# 22087                                         NaN                     NaN
#
#       planned_new_nameplate_capacity_mw planned_repower_month  \
# 195
# 196
# 197
# 887
# 888
# ...                                 ...                   ...
# 22006
# 22007
# 22076
# 22077
# 22087
#
#       planned_repower_year other_planned_modifications  \
# 195                                                NaN
# 196                                                NaN
# 197                                                NaN
# 887                                                NaN
# 888                                                NaN
# ...                    ...                         ...
# 22006                                              NaN
# 22007                                              NaN
# 22076                                              NaN
# 22077                                              NaN
# 22087                                              NaN
#
#       other_modifications_month other_modifications_year multiple_fuels  \
# 195                                                                 NaN
# 196                                                                 NaN
# 197                                                                 NaN
# 887                                                                 NaN
# 888                                                                   N
# ...                         ...                      ...            ...
# 22006                                                               NaN
# 22007                                                               NaN
# 22076                                                                 N
# 22077                                                                 N
# 22087                                                               NaN
#
#       cofire_fuels switch_between_oil_and_natural_gas  \
# 195            NaN                                NaN
# 196            NaN                                NaN
# 197            NaN                                NaN
# 887            NaN                                NaN
# 888            NaN                                NaN
# ...            ...                                ...
# 22006          NaN                                NaN
# 22007          NaN                                NaN
# 22076          NaN                                NaN
# 22077          NaN                                NaN
# 22087          NaN                                NaN
#
#                        street_address         city state    zip  \
# 195                    1226 Port Road         Nome    AK  99762
# 196                    1226 Port Road         Nome    AK  99762
# 197                    1226 Port Road         Nome    AK  99762
# 887              100 North 2nd Street        Lamar    CO  81052
# 888              100 North 2nd Street        Lamar    CO  81052
# ...                               ...          ...   ...    ...
# 22006                    1 River Road  Schenectady    NY  12345
# 22007                    1 River Road  Schenectady    NY  12345
# 22076                358 Timothy Lane      Ontario    NY  14519
# 22077                358 Timothy Lane      Ontario    NY  14519
# 22087  One Denver Federal Center, Bld     Lakewood    CO  80225
#
#       owner_of_plants_reported_on_form operator_of_plants_reported_on_form  \
# 195                                  Y                                   0
# 196                                  Y                                   0
# 197                                  Y                                   0
# 887                                  0                                   Y
# 888                                  0                                   Y
# ...                                ...                                 ...
# 22006                                Y                                   0
# 22007                                Y                                   0
# 22076                                Y                                   Y
# 22077                                Y                                   Y
# 22087                                Y                                   Y
#
#       asset_manager_of_plants_reported_on_form  \
# 195                                          0
# 196                                          0
# 197                                          0
# 887                                          0
# 888                                          0
# ...                                        ...
# 22006                                        0
# 22007                                        0
# 22076                                        Y
# 22077                                        Y
# 22087                                        Y
#
#       other_relationships_with_plants_reported_on_form entity_type  \
# 195                                                  0           M
# 196                                                  0           M
# 197                                                  0           M
# 887                                                  0           M
# 888                                                  0           M
# ...                                                ...         ...
# 22006                                                0           Q
# 22007                                                0           Q
# 22076                                                0         IND
# 22077                                                0         IND
# 22087                                                0           F
#
#       joint_owner single_owner other_owner                      owner_name  \
# 195             0            1           0                             NaN
# 196             0            1           0                             NaN
# 197             0            1           0                             NaN
# 887             0            1           0                             NaN
# 888             0            0           1  Arkansas River Power Authority
# ...           ...          ...         ...                             ...
# 22006           0            1           0                             NaN
# 22007           0            1           0                             NaN
# 22076           0            1           0                             NaN
# 22077           0            1           0                             NaN
# 22087           0            1           0                             NaN
#
#                    owner_street_address owner_city owner_state owner_zip  \
# 195                                 NaN        NaN         NaN       NaN
# 196                                 NaN        NaN         NaN       NaN
# 197                                 NaN        NaN         NaN       NaN
# 887                                 NaN        NaN         NaN       NaN
# 888    P O Box 703409 South Main Street      Lamar          CO     81052
# ...                                 ...        ...         ...       ...
# 22006                               NaN        NaN         NaN       NaN
# 22007                               NaN        NaN         NaN       NaN
# 22076                               NaN        NaN         NaN       NaN
# 22077                               NaN        NaN         NaN       NaN
# 22087                               NaN        NaN         NaN       NaN
#
#       ownership_id  percent_owned  perc_owned  num_owners     idx  \
# 195            NaN            NaN         NaN         NaN     NaN
# 196            NaN            NaN         NaN         NaN     NaN
# 197            NaN            NaN         NaN         NaN     NaN
# 887            NaN            NaN         NaN         NaN     NaN
# 888          712.0        100.00%       100.0         1.0  508_T4
# ...            ...            ...         ...         ...     ...
# 22006          NaN            NaN         NaN         NaN     NaN
# 22007          NaN            NaN         NaN         NaN     NaN
# 22076          NaN            NaN         NaN         NaN     NaN
# 22077          NaN            NaN         NaN         NaN     NaN
# 22087          NaN            NaN         NaN         NaN     NaN
#
#                               owner_1 owner_2 owner_3 owner_4  perc_owner_1  \
# 195                               NaN     NaN     NaN     NaN           NaN
# 196                               NaN     NaN     NaN     NaN           NaN
# 197                               NaN     NaN     NaN     NaN           NaN
# 887                               NaN     NaN     NaN     NaN           NaN
# 888    Arkansas River Power Authority     NaN     NaN     NaN         100.0
# ...                               ...     ...     ...     ...           ...
# 22006                             NaN     NaN     NaN     NaN           NaN
# 22007                             NaN     NaN     NaN     NaN           NaN
# 22076                             NaN     NaN     NaN     NaN           NaN
# 22077                             NaN     NaN     NaN     NaN           NaN
# 22087                             NaN     NaN     NaN     NaN           NaN
#
#       perc_owner_2  perc_owner_3  perc_owner_4  \
# 195            NaN           NaN           NaN
# 196            NaN           NaN           NaN
# 197            NaN           NaN           NaN
# 887            NaN           NaN           NaN
# 888            NaN           NaN           NaN
# ...            ...           ...           ...
# 22006          NaN           NaN           NaN
# 22007          NaN           NaN           NaN
# 22076          NaN           NaN           NaN
# 22077          NaN           NaN           NaN
# 22087          NaN           NaN           NaN
#
#                                          parent_1 parent_2 parent_3 parent_4  \
# 195                    nome joint utility systems      NaN      NaN      NaN
# 196                    nome joint utility systems      NaN      NaN      NaN
# 197                    nome joint utility systems      NaN      NaN      NaN
# 887                          city of lamar - (co)      NaN      NaN      NaN
# 888                arkansas river power authority      NaN      NaN      NaN
# ...                                           ...      ...      ...      ...
# 22006                          ge wind energy llc      NaN      NaN      NaN
# 22007                          ge wind energy llc      NaN      NaN      NaN
# 22076                               harbec energy      NaN      NaN      NaN
# 22077                               harbec energy      NaN      NaN      NaN
# 22087  general services administration - region 8      NaN      NaN      NaN
#
#       diff_parent  nameplate_cap
# 195           NaN            0.8
# 196           NaN            0.9
# 197           NaN            0.9
# 887           NaN            4.5
# 888          True            1.5
# ...           ...            ...
# 22006         NaN            2.5
# 22007         NaN            2.8
# 22076         NaN            0.3
# 22077         NaN            0.9
# 22087         NaN            1.0
#
# [1316 rows x 109 columns]

# %% [markdown]
# ## answer ga solar questions

# %%
ga_solar = solar[solar['plant_state']=='GA']

# %%
ga_solar[ga_solar['parent_1'] == 'southern company']
# Out:
#        utility_id       utility_name  plant_code  \
# 19075       17650  Southern Power Co     59449.0
# 19076       17650  Southern Power Co     59450.0
# 19185        7140   Georgia Power Co     59556.0
# 19552        7140   Georgia Power Co     59862.0
# 19553        7140   Georgia Power Co     59863.0
# 19554        7140   Georgia Power Co     59864.0
# 19555        7140   Georgia Power Co     59865.0
# 19563        7140   Georgia Power Co     59876.0
# 19567       17650  Southern Power Co     59891.0
# 19568       17650  Southern Power Co     59894.0
# 19569       17650  Southern Power Co     59896.0
# 19570       17650  Southern Power Co     59897.0
# 20193        7140   Georgia Power Co     60544.0
# 21291        7140   Georgia Power Co     61554.0
# 21881        7140   Georgia Power Co     62393.0
# 21882        7140   Georgia Power Co     62393.0
# 21883        7140   Georgia Power Co     62393.0
#
#                                plant_name plant_state         county  \
# 19075        Decatur County Solar Project          GA        Decatur
# 19076  Decatur Parkway Solar Project, LLC          GA        Decatur
# 19185                            Dalton 2          GA         Murray
# 19552         Fort Benning Solar Facility          GA  Chattahoochee
# 19553          Fort Gordon Solar Facility          GA       Richmond
# 19554           King's Bay Solar Facility          GA         Camden
# 19555         Fort Stewart Solar Facility          GA        Liberty
# 19563   Marine Corps Logistics Base Solar          GA      Dougherty
# 19567                Butler Solar Farm 20          GA         Taylor
# 19568                  Pawpaw Solar Plant          GA         Taylor
# 19569            Butler Solar Project 103          GA         Taylor
# 19570                 Taylor County Solar          GA         Taylor
# 20193           Tri-County Solar Facility          GA         Putnam
# 21291                         Comer Solar          GA        Madison
# 21881               Atlanta Falcons Solar          GA         Fulton
# 21882               Atlanta Falcons Solar          GA         Fulton
# 21883               Atlanta Falcons Solar          GA         Fulton
#
#       generator_id          technology prime_mover unit_code ownership  \
# 19075        DCSP1  Solar Photovoltaic          PV       NaN         S
# 19076        DPSP1  Solar Photovoltaic          PV       NaN         S
# 19185            1  Solar Photovoltaic          PV       NaN         S
# 19552            1  Solar Photovoltaic          PV       NaN         S
# 19553            1  Solar Photovoltaic          PV       NaN         S
# 19554            1  Solar Photovoltaic          PV       NaN         S
# 19555            1  Solar Photovoltaic          PV       NaN         S
# 19563            1  Solar Photovoltaic          PV       NaN         S
# 19567            1  Solar Photovoltaic          PV       NaN         S
# 19568            1  Solar Photovoltaic          PV       NaN         S
# 19569            1  Solar Photovoltaic          PV       NaN         S
# 19570            1  Solar Photovoltaic          PV       NaN         S
# 20193          PV1  Solar Photovoltaic          PV       NaN         S
# 21291            1  Solar Photovoltaic          PV       NaN         S
# 21881            1  Solar Photovoltaic          PV       NaN         S
# 21882            2  Solar Photovoltaic          PV       NaN         S
# 21883            3  Solar Photovoltaic          PV       NaN         S
#
#       duct_burners can_bypass_heat_recovery_steam_generator  \
# 19075            X                                        X
# 19076            X                                        X
# 19185            X                                        X
# 19552            X                                        X
# 19553            X                                        X
# 19554            X                                        X
# 19555            X                                        X
# 19563            X                                        X
# 19567            X                                        X
# 19568            X                                        X
# 19569            X                                        X
# 19570            X                                        X
# 20193            X                                        X
# 21291            X                                        X
# 21881            X                                        X
# 21882            X                                        X
# 21883            X                                        X
#
#       rto/iso_lmp_node_designation  \
# 19075                          NaN
# 19076                          NaN
# 19185                          NaN
# 19552                          NaN
# 19553                          NaN
# 19554                          NaN
# 19555                          NaN
# 19563                          NaN
# 19567                          NaN
# 19568                          NaN
# 19569                          NaN
# 19570                          NaN
# 20193                          NaN
# 21291                          NaN
# 21881                          NaN
# 21882                          NaN
# 21883                          NaN
#
#       rto/iso_location_designation_for_reporting_wholesale_sales_data_to_ferc  \
# 19075                                                NaN
# 19076                                                NaN
# 19185                                                NaN
# 19552                                                NaN
# 19553                                                NaN
# 19554                                                NaN
# 19555                                                NaN
# 19563                                                NaN
# 19567                                                NaN
# 19568                                                NaN
# 19569                                                NaN
# 19570                                                NaN
# 20193                                                NaN
# 21291                                                NaN
# 21881                                                NaN
# 21882                                                NaN
# 21883                                                NaN
#
#       nameplate_capacity_mw nameplate_power_factor summer_capacity_mw  \
# 19075                    20                                      19.0
# 19076                    80                                      80.0
# 19185                   6.5                                       6.5
# 19552                    30                                      30.0
# 19553                    30                                      30.0
# 19554                    30                                      30.2
# 19555                    30                                      30.0
# 19563                    31                                      31.2
# 19567                    20                                      20.0
# 19568                    30                                      30.0
# 19569                   103                                     100.0
# 19570                   148                                     143.0
# 20193                     1                                       1.0
# 21291                     2                                       2.2
# 21881                   0.3                                       0.3
# 21882                   0.2                                       0.2
# 21883                   0.5                                       0.5
#
#       winter_capacity_mw minimum_load_mw  \
# 19075               19.0
# 19076               80.0
# 19185                6.5
# 19552               30.0
# 19553               30.0
# 19554               30.2
# 19555               30.0
# 19563               31.2
# 19567               20.0
# 19568               30.0
# 19569              100.0
# 19570              143.0
# 20193                1.0
# 21291                2.2
# 21881                0.3
# 21882                0.2
# 21883                0.5
#
#       uprate_or_derate_completed_during_year month_uprate_or_derate_completed  \
# 19075                                      N
# 19076                                      N
# 19185                                      N
# 19552                                      N
# 19553                                      N
# 19554                                      N
# 19555                                      N
# 19563                                      N
# 19567                                      N
# 19568                                      N
# 19569                                      N
# 19570                                      N
# 20193                                      N
# 21291                                      N
# 21881                                      N
# 21882                                      N
# 21883                                      N
#
#       year_uprate_or_derate_completed status  \
# 19075                                     OP
# 19076                                     OP
# 19185                                     OP
# 19552                                     OP
# 19553                                     OP
# 19554                                     OP
# 19555                                     OP
# 19563                                     OP
# 19567                                     OP
# 19568                                     OP
# 19569                                     OP
# 19570                                     OP
# 20193                                     OP
# 21291                                     OP
# 21881                                     OP
# 21882                                     OP
# 21883                                     OP
#
#       synchronized_to_transmission_grid  operating_month  operating_year  \
# 19075                                 X             12.0          2015.0
# 19076                                 X             12.0          2015.0
# 19185                                 X             12.0          2014.0
# 19552                                 X             12.0          2015.0
# 19553                                 X             10.0          2016.0
# 19554                                 X             12.0          2016.0
# 19555                                 X             10.0          2016.0
# 19563                                 X              2.0          2018.0
# 19567                                 X              2.0          2016.0
# 19568                                 X              3.0          2016.0
# 19569                                 X             12.0          2016.0
# 19570                                 X             11.0          2016.0
# 20193                                 X              6.0          2016.0
# 21291                                 X              1.0          2018.0
# 21881                                 X             10.0          2015.0
# 21882                                 X             10.0          2017.0
# 21883                                 X              9.0          2016.0
#
#       planned_retirement_month planned_retirement_year  \
# 19075
# 19076
# 19185
# 19552
# 19553
# 19554
# 19555
# 19563
# 19567
# 19568
# 19569
# 19570
# 20193
# 21291
# 21881
# 21882
# 21883
#
#       associated_with_combined_heat_and_power_system       sector_name  \
# 19075                                              N       IPP Non-CHP
# 19076                                              N       IPP Non-CHP
# 19185                                              N  Electric Utility
# 19552                                              N  Electric Utility
# 19553                                              N  Electric Utility
# 19554                                              N  Electric Utility
# 19555                                              N  Electric Utility
# 19563                                              N  Electric Utility
# 19567                                              N       IPP Non-CHP
# 19568                                              N       IPP Non-CHP
# 19569                                              N       IPP Non-CHP
# 19570                                              N       IPP Non-CHP
# 20193                                              N  Electric Utility
# 21291                                              N  Electric Utility
# 21881                                              N  Electric Utility
# 21882                                              N  Electric Utility
# 21883                                              N  Electric Utility
#
#        sector topping_or_bottoming energy_source_1 energy_source_2  \
# 19075     2.0                    X             SUN             NaN
# 19076     2.0                    X             SUN             NaN
# 19185     1.0                    X             SUN             NaN
# 19552     1.0                    X             SUN             NaN
# 19553     1.0                    X             SUN             NaN
# 19554     1.0                    X             SUN             NaN
# 19555     1.0                    X             SUN             NaN
# 19563     1.0                    X             SUN             NaN
# 19567     2.0                    X             SUN             NaN
# 19568     2.0                    X             SUN             NaN
# 19569     2.0                    X             SUN             NaN
# 19570     2.0                    X             SUN             NaN
# 20193     1.0                    X             SUN             NaN
# 21291     1.0                    X             SUN             NaN
# 21881     1.0                    X             SUN             NaN
# 21882     1.0                    X             SUN             NaN
# 21883     1.0                    X             SUN             NaN
#
#       energy_source_3 energy_source_4 energy_source_5 energy_source_6  \
# 19075             NaN             NaN             NaN             NaN
# 19076             NaN             NaN             NaN             NaN
# 19185             NaN             NaN             NaN             NaN
# 19552             NaN             NaN             NaN             NaN
# 19553             NaN             NaN             NaN             NaN
# 19554             NaN             NaN             NaN             NaN
# 19555             NaN             NaN             NaN             NaN
# 19563             NaN             NaN             NaN             NaN
# 19567             NaN             NaN             NaN             NaN
# 19568             NaN             NaN             NaN             NaN
# 19569             NaN             NaN             NaN             NaN
# 19570             NaN             NaN             NaN             NaN
# 20193             NaN             NaN             NaN             NaN
# 21291             NaN             NaN             NaN             NaN
# 21881             NaN             NaN             NaN             NaN
# 21882             NaN             NaN             NaN             NaN
# 21883             NaN             NaN             NaN             NaN
#
#       startup_source_1 startup_source_2 startup_source_3 startup_source_4  \
# 19075              NaN              NaN              NaN              NaN
# 19076              NaN              NaN              NaN              NaN
# 19185              NaN              NaN              NaN              NaN
# 19552              NaN              NaN              NaN              NaN
# 19553              NaN              NaN              NaN              NaN
# 19554              NaN              NaN              NaN              NaN
# 19555              NaN              NaN              NaN              NaN
# 19563              NaN              NaN              NaN              NaN
# 19567              NaN              NaN              NaN              NaN
# 19568              NaN              NaN              NaN              NaN
# 19569              NaN              NaN              NaN              NaN
# 19570              NaN              NaN              NaN              NaN
# 20193              NaN              NaN              NaN              NaN
# 21291              NaN              NaN              NaN              NaN
# 21881              NaN              NaN              NaN              NaN
# 21882              NaN              NaN              NaN              NaN
# 21883              NaN              NaN              NaN              NaN
#
#       solid_fuel_gasification_system carbon_capture_technology  \
# 19075                            NaN                       NaN
# 19076                            NaN                       NaN
# 19185                            NaN                       NaN
# 19552                            NaN                       NaN
# 19553                            NaN                       NaN
# 19554                            NaN                       NaN
# 19555                            NaN                       NaN
# 19563                            NaN                       NaN
# 19567                            NaN                       NaN
# 19568                            NaN                       NaN
# 19569                            NaN                       NaN
# 19570                            NaN                       NaN
# 20193                            NaN                       NaN
# 21291                            NaN                       NaN
# 21881                            NaN                       NaN
# 21882                            NaN                       NaN
# 21883                            NaN                       NaN
#
#       turbines_or_hydrokinetic_buoys time_from_cold_shutdown_to_full_load  \
# 19075                                                                 NaN
# 19076                                                                 NaN
# 19185                                                                 NaN
# 19552                                                                 NaN
# 19553                                                                 NaN
# 19554                                                                 NaN
# 19555                                                                 NaN
# 19563                                                                 NaN
# 19567                                                                 NaN
# 19568                                                                 NaN
# 19569                                                                 NaN
# 19570                                                                 NaN
# 20193                                                                 NaN
# 21291                                                                 NaN
# 21881                                                                 NaN
# 21882                                                                 NaN
# 21883                                                                 NaN
#
#       fluidized_bed_technology pulverized_coal_technology stoker_technology  \
# 19075                      NaN                        NaN               NaN
# 19076                      NaN                        NaN               NaN
# 19185                      NaN                        NaN               NaN
# 19552                      NaN                        NaN               NaN
# 19553                      NaN                        NaN               NaN
# 19554                      NaN                        NaN               NaN
# 19555                      NaN                        NaN               NaN
# 19563                      NaN                        NaN               NaN
# 19567                      NaN                        NaN               NaN
# 19568                      NaN                        NaN               NaN
# 19569                      NaN                        NaN               NaN
# 19570                      NaN                        NaN               NaN
# 20193                      NaN                        NaN               NaN
# 21291                      NaN                        NaN               NaN
# 21881                      NaN                        NaN               NaN
# 21882                      NaN                        NaN               NaN
# 21883                      NaN                        NaN               NaN
#
#        ... planned_net_winter_capacity_derate_mw planned_derate_month  \
# 19075  ...
# 19076  ...
# 19185  ...
# 19552  ...
# 19553  ...
# 19554  ...
# 19555  ...
# 19563  ...
# 19567  ...
# 19568  ...
# 19569  ...
# 19570  ...
# 20193  ...
# 21291  ...
# 21881  ...
# 21882  ...
# 21883  ...
#
#       planned_derate_year planned_new_prime_mover planned_energy_source_1  \
# 19075                                         NaN                     NaN
# 19076                                         NaN                     NaN
# 19185                                         NaN                     NaN
# 19552                                         NaN                     NaN
# 19553                                         NaN                     NaN
# 19554                                         NaN                     NaN
# 19555                                         NaN                     NaN
# 19563                                         NaN                     NaN
# 19567                                         NaN                     NaN
# 19568                                         NaN                     NaN
# 19569                                         NaN                     NaN
# 19570                                         NaN                     NaN
# 20193                                         NaN                     NaN
# 21291                                         NaN                     NaN
# 21881                                         NaN                     NaN
# 21882                                         NaN                     NaN
# 21883                                         NaN                     NaN
#
#       planned_new_nameplate_capacity_mw planned_repower_month  \
# 19075
# 19076
# 19185
# 19552
# 19553
# 19554
# 19555
# 19563
# 19567
# 19568
# 19569
# 19570
# 20193
# 21291
# 21881
# 21882
# 21883
#
#       planned_repower_year other_planned_modifications  \
# 19075                                              NaN
# 19076                                              NaN
# 19185                                              NaN
# 19552                                              NaN
# 19553                                              NaN
# 19554                                              NaN
# 19555                                              NaN
# 19563                                              NaN
# 19567                                              NaN
# 19568                                              NaN
# 19569                                              NaN
# 19570                                              NaN
# 20193                                              NaN
# 21291                                              NaN
# 21881                                              NaN
# 21882                                              NaN
# 21883                                              NaN
#
#       other_modifications_month other_modifications_year multiple_fuels  \
# 19075                                                                 N
# 19076                                                                 N
# 19185                                                                 N
# 19552                                                                 N
# 19553                                                                 N
# 19554                                                                 N
# 19555                                                                 N
# 19563                                                                 N
# 19567                                                                 N
# 19568                                                                 N
# 19569                                                                 N
# 19570                                                                 N
# 20193                                                                 N
# 21291                                                               NaN
# 21881                                                               NaN
# 21882                                                               NaN
# 21883                                                               NaN
#
#       cofire_fuels switch_between_oil_and_natural_gas  \
# 19075          NaN                                NaN
# 19076          NaN                                NaN
# 19185          NaN                                NaN
# 19552          NaN                                NaN
# 19553          NaN                                NaN
# 19554          NaN                                NaN
# 19555          NaN                                NaN
# 19563          NaN                                NaN
# 19567          NaN                                NaN
# 19568          NaN                                NaN
# 19569          NaN                                NaN
# 19570          NaN                                NaN
# 20193          NaN                                NaN
# 21291          NaN                                NaN
# 21881          NaN                                NaN
# 21882          NaN                                NaN
# 21883          NaN                                NaN
#
#                    street_address     city state    zip  \
# 19075  30 Ivan Allen Jr. Blvd, NW  Atlanta    GA  30308
# 19076  30 Ivan Allen Jr. Blvd, NW  Atlanta    GA  30308
# 19185                P O Box 4545  Atlanta    GA  30302
# 19552                P O Box 4545  Atlanta    GA  30302
# 19553                P O Box 4545  Atlanta    GA  30302
# 19554                P O Box 4545  Atlanta    GA  30302
# 19555                P O Box 4545  Atlanta    GA  30302
# 19563                P O Box 4545  Atlanta    GA  30302
# 19567  30 Ivan Allen Jr. Blvd, NW  Atlanta    GA  30308
# 19568  30 Ivan Allen Jr. Blvd, NW  Atlanta    GA  30308
# 19569  30 Ivan Allen Jr. Blvd, NW  Atlanta    GA  30308
# 19570  30 Ivan Allen Jr. Blvd, NW  Atlanta    GA  30308
# 20193                P O Box 4545  Atlanta    GA  30302
# 21291                P O Box 4545  Atlanta    GA  30302
# 21881                P O Box 4545  Atlanta    GA  30302
# 21882                P O Box 4545  Atlanta    GA  30302
# 21883                P O Box 4545  Atlanta    GA  30302
#
#       owner_of_plants_reported_on_form operator_of_plants_reported_on_form  \
# 19075                                Y                                   0
# 19076                                Y                                   0
# 19185                                Y                                   0
# 19552                                Y                                   0
# 19553                                Y                                   0
# 19554                                Y                                   0
# 19555                                Y                                   0
# 19563                                Y                                   0
# 19567                                Y                                   0
# 19568                                Y                                   0
# 19569                                Y                                   0
# 19570                                Y                                   0
# 20193                                Y                                   0
# 21291                                Y                                   0
# 21881                                Y                                   0
# 21882                                Y                                   0
# 21883                                Y                                   0
#
#       asset_manager_of_plants_reported_on_form  \
# 19075                                        0
# 19076                                        0
# 19185                                        0
# 19552                                        0
# 19553                                        0
# 19554                                        0
# 19555                                        0
# 19563                                        0
# 19567                                        0
# 19568                                        0
# 19569                                        0
# 19570                                        0
# 20193                                        0
# 21291                                        0
# 21881                                        0
# 21882                                        0
# 21883                                        0
#
#       other_relationships_with_plants_reported_on_form entity_type  \
# 19075                                                0           I
# 19076                                                0           I
# 19185                                                0           I
# 19552                                                0           I
# 19553                                                0           I
# 19554                                                0           I
# 19555                                                0           I
# 19563                                                0           I
# 19567                                                0           I
# 19568                                                0           I
# 19569                                                0           I
# 19570                                                0           I
# 20193                                                0           I
# 21291                                                0           I
# 21881                                                0           I
# 21882                                                0           I
# 21883                                                0           I
#
#       joint_owner single_owner other_owner owner_name owner_street_address  \
# 19075           0            1           0        NaN                  NaN
# 19076           0            1           0        NaN                  NaN
# 19185           0            1           0        NaN                  NaN
# 19552           0            1           0        NaN                  NaN
# 19553           0            1           0        NaN                  NaN
# 19554           0            1           0        NaN                  NaN
# 19555           0            1           0        NaN                  NaN
# 19563           0            1           0        NaN                  NaN
# 19567           0            1           0        NaN                  NaN
# 19568           0            1           0        NaN                  NaN
# 19569           0            1           0        NaN                  NaN
# 19570           0            1           0        NaN                  NaN
# 20193           0            1           0        NaN                  NaN
# 21291           0            1           0        NaN                  NaN
# 21881           0            1           0        NaN                  NaN
# 21882           0            1           0        NaN                  NaN
# 21883           0            1           0        NaN                  NaN
#
#       owner_city owner_state owner_zip ownership_id  percent_owned  \
# 19075        NaN         NaN       NaN          NaN            NaN
# 19076        NaN         NaN       NaN          NaN            NaN
# 19185        NaN         NaN       NaN          NaN            NaN
# 19552        NaN         NaN       NaN          NaN            NaN
# 19553        NaN         NaN       NaN          NaN            NaN
# 19554        NaN         NaN       NaN          NaN            NaN
# 19555        NaN         NaN       NaN          NaN            NaN
# 19563        NaN         NaN       NaN          NaN            NaN
# 19567        NaN         NaN       NaN          NaN            NaN
# 19568        NaN         NaN       NaN          NaN            NaN
# 19569        NaN         NaN       NaN          NaN            NaN
# 19570        NaN         NaN       NaN          NaN            NaN
# 20193        NaN         NaN       NaN          NaN            NaN
# 21291        NaN         NaN       NaN          NaN            NaN
# 21881        NaN         NaN       NaN          NaN            NaN
# 21882        NaN         NaN       NaN          NaN            NaN
# 21883        NaN         NaN       NaN          NaN            NaN
#
#        perc_owned  num_owners  idx owner_1 owner_2 owner_3 owner_4  \
# 19075         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19076         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19185         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19552         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19553         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19554         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19555         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19563         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19567         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19568         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19569         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 19570         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 20193         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 21291         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 21881         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 21882         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# 21883         NaN         NaN  NaN     NaN     NaN     NaN     NaN
#
#        perc_owner_1 perc_owner_2  perc_owner_3  perc_owner_4  \
# 19075           NaN          NaN           NaN           NaN
# 19076           NaN          NaN           NaN           NaN
# 19185           NaN          NaN           NaN           NaN
# 19552           NaN          NaN           NaN           NaN
# 19553           NaN          NaN           NaN           NaN
# 19554           NaN          NaN           NaN           NaN
# 19555           NaN          NaN           NaN           NaN
# 19563           NaN          NaN           NaN           NaN
# 19567           NaN          NaN           NaN           NaN
# 19568           NaN          NaN           NaN           NaN
# 19569           NaN          NaN           NaN           NaN
# 19570           NaN          NaN           NaN           NaN
# 20193           NaN          NaN           NaN           NaN
# 21291           NaN          NaN           NaN           NaN
# 21881           NaN          NaN           NaN           NaN
# 21882           NaN          NaN           NaN           NaN
# 21883           NaN          NaN           NaN           NaN
#
#                parent_1 parent_2 parent_3 parent_4 diff_parent  nameplate_cap
# 19075  southern company      NaN      NaN      NaN         NaN           20.0
# 19076  southern company      NaN      NaN      NaN         NaN           80.0
# 19185  southern company      NaN      NaN      NaN         NaN            6.5
# 19552  southern company      NaN      NaN      NaN         NaN           30.0
# 19553  southern company      NaN      NaN      NaN         NaN           30.0
# 19554  southern company      NaN      NaN      NaN         NaN           30.0
# 19555  southern company      NaN      NaN      NaN         NaN           30.0
# 19563  southern company      NaN      NaN      NaN         NaN           31.0
# 19567  southern company      NaN      NaN      NaN         NaN           20.0
# 19568  southern company      NaN      NaN      NaN         NaN           30.0
# 19569  southern company      NaN      NaN      NaN         NaN          103.0
# 19570  southern company      NaN      NaN      NaN         NaN          148.0
# 20193  southern company      NaN      NaN      NaN         NaN            1.0
# 21291  southern company      NaN      NaN      NaN         NaN            2.0
# 21881  southern company      NaN      NaN      NaN         NaN            0.3
# 21882  southern company      NaN      NaN      NaN         NaN            0.2
# 21883  southern company      NaN      NaN      NaN         NaN            0.5
#
# [17 rows x 109 columns]
