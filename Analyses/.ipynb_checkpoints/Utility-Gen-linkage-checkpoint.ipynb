# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
# %matplotlib inline

pd.options.display.max_rows = 999
plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = [15, 10]

dataDir = '/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/'
jsonDir = '/Users/rachelanderson/Dropbox (Princeton)/Tax Equity Code/Analyses/'

# %% [markdown]
# ## Read and fix data

# %%
utils = pd.read_csv(dataDir + 'eia_data/eia8602018/utility_2018.csv',header=1).fillna(0)
utils.columns = [x.lower().replace(" ","_").replace("?","") for x in utils.columns]
# owners = pd.read_csv(dataDir + 'owner_2018.csv', header=1)b

# %%
utils['owner_of_plants_reported_on_form'].value_counts()
# Out:
# Y    4400
# 0     639
# Name: owner_of_plants_reported_on_form, dtype: int64

# %%
utils[utils['owner_of_plants_reported_on_form']==0];

# %%
gen_data = pd.read_csv(dataDir + 'eia_data/eia8602018/gen_2018.csv')
gen_data.drop(['Unnamed: 0'],axis=1,inplace=True)
gen_data = gen_data[~gen_data['Utility ID'].str.contains('NOTE', na=False)]
gen_data['Utility ID'] = pd.to_numeric(gen_data['Utility ID'])
gen_data.columns = gen_data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace('?','')

# %% [markdown]
# Now I want to merge the utility data with the generator data so I can do some sick analyses bro
#
# I'll start by merging the utility list with the list of generators (all in 2018), so I'll see if any columns will conflict

# %%
[print(x) for x in gen_data.columns if x in utils.columns]
# Out:
# utility_id
# utility_name
# state
# [None, None, None]

# %% [markdown]
# I'm merging by utility_id so let's fix the state variable

# %%
gen_data = gen_data.rename(columns={'state': 'plant_state'})

# %%
merged = gen_data.merge(utils, how='left', on=['utility_id','utility_name'])

# %% [markdown]
# Various checks assures me that the merge was successful. So now I want to merge in ownership data in a clever way

# %% [markdown]
# ## Now merge in the owner variable in a creative way
# ### solution is to add owner_1 owner_1_perc, owner_2 ... etc.  for each plant

# %%
# S Single ownership by respondent 
# J Jointly owned with another entity
# W Wholly owned by an entity other than respondent
df = merged.join(pd.get_dummies(merged['ownership']))
df.rename(columns={'S': 'single_owner', 'W': 'other_owner', 'J':'joint_owner'},inplace=True)

# %%
owners = pd.read_csv(dataDir + 'eia_data/eia8602018/owner_2018.csv',header=1)
owners.columns = owners.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '').str.replace('?','')
owners['perc_owned'] = pd.to_numeric(owners['percent_owned'].str.replace("%",""))
num_owners = owners.groupby(['plant_name', 'generator_id']).apply(lambda grp: len(grp.owner_name.unique())).reset_index()
num_owners.rename(columns={0: 'num_owners'},inplace=True)
owners = owners.merge(num_owners, how='outer', on=['plant_name','generator_id'])

# %%
owners = owners.sort_values(['plant_name','generator_id','perc_owned'])

# %%
# owner_dict with key = generator; value = owners 
owner_dict = owners.groupby(['plant_name','generator_id']).owner_name.apply(lambda grp: list(grp.value_counts().index)).to_dict()

# %%
owners.groupby(['plant_name','generator_id']).perc_owned.apply(lambda grp: list(grp.value_counts().index)).to_dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     724             try:
# --> 725                 result = self._python_apply_general(f)
#     726             except Exception:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     741     def _python_apply_general(self, f):
# --> 742         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     743
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     236             group_axes = _get_axes(group)
# --> 237             res = f(group)
#     238             if not _is_indexed_like(res, group_axes):
#
# <ipython-input-250-61c12ff71592> in <lambda>(grp)
# ----> 1 owners.groupby(['plant_name','generator_id']).perc_owned.apply(lambda grp: list(grp.values.index)).to_dict()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-250-61c12ff71592> in <module>
# ----> 1 owners.groupby(['plant_name','generator_id']).perc_owned.apply(lambda grp: list(grp.values.index)).to_dict()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/generic.py in apply(self, func, *args, **kwargs)
#     813     )
#     814     def apply(self, func, *args, **kwargs):
# --> 815         return super().apply(func, *args, **kwargs)
#     816
#     817     @Substitution(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     735
#     736                 with _group_selection_context(self):
# --> 737                     return self._python_apply_general(f)
#     738
#     739         return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     740
#     741     def _python_apply_general(self, f):
# --> 742         keys, values, mutated = self.grouper.apply(f, self._selected_obj, self.axis)
#     743
#     744         return self._wrap_applied_output(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     235             # group might be modified
#     236             group_axes = _get_axes(group)
# --> 237             res = f(group)
#     238             if not _is_indexed_like(res, group_axes):
#     239                 mutated = True
#
# <ipython-input-250-61c12ff71592> in <lambda>(grp)
# ----> 1 owners.groupby(['plant_name','generator_id']).perc_owned.apply(lambda grp: list(grp.values.index)).to_dict()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'index'

# %%
perc_owned_dict = {}
for x in owner_dict:
    temp_dict = {}
    for i,y in enumerate(owner_dict[x]):
        print(str(y) + str(i) + " : ")
        print(perc_dict[x][i])
        temp_dict.update({y : perc_dict[x][i]})
    perc_owned_dict[x] = temp_dict
# Out:
# 231 Dixon 74 Solar I, LLC0 :
# 100.0
# Dependable Highway Express Inc0 :
# 100.0
# Holocene Renewable Energy Fund 3, LLC0 :
# 100.0
# Edison Mission Energy0 :
# 100.0
# Edison Mission Energy0 :
# 100.0
# AL Sandersville0 :
# 100.0
# AL Sandersville0 :
# 100.0
# AL Sandersville0 :
# 100.0
# AL Sandersville0 :
# 100.0
# AL Sandersville0 :
# 100.0
# AL Sandersville0 :
# 100.0
# AL Sandersville0 :
# 100.0
# AL Sandersville0 :
# 100.0
# Strata Solar Farms, LLC0 :
# 100.0
# Solar Mission Sunstone US LLC0 :
# 100.0
# Solar Mission Sunstone US LLC0 :
# 100.0
# Apple, Inc0 :
# 100.0
# Apple, Inc0 :
# 100.0
# Apple, Inc0 :
# 100.0
# Wells Fargo0 :
# 100.0
# KeyBank0 :
# 100.0
# KeyBank0 :
# 100.0
# New York Community Bank0 :
# 100.0
# Key Equipment Finance0 :
# 100.0
# Mound Solar Owner X, LLC0 :
# 100.0
# Entergy Corp0 :
# 100.0
# Entergy Corp0 :
# 100.0
# Entergy Corp0 :
# 100.0
# Ameresco Solar Acton LLC0 :
# 100.0
# National Bank of Arizona0 :
# 100.0
# GLC-(CA) Edwards AFB,LLC0 :
# 100.0
# Acushnet Company0 :
# 100.0
# Acushnet Company0 :
# 100.0
# GLC-(CA) Edwards AFB,LLC0 :
# 100.0
# GLC-(MA) Acushnet - High Hill, LLC0 :
# 100.0
# GLC-(MA) Acushnet - Braley Road 1, LLC0 :
# 100.0
# BE Minnesota Wind Holdings LLC0 :
# 80.0
# Adams Wind Generations LLC1 :
# 20.0
# Adobe Systems Incorporated0 :
# 100.0
# Adobe Systems Incorporated0 :
# 100.0
# Southern Turner Renewable Energy0 :
# 100.0
# DTE Biomass0 :
# 50.0
# LES Project Holdings LLC1 :
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-244-9e5324683c2c> in <module>
#       4     for i,y in enumerate(owner_dict[x]):
#       5         print(str(y) + str(i) + " : ")
# ----> 6         print(perc_dict[x][i])
#       7         temp_dict.update({y : perc_dict[x][i]})
#       8     perc_owned_dict[x] = temp_dict
#
# IndexError: list index out of range

# %%
owner_dict[('Adams Wind Generations LLC', 'AWG')]
# Out:
# ['BE Minnesota Wind Holdings LLC', 'Adams Wind Generations LLC']

# %%
owner_dict[('231 Dixon 74 Solar I, LLC', 'DIXON')][0]
# Out:
# '231 Dixon 74 Solar I, LLC'

# %%
owners.sort_values(by=['plant_name','perc_owned']).head(20)
# Out:
#       utility_id                              utility_name  plant_code  \
# 4370       60163                               Soltage LLC       61195
# 3427       11208   Los Angeles Department of Water & Power       57871
# 3973       60025  Greenbacker Renewable Energy Corporation       59534
# 66         23693                  AES Huntington Beach LLC         335
# 67         23693                  AES Huntington Beach LLC         335
# 2745       59417          SEPG Operating Services, LLC ALS       55672
# 2746       59417          SEPG Operating Services, LLC ALS       55672
# 2747       59417          SEPG Operating Services, LLC ALS       55672
# 2748       59417          SEPG Operating Services, LLC ALS       55672
# 2749       59417          SEPG Operating Services, LLC ALS       55672
# 2750       59417          SEPG Operating Services, LLC ALS       55672
# 2751       59417          SEPG Operating Services, LLC ALS       55672
# 2752       59417          SEPG Operating Services, LLC ALS       55672
# 3625       58330                              AM Best Farm       58344
# 4582       60584                 Onyx Asset Services Group       62629
# 4581       60584                 Onyx Asset Services Group       62628
# 4578       57128                              Bloom Energy       62577
# 4579       57128                              Bloom Energy       62577
# 4580       57128                              Bloom Energy       62577
# 4368       57128                              Bloom Energy       61154
#
#                      plant_name state generator_id status  \
# 4370  231 Dixon 74 Solar I, LLC    NC        DIXON     OP
# 3427          2555 E Olympic Bl    CA            1     OP
# 3973                      4Oaks    NC        4OAKS     OP
# 66     AES Huntington Beach LLC    CA            3     RE
# 67     AES Huntington Beach LLC    CA            4     RE
# 2745        AL Sandersville LLC    GA          CT1     OP
# 2746        AL Sandersville LLC    GA          CT2     OP
# 2747        AL Sandersville LLC    GA          CT3     OP
# 2748        AL Sandersville LLC    GA          CT4     OP
# 2749        AL Sandersville LLC    GA          CT5     OP
# 2750        AL Sandersville LLC    GA          CT6     OP
# 2751        AL Sandersville LLC    GA          CT7     OP
# 2752        AL Sandersville LLC    GA          CT8     OP
# 3625               AM Best Farm    NC            1     OP
# 4582         APG New Chesapeake    MD        10115     OP
# 4581            APG Old Bayside    MD        10115     OP
# 4578              APP Prune A-D    CA        AP11A     OP
# 4579              APP Prune A-D    CA        AP11B     OP
# 4580              APP Prune A-D    CA        AP11D     OP
# 4368               AT&T Anaheim    CA        AT058     OP
#
#                                  owner_name  \
# 4370              231 Dixon 74 Solar I, LLC
# 3427         Dependable Highway Express Inc
# 3973  Holocene Renewable Energy Fund 3, LLC
# 66                    Edison Mission Energy
# 67                    Edison Mission Energy
# 2745                        AL Sandersville
# 2746                        AL Sandersville
# 2747                        AL Sandersville
# 2748                        AL Sandersville
# 2749                        AL Sandersville
# 2750                        AL Sandersville
# 2751                        AL Sandersville
# 2752                        AL Sandersville
# 3625                Strata Solar Farms, LLC
# 4582          Solar Mission Sunstone US LLC
# 4581          Solar Mission Sunstone US LLC
# 4578                             Apple, Inc
# 4579                             Apple, Inc
# 4580                             Apple, Inc
# 4368                            Wells Fargo
#
#                             owner_street_address     owner_city owner_state  \
# 4370  c/o Soltage, LLC 66 York Street, 5th Floor    Jersey City          NJ
# 3427                        2555 E. Olympic Blvd    Los Angeles          CA
# 3973                24600 W 26th Ave., Ste. 280C         Denver          CO
# 66                         2244 WALNUT GROVE AVE       Rosemead          CA
# 67                         2244 WALNUT GROVE AVE       Rosemead          CA
# 2745                       9405 Arrowpoint Blvd.      Charlotte          NC
# 2746                       9405 Arrowpoint Blvd.      Charlotte          NC
# 2747                       9405 Arrowpoint Blvd.      Charlotte          NC
# 2748                       9405 Arrowpoint Blvd.      Charlotte          NC
# 2749                       9405 Arrowpoint Blvd.      Charlotte          NC
# 2750                       9405 Arrowpoint Blvd.      Charlotte          NC
# 2751                       9405 Arrowpoint Blvd.      Charlotte          NC
# 2752                       9405 Arrowpoint Blvd.      Charlotte          NC
# 3625                        1119 US 15 501 Hwy S    Chapel Hill          NC
# 4582                  230 Park Avenue, Suite 845       New York          NY
# 4581                  230 Park Avenue, Suite 845       New York          NY
# 4578                             1 Infinite Loop      Cupertino          CA
# 4579                             1 Infinite Loop      Cupertino          CA
# 4580                             1 Infinite Loop      Cupertino          CA
# 4368                            20 Montgomery St  San Francisco          CA
#
#      owner_zip  ownership_id percent_owned  perc_owned
# 4370      7302         60845       100.00%       100.0
# 3427     90023         59552       100.00%       100.0
# 3973     80211         59280       100.00%       100.0
# 66       91770         34505       100.00%       100.0
# 67       91770         34505       100.00%       100.0
# 2745     28273         57261       100.00%       100.0
# 2746     28273         57261       100.00%       100.0
# 2747     28273         57261       100.00%       100.0
# 2748     28273         57261       100.00%       100.0
# 2749     28273         57261       100.00%       100.0
# 2750     28273         57261       100.00%       100.0
# 2751     28273         57261       100.00%       100.0
# 2752     28273         57261       100.00%       100.0
# 3625     27517         58346       100.00%       100.0
# 4582     10169         62144       100.00%       100.0
# 4581     10169         62144       100.00%       100.0
# 4578     95014         57369       100.00%       100.0
# 4579     95014         57369       100.00%       100.0
# 4580     95014         57369       100.00%       100.0
# 4368     94104         60949       100.00%       100.0

# %%
num_owners.apply(lambda x: )
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1576    1
# 1577    1
# 1578    1
# 1579    3
# 1580    1
# Name: num_owners, Length: 1581, dtype: int64

# %%
owners.groupby(['plant_name']).percent_owned.apply(lambda grp: list(grp.value_counts().index)).to_dict()
# Out:
# {'231 Dixon 74 Solar I, LLC': ['100.00%'],
#  '2555 E Olympic Bl': ['100.00%'],
#  '4Oaks': ['100.00%'],
#  'AES Huntington Beach LLC': ['100.00%'],
#  'AL Sandersville LLC': ['100.00%'],
#  'AM Best Farm': ['100.00%'],
#  'APG New Chesapeake': ['100.00%'],
#  'APG Old Bayside': ['100.00%'],
#  'APP Prune A-D': ['100.00%'],
#  'AT&T Anaheim': ['100.00%'],
#  'AT&T Holger': ['100.00%'],
#  'ATT  Kelvin': ['100.00%'],
#  'ATT Jericho': ['100.00%'],
#  'ATT Van Nyus': ['100.00%'],
#  'AVS Lancaster 1': ['100.00%'],
#  'Acadia Energy Center': ['100.00%'],
#  'Acton Solar Landfill': ['100.00%'],
#  'Actus Lend Lease DMAFB': ['100.00%'],
#  'Acushnet AD Makepeace': ['100.00%'],
#  'Acushnet Ball Plant 2': ['100.00%'],
#  'Acushnet Hawes Reed Road': ['100.00%'],
#  'Acushnet- High Hill': ['100.00%'],
#  'Acushnet-Braley Road 1': ['100.00%'],
#  'Adams Wind Generations LLC': ['20.00%', '80.00%'],
#  'Adobe San Jose': ['100.00%'],
#  'Adobe Solar': ['100.00%'],
#  'Adrian Energy Associates LLC': ['50.00%'],
#  'Advance Stores Company, Inc': ['100.00%'],
#  'Aerojet I': ['100.00%'],
#  'Aerojet II': ['100.00%'],
#  'Agassiz Beach LLC': ['51.00%', '49.00%'],
#  'Agawam Solar': ['100.00%'],
#  'Agua Caliente Solar Project': ['100.00%', '51.00%', '49.00%'],
#  'Agua Mansa Power Plant': ['100.00%'],
#  'Ahoskie': ['100.00%'],
#  'Air Products Port Arthur': ['100.00%'],
#  'Akron Recycle Energy Plant': ['100.00%'],
#  'Alamo Solar': ['33.00%', '67.00%'],
#  'Alamogordo Solar Energy Center': ['100.00%'],
#  'Albany Solar': ['100.00%'],
#  'Albuquerque Solar Energy Center': ['100.00%'],
#  'Alethea I': ['100.00%'],
#  'Algodones': ['50.00%'],
#  'Allegheny Ridge Wind Farm': ['100.00%'],
#  'Alliant SBD 9901 Wells Fargo': ['100.00%'],
#  'Aloha Solar Energy Fund 1 PK1': ['100.00%'],
#  'Alpaugh 50': ['50.00%'],
#  'Alpaugh North': ['50.00%'],
#  'Alta Wind Energy Center I': ['100.00%'],
#  'Alta Wind Energy Center II': ['100.00%'],
#  'Alta Wind Energy Center III': ['100.00%'],
#  'Alta Wind Energy Center IV': ['100.00%'],
#  'Alta Wind Energy Center V': ['100.00%'],
#  'Alta Wind VIII': ['100.00%'],
#  'Alta Wind X': ['100.00%'],
#  'Alta Wind XI': ['100.00%'],
#  'Altamont Midway Ltd': ['100.00%'],
#  'Amazon': ['100.00%'],
#  'Amazon San Bernardino': ['100.00%'],
#  'American Legion PV 1': ['100.00%'],
#  'Amsterdam North': ['100.00%'],
#  'Amsterdam South': ['100.00%'],
#  'Anderson Farm LLC': ['100.00%'],
#  'Anderson Wind I': ['100.00%'],
#  'Anderson Wind II': ['100.00%'],
#  'Anheuser-Busch #2': ['100.00%'],
#  'Annandale Solar': ['100.00%'],
#  'Anoka County MN CONX': ['100.00%'],
#  'Anthony Wayne Solar #1': ['5.00%', '89.00%', '6.00%'],
#  'Apache Solar 1': ['100.00%'],
#  'Apex Solar PV Power Project': ['100.00%'],
#  'Apple Blossom Wind Farm': ['100.00%'],
#  'Aragonne Mesa Phase II': ['100.00%'],
#  'Aragonne Wind LLC': ['100.00%'],
#  'ArcelorMittal Burns Harbor': ['100.00%'],
#  'ArcelorMittal Indiana Harbor West': ['100.00%'],
#  'Argus Cogen Plant': ['100.00%'],
#  'Arndt Farm': ['100.00%'],
#  'Arrache 4006': ['100.00%'],
#  'Arrache 4013': ['100.00%'],
#  'Arrache 8083': ['100.00%'],
#  'Arthur Kill Generating Station': ['100.00%'],
#  'Arthur Solar, LLC': ['100.00%'],
#  'Athens MN CONX': ['100.00%'],
#  'Atlantic Coast Freezers Solar Facility': ['100.00%'],
#  'Atwater Solar': ['100.00%'],
#  'Atwell Island': ['100.00%'],
#  'Auburndale Peaker Energy Center': ['100.00%'],
#  'Augusta Solar Farm': ['100.00%'],
#  'Autumn Hills LLC': ['51.00%', '49.00%'],
#  'Avalon Solar II': ['1.00%', '99.00%'],
#  'Azalea Solar, LLC': ['33.00%', '67.00%'],
#  'Aziscohos Hydroelectric Project': ['100.00%'],
#  "BJ's Wholesale Club Inc Dist Center": ['100.00%'],
#  "BJ's Wholesale Club, Inc- Uxbridge": ['100.00%'],
#  'BPU Solar Farm': ['100.00%'],
#  'Bacliff': ['100.00%', '75.00%', '25.00%'],
#  'Baconton Power Plant': ['35.00%', '65.00%'],
#  'Badger Creek Limited': ['100.00%'],
#  'Bailey Farm LLC': ['100.00%'],
#  'Baker City Solar': ['100.00%'],
#  'Baker PV 1': ['100.00%'],
#  'Bakerstand Solar (NY)': ['100.00%'],
#  'Baldock Solar Highway': ['100.00%'],
#  'Baltimore Church Solar, LLC': ['100.00%'],
#  'Bandera Electric Coop PV': ['100.00%'],
#  'Barker Solar, LLC': ['100.00%'],
#  'Barre': ['100.00%'],
#  'Barrett Farm Solar - Phase I': ['100.00%'],
#  'Barrett PV': ['50.00%'],
#  'Barrow': ['100.00%'],
#  'Bartow Solar Energy LLC': ['100.00%'],
#  'Basin Creek Plant': ['94.89%', '5.11%'],
#  'Bath County': ['40.00%', '60.00%'],
#  'Bay Windpower I': ['100.00%'],
#  'BayWa r.e Mozart LLC': ['100.00%'],
#  'Bayonne MUA- Leitner-Poma Wind Turbine': ['100.00%'],
#  'Bayonne Plant Holding LLC': ['100.00%'],
#  'Bayou Cove Peaking Power': ['100.00%'],
#  'Bayshore Solar A, LLC': ['100.00%'],
#  'Bayshore Solar B, LLC': ['100.00%'],
#  'Bayshore Solar C, LLC': ['100.00%'],
#  "Bd of Educ of Queen Anne's Cnty, Cnty HS": ['100.00%'],
#  'Bear Mountain Limited': ['100.00%'],
#  'Bear Swamp': ['50.00%'],
#  'Bearkat': ['100.00%'],
#  'Beaver Run': ['50.00%'],
#  'Beaver Valley': ['100.00%'],
#  'Beecher Gas Recovery': ['100.00%'],
#  'Belchertown': ['100.00%'],
#  'Belle River': ['18.61%', '81.39%'],
#  'Belleville Dam': ['3.02%',
#   '10.63%',
#   '5.62%',
#   '5.69%',
#   '15.73%',
#   '2.19%',
#   '7.14%',
#   '7.35%',
#   '25.96%',
#   '16.67%'],
#  'Bellevue Solar Project': ['100.00%'],
#  'Belwood Farm': ['1.00%', '99.00%'],
#  'Benthall Bridge PV 1': ['100.00%'],
#  'Benton Falls Associates': ['1.00%', '99.00%'],
#  'BentonSun LLC': ['100.00%'],
#  'Berkshire Power': ['100.00%'],
#  'Berkshire Wind Power Project': ['100.00%'],
#  'Bethlehem Renewable Energy LLC': ['100.00%'],
#  'Big Cajun 2': ['17.85%', '58.00%', '24.15%'],
#  'Big George PV CSG': ['100.00%'],
#  'Big Spring Wind Power Facility': ['100.00%'],
#  'Big Stone': ['23.40%', '53.90%', '22.70%'],
#  'Biltmore Solar Fields': ['40.00%', '60.00%'],
#  'Birchwood Power': ['2.00%', '48.00%', '0.50%', '47.50%'],
#  'Bisson Windfarm LLC': ['100.00%'],
#  'Black River Hydro Associates': ['98.50%', '1.50%'],
#  'Bladenboro Farm': ['100.00%'],
#  'Blue Shld Of Cal- El Dorado Hlls Mtr B': ['100.00%'],
#  'Boardman': ['10.00%', '90.00%'],
#  'Bolton Farm': ['100.00%'],
#  'Bonanza': ['3.75%', '96.25%'],
#  'Bos Dairy, LLC': ['100.00%'],
#  'Boulder Solar Power, LLC': ['51.00%', '49.00%'],
#  'Bourne (MA) - Holliston I': ['100.00%'],
#  'Bowling Green Wind': ['100.00%'],
#  'Boykin PV1': ['100.00%'],
#  'Bradley Energy Center': ['100.00%'],
#  'Bradley Lake': ['100.00%'],
#  'Bradley PV1': ['100.00%'],
#  'Brady': ['100.00%'],
#  'Brame Energy Center': ['20.00%', '50.00%', '30.00%'],
#  'Brassua Hydroelectric Project': ['75.80%', '24.20%'],
#  'Bridgewater Complex Co-Generation Plant': ['100.00%'],
#  'Bridgewater Power LP': ['20.00%', '80.00%'],
#  'Broadalbin': ['100.00%'],
#  'Broadridge Cogen': ['100.00%'],
#  'Broadridge Solar, LLC': ['100.00%'],
#  'Broadview Energy JN, LLC': ['100.00%'],
#  'Broadview Energy KW, LLC': ['100.00%'],
#  'Broadview Energy Prime 2 LLC': ['100.00%'],
#  'Broadview Energy Prime LLC': ['100.00%'],
#  'Broken Bow Wind LLC': ['19.90%', '80.10%'],
#  'Brookfield Solar 2013 LLC': ['100.00%'],
#  'Brookfield Tehachapi 1': ['100.00%'],
#  'Brooklyn Navy Yard Cogeneration': ['40.33%', '19.34%', '20.78%', '58.44%'],
#  'Broome County': ['100.00%'],
#  'Brunswick Nuclear': ['18.33%', '81.67%'],
#  'Brush Generation Facility': ['100.00%'],
#  'Brush Solar Center': ['100.00%'],
#  'Bryan Solar Field': ['100.00%'],
#  'Bryan Solar, LLC': ['100.00%'],
#  'Buchanan Generation LLC': ['50.00%'],
#  'Buena Vista Energy LLC': ['100.00%'],
#  'Buffalo Ridge Windplant WPP 1993': ['100.00%'],
#  'Bulls Bridge': ['100.00%'],
#  'Burney Forest Products': ['44.44%', '55.56%'],
#  'Busch Ranch Wind Energy Farm': ['50.00%'],
#  'Butler Solar Power Project': ['100.00%'],
#  'Buzzard Roost': ['100.00%'],
#  'Buzzard Roost GT': ['100.00%'],
#  'C D McIntosh Jr': ['40.00%', '60.00%'],
#  'CBS Television City': ['100.00%'],
#  'CDCR (CA) - Pleasant Valley State Prison': ['100.00%'],
#  'CE Leathers': ['100.00%'],
#  'CE Turbo LLC': ['100.00%'],
#  'CEIP Substation Distributed Generation': ['100.00%'],
#  'CF Novel Solar CSG Gardens Eleven, LLC': ['100.00%'],
#  'CF Novel Solar CSG Gardens Two, LLC': ['100.00%'],
#  'CFW Solar X LLC - Vaughn': ['100.00%'],
#  'CG Windfarm LLC': ['100.00%'],
#  'CID Solar, LLC': ['33.00%', '67.00%'],
#  'CII Methane Management III LFG Plant': ['100.00%'],
#  'CII Methane Management IV, LLC': ['100.00%'],
#  'CMEEC - Bozrah': ['100.00%'],
#  'CMEEC - Navy NE Trident': ['100.00%'],
#  'CMEEC - Norwich Stott St Solar': ['100.00%'],
#  'CMEEC - Polaris Park Solar': ['100.00%'],
#  'COC Surry LFG, LLC': ['100.00%'],
#  'CSD 2 - Heritage High': ['100.00%'],
#  'CSD 2- Freedom High': ['100.00%'],
#  'CSUF Nutwood Solar': ['100.00%'],
#  'CSUF State College': ['100.00%'],
#  'CT Resource Rec Authority Facility': ['100.00%'],
#  'CTV Power Purchase Contract Trust': ['100.00%', '0.10%', '99.90%'],
#  'Cabazon Wind Partners': ['50.00%'],
#  'CalPeak Power Border Peaker Plant': ['100.00%'],
#  'CalPeak Power Enterprise Peaker Plant': ['100.00%'],
#  'CalPeak Power Panoche Peaker Plant': ['100.00%'],
#  'CalPeak Power Vaca Dixon Peaker Plant': ['100.00%'],
#  'Caledonia': ['100.00%'],
#  'Calhoun Energy Center': ['100.00%'],
#  'California Valley Solar Ranch': ['100.00%'],
#  'Calipatria Solar Farm': ['100.00%'],
#  'Calumet Energy Team LLC': ['100.00%'],
#  'Calvert Cliffs Nuclear Power Plant': ['50.01%', '49.99%'],
#  'Cambria Cogen': ['100.00%'],
#  'Camden Plant Holdings LLC': ['100.00%'],
#  'Cameron Ridge LLC': ['100.00%'],
#  'Camp Far West': ['100.00%'],
#  'Campo Verde Solar': ['100.00%'],
#  'Canadian Hills Wind': ['1.00%', '99.00%'],
#  'Cane Island': ['50.00%', '100.00%'],
#  'Cane Run': ['22.00%', '78.00%'],
#  'Canyon Power Plant': ['100.00%'],
#  'Caprock Wind Farm': ['100.00%'],
#  'Cardinal': ['100.00%'],
#  'Carlsbad Energy Center': ['100.00%'],
#  'Carr Street Generating Station': ['100.00%'],
#  'Carrizozo Solar': ['100.00%'],
#  'Carson Cogeneration': ['98.00%', '2.00%'],
#  'Carson Ice-Gen Project': ['100.00%'],
#  'Carson Solar I': ['100.00%'],
#  'Carstensen Wind': ['1.00%', '99.00%'],
#  'Carter PV1': ['100.00%'],
#  'Cashton Greens Wind Farm': ['50.00%'],
#  'Castle Rock': ['50.00%'],
#  'Castleton Energy Center': ['100.00%'],
#  'Castor Solar': ['100.00%'],
#  'Catalina Solar 2, LLC': ['33.00%', '67.00%'],
#  'Catawba': ['37.50%', '19.25%', '30.75%', '12.50%'],
#  'Causey': ['100.00%'],
#  'Cedar Bayou 4': ['50.00%'],
#  'Cedar Creek II': ['50.00%'],
#  'Cedar Creek Wind': ['100.00%'],
#  'Cedarville CSG': ['100.00%'],
#  'Cedro Hill Wind LLC': ['19.90%', '80.10%'],
#  'Celanese Acetate LLC': ['100.00%'],
#  'Central Antelope Dry Ranch C': ['100.00%'],
#  'Chadbourn Farm': ['100.00%'],
#  'Chalk Cliff Limited': ['100.00%'],
#  'Chambers Cogeneration LP': ['100.00%'],
#  'Champepaden Wind Power': ['100.00%'],
#  'Chandler Hills Wind Farm': ['100.00%'],
#  'Channel Energy Center LLC': ['100.00%'],
#  'Channelview Cogeneration Plant': ['100.00%'],
#  'Chauncey Farm LLC': ['100.00%'],
#  'Chautauqua LFGTE Facility': ['100.00%'],
#  'Cherokee Falls': ['100.00%'],
#  'Chesapeake College': ['100.00%'],
#  'Cheyenne Prairie Generating Station': ['58.00%', '100.00%', '42.00%'],
#  'Chicago West Side Energy Center': ['100.00%'],
#  'Chicopee Granby Road Solar': ['100.00%'],
#  'Chicopee River Solar': ['100.00%'],
#  'Chicopee Solar': ['100.00%'],
#  'Chillicothe Solar Farm': ['100.00%'],
#  'China Mill Hydro': ['100.00%'],
#  'Chisago Solar': ['100.00%'],
#  'Cholla': ['100.00%'],
#  'Church Road Solar LLC': ['100.00%'],
#  'Cibola': ['100.00%'],
#  'Cimarron River': ['100.00%'],
#  'Cimarron Solar Facility': ['100.00%'],
#  'Cimarron Windpower II': ['50.00%'],
#  'Citizens Agawam Landfill Solar': ['100.00%'],
#  'City of Boulder WWTP': ['100.00%'],
#  'City of Soledad Water Reclamation': ['100.00%'],
#  'Clay Boswell': ['80.00%', '20.00%'],
#  'Cleary Flood': ['86.37%', '9.09%', '4.54%'],
#  'Clif Bar Bakery of Twin Falls': ['100.00%'],
#  'Clifton': ['100.00%'],
#  'Clinton LFGTE Facility': ['100.00%'],
#  'Clover': ['50.00%'],
#  'CoServ Community Solar Station': ['100.00%'],
#  'Coalinga Cogeneration Facility': ['100.00%'],
#  'Cobble Mountain': ['100.00%'],
#  'Cogentrix of Alamosa': ['100.00%'],
#  'Coleto Creek': ['100.00%'],
#  'Collierville Powerhouse': ['100.00%'],
#  'Colon PV': ['100.00%'],
#  'Colorado Green Holdings LLC': ['50.00%'],
#  'Colstrip': ['50.00%', '30.00%', '10.00%', '15.00%', '20.00%', '25.00%'],
#  'Columbia (WI)': ['28.10%', '19.40%', '52.50%'],
#  'Columbia Canal Hydro': ['100.00%'],
#  'Colver Power Project': ['100.00%'],
#  'Comanche (CO)': ['25.33%', '66.67%', '8.00%'],
#  'Comanche Peak': ['100.00%'],
#  'Comanche Solar': ['100.00%'],
#  'Commerce Refuse To Energy': ['50.00%'],
#  'Commonwealth Chesapeake': ['100.00%'],
#  'Community Wind North LLC': ['1.00%', '99.00%'],
#  'Concord Blue Eagar, LLC': ['40.00%', '60.00%'],
#  'Conemaugh': ['16.25%', '16.45%', '22.50%', '5.97%', '35.11%', '3.72%'],
#  'Conemaugh Hydro Plant': ['5.00%', '95.00%'],
#  'Conesville': ['40.00%', '43.50%', '16.50%'],
#  'Conn Mun Electric Energy Coop': ['100.00%'],
#  'Conrath DPC Solar': ['100.00%'],
#  'Coram Energy LLC': ['100.00%'],
#  'Coram Energy LLC (ECT)': ['100.00%'],
#  'Corcoran Solar': ['50.00%'],
#  'Corning Pharmaceutical Glass': ['100.00%'],
#  'Corona Energy Partners, Ltd': ['100.00%'],
#  'Cosumnes': ['100.00%'],
#  'Cottonwood Solar, LLC (City of Corcoran)': ['33.00%', '67.00%'],
#  'Cottonwood Solar, LLC (Goose Lake)': ['33.00%', '67.00%'],
#  'Cottonwood Solar, LLC Cottonwood Carport': ['33.00%', '67.00%'],
#  'County Home Solar LLC': ['100.00%'],
#  'Countyside Genco LLC': ['100.00%'],
#  'Covanta Hennepin Energy': ['100.00%'],
#  'Covanta Mendota': ['100.00%'],
#  'Covanta Tulsa Renewable Energy LLC': ['100.00%'],
#  'Coventry Photovoltaic, LLC': ['100.00%'],
#  'Coyote': ['30.00%', '10.00%', '35.00%', '25.00%'],
#  'Craig (CO)': ['19.28%', '18.00%', '24.00%', '29.00%', '9.72%'],
#  'Cranberry Point Energy Storage': ['100.00%'],
#  'Craven County Wood Energy LP': ['50.00%'],
#  'Crescent Ridge': ['100.00%'],
#  'Crescent Ridge II Wind Energy Project': ['100.00%'],
#  'Cricket Valley Energy': ['100.00%'],
#  'Crockett Cogen Project': ['8.30%', '1.00%', '90.70%'],
#  'Crofton Bluffs Wind LLC': ['19.90%', '80.10%'],
#  'Crooked Run': ['100.00%'],
#  'Crosswind Energy Project': ['1.00%', '99.00%'],
#  'Crystal River': ['1.70%', '4.92%', '91.78%', '1.60%'],
#  'Cumberland County Solid Waste Complex': ['100.00%'],
#  'Curtis H Stanton Energy Center': ['3.50%', '28.00%', '65.00%', '100.00%'],
#  'DDR Shoppers World': ['100.00%'],
#  'DOE Golden NREL Main Campus': ['100.00%'],
#  'DOE Golden NWTC Load Side': ['100.00%'],
#  'DOE Golden NWTC Turbine Side': ['100.00%'],
#  'DSH (CA) - Coalinga State Hospital': ['100.00%'],
#  'Dairyland WTE Plant': ['100.00%'],
#  'Dakota Solar': ['100.00%'],
#  'Daniel Farm LLC': ['100.00%'],
#  'Danielson Wind Farms LLC': ['20.00%', '80.00%'],
#  'Darby Power, LLC': ['100.00%'],
#  'Dartmouth Landfill': ['100.00%'],
#  'Dartmouth Power Associates LP': ['100.00%'],
#  'Davis Besse': ['100.00%'],
#  'DeCordova Steam Electric Station': ['100.00%', '0.00%'],
#  'Del Ranch Company': ['100.00%'],
#  'Delano Energy Center': ['1.00%', '99.00%'],
#  'Deming Solar Energy Center': ['100.00%'],
#  'Denver Intl Airport IV Solar': ['100.00%'],
#  'Des Plaines Gas Recovery': ['100.00%'],
#  'Desert Peak Power Plant': ['100.00%'],
#  'Desert Sunlight 250, LLC': ['25.00%',
#   '1.00%',
#   '24.00%',
#   '50.00%',
#   '0.10%',
#   '49.90%',
#   '24.90%'],
#  'Desert Sunlight 300, LLC': ['25.00%', '50.00%', '0.10%', '24.90%', '49.90%'],
#  'Dibrell Farm': ['100.00%'],
#  'Dickinson Solar Array': ['100.00%'],
#  'Digital Fairfield': ['100.00%'],
#  'Dinuba Wastewater Treatment Plant': ['100.00%'],
#  'Disney Prospect': ['100.00%'],
#  'Division': ['100.00%'],
#  'Division 1': ['100.00%'],
#  'Division 2': ['100.00%'],
#  'Division 3': ['100.00%'],
#  'Dodge Center Solar': ['100.00%'],
#  'DodgeSun CSG': ['100.00%'],
#  'Dogwood Energy Facility': ['10.30%',
#   '12.30%',
#   '17.00%',
#   '8.20%',
#   '52.20%',
#   '33.90%',
#   '10.10%',
#   '16.40%'],
#  'Dolet Hills': ['40.24%', '3.90%', '5.86%', '50.00%'],
#  'Dominion/Lo Mar': ['50.00%'],
#  'Don Pedro': ['31.54%', '68.46%'],
#  'Double C Generation Limited Partnership': ['100.00%'],
#  'Dougherty County Solar, LLC': ['100.00%'],
#  'Dover Peaking': ['5.22%',
#   '27.10%',
#   '14.32%',
#   '3.73%',
#   '7.46%',
#   '2.98%',
#   '4.29%',
#   '23.87%',
#   '5.81%'],
#  'Downs Farm Solar': ['100.00%'],
#  'Downsville DPC Solar': ['100.00%'],
#  'Dry Fork Station': ['7.10%', '92.90%'],
#  'Duane Arnold Energy Center': ['20.00%', '10.00%', '70.00%'],
#  'Duanesburg': ['100.00%'],
#  'Dunbarton Energy Partners LP': ['100.00%'],
#  'Dunkirk Generating Plant': ['100.00%'],
#  'Dunn': ['99.99%', '0.01%'],
#  'Duplin Solar I LLC (160 Houston Lane)': ['100.00%'],
#  'Dyer Road': ['100.00%'],
#  'E C Gaston': ['50.00%'],
#  'E Nash PV1': ['100.00%'],
#  'E W Brown': ['38.00%', '62.00%', '47.00%', '61.00%', '39.00%', '53.00%'],
#  'EAFB - North Base': ['100.00%'],
#  'EAFB - South Base': ['100.00%'],
#  'EBZ Solar': ['100.00%'],
#  'EDF Renewable Windfarm V Inc': ['100.00%'],
#  'EGP Stillwater Solar PV II, LLC': ['100.00%'],
#  'ESI Project': ['100.00%'],
#  'ESS Fairgrounds': ['100.00%'],
#  'ESS Lewes': ['100.00%'],
#  'ESS Wesel': ['100.00%'],
#  'ETS Ewing Solar Facility': ['100.00%'],
#  'Eagle Mountain': ['100.00%'],
#  'Eagle Point Power Generation': ['100.00%'],
#  'Earl F Wisdom': ['50.00%'],
#  'East Wayne Solar LLC': ['100.00%'],
#  'Eastern Iowa Solar': ['100.00%'],
#  'Eastern Landfill Gas LLC': ['100.00%'],
#  'Easthampton Landfill-City of Easthampton': ['100.00%'],
#  'Easton Landfill': ['100.00%'],
#  'Eastwood Solar': ['100.00%'],
#  'Ebensburg Power': ['0.50%', '99.50%'],
#  'Ecogen Wind': ['100.00%'],
#  'Edgecombe Genco LLC': ['100.00%'],
#  'Edgerton': ['5.22%',
#   '27.10%',
#   '14.32%',
#   '3.73%',
#   '7.46%',
#   '2.98%',
#   '4.29%',
#   '23.87%',
#   '5.81%'],
#  'Edgewater': ['31.80%', '68.20%'],
#  'Edom Hills Project 1 LLC': ['100.00%'],
#  'Edwards Air Force Base': ['100.00%'],
#  'Edwin I Hatch': ['2.20%', '50.10%', '30.00%', '17.70%'],
#  'Effingham County Power Project': ['100.00%'],
#  'Eklutna Hydro Project': ['16.70%', '53.30%', '30.00%'],
#  'El Cajon': ['100.00%'],
#  'El Dorado Springs Solar Farm': ['100.00%'],
#  'El Paso Wind Project': ['100.00%'],
#  'El Segundo Cogen': ['100.00%'],
#  'El Segundo Energy Center LLC': ['100.00%'],
#  'El Segundo Power': ['100.00%'],
#  'Elevation Solar C': ['100.00%'],
#  'Elk Basin Gasoline Plant': ['64.00%', '36.00%'],
#  'Elk Hills Power LLC': ['100.00%'],
#  'Elk Wind Farm': ['90.00%', '10.00%'],
#  'Elkhorn Ridge Wind LLC': ['11.00%', '67.00%'],
#  'Elm Road Generating Station': ['8.33%', '83.34%'],
#  'Elmore Company': ['100.00%'],
#  'Elmwood Park Power LLC': ['100.00%'],
#  'Eltopia Branch Canal 4.6': ['33.33%', '33.34%'],
#  'Elwood Energy LLC': ['100.00%'],
#  'Encina': ['100.00%'],
#  'Enerparc CA1 LLC': ['100.00%'],
#  'Enterprise Products Operating': ['12.50%', '75.00%'],
#  'Equinix San Jose': ['100.00%'],
#  'Equus Freeport Power': ['100.00%'],
#  'Erwin Farm': ['100.00%'],
#  'Escondido Energy Center': ['100.00%'],
#  'Estrella Mountain PV': ['100.00%'],
#  'Eubank Landfill Solar Array': ['100.00%'],
#  'Everett PV1': ['100.00%'],
#  'Evergreen Community Power': ['100.00%'],
#  'Ewa Nui Substation DG': ['100.00%'],
#  'Exeter Energy LP': ['100.00%'],
#  'FC Landfill Energy': ['100.00%'],
#  'FGE Texas II': ['100.00%'],
#  'FLEX Gibraltar': ['100.00%'],
#  'FLS Solar 230 (Warren)': ['100.00%'],
#  'Facile Solar': ['100.00%'],
#  'Fairfield Wind': ['100.00%'],
#  'Fairhaven Power': ['100.00%'],
#  'Falls Creek': ['49.05%', '50.95%'],
#  'Falls Village': ['100.00%'],
#  'Falmouth Landfill Solar': ['100.00%'],
#  'Farmington Solar Farm': ['100.00%'],
#  'Farrington Farm': ['1.00%', '99.00%'],
#  'Fayette Power Project': ['50.00%'],
#  'Felton CSG PV1-5': ['100.00%'],
#  'Fife Brook': ['50.00%'],
#  'Findlay Wind Farm': ['5.00%', '95.00%'],
#  'Fire Island Wind': ['100.00%'],
#  'FirstEnergy Acme': ['100.00%'],
#  'FirstEnergy Ashtabula': ['100.00%'],
#  'FirstEnergy Bay Shore': ['100.00%'],
#  'FirstEnergy Harrison Power Station': ['100.00%'],
#  'FirstEnergy Pleasants Power Station': ['100.00%'],
#  'FirstEnergy R E Burger': ['100.00%'],
#  'FirstEnergy Toronto': ['100.00%'],
#  'Flat Meeks PV 1': ['100.00%'],
#  'Flat Ridge 2 Wind Energy LLC': ['50.00%'],
#  'Flat Ridge Wind Energy LLC': ['100.00%'],
#  'Flint Creek': ['50.00%'],
#  'Florence Hills LLC': ['51.00%', '49.00%'],
#  'Foote Creek I': ['21.21%', '78.79%'],
#  'Foote Creek III': ['100.00%'],
#  'Foothill Solar Project': ['100.00%'],
#  'Forever 21 Retail, Inc.': ['100.00%'],
#  'Fort Dodge': ['100.00%'],
#  'Fortistar North Tonawanda': ['100.00%'],
#  'Foster Wheeler Martinez': ['1.00%', '99.00%'],
#  'Foundation Cemex BMQ': ['100.00%'],
#  'Foundation Cemex Madison': ['100.00%'],
#  'Foundation Cemex River Plant': ['100.00%'],
#  'Foundation NWNA': ['100.00%'],
#  'Foundation RRM': ['100.00%'],
#  'Foundation Superior Farms': ['100.00%'],
#  'Foundation Wal-Mart Red Bluff': ['100.00%'],
#  'Four Corners': ['7.00%', '13.00%', '10.00%', '63.00%'],
#  'Four Peaks Camino Real': ['100.00%'],
#  'Fourth Branch Hydroelectric Facility': ['100.00%'],
#  'Fowler Ridge IV Wind Farm LLC': ['100.00%'],
#  'Fowler Ridge Wind Farm LLC': ['50.00%', '100.00%'],
#  'Fox Island Wind LLC': ['100.00%'],
#  'Foxtail Wind, LLC': ['100.00%'],
#  'Frankenheimer Power Plant': ['100.00%'],
#  'Franklin Templeton San Mateo': ['100.00%'],
#  'Frederickson Power LP': ['50.15%', '49.85%'],
#  'Freeport Energy Center': ['100.00%'],
#  'Freestone Energy Center': ['75.00%', '25.00%'],
#  'Fremont Farm': ['100.00%'],
#  'Fresno Cogen Partners': ['75.00%', '25.00%'],
#  'Frontier HS Solar Project': ['100.00%'],
#  'G&S Wantage Solar LLC': ['44.35%', '55.65%'],
#  'GKS Solar': ['100.00%'],
#  'GL Wind': ['50.00%'],
#  'GM Lordstown Assembly Solar Array': ['100.00%'],
#  'GMP Solar - Hartford': ['100.00%'],
#  'GMP Solar - Panton': ['100.00%'],
#  'GMP Solar - Richmond': ['100.00%'],
#  'GMP Solar - Williamstown': ['100.00%'],
#  'GMP Solar - Williston': ['100.00%'],
#  'GMP Solar/Storage-Essex': ['100.00%'],
#  'GMP Solar/Storage-Ferrisburgh': ['100.00%'],
#  'GMP Solar/Storage-Milton': ['100.00%'],
#  'GRE Marshan Solar': ['100.00%'],
#  'GSG LLC': ['100.00%'],
#  'Galion': ['5.22%',
#   '27.10%',
#   '14.32%',
#   '3.73%',
#   '7.46%',
#   '2.98%',
#   '4.29%',
#   '23.87%',
#   '5.81%'],
#  'Gallatin #2': ['100.00%'],
#  'Garnet Solar Generation Station I LLC': ['83.00%', '17.00%'],
#  'Garnet Wind Energy Center': ['100.00%'],
#  'Garrell Solar Farm': ['100.00%'],
#  'Garrett County - DPU Treatment Plant': ['100.00%'],
#  'Gaston Memorial Hospital': ['100.00%'],
#  'Gastonia, Tulip Drive': ['100.00%'],
#  'Gates Peaker': ['75.00%', '25.00%'],
#  'Gateway': ['100.00%'],
#  'Gavilan District College Solar Project': ['100.00%'],
#  'Gavin Power, LLC': ['100.00%'],
#  'Gaviota Oil Plant': ['8.26%', '10.33%', '1.70%', '6.07%', '69.34%', '4.30%'],
#  'Genentech Vacaville Meter #1': ['100.00%'],
#  'Genentech-Oceanside': ['100.00%'],
#  'General Electric Aircraft Engines': ['100.00%'],
#  'Genesee Power Station LP': ['49.75%', '1.00%', '48.75%', '0.50%'],
#  'George Neal North': ['72.00%', '28.00%'],
#  'George Neal South': ['0.52%',
#   '0.35%',
#   '40.57%',
#   '2.60%',
#   '25.70%',
#   '2.50%',
#   '8.70%',
#   '2.94%',
#   '0.33%',
#   '1.21%',
#   '8.68%',
#   '4.86%',
#   '0.17%'],
#  'Georgetown': ['100.00%'],
#  'Georgia-Pacific Taylorsville Plywood': ['61.00%', '39.00%'],
#  'Georgia-Pacific Wauna Mill': ['100.00%'],
#  'Gibson': ['50.05%', '24.95%', '25.00%'],
#  'Gila River Power Block 3': ['75.00%', '25.00%'],
#  'Gilroy Peaking Energy Center': ['100.00%'],
#  'Glen Ullin Energy Center': ['100.00%'],
#  'Goat Wind LP': ['0.05%', '99.90%', '0.10%'],
#  'Golden Acorn Casino': ['100.00%'],
#  'Golden Renewable Energy, LLC': ['25.00%'],
#  'Goodhue Solar': ['100.00%'],
#  'Goose Lake MN DPC-GM': ['100.00%'],
#  'Gopher CSG': ['100.00%'],
#  'Goshen Phase II': ['50.00%'],
#  'Grady Wind Energy Center, LLC': ['100.00%'],
#  'Grahamsville': ['100.00%'],
#  'Grand Gulf': ['90.00%', '10.00%'],
#  'Grand Isle Gas Plant / Treating Station': ['100.00%'],
#  'Grand Valley Project Power Plant': ['100.00%'],
#  'Grandy PV 1': ['100.00%'],
#  'Granite Reliable Power': ['10.52%', '89.48%'],
#  'Graniteville Enterprise Division': ['100.00%'],
#  'Granville Solar PV Power Project': ['100.00%'],
#  'Grayling Generating Station': ['50.00%', '1.00%', '49.00%'],
#  'Great Bend - Sunflower': ['100.00%'],
#  'Great Plains Windpark LLC': ['100.00%'],
#  'Green Acres Solar Facility 1': ['100.00%'],
#  'Green Acres Solar Facility 2': ['100.00%'],
#  'Green City Recovery, LLC': ['100.00%'],
#  'Green Island Hydroelectric Station': ['100.00%'],
#  'Green Knight Energy Center': ['100.00%'],
#  'Green Machine': ['100.00%'],
#  'Green Meadows': ['100.00%'],
#  'Green Pastures Wind I': ['100.00%'],
#  'Green Pastures Wind II': ['100.00%'],
#  'Green Power 2': ['100.00%'],
#  'Greenback Energy': ['1.00%', '99.00%'],
#  'Greene County': ['40.00%', '60.00%'],
#  'Greene County Meter #1': ['100.00%'],
#  'Greenup Hydro': ['48.60%', '51.40%'],
#  'H Power': ['100.00%'],
#  'HEBT Irvine 1': ['100.00%'],
#  'HEBT Irvine 2': ['100.00%'],
#  'HEBT WLA 1': ['100.00%'],
#  'HL Power': ['100.00%'],
#  'HMP&L Station Two Henderson': ['100.00%'],
#  'HNL Emergency Power Facility': ['100.00%'],
#  'HQC Rock River Solar Power Gen Station': ['57.60%', '42.40%'],
#  'Hadley Ridge LLC': ['51.00%', '49.00%'],
#  'Halifax County Biomass': ['100.00%'],
#  'Hampden': ['100.00%'],
#  'Hampshire College': ['100.00%'],
#  'Hanover Solar, LLC': ['100.00%'],
#  'Happy Hollow CSG': ['100.00%'],
#  'Harbor Wind LLC': ['50.01%', '49.99%'],
#  'Hardee Power Station': ['100.00%'],
#  'Hardin Hilltop Wind LLC': ['1.00%', '99.00%'],
#  'Harpster Wind': ['5.00%', '95.00%'],
#  'Harrisburg Facility': ['100.00%'],
#  'Harrison County Power Project': ['55.00%', '45.00%'],
#  'Hastings Solar': ['100.00%'],
#  'Hatchet Ridge Wind Project': ['100.00%'],
#  'Hawaii Cogen': ['100.00%'],
#  'Hawkeye Power Partners LLC': ['100.00%'],
#  'Hawkeye Wind Farm': ['90.00%', '10.00%'],
#  'Hawks Nest Hydro': ['100.00%'],
#  'Hayden': ['75.50%', '37.40%', '50.00%', '12.60%', '24.50%'],
#  'Haynes Farm': ['79.00%', '21.00%'],
#  'Haywood Solar': ['100.00%'],
#  'Hazle Spindle': ['100.00%'],
#  'Heat Plant 770': ['100.00%'],
#  'Heat Recovery Coke Facility': ['100.00%'],
#  'Heber Geothermal': ['100.00%'],
#  'Helemano Substation DG': ['100.00%'],
#  'Henrietta D Energy Storage LLC': ['100.00%'],
#  'Henrietta Solar Project': ['51.00%', '49.00%'],
#  'Hermiston Generating Plant': ['50.00%'],
#  'Hesperia': ['100.00%'],
#  'Hewlett-Packard (HP) - Andover, MA': ['100.00%'],
#  'Hidalgo Energy Center': ['79.00%', '21.00%'],
#  'Hidden View Dairy, LLC': ['100.00%'],
#  'Higginsville Solar Farm': ['100.00%'],
#  'High Shoals PV1': ['100.00%'],
#  'High Sierra Limited': ['100.00%'],
#  'High Winds LLC': ['100.00%'],
#  'Higley': ['100.00%'],
#  'Hiilangaay Hydro': ['50.00%'],
#  'Hill AFB LFG Facility, Bldg #737': ['100.00%'],
#  'Hill Top Energy Center, LLC': ['85.00%', '15.00%'],
#  'Holland Energy Facility': ['100.00%'],
#  'Holly': ['87.00%', '13.00%'],
#  'Homer City Generating Station': ['98.00%', '2.00%'],
#  'Homer Street East': ['25.00%'],
#  'Homer Street West': ['25.00%'],
#  'Honda Torrance': ['100.00%'],
#  'Hope Creek LLC': ['51.00%', '49.00%'],
#  'Horn': ['100.00%'],
#  'Howland Hydro Station': ['100.00%'],
#  'Hudson Falls Hydroelectric Project': ['0.50%', '99.00%'],
#  'Hunter': ['14.59%', '60.31%', '25.10%', '6.25%', '93.75%'],
#  'Hurricane Creek Lift Station': ['100.00%'],
#  'Hyland LFGTE Facility': ['100.00%'],
#  'Hyperion Treatment Plant CHP Plant': ['100.00%'],
#  'IBM Southbury': ['100.00%'],
#  'IP Springfield Oregon': ['100.00%'],
#  'IVC Solar': ['100.00%'],
#  'Iatan': ['18.00%', '12.00%', '70.00%', '11.76%', '3.53%', '54.71%'],
#  'Imperial Solar Energy Center South': ['48.00%', '3.00%', '49.00%'],
#  'Imperial Solar Energy Center West': ['74.00%', '1.00%', '25.00%'],
#  'Imperial Valley Solar Co (IVSC) 2, LLC': ['33.00%', '67.00%'],
#  'Independence II Solar Farm': ['100.00%'],
#  'Independence Solar Farm': ['100.00%'],
#  'Independence Steam Electric Station': ['1.00%',
#   '0.50%',
#   '25.00%',
#   '35.00%',
#   '2.00%',
#   '31.50%',
#   '7.10%',
#   '14.40%',
#   '15.00%',
#   '5.00%'],
#  'Indian River Generating Station': ['100.00%'],
#  'Indian River Plant': ['79.00%', '12.20%', '21.00%', '39.00%', '48.80%'],
#  'Indiana Harbor E 5 AC Station': ['100.00%'],
#  'Indianapolis Motor Speedway Solar PV': ['1.00%', '99.00%'],
#  'Indy Solar I, LLC': ['33.00%', '67.00%'],
#  'Indy Solar II, LLC': ['33.00%', '67.00%'],
#  'Indy Solar III, LLC': ['33.00%', '67.00%'],
#  'Ingleside Cogeneration': ['98.00%', '2.00%'],
#  'Innovative Solar 16': ['100.00%'],
#  'Innovative Solar 18, LLC': ['100.00%'],
#  'Innovative Solar 26, LLC': ['100.00%'],
#  'Innovative Solar 31': ['85.00%', '15.00%'],
#  'Innovative Solar 44': ['100.00%'],
#  'Innovative Solar 63, LLC': ['100.00%'],
#  'Intel - Ocotillo Campus Solar': ['100.00%'],
#  'Intel Folsom': ['100.00%'],
#  'Intel Folsom Phase 3': ['100.00%'],
#  'Intel Santa Clara': ['100.00%'],
#  'Intercession City': ['66.67%', '33.33%'],
#  'Intermountain Power Project': ['100.00%'],
#  'International Paper - Orange': ['100.00%'],
#  'Ironwood Wind': ['50.00%'],
#  'Ivanpah 1': ['100.00%'],
#  'Ivanpah 2': ['100.00%'],
#  'Ivanpah 3': ['100.00%'],
#  'Iwilei Tank Farm DG': ['100.00%'],
#  'J C McNeil': ['19.00%', '31.00%', '50.00%'],
#  'J H Campbell': ['93.31%', '4.80%', '1.89%'],
#  'J M Stuart': ['35.00%', '26.00%', '39.00%'],
#  'Jack River LLC': ['51.00%', '49.00%'],
#  'Jackson Board of Education-Liberty HS': ['100.00%'],
#  'Jackson Cntr Peaking': ['5.22%',
#   '27.10%',
#   '14.32%',
#   '3.73%',
#   '7.46%',
#   '2.98%',
#   '4.29%',
#   '23.87%',
#   '5.81%'],
#  'James H Miller Jr': ['8.16%', '91.84%'],
#  'Jeffco Community Solar Gardens LLC': ['100.00%'],
#  'Jeffers Wind 20 LLC': ['0.10%', '99.90%'],
#  'Jeffrey Energy Center': ['20.00%', '72.00%', '8.00%'],
#  'Jersey-Atlantic Wind Farm': ['100.00%'],
#  'Jessica Mills LLC': ['51.00%', '49.00%'],
#  'Jim Bridger': ['66.67%', '33.33%'],
#  'John A Logan College Solar': ['100.00%'],
#  'John R Kelly': ['100.00%'],
#  'John Street 1, 3, 4 & 5': ['100.00%'],
#  'John W Turk Jr Power Plant': ['11.70%', '8.30%', '73.30%', '6.70%'],
#  'Johnson Solar CSG': ['100.00%'],
#  'Johnstown': ['100.00%'],
#  'Joppa Steam': ['80.00%', '20.00%'],
#  'Julia Hills LLC': ['51.00%', '49.00%'],
#  'Juniper Networks Sunnyvale': ['100.00%'],
#  'KIUC Kapaia PV and BA Storage Project': ['100.00%'],
#  'KS Solar Six LLC': ['51.00%', '49.00%'],
#  'Kalaeloa Cogen Plant': ['51.00%', '49.00%'],
#  'Kalaeloa Renewable Energy Park': ['100.00%'],
#  'Kalaeoloa Pole Yard DG': ['100.00%'],
#  'Kearney NPPD Solar Project': ['100.00%'],
#  'Kearny': ['100.00%'],
#  'Kelford': ['100.00%'],
#  "Kellogg's - San Jose": ['100.00%'],
#  'Kelly Solar, LLC': ['100.00%'],
#  'Kennedy International Airport Cogen': ['100.00%'],
#  'Kern Front Limited': ['100.00%'],
#  'Kettering Solar 1': ['100.00%'],
#  'Kettering Solar 2': ['100.00%'],
#  'Kettleman Solar -Centaurus': ['1.00%', '99.00%'],
#  'Keystone': ['16.67%', '22.84%', '12.34%', '44.45%', '3.70%'],
#  'Kiamichi Energy Facility': ['0.65%', '99.00%', '0.35%'],
#  'Killen Station': ['33.00%', '67.00%'],
#  'Kilroy Solar': ['100.00%'],
#  'Kingbird A Solar LLC': ['70.00%', '30.00%'],
#  'Kingbird B Solar, LLC': ['70.00%', '30.00%'],
#  'Kingman 1': ['100.00%'],
#  'Kingman Wind': ['100.00%'],
#  'Kinneytown New Old': ['100.00%'],
#  'Kinston': ['100.00%'],
#  'Kinston Solar': ['100.00%'],
#  'Klamath Cogeneration Plant': ['100.00%'],
#  'Klamath Expansion Project': ['100.00%'],
#  'Kline Township Cogen Facility': ['100.00%'],
#  'Kohls San Bernardino Solar Facility': ['100.00%'],
#  'Kokomo Solar 1, LLC': ['20.00%', '80.00%'],
#  'Koma Kulshan Associates': ['50.00%'],
#  'Koppelman Sun CSG': ['100.00%'],
#  'Kramer Solar CSG': ['100.00%'],
#  'Kumeyaay Wind': ['100.00%'],
#  'LRI LFGTE Facility': ['100.00%'],
#  'LSP-Cottage Grove LP': ['1.00%', '38.22%', '26.78%', '34.00%'],
#  'LSP-Whitewater LP': ['1.00%', '39.17%', '25.83%', '34.00%'],
#  'La Cygne': ['50.00%'],
#  'Lafayette DPC Solar': ['100.00%'],
#  'Lafayette Energy Partners LP': ['100.00%'],
#  'Lahontan': ['100.00%'],
#  'Lahr 1, LLC': ['100.00%'],
#  'Lake Benton II': ['100.00%'],
#  'Lake Creek': ['100.00%'],
#  'Lake Emily Solar': ['100.00%'],
#  'Lake Pleasant WTP': ['100.00%'],
#  'Lake Pulaski Solar': ['100.00%'],
#  'Lakefield Wind Project LLC': ['100.00%'],
#  'Lakeland Electric Co. (FL) - Aiport II': ['100.00%'],
#  'Lakeland Electric Co. (FL)-Airport 1': ['100.00%'],
#  'Lakota Ridge LLC': ['75.00%', '25.00%'],
#  'Lalamilo Windfarm': ['100.00%'],
#  'Lamar Plant': ['100.00%'],
#  'Lancaster Baptist Church': ['100.00%'],
#  'Lancaster County Resource Recovery': ['100.00%'],
#  'Lancaster Wind Farm Project': ['100.00%'],
#  'Langley PV1': ['100.00%'],
#  'Laramie River Station': ['2.54%',
#   '36.14%',
#   '2.11%',
#   '59.21%',
#   '8.42%',
#   '33.16%',
#   '8.95%',
#   '49.47%'],
#  'Las Vegas Solar Energy Center': ['100.00%'],
#  'Las Virgenes Municipal Water District': ['100.00%'],
#  'Laurinburg Solar': ['100.00%'],
#  'Lawrence County Station': ['100.00%'],
#  'Lawrence Creek Solar': ['100.00%'],
#  'Lawrenceburg Power, LLC': ['100.00%'],
#  'Lebanon Solar Farm (MO)': ['100.00%'],
#  'Lee Energy Facility': ['100.00%'],
#  'Leicester One MA Solar LLC': ['90.00%', '10.00%'],
#  'Lenoir Farm': ['100.00%'],
#  'Lenoir Farm 2': ['79.00%', '21.00%'],
#  'Liberty HS Solar Project': ['100.00%'],
#  'Liberty Pole DPC Solar': ['100.00%'],
#  'Life Technologies - Pleasanton': ['100.00%'],
#  'Life Technologies Carlsbad': ['100.00%'],
#  'Linden Wind Energy Project': ['100.00%'],
#  'Lindstrom Solar CSG': ['100.00%'],
#  'Little Bay': ['100.00%'],
#  'Little River PV 1': ['100.00%'],
#  'Live Oak Limited': ['100.00%'],
#  'Livingston Solar Canopies': ['100.00%'],
#  'Llano Estacado Wind Ranch': ['100.00%'],
#  'Lockheed Martin Sunnyvale': ['100.00%'],
#  'Locust Ridge': ['55.00%', '45.00%'],
#  'Logan Generating Company LP': ['100.00%'],
#  'Logans Gap Wind LLC': ['100.00%'],
#  'Long Beach Generation LLC': ['50.00%', '100.00%'],
#  'Longview Power Plant': ['100.00%'],
#  'Lopez Canyon': ['100.00%'],
#  'Los Lunas Solar Energy Center': ['100.00%'],
#  'Lost Hills/Blackwell': ['51.00%', '49.00%'],
#  'Lost Pines 1 Power Project': ['50.00%'],
#  'Louisa': ['0.50%', '1.10%', '0.80%', '4.00%', '88.00%', '4.60%'],
#  'Louisiana 1': ['100.00%'],
#  'Lower Mount Bethel Energy': ['100.00%'],
#  'Lower Saranac Hydroelectric Facility': ['1.00%', '99.00%', '100.00%'],
#  'Lucky Wind': ['1.00%', '99.00%'],
#  'Ludington': ['51.00%', '49.00%'],
#  'Ludlow Landfill': ['100.00%'],
#  'Luna Energy Facility': ['33.30%', '33.40%'],
#  'MCRD Parris Island PV': ['100.00%'],
#  'MEBA': ['100.00%'],
#  'MEPI GT Facility': ['100.00%', '80.00%', '20.00%'],
#  'MER Queens': ['100.00%'],
#  'MF Mesa Lane LLC': ['100.00%'],
#  'MPC Generating': ['100.00%'],
#  'Ma': ['100.00%'],
#  'MacArthur Waste to Energy Facility': ['100.00%'],
#  'Macho Springs': ['100.00%'],
#  'Macon Solar Power Project': ['100.00%'],
#  "Macy's MD Joppa Solar Project": ['100.00%'],
#  'Madera 1 PV': ['100.00%'],
#  'Madera Community Hospital': ['100.00%'],
#  'Magnolia Power Project': ['100.00%'],
#  'Mahoney Lake Hydroelectric': ['50.00%'],
#  'Main Canal Headworks': ['33.33%', '33.34%'],
#  'Majestic 1 Wind Farm': ['100.00%'],
#  'Malaga Power LLC': ['100.00%'],
#  'Malburg': ['100.00%'],
#  'Mammoth Pacific I': ['100.00%'],
#  'Mammoth Pacific II': ['100.00%'],
#  'Manchester Community College East': ['100.00%'],
#  'Manchester Community College North': ['100.00%'],
#  'Manning PV 1': ['100.00%'],
#  'Manzano Solar': ['100.00%'],
#  'Maple Ridge Wind Farm': ['50.00%'],
#  'March Point Cogeneration': ['100.00%'],
#  'Marcus Hook Energy LP': ['100.00%'],
#  'Marcus Hook Refinery Cogen': ['100.00%'],
#  'Maricopa West Solar PV, LLC': ['33.00%', '67.00%'],
#  'Market Farm': ['100.00%'],
#  'Marmas Solar CSG': ['100.00%'],
#  'Marsh Landing Generating Station': ['100.00%'],
#  'Marshall Solar Farm (MO)': ['100.00%'],
#  'Marshville Farm': ['79.00%', '21.00%'],
#  'Martin Creek Farm LLC': ['100.00%'],
#  'Martin Lake': ['100.00%'],
#  'Maryland Solar': ['100.00%'],
#  'Mascoma Hydro': ['100.00%'],
#  'Mashpee Landfill Solar': ['100.00%'],
#  'Maxim': ['100.00%'],
#  'Maywood Photovoltaic Project': ['100.00%'],
#  'McCallum Farm': ['100.00%'],
#  'McClain Energy Facility': ['23.00%', '77.00%'],
#  'McClellan (CA)': ['100.00%'],
#  'McKay Bay Facility': ['100.00%'],
#  'McKee Run': ['100.00%'],
#  'McKenzie Farm': ['1.00%', '99.00%'],
#  'McKittrick Limited': ['100.00%'],
#  'McNary Dam Fish Attraction Project': ['50.00%'],
#  'Meadow Lake Solar Energy Center': ['100.00%'],
#  'Meadow Solar': ['100.00%'],
#  'Medford DPC Solar': ['100.00%'],
#  'Medicine Bow': ['100.00%'],
#  'Mehoopany Wind Energy LLC': ['50.00%'],
#  'Meldahl Hydroelectric Project': ['48.60%', '51.40%'],
#  'Mendota Hills, LLC': ['100.00%'],
#  'Merced 1 PV': ['100.00%'],
#  'Meridian Vineyards': ['100.00%'],
#  'Mesa Wind Power Corp': ['100.00%'],
#  'Methuen Landfill': ['100.00%'],
#  'Metro Wastewater Reclamation District': ['100.00%'],
#  'Miami Fort': ['100.00%'],
#  'Michael Solar': ['100.00%'],
#  'Michigan Power LP': ['100.00%'],
#  'Micro Santa Clara': ['100.00%'],
#  'Mid-Georgia Cogeneration Facility': ['100.00%'],
#  'Mid-Set Cogeneration': ['100.00%'],
#  'Middle Daisy': ['100.00%'],
#  'Middle Falls Hydro': ['98.00%', '2.00%'],
#  'Midway Peaking LLC': ['100.00%'],
#  'Midway Solar - TX': ['100.00%'],
#  'Midway Sunset Cogen': ['50.00%'],
#  'Mile Farm': ['79.00%', '21.00%'],
#  'Milford Power LP': ['100.00%'],
#  'Milhurst Solar': ['100.00%'],
#  'Mill Pond Solar Farm, LLC': ['100.00%'],
#  'Mill Seat Renewable Energy Facility': ['100.00%'],
#  'Millbrook School': ['100.00%'],
#  'Millstone': ['4.80%', '93.47%', '1.73%'],
#  'Milton R Young': ['100.00%'],
#  'Minnesota River': ['100.00%'],
#  'Minwind 3-9': ['100.00%'],
#  'Miramar': ['100.00%'],
#  'Missouri Center for Waste to Energy': ['100.00%'],
#  'Mitchell (WV)': ['50.00%'],
#  'Moapa Southern Paiute': ['35.00%', '65.00%'],
#  'Mocksville Farm': ['100.00%'],
#  'Mohave': ['14.00%', '10.00%', '20.00%', '56.00%'],
#  'Moncure Farm LLC': ['100.00%'],
#  'Monterey Regional Water Pollution Contro': ['100.00%'],
#  'Montgomery County Oaks LFGE Plant': ['100.00%'],
#  'Montgomery County Resource Recovery': ['100.00%'],
#  'Monticello': ['100.00%'],
#  'Montpelier': ['5.22%',
#   '27.10%',
#   '14.32%',
#   '3.73%',
#   '7.46%',
#   '2.98%',
#   '4.29%',
#   '23.87%',
#   '5.81%'],
#  'Montrose Solar': ['100.00%'],
#  'Moore Solar Farm': ['79.00%', '21.00%'],
#  'Moorings Farm': ['79.00%', '21.00%'],
#  'Morelos del Sol': ['100.00%'],
#  'Morgan City': ['100.00%'],
#  'Morgan Creek': ['100.00%'],
#  'Morgan Solar Center': ['100.00%'],
#  'Morin Solar 2013 LLC': ['100.00%'],
#  'Morris Genco LLC': ['100.00%'],
#  'Mosinee Mill': ['100.00%'],
#  'Moulton Wind Power': ['100.00%'],
#  'Mount Olive Farm': ['100.00%'],
#  'Mount Tom': ['100.00%'],
#  'Mountain Home Energy Center': ['100.00%'],
#  'Mountain View I&2': ['100.00%'],
#  'Mountain View Solar': ['100.00%'],
#  'Mountain Wind Power II LLC': ['19.90%', '80.10%'],
#  'Mountain Wind Power LLC': ['19.90%', '80.10%'],
#  'Mt Olive Farm 2': ['100.00%'],
#  'Mt Olive Solar 1': ['100.00%'],
#  'Mt Poso Cogeneration': ['66.66%', '33.34%'],
#  'Mt. Hope DPC Solar': ['100.00%'],
#  'Mt. Jackson Solar': ['1.00%', '99.00%'],
#  'Muck Valley Hydroelectric': ['100.00%'],
#  'Mulberry Cogeneration Facility': ['100.00%'],
#  'Mulberry Farm LLC': ['33.00%', '67.00%'],
#  'NA 1(Hagerstown)': ['100.00%'],
#  'NAEA Lakewood LLC': ['100.00%'],
#  'NAEA Ocean Peaking Power LLC': ['100.00%'],
#  'NAFTA Region Olefins Complex Cogen Fac': ['40.00%', '60.00%'],
#  'NASA Johnson Space Center CHP': ['100.00%'],
#  'NCAH Central Utility Plant': ['100.00%'],
#  'NIH Cogeneration Facility': ['100.00%'],
#  'NVSS-II': ['100.00%'],
#  'NWP Indian Mesa Wind Farm': ['100.00%'],
#  'Nalco': ['100.00%'],
#  'Nantucket': ['100.00%'],
#  'Napoleon Peaking': ['5.22%',
#   '14.32%',
#   '7.46%',
#   '2.98%',
#   '23.87%',
#   '5.81%',
#   '35.12%'],
#  'Nash 58 Farm': ['100.00%'],
#  'Nash 64 Farm': ['100.00%'],
#  'Nassau Energy Corp': ['100.00%'],
#  'Navajo': ['7.50%',
#   '24.30%',
#   '14.00%',
#   '11.30%',
#   '21.70%',
#   '21.20%',
#   '42.90%'],
#  'Naval Air Weapons Station China Lake': ['100.00%'],
#  'Naval Station': ['100.00%'],
#  'Naval Station Energy Facility': ['100.00%'],
#  'Naval Training Center': ['100.00%'],
#  'Neal Hot Springs Geothermal Project': ['100.00%'],
#  'NedPower Mount Storm': ['50.00%'],
#  'Neenach Solar Center': ['100.00%'],
#  'Neil Simpson Gas Turbine #2': ['100.00%'],
#  'Nesvold Watertown Solar': ['100.00%'],
#  'Nevada Cogen Assoc#1 GarnetVly': ['50.00%'],
#  'Nevada Cogen Associates 2 Black Mountain': ['100.00%'],
#  'Neversink': ['100.00%'],
#  'New Auburn DPC Solar': ['100.00%'],
#  'New Bern Farm': ['79.00%', '21.00%'],
#  'New Haven Harbor': ['100.00%'],
#  'New Hogan Power Plant': ['100.00%'],
#  'New York State Dam Hydro': ['98.00%', '2.00%'],
#  'Newark Energy Center': ['100.00%'],
#  'Newgulf Cogen': ['100.00%'],
#  'Nine Mile Point Nuclear Station': ['41.01%',
#   '50.01%',
#   '49.99%',
#   '18.00%',
#   '40.99%'],
#  'Ninnescah Wind Energy, LLC': ['100.00%'],
#  'Nitro Solar': ['100.00%'],
#  'Noble Altona Windpark LLC': ['100.00%'],
#  'Noble Bliss Windpark LLC': ['100.00%'],
#  'Noble Chateaugay Windpark LLC': ['100.00%'],
#  'Noble Clinton Windpark LLC': ['100.00%'],
#  'Noble Ellenburg Windpark LLC': ['100.00%'],
#  'Noble Wethersfield Windpark LLC': ['100.00%'],
#  'Nobles 2 Wind Project': ['51.00%', '49.00%'],
#  'NorWest Energy 4, LLC': ['100.00%'],
#  'NorWest Energy 9 LLC': ['100.00%'],
#  'Nordhoff Place': ['100.00%'],
#  'North Anna': ['11.60%', '88.40%'],
#  'North Chicago Energy Center': ['100.00%'],
#  'North Island': ['100.00%'],
#  'North Jersey Media Group Solar Facility': ['100.00%'],
#  'North Lake': ['100.00%'],
#  'North Lancaster Ranch': ['100.00%'],
#  'North Palm Springs 1A': ['100.00%'],
#  'North Palm Springs 4A': ['100.00%'],
#  'North Smithfield Solar Power 1': ['100.00%'],
#  'North Star Solar': ['51.00%', '49.00%'],
#  'North Valmy': ['50.00%'],
#  'NorthPark Solar': ['100.00%'],
#  'Northern Lights Wind LLC': ['1.00%', '99.00%'],
#  'Norton Landfill Solar': ['100.00%'],
#  'Notrees Windpower': ['1.00%', '99.00%'],
#  'Novel - OYA of Mapleton': ['100.00%'],
#  'Novel OYA of Osakis': ['100.00%'],
#  'Nunn': ['100.00%'],
#  'OCI Alamo 4, LLC': ['50.00%'],
#  'OR Solar 2, LLC': ['100.00%'],
#  'Oak Creek Energy Systems I': ['100.00%'],
#  'Oak Point Cogen': ['100.00%'],
#  ...}

# %%
df['owner_2']
# Out:
# {'231 Dixon 74 Solar I, LLC': ['231 Dixon 74 Solar I, LLC'],
#  '2555 E Olympic Bl': ['Dependable Highway Express Inc'],
#  '4Oaks': ['Holocene Renewable Energy Fund 3, LLC'],
#  'AES Huntington Beach LLC': ['Edison Mission Energy'],
#  'AL Sandersville LLC': ['AL Sandersville'],
#  'AM Best Farm': ['Strata Solar Farms, LLC'],
#  'APG New Chesapeake': ['Solar Mission Sunstone US LLC'],
#  'APG Old Bayside': ['Solar Mission Sunstone US LLC'],
#  'APP Prune A-D': ['Apple, Inc'],
#  'AT&T Anaheim': ['Wells Fargo'],
#  'AT&T Holger': ['KeyBank'],
#  'ATT  Kelvin': ['KeyBank'],
#  'ATT Jericho': ['New York Community Bank'],
#  'ATT Van Nyus': ['Key Equipment Finance'],
#  'AVS Lancaster 1': ['Mound Solar Owner X, LLC'],
#  'Acadia Energy Center': ['Entergy Corp'],
#  'Acton Solar Landfill': ['Ameresco Solar Acton LLC'],
#  'Actus Lend Lease DMAFB': ['National Bank of Arizona'],
#  'Acushnet AD Makepeace': ['GLC-(CA) Edwards AFB,LLC'],
#  'Acushnet Ball Plant 2': ['Acushnet Company'],
#  'Acushnet Hawes Reed Road': ['GLC-(CA) Edwards AFB,LLC'],
#  'Acushnet- High Hill': ['GLC-(MA) Acushnet - High Hill, LLC'],
#  'Acushnet-Braley Road 1': ['GLC-(MA) Acushnet - Braley Road 1, LLC'],
#  'Adams Wind Generations LLC': ['BE Minnesota Wind Holdings LLC',
#   'Adams Wind Generations LLC'],
#  'Adobe San Jose': ['Adobe Systems Incorporated'],
#  'Adobe Solar': ['Southern Turner Renewable Energy'],
#  'Adrian Energy Associates LLC': ['DTE Biomass', 'LES Project Holdings LLC'],
#  'Advance Stores Company, Inc': ['Three Rivers Solar I, LLC'],
#  'Aerojet I': ['Master Tenant 2008-C LLC'],
#  'Aerojet II': ['Solar Tax Partners 2, LLC'],
#  'Agassiz Beach LLC': ['Northern Alternative Energy',
#   'Enel North America, Inc.'],
#  'Agawam Solar': ['Citizens Solar Holdings LLC'],
#  'Agua Caliente Solar Project': ['First Solar Project Development',
#   'MidAmerican Solar LLC',
#   'Agua Caliente Solar'],
#  'Agua Mansa Power Plant': ['City of Colton - (CA)'],
#  'Ahoskie': ['FLS 2015 Solar H, LLC'],
#  'Air Products Port Arthur': ['The Premcor Refining Group Inc'],
#  'Akron Recycle Energy Plant': ['City of Akron'],
#  'Alamo Solar': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'Alamogordo Solar Energy Center': ['Public Service Co of NM'],
#  'Albany Solar': ['Albany Solar, LLC'],
#  'Albuquerque Solar Energy Center': ['Public Service Co of NM'],
#  'Alethea I': ['The Joan Turnure 2010 Irrevocable Trust'],
#  'Algodones': ['Tri-State G & T Assn, Inc', 'Public Service Co of NM'],
#  'Allegheny Ridge Wind Farm': ['Allegheny Ridge Wind Farm LLC'],
#  'Alliant SBD 9901 Wells Fargo': ['Well Fargo'],
#  'Aloha Solar Energy Fund 1 PK1': ['Aloha Solar Energy Fund I LLC'],
#  'Alpaugh 50': ['Consolidated Edison Development Inc.',
#   'Fremont Energy Center'],
#  'Alpaugh North': ['Consolidated Edison Development Inc.',
#   'Fremont Energy Center'],
#  'Alta Wind Energy Center I': ['NRG Renew'],
#  'Alta Wind Energy Center II': ['NRG Renew'],
#  'Alta Wind Energy Center III': ['NRG Renew'],
#  'Alta Wind Energy Center IV': ['NRG Renew'],
#  'Alta Wind Energy Center V': ['NRG Renew'],
#  'Alta Wind VIII': ['Brookfield Renewable Energy Group'],
#  'Alta Wind X': ['NRG Renew'],
#  'Alta Wind XI': ['NRG Renew'],
#  'Altamont Midway Ltd': ['Biscoe Owner, LLC'],
#  'Amazon': ['380 Middlesex Solar LLC'],
#  'Amazon San Bernardino': ['Amazon'],
#  'American Legion PV 1': ['Fresh Air Energy XIX, LLC'],
#  'Amsterdam North': ['GenE Solar I LLC'],
#  'Amsterdam South': ['GenE Solar I LLC'],
#  'Anderson Farm LLC': ['Strata Solar, LLC'],
#  'Anderson Wind I': ['Anderson Wind Project, LLC'],
#  'Anderson Wind II': ['Anderson Wind Project, LLC'],
#  'Anheuser-Busch #2': ['Foundation CA Fund VII Owner, LLC'],
#  'Annandale Solar': ['Annandale Solar, LLC'],
#  'Anoka County MN CONX': ['SoCore 2018 ProjectCo-W26 LLC'],
#  'Anthony Wayne Solar #1': ['RL Solar', 'Dale Solar Investments', 'NLN LLC'],
#  'Apache Solar 1': ['Sierra Southwest Cooperative'],
#  'Apex Solar PV Power Project': ['Southern Turner Renewable Energy'],
#  'Apple Blossom Wind Farm': ['Sempra Renewables, LLC'],
#  'Aragonne Mesa Phase II': ['Aragonne Wind II LLC'],
#  'Aragonne Wind LLC': ['Aragonne Wind LLC'],
#  'ArcelorMittal Burns Harbor': ['ArcelorMittal USA Inc'],
#  'ArcelorMittal Indiana Harbor West': ['ArcelorMittal USA Inc',
#   'Ironside Energy, LLC'],
#  'Argus Cogen Plant': ['Karnavati Holdings Inc'],
#  'Arndt Farm': ['NC Renewable Investor 1, LLC'],
#  'Arrache 4006': ['CD US Solar PO 2 LLC'],
#  'Arrache 4013': ['CD US Solar PO 2 LLC'],
#  'Arrache 8083': ['CD US Solar PO 2 LLC'],
#  'Arthur Kill Generating Station': ['Arthur Kill Power LLC'],
#  'Arthur Solar, LLC': ['New Energy Solar'],
#  'Athens MN CONX': ['SoCore 2018 ProjectCo-W26 LLC'],
#  'Atlantic Coast Freezers Solar Facility': ['KDC Solar ACF LLC'],
#  'Atwater Solar': ['Atwater Solar, LLC'],
#  'Atwell Island': ['Atwell Solar Trust 2012'],
#  'Auburndale Peaker Energy Center': ['Auburndale Peaker Energy Center LLC'],
#  'Augusta Solar Farm': ['TGCOP Operating Hodings I, LLC'],
#  'Autumn Hills LLC': ['Northern Alternative Energy',
#   'Enel North America, Inc.'],
#  'Avalon Solar II': ['CRE-Avalon Arizona LLC', 'Firstar Development, LLC'],
#  'Azalea Solar, LLC': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'Aziscohos Hydroelectric Project': ['ARCO'],
#  "BJ's Wholesale Club Inc Dist Center": ['Three Rivers Solar I, LLC'],
#  "BJ's Wholesale Club, Inc- Uxbridge": ['Three Rivers Solar II, LLC'],
#  'BPU Solar Farm': ['MCP-KCBPU, LLC'],
#  'Bacliff': ['BTEC Turbines LP', 'Rockland Power Partners, LLC'],
#  'Baconton Power Plant': ['Sowega Energy Resources LLC',
#   'Tejas Power Generation LLC'],
#  'Badger Creek Limited': ['WGP Redwood Holdings, LLC'],
#  'Bailey Farm LLC': ['Strata Fund 11 Lessor LLC'],
#  'Baker City Solar': ['Enerparc Solar Development, LLC'],
#  'Baker PV 1': ['Fresh Air Energy XXII, LLC'],
#  'Bakerstand Solar (NY)': ['Empire Renewables, LLC'],
#  'Baldock Solar Highway': ['Banc of America Leasing & Capital LLC'],
#  'Baltimore Church Solar, LLC': ['Baltimore Church Solar, LLC'],
#  'Bandera Electric Coop PV': ['SoCore Bandera LLC'],
#  'Barker Solar, LLC': ['Barker Solar, LLC'],
#  'Barre': ['Barre Energy Partners LP'],
#  'Barrett Farm Solar - Phase I': ['Janus Solar Fund LP'],
#  'Barrett PV': ['BWC French River, LLC', 'BWC Stillwater River, LLC'],
#  'Barrow': ['North Slope Borough Power & Light'],
#  'Bartow Solar Energy LLC': ['ARE RP Bartow, LLC'],
#  'Basin Creek Plant': ['Maxim Power (USA) Inc',
#   'Basin Creek Power Services LLC'],
#  'Bath County': ['Virginia Electric & Power Co',
#   'First Energy Solutions Corp.'],
#  'Bay Windpower I': ['Crystal Flash Ltd'],
#  'BayWa r.e Mozart LLC': ['BayWa r.e. USA, LLC'],
#  'Bayonne MUA- Leitner-Poma Wind Turbine': ['Bayonne Municipal Utilities Authority'],
#  'Bayonne Plant Holding LLC': ['Bayonne Plant Holdings, LLC'],
#  'Bayou Cove Peaking Power': ['City of Alexandria - (LA)'],
#  'Bayshore Solar A, LLC': ['Bayshore Solar A LLC'],
#  'Bayshore Solar B, LLC': ['Bayshore Solar B LLC'],
#  'Bayshore Solar C, LLC': ['Bayshore Solar C LLC'],
#  "Bd of Educ of Queen Anne's Cnty, Cnty HS": ['Delmarva Power'],
#  'Bear Mountain Limited': ['WGP Redwood Holdings, LLC'],
#  'Bear Swamp': ['Bear Swamp Power Company LLC', 'Emera Inc'],
#  'Bearkat': ['Bearkat II TE Partnership LLC', 'Bearkat I TE Partnership LLC'],
#  'Beaver Run': ['Vitruvio Partners, LLC', 'Harmonyvale Energy, LLC'],
#  'Beaver Valley': ['FirstEnergy Nuclear Generation Corp'],
#  'Beecher Gas Recovery': ['31st Street Energy LLC'],
#  'Belchertown': ['BE MA Solar, LLC'],
#  'Belle River': ['Michigan Public Power Agency', 'DTE Electric Company'],
#  'Belleville Dam': ['City of Oberlin - (OH)',
#   'City of Napoleon - (OH)',
#   'City of Jackson - (OH)',
#   'City of Hudson - (OH)',
#   'Other',
#   'City of Cuyahoga Falls - (OH)',
#   'City of Bowling Green - (OH)',
#   'City of Bryan - (OH)',
#   'City of Niles - (OH)',
#   'City of Wadsworth - (OH)'],
#  'Bellevue Solar Project': ['enXco Development Corporation'],
#  'Belwood Farm': ['Strata Fund 3, LLC',
#   'Red Stone Renewable Energy Fund, LLC'],
#  'Benthall Bridge PV 1': ['Fresh Air Energy XXI, LLC'],
#  'Benton Falls Associates': ['Concord Hydro Associates',
#   'Essex Hydro Associates LLC'],
#  'BentonSun LLC': ['BentonSun, LLC'],
#  'Berkshire Power': ['Tenaska Energy, Inc.'],
#  'Berkshire Wind Power Project': ['Berkshire Wind Power Cooperative Corp'],
#  'Bethlehem Renewable Energy LLC': ['Exelon Generation Co LLC'],
#  'Big Cajun 2': ['Entergy Texas Inc.',
#   'Louisiana Generating LLC',
#   'Entergy Louisiana LLC'],
#  'Big George PV CSG': ['REDP Big George Solar, LLC'],
#  'Big Spring Wind Power Facility': ['Texas Big Spring, L.P.'],
#  'Big Stone': ['Montana-Dakota Utilities Co',
#   'Otter Tail Power Co',
#   'NorthWestern Energy - (SD)'],
#  'Biltmore Solar Fields': ['Biltmore Energy Company, LLC',
#   'Biltmore Natural Resources, LLC'],
#  'Birchwood Power': ['EFS Birchwood, LLC',
#   'TIFD III-T LLC',
#   'GESF Birchwood-GP LLC',
#   'J-POWER Birchwood LP',
#   'J-POWER Birchwood Power GP LLC'],
#  'Bisson Windfarm LLC': ['Custom Farm Systems'],
#  'Black River Hydro Associates': ['BT Capital', 'CHI Energy Inc'],
#  'Bladenboro Farm': ['Strata Master Lessee 1, LLC'],
#  'Blue Shld Of Cal- El Dorado Hlls Mtr B': ['Weisshorn Solar I, LLC'],
#  'Boardman': ['Idaho Power Co', 'Portland General Electric Co'],
#  'Bolton Farm': ['Strata Solar Farms, LLC'],
#  'Bonanza': ['Deseret Generation & Tran Coop', 'Utah Municipal Power Agency'],
#  'Bos Dairy, LLC': ['T & M Limited Partnership', 'T&M Limited Partnership'],
#  'Boulder Solar Power, LLC': ['SunPower Holding Company', 'Southern Power Co'],
#  'Bourne (MA) - Holliston I': ['SunE Solar XV Lessor, LLC'],
#  'Bowling Green Wind': ['OMEGA Joint Venture 6'],
#  'Boykin PV1': ['Fresh Air Energy XXXVIII, LLC'],
#  'Bradley Energy Center': ['Connecticut Airport Authority'],
#  'Bradley Lake': ['Alaska Energy Authority'],
#  'Bradley PV1': ['Fresh Air Energy IX LLC'],
#  'Brady': ['Brady Power Partners'],
#  'Brame Energy Center': ['Lafayette Utilities System',
#   'Cleco Power LLC',
#   'Louisiana Energy & Power Authority'],
#  'Brassua Hydroelectric Project': ['Brookfield Power New England',
#   'Eagle Creek Madison Hydro, LLC'],
#  'Bridgewater Complex Co-Generation Plant': ['Commonwealth of Massachusetts'],
#  'Bridgewater Power LP': ['Olympus Power', 'no name'],
#  'Broadalbin': ['GenE Solar I LLC'],
#  'Broadridge Cogen': ['WIM Core Portfolio Owner, LLC c/o Oak Street Real Estate Capital, LLC'],
#  'Broadridge Solar, LLC': ['Broadridge Solar, LLC'],
#  'Broadview Energy JN, LLC': ['Broadview Energy JN, LLC'],
#  'Broadview Energy KW, LLC': ['Broadview Energy KW, LLC'],
#  'Broadview Energy Prime 2 LLC': ['Brahms Wind, LLC'],
#  'Broadview Energy Prime LLC': ['Brahms Wind, LLC'],
#  'Broken Bow Wind LLC': ['Edison Mission Energy', 'NRG Energy, Inc'],
#  'Brookfield Solar 2013 LLC': ['Brookfield Solar 2013, LLC'],
#  'Brookfield Tehachapi 1': ['Brookfield Renewable Energy Group'],
#  'Brooklyn Navy Yard Cogeneration': ['Mission Energy of NY',
#   'B-41 Associates',
#   'Energy Investors Fund II LP'],
#  'Broome County': ['Dom Solar Lessor I, LP'],
#  'Brunswick Nuclear': ['North Carolina Eastern M P A',
#   'Duke Energy Progress - (NC)'],
#  'Brush Generation Facility': ['Bicent Power',
#   'Altagas Blythe Operations Inc.'],
#  'Brush Solar Center': ['Enerparc Solar Development, LLC'],
#  'Bryan Solar Field': ['Key Government Finance, Inc.'],
#  'Bryan Solar, LLC': ['Macquarie Infrastructure Company'],
#  'Buchanan Generation LLC': ['CONSOL Energy Inc',
#   'FirstEnergy Generation Corp',
#   'Buchanan Generation, LLC'],
#  'Buena Vista Energy LLC': ['Buena Vista Energy LLC'],
#  'Buffalo Ridge Windplant WPP 1993': ['NextEra Energy Resources'],
#  'Bulls Bridge': ['FirstLight Hydro Generating Company'],
#  'Burney Forest Products': ['Forest Product, L.P.',
#   'Burney Biomass Power LLC'],
#  'Busch Ranch Wind Energy Farm': ['Black Hills Electric Generation LLC',
#   'Black Hills Colorado Electric, LLC'],
#  'Butler Solar Power Project': ['MCP-Butler LP'],
#  'Buzzard Roost': ['Greenwood County'],
#  'Buzzard Roost GT': ['Greenwood County'],
#  'C D McIntosh Jr': ['Orlando Utilities Comm', 'City of Lakeland - (FL)'],
#  'CBS Television City': ['CBS Television City'],
#  'CDCR (CA) - Pleasant Valley State Prison': ['SunE Pleasant Valley SP Owner, LLC'],
#  'CE Leathers': ['CE Generation'],
#  'CE Turbo LLC': ['CE Generation'],
#  'CEIP Substation Distributed Generation': ['Hawthorne Power Systems'],
#  'CF Novel Solar CSG Gardens Eleven, LLC': ['CF Novel Solar Gardens Eleven LLC'],
#  'CF Novel Solar CSG Gardens Two, LLC': ['CF Novel Solar Gardens Two LLC'],
#  'CFW Solar X LLC - Vaughn': ['CFW Solar X LLC'],
#  'CG Windfarm LLC': ['Custom Farm Systems'],
#  'CID Solar, LLC': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'CII Methane Management III LFG Plant': ['Athens-Johnston Renewables, LLC'],
#  'CII Methane Management IV, LLC': ['Athens-Johnston Renewables, LLC'],
#  'CMEEC - Bozrah': ['Dom Solar Lessor I, LP'],
#  'CMEEC - Navy NE Trident': ['Dom Solar Lessor I, LP'],
#  'CMEEC - Norwich Stott St Solar': ['Dom Solar Lessor I, LP'],
#  'CMEEC - Polaris Park Solar': ['Dom Solar Lessor I, LP'],
#  'COC Surry LFG, LLC': ['Cary Oil Company'],
#  'CSD 2 - Heritage High': ['GLC-(CA) CSD 2, LLC'],
#  'CSD 2- Freedom High': ['GLC-(CA) CSD 2, LLC'],
#  'CSUF Nutwood Solar': ['Wells Fargo Equipment Finance Inc'],
#  'CSUF State College': ['Wells Fargo Equipment Finance Inc'],
#  'CT Resource Rec Authority Facility': ['Materials Innovation Recycling Authority'],
#  'CTV Power Purchase Contract Trust': ['Coram Energy, LLC',
#   'CTV Marketing Group'],
#  'Cabazon Wind Partners': ['Terra-Gen California Wind Holdings LLC',
#   'Shell Wind Energy Inc.'],
#  'CalPeak Power Border Peaker Plant': ['CalPeak Power - Border LLC'],
#  'CalPeak Power Enterprise Peaker Plant': ['CalPeak Power - Enterprise LLC'],
#  'CalPeak Power Panoche Peaker Plant': ['CalPeak Power - Panoche LLC'],
#  'CalPeak Power Vaca Dixon Peaker Plant': ['CalPeak Power - Vaca Dixon LLC'],
#  'Caledonia': ['GE Energy Financial Services'],
#  'Calhoun Energy Center': ['Harbert Power Fund V'],
#  'California Valley Solar Ranch': ['High Plains Ranch II, LLC'],
#  'Calipatria Solar Farm': ['Southern Turner Renewable Energy'],
#  'Calumet Energy Team LLC': ['Engie North America'],
#  'Calvert Cliffs Nuclear Power Plant': ['Exelon Nuclear',
#   'Electricity de France'],
#  'Cambria Cogen': ['Northern Star Generation Services Co LLC'],
#  'Camden Plant Holdings LLC': ['Camden Plant Holdings, L.L.C.'],
#  'Cameron Ridge LLC': ['Cameron Ridge LLC'],
#  'Camp Far West': ['South Sutter Water District'],
#  'Campo Verde Solar': ['Southern Turner Renewable Energy'],
#  'Canadian Hills Wind': ['Apex Wind Energy Holdings, LLC',
#   'Atlantic Power Corporation'],
#  'Cane Island': ['Florida Municipal Power Agency',
#   'Kissimmee Utility Authority'],
#  'Cane Run': ['Louisville Gas & Electric Co', 'Kentucky Utilities Co'],
#  'Canyon Power Plant': ['Southern California P P A'],
#  'Caprock Wind Farm': ['Caprock wind LLC'],
#  'Cardinal': ['Buckeye Power, Inc', 'AEP Generation Resources Inc'],
#  'Carlsbad Energy Center': ['Carlsbad Energy Center LLC'],
#  'Carr Street Generating Station': ['BRASCAN Power Corporation'],
#  'Carrizozo Solar': ['SoCore 2017 ProjectCo-NM6 LLC'],
#  'Carson Cogeneration': ['CMD Carson GP LLC', 'CMD Carson LLC'],
#  'Carson Ice-Gen Project': ['Central Valley Financing Auth'],
#  'Carson Solar I': ['MS Greenrock, LLC'],
#  'Carstensen Wind': ['JDR Holdings LLC', 'Carstensen Wind LLC'],
#  'Carter PV1': ['Fresh Air Energy XIV LLC'],
#  'Cashton Greens Wind Farm': ['GL Envision LLC', 'CROPP Cooperative'],
#  'Castle Rock': ['Wisconsin Public Service Corp',
#   'Wisconsin Power & Light Co'],
#  'Castleton Energy Center': ['Castleton Energy Center'],
#  'Castor Solar': ['GL Castor I, LLC'],
#  'Catalina Solar 2, LLC': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'Catawba': ['Piedmont Municipal Power Agny',
#   'North Carolina El Member Corp',
#   'Duke Energy Carolinas, LLC',
#   'North Carolina Mun Power Agny #1'],
#  'Causey': ['U S Bureau of Reclamation'],
#  'Cedar Bayou 4': ['NRG Cedar Bayou Development Company LLC',
#   'Optim Energy Cedar Bayou 4 LLC'],
#  'Cedar Creek II': ['BP Wind Energy North America Inc', 'Sempra Generation'],
#  'Cedar Creek Wind': ['Cedar Creek Wind Energy LLC'],
#  'Cedarville CSG': ['Cedarville Solar Phase II, LLC',
#   'Cedarville Solar III, LLC',
#   'REDP Cedarville Solar I LLC'],
#  'Cedro Hill Wind LLC': ['Edison Mission Energy', 'NRG Energy, Inc'],
#  'Celanese Acetate LLC': ['Celanese Acetate Corp'],
#  'Central Antelope Dry Ranch C': ['Central Antelope Dry Ranch C LLC'],
#  'Chadbourn Farm': ['Strata Fund 4, LLC'],
#  'Chalk Cliff Limited': ['WGP Redwood Holdings, LLC'],
#  'Chambers Cogeneration LP': ['Chambers Cogeneration LP'],
#  'Champepaden Wind Power': ['Champepadan Wind Power Partners, LLC'],
#  'Chandler Hills Wind Farm': ['Caithness Energy'],
#  'Channel Energy Center LLC': ['Calpine Corp'],
#  'Channelview Cogeneration Plant': ['EIF CV Holdings, LLC'],
#  'Chauncey Farm LLC': ['Strata Fund 17 Lessor'],
#  'Chautauqua LFGTE Facility': ['Chautauqua County'],
#  'Cherokee Falls': ['Cherokee Falls Hydroelectric Project, LLC'],
#  'Chesapeake College': ['Solar Integrated Fund IV-A, LLC'],
#  'Cheyenne Prairie Generating Station': ['Cheyenne Light Fuel & Power d/b/a Black Hills Energy',
#   'Black Hills Power, Inc. d/b/a',
#   'no name'],
#  'Chicago West Side Energy Center': ['Amalgamated Bank of Chicago'],
#  'Chicopee Granby Road Solar': ['Citizens Solar Holdings III, LLC'],
#  'Chicopee River Solar': ['Citizens Solar Holdings III, LLC'],
#  'Chicopee Solar': ['Citizens Solar Holdings II MA, LLC'],
#  'Chillicothe Solar Farm': ['MCP-Chillicothe, LLC'],
#  'China Mill Hydro': ['Perfect Fit Industries LLC'],
#  'Chisago Solar': ['Chisago Solar, LLC'],
#  'Cholla': ['PacifiCorp'],
#  'Church Road Solar LLC': ['New Energy Solar'],
#  'Cibola': ['Public Service Co of NM'],
#  'Cimarron River': ['Mid-Kansas Electric Company Inc.'],
#  'Cimarron Solar Facility': ['Southern Turner Renewable Energy'],
#  'Cimarron Windpower II': ['DEGS Wind 1 LLC',
#   'Sumitomo Corporation of America'],
#  'Citizens Agawam Landfill Solar': ['Citizens Solar Holdings V, LLC'],
#  'City of Boulder WWTP': ['WF-SE-I Solar Statutory Trust'],
#  'City of Soledad Water Reclamation': ['Foundation CA Fund VII Owner, LLC'],
#  'Clay Boswell': ['WPPI Energy', 'ALLETE, Inc.'],
#  'Cleary Flood': ['City of Taunton',
#   'Town of Hudson - (MA)',
#   'Town of North Attleborough - (MA)'],
#  'Clif Bar Bakery of Twin Falls': ['Clif Bar Bakery of Twinn Falls, LLC'],
#  'Clifton': ['Mid-Kansas Electric Company Inc.'],
#  'Clinton LFGTE Facility': ['Casella Waste Systems'],
#  'Clover': ['Virginia Electric & Power Co', 'Old Dominion Electric Coop'],
#  'CoServ Community Solar Station': ['Renewable Energy Alternatives, LLC'],
#  'Coalinga Cogeneration Facility': ['AERA Energy LLC'],
#  'Cobble Mountain': ['Springfield Water & Sewer Comm'],
#  'Cogentrix of Alamosa': ['Kepco Alamosa, LLC'],
#  'Coleto Creek': ['Luminant Generation Company LLC'],
#  'Collierville Powerhouse': ['Calaveras County Water Dist'],
#  'Colon PV': ['Colon FiT LLC'],
#  'Colorado Green Holdings LLC': ['Avangrid Renewables LLC',
#   'Shell Wind Energy Inc.'],
#  'Colstrip': ['Puget Sound Energy Inc',
#   'Talen Montana LLC',
#   'Avista Corp',
#   'Portland General Electric Co',
#   'PacifiCorp',
#   'NorthWestern Energy'],
#  'Columbia (WI)': ['Madison Gas & Electric Co',
#   'Wisconsin Public Service Corp',
#   'Wisconsin Power & Light Co'],
#  'Columbia Canal Hydro': ['City of Columbia SC'],
#  'Colver Power Project': ['TIFD VIII-W Inc'],
#  'Comanche (CO)': ['Public Service Co of Colorado',
#   'Intermountain Rural Elec Assn',
#   'Holy Cross Electric Assn, Inc'],
#  'Comanche Peak': ['Comanche Peak Power Co, LLC'],
#  'Comanche Solar': ['Comanche Solar PV, LLC'],
#  'Commerce Refuse To Energy': ['Los Angeles County Sanitation',
#   'Los Angeles County'],
#  'Commonwealth Chesapeake': ['Tyr Energy, Inc'],
#  'Community Wind North LLC': ['Norgard 1', 'NRG Energy, Inc'],
#  'Concord Blue Eagar, LLC': ['Concord Blue Development, LLC',
#   'Western Energy Solutions, LLC'],
#  'Conemaugh': ['Montour LLC',
#   'PSEG Fossil LLC',
#   'Chief Conemaugh Power LLC',
#   'UGI Development Co',
#   'Conemaugh Power LLC',
#   'Conemaugh Power Pass-Through Holders LLC'],
#  'Conemaugh Hydro Plant': ['NRR Conemaugh LP', 'Conemaugh Hydro Station'],
#  'Conesville': ['Dynegy',
#   'Dayton Power & Light Co',
#   'AEP Generation Resources Inc'],
#  'Conn Mun Electric Energy Coop': ['Dom Solar Lessor I, LP'],
#  'Conrath DPC Solar': ['SoCore 2016 ProjectCo-W1 LLC'],
#  'Coram Energy LLC': ['CTV Marketing Group', 'Coram Energy, LLC'],
#  'Coram Energy LLC (ECT)': ['Coram Energy, LLC'],
#  'Corcoran Solar': ['Consolidated Edison Development Inc.',
#   'Fremont Energy Center'],
#  'Corning Pharmaceutical Glass': ['KDC Solar GG LLC'],
#  'Corona Energy Partners, Ltd': ['WGP Redwood Holdings, LLC'],
#  'Cosumnes': ['Sacramento Financing Authority'],
#  'Cottonwood Solar, LLC (City of Corcoran)': ['SunEdison LLC',
#   'Dominion Renewable Energy'],
#  'Cottonwood Solar, LLC (Goose Lake)': ['SunEdison LLC',
#   'Dominion Renewable Energy'],
#  'Cottonwood Solar, LLC Cottonwood Carport': ['SunEdison LLC',
#   'Dominion Renewable Energy'],
#  'County Home Solar LLC': ['New Energy Solar'],
#  'Countyside Genco LLC': ['Biogas Energy Solutions'],
#  'Covanta Hennepin Energy': ['Hennepin County Department of Environmental Services'],
#  'Covanta Mendota': ['Covanta Energy Inc'],
#  'Covanta Tulsa Renewable Energy LLC': ['Walter B Hall Resource Recovery Facility'],
#  'Coventry Photovoltaic, LLC': ['Coventry Photovoltaic, LLC'],
#  'Coyote': ['NorthWestern Energy - (SD)',
#   'Montana-Dakota Utilities Co',
#   'Otter Tail Power Co',
#   'Minnkota Power Coop, Inc'],
#  'Craig (CO)': ['Platte River Power Authority',
#   'Public Service Co of Colorado',
#   'Tri-State G & T Assn, Inc',
#   'PacifiCorp',
#   'Salt River Project'],
#  'Cranberry Point Energy Storage': ['Enel Energy Storage Holdings LLC'],
#  'Craven County Wood Energy LP': ['AltaGas Renewable Energy CO LLC',
#   'CMS Generation MI Power LLC'],
#  'Crescent Ridge': ['Crescent Ridge LLC'],
#  'Crescent Ridge II Wind Energy Project': ['Babcock & Brown Renewable Holdings Inc'],
#  'Cricket Valley Energy': ['Cricket Valley Energy Holdings LLC'],
#  'Crockett Cogen Project': ['Pacific Crockett Energy Inc',
#   'ENI Crockett Ltd',
#   'OGPA Crockett  LLC'],
#  'Crofton Bluffs Wind LLC': ['Edison Mission Energy', 'NRG Energy, Inc'],
#  'Crooked Run': ['Cubico USA, LLC'],
#  'Crosswind Energy Project': ['NRG Energy, Inc', 'Other'],
#  'Crystal River': ['Several Municipals and Coops',
#   'Duke Energy Florida, LLC',
#   'Seminole Electric Cooperative Inc',
#   'Orlando Utilities Comm'],
#  'Cumberland County Solid Waste Complex': ['PPL New Jersey Biogas LLC'],
#  'Curtis H Stanton Energy Center': ['Orlando Utilities Comm',
#   'Kissimmee Utility Authority',
#   'Florida Municipal Power Agency',
#   'Southern Energy Co',
#   'Stanton Clean Energy LLC '],
#  'DDR Shoppers World': ['SW MA Solar, LLC'],
#  'DOE Golden NREL Main Campus': ['Sun Edison',
#   'Longroad Energy Services LLC',
#   'Radian Generation'],
#  'DOE Golden NWTC Load Side': ['Radian Generation'],
#  'DOE Golden NWTC Turbine Side': ['Siemens Corp.',
#   'Alstom Power, Inc. c/o GE Renewable Energy'],
#  'DSH (CA) - Coalinga State Hospital': ['SunE Coalinga SH Owner, LLC'],
#  'Dairyland WTE Plant': ['WTE-Dairyland, LLC'],
#  'Dakota Solar': ['SoCore 2016 ProjectCo-W1 LLC'],
#  'Daniel Farm LLC': ['Strata RS Solar Holding Fund 3 LLC'],
#  'Danielson Wind Farms LLC': ['BE Minnesota Wind Holdings LLC',
#   'Danielson Wind Farms LLC'],
#  'Darby Power, LLC': ['Lightstone Generation LLC'],
#  'Dartmouth Landfill': ['GLC-(MA) Dartmouth, LLC'],
#  'Dartmouth Power Associates LP': ['Dartmouth Power Associates LP'],
#  'Davis Besse': ['FirstEnergy Nuclear Generation Corp'],
#  'DeCordova Steam Electric Station': ['DeCordova Power Company LLC',
#   'DeCordova ll Power Company LLC',
#   'Luminant Generation Company LLC'],
#  'Del Ranch Company': ['CE Generation'],
#  'Delano Energy Center': ['California Holdings Delano LLC',
#   'California Holdings Delano 2 LLC'],
#  'Deming Solar Energy Center': ['Public Service Co of NM'],
#  'Denver Intl Airport IV Solar': ['SH COD I, LLC'],
#  'Des Plaines Gas Recovery': ['31st Street Energy LLC'],
#  'Desert Peak Power Plant': ['ORNI 3 LLC', 'Brady Power Partners'],
#  'Desert Sunlight 250, LLC': ['Sumitomo Corporation of America',
#   'NRG Yield LLC',
#   'NextEra Energy Resources',
#   'CalPERS',
#   'NextEra Energy Partners LP',
#   'Harbert Power Fund V',
#   'NextEra Energy Desert Sunlight 250, LLC'],
#  'Desert Sunlight 300, LLC': ['Sumitomo Corporation of America',
#   'NextEra Energy Resources',
#   'General Electric Capital Corp',
#   'NextEra Energy Partners LP',
#   'NRG Yield LLC',
#   'Harbert Power Fund V'],
#  'Dibrell Farm': ['Strata Solar Development, LLC'],
#  'Dickinson Solar Array': ['Farm Credit Leasing Service Corp'],
#  'Digital Fairfield': ['Wells Fargo Equipment Finance Inc'],
#  'Dinuba Wastewater Treatment Plant': ['PNC Energy Capital LLC'],
#  'Disney Prospect': ['The Walt Disney Company'],
#  'Division': ['NRG Energy, Inc'],
#  'Division 1': ['Mound Solar Owner VII, LLC'],
#  'Division 2': ['Mound Solar Owner VII, LLC'],
#  'Division 3': ['Mound Solar Owner VII, LLC'],
#  'Dodge Center Solar': ['Dodge Center Distributed Solar, LLC'],
#  'DodgeSun CSG': ['Nordic Solar, LLC'],
#  'Dogwood Energy Facility': ['Dogwood Energy LLC',
#   'Missouri Jnt Muni.Pwr Elec. Ut. Comm.',
#   'Kansas Power Pool',
#   'City of Independence - (MO)',
#   'City of Kansas City - (KS)',
#   'Kansas Municipal Energy Agency'],
#  'Dolet Hills': ['Northeast Texas Elec Coop, Inc',
#   'Southwestern Electric Power Co',
#   'Oklahoma Municipal Power Authority',
#   'Cleco Power LLC'],
#  'Dominion/Lo Mar': ['City of Manassas - (VA)', 'City of Harrisonburg - (VA)'],
#  'Don Pedro': ['Turlock Irrigation District', 'Modesto Irrigation District'],
#  'Double C Generation Limited Partnership': ['WGP Redwood Holdings, LLC'],
#  'Dougherty County Solar, LLC': ['Quitman Solar, LLC'],
#  'Dover Peaking': ['City of Wadsworth - (OH)',
#   'City of Galion',
#   'City of Hamilton - (OH)',
#   'City of Amherst- (OH)',
#   'City of Bowie - (TX)',
#   'Other',
#   'City of Cuyahoga Falls - (OH)',
#   'City of Dover - (OH)',
#   'City of Painesville',
#   'City of St Marys - (OH)'],
#  'Downs Farm Solar': ['FLS 2014 Solar B, LLC'],
#  'Downsville DPC Solar': ['SoCore 2016 ProjectCo-W2 LLC'],
#  'Dry Fork Station': ['Basin Electric Power Coop',
#   'Wyoming Municipal Power Agency'],
#  'Duane Arnold Energy Center': ['Central Iowa Power Cooperative',
#   'NextEra Energy Duane Arnold LLC',
#   'Corn Belt Power Coop'],
#  'Duanesburg': ['GenE Solar I LLC'],
#  'Dunbarton Energy Partners LP': ['Dunbarton Energy Partners LP'],
#  'Dunkirk Generating Plant': ['NRG Energy, Inc'],
#  'Dunn': ['FLS Operations, LLC', 'Nationwide Life Insurance Company'],
#  'Duplin Solar I LLC (160 Houston Lane)': ['Duplin Solar I, LLC'],
#  'Dyer Road': ['New Dimension Energy Company, LLC'],
#  'E C Gaston': ['Alabama Power Co', 'Georgia Power Co'],
#  'E Nash PV1': ['Fresh Air Energy XXIII, LLC'],
#  'E W Brown': ['Louisville Gas & Electric Co', 'Kentucky Utilities Co'],
#  'EAFB - North Base': ['GLC-(CA) Edwards AFB,LLC'],
#  'EAFB - South Base': ['GLC-(CA) Edwards AFB,LLC'],
#  'EBZ Solar': ['Citizens Solar Holdings LLC'],
#  'EDF Renewable Windfarm V Inc': ['EDF Renewable Windfarm V, Inc'],
#  'EGP Stillwater Solar PV II, LLC': ['Enel Green Power NA, Inc.'],
#  'ESI Project': ['New Dimension Energy Company, LLC'],
#  'ESS Fairgrounds': ['ESS Fairgrounds Project, LLC'],
#  'ESS Lewes': ['ESS Lewes Project, LLC'],
#  'ESS Wesel': ['ESS Wesel Project, LLC'],
#  'ETS Ewing Solar Facility': ['Wells Fargo Equipment Finance Inc'],
#  'Eagle Mountain': ['Luminant Gen Co LLC Fin Holding',
#   'Luminant Generation Company LLC',
#   'Eagle Mountain Power Company LLC'],
#  'Eagle Point Power Generation': ['Rockland Power Partners, LLC'],
#  'Earl F Wisdom': ['Basin Electric Power Coop', 'Corn Belt Power Coop'],
#  'East Wayne Solar LLC': ['Strata Master Lessee 1, LLC'],
#  'Eastern Iowa Solar': ['Farm Credit Leasing Service Corp'],
#  'Eastern Landfill Gas LLC': ['Exelon Generation Co LLC'],
#  'Easthampton Landfill-City of Easthampton': ['GLC-(MA) Easthampton, LLC'],
#  'Easton Landfill': ['GLC-(MA) Easton, LLC'],
#  'Eastwood Solar': ['Eastwood Solar, LLC'],
#  'Ebensburg Power': ['Ebensburg Generation, LLC',
#   'Revloc Reclamation Service, Inc.'],
#  'Ecogen Wind': ['Ecogen Wind LLC'],
#  'Edgecombe Genco LLC': ['Edgecombe Manager LLC', 'Energy Investment Fund'],
#  'Edgerton': ['City of Wadsworth - (OH)',
#   'City of Galion',
#   'City of Hamilton - (OH)',
#   'City of Amherst- (OH)',
#   'City of Bowie - (TX)',
#   'Other',
#   'City of Cuyahoga Falls - (OH)',
#   'City of Dover - (OH)',
#   'City of Painesville',
#   'City of St Marys - (OH)'],
#  'Edgewater': ['Wisconsin Public Service Corp', 'Wisconsin Power & Light Co'],
#  'Edom Hills Project 1 LLC': ['BP Wind Energy North America Inc'],
#  'Edwards Air Force Base': ['GLC-(CA) Edwards AFB,LLC'],
#  'Edwin I Hatch': ['Municipal Electric Authority',
#   'Georgia Power Co',
#   'Dalton Utilities',
#   'Oglethorpe Power Corporation'],
#  'Effingham County Power Project': ['Effingham County Power, LLC'],
#  'Eklutna Hydro Project': ['Anchorage Municipal Light and Power',
#   'Chugach Electric Assn Inc',
#   'Matanuska Electric Assn Inc'],
#  'El Cajon': ['NRG Energy, Inc'],
#  'El Dorado Springs Solar Farm': ['MCP-El Dorado Springs, LLC'],
#  'El Paso Wind Project': ['El Paso Wind LLC'],
#  'El Segundo Cogen': ['Chevron USA Inc'],
#  'El Segundo Energy Center LLC': ['NRG Energy, Inc', 'NRG Yield LLC'],
#  'El Segundo Power': ['NRG Energy, Inc'],
#  'Elevation Solar C': ['Elevation Solar C'],
#  'Elk Basin Gasoline Plant': ['Vanguard Natural Resources LLC',
#   'ExxonMobil Oil Corp'],
#  'Elk Hills Power LLC': ['California Resources Elk Hills LLC'],
#  'Elk Wind Farm': ['RPG Elk/Hawkeye Investco, LLC', 'RPMA Wind Holding II'],
#  'Elkhorn Ridge Wind LLC': ['Tenaska Elkhorn Ridge I LLC',
#   'Tenaska Elkhorn Ridge II LLC',
#   'NRG Energy, Inc',
#   'Tenaska Elkhorn Ridge III LLC'],
#  'Elm Road Generating Station': ['Madison Gas & Electric Co',
#   'We Power',
#   'WPPI Energy'],
#  'Elmore Company': ['CE Generation'],
#  'Elmwood Park Power LLC': ['Elmwood Park Power, L.L.C.'],
#  'Eltopia Branch Canal 4.6': ['Quincy-Columbia Basin Irr Dist',
#   'South Columbia Basin Irr Dist',
#   'East Columbia Basin Irr Dist'],
#  'Elwood Energy LLC': ['J Power USA Development Co Ltd'],
#  'Encina': ['NRG Energy, Inc'],
#  'Enerparc CA1 LLC': ['PNC Energy Capital LLC'],
#  'Enterprise Products Operating': ['Enterprise Products Optg LP',
#   'Phillips 66 Company',
#   'DCP NGL Services'],
#  'Equinix San Jose': ['Equinix'],
#  'Equus Freeport Power': ['J Power USA Development Co Ltd'],
#  'Erwin Farm': ['Strata Solar Farms 2 LLC'],
#  'Escondido Energy Center': ['MMC Escondido LLC'],
#  'Estrella Mountain PV': ['Dom Solar Lessor I, LP'],
#  'Eubank Landfill Solar Array': ['Emcore Solar New Mexico, LLC'],
#  'Everett PV1': ['Whitehurst PV1, LLC'],
#  'Evergreen Community Power': ['Interstate Resources, Inc.'],
#  'Ewa Nui Substation DG': ['Hawthorne Power Systems'],
#  'Exeter Energy LP': ['ReEnergy Holdings LLC'],
#  'FC Landfill Energy': ['DCO Energy LLC'],
#  'FGE Texas II': ['FGE Power, LLC'],
#  'FLEX Gibraltar': ['KeyBank'],
#  'FLS Solar 230 (Warren)': ['FLS 2014 Solar D, LLC'],
#  'Facile Solar': ['Indigo Solar'],
#  'Fairfield Wind': ['Fairfield Wind Owner, LLC'],
#  'Fairhaven Power': ['EWP RENEWABLE CORP.'],
#  'Falls Creek': ['Frontier Technology Inc', 'Gary P Marcus'],
#  'Falls Village': ['FirstLight Hydro Generating Company'],
#  'Falmouth Landfill Solar': ['Citizens Solar Holdings V, LLC'],
#  'Farmington Solar Farm': ['MCP-Farmington, LLC'],
#  'Farrington Farm': ['NC Renewable Investor 1, LLC', 'Strata Fund 1, LLC'],
#  'Fayette Power Project': ['Lower Colorado River Authority', 'Austin Energy'],
#  'Felton CSG PV1-5': ['Felton Farms CSG 1, LLC'],
#  'Fife Brook': ['Bear Swamp Power Company LLC', 'Emera Inc'],
#  'Findlay Wind Farm': ['One Energy Capital LLC',
#   'Todd A.Stoller Living Trust'],
#  'Fire Island Wind': ['Cook Inlet Region, Inc.'],
#  'FirstEnergy Acme': ['The Toledo Edison Co'],
#  'FirstEnergy Ashtabula': ['Cleveland Electric Illum Co'],
#  'FirstEnergy Bay Shore': ['Orca Acquisitions, LLC'],
#  'FirstEnergy Harrison Power Station': ['Monongahela Power Co'],
#  'FirstEnergy Pleasants Power Station': ['FirstEnergy Generation Corp'],
#  'FirstEnergy R E Burger': ['Ohio Edison Co'],
#  'FirstEnergy Toronto': ['Ohio Edison Co'],
#  'Flat Meeks PV 1': ['Flat Meeks PV1, LLC'],
#  'Flat Ridge 2 Wind Energy LLC': ['BP Wind Energy North America Inc',
#   'Sempra Generation'],
#  'Flat Ridge Wind Energy LLC': ['BP Wind Energy North America Inc'],
#  'Flint Creek': ['Arkansas Electric Coop Corp',
#   'Southwestern Electric Power Co'],
#  'Florence Hills LLC': ['Northern Alternative Energy',
#   'Enel North America, Inc.'],
#  'Foote Creek I': ['Eugene Water & Electric Board', 'PacifiCorp'],
#  'Foote Creek III': ['Cinergy Power Generation Serv'],
#  'Foothill Solar Project': ['Foothill Solar LLC'],
#  'Forever 21 Retail, Inc.': ['3880 North Mission Road Solar LLC'],
#  'Fort Dodge': ['Mid-Kansas Electric Company Inc.'],
#  'Fortistar North Tonawanda': ['Fortistar LLC'],
#  'Foster Wheeler Martinez': ['BRE Partner - BRE',
#   'Foster Wheeler Power Sys Inc',
#   'Foster Wheeler Martinez Inc'],
#  'Foundation Cemex BMQ': ['Foundation CA Fund VI Owner, LLC'],
#  'Foundation Cemex Madison': ['Foundation CA Fund V Owner, LLC'],
#  'Foundation Cemex River Plant': ['Foundation CA Fund VI Owner, LLC'],
#  'Foundation NWNA': ['Foundation CA Fund V Owner, LLC'],
#  'Foundation RRM': ['Foundation CA Fund V Owner, LLC'],
#  'Foundation Superior Farms': ['Foundation CA Fund VI Owner, LLC'],
#  'Foundation Wal-Mart Red Bluff': ['Foundation CA Fund VI Owner, LLC'],
#  'Four Corners': ['Arizona Public Service Co',
#   'Tucson Electric Power Co',
#   'Salt River Project',
#   'Public Service Co of NM',
#   'El Paso Electric Co',
#   '4C Acquisition, LLC'],
#  'Four Peaks Camino Real': ['Four Peaks Energy LLC', 'Four Peaks Energy Inc'],
#  'Fourth Branch Hydroelectric Facility': ['Adirondack Hydro-Fourth Branch LLC'],
#  'Fowler Ridge IV Wind Farm LLC': ['Fowler Ridge Wind LLC'],
#  'Fowler Ridge Wind Farm LLC': ['Dominion Fowler Ridge Wind LLC',
#   'Fowler Ridge Holdings LLC',
#   'BP Wind Energy North America Inc',
#   'Sempra Generation'],
#  'Fox Island Wind LLC': ['Fox Islands Electric Coop, Inc'],
#  'Foxtail Wind, LLC': ['Northern States Power Co - Minnesota'],
#  'Frankenheimer Power Plant': ['South San Joaquin Irr District'],
#  'Franklin Templeton San Mateo': ['Franklin Templeton Companies LLC'],
#  'Frederickson Power LP': ['Puget Sound Energy Inc',
#   'Atlantic Power Corporation'],
#  'Freeport Energy Center': ['Calpine Corp'],
#  'Freestone Energy Center': ['Freestone Power Generation LLC',
#   'Rayburn Country Elec Coop, Inc'],
#  'Fremont Farm': ['Strata Solar, LLC'],
#  'Fresno Cogen Partners': ['Fresno Power Investors LP', 'Fresno Cogen Inc'],
#  'Frontier HS Solar Project': ['126 Grove Solar LLC'],
#  'G&S Wantage Solar LLC': ['SunRay Power LLC', 'Centaurus Holdings, LLC'],
#  'GKS Solar': ['FLS 2014 Solar B, LLC'],
#  'GL Wind': ['GL Envision LLC', 'ALM Holding Company'],
#  'GM Lordstown Assembly Solar Array': ['General Motors Corp-Warren'],
#  'GMP Solar - Hartford': ['GMP VT Solar LLC'],
#  'GMP Solar - Panton': ['GMP VT Solar LLC', 'GMP VT Microgrid LLC'],
#  'GMP Solar - Richmond': ['GMP VT Solar LLC'],
#  'GMP Solar - Williamstown': ['GMP VT Solar LLC'],
#  'GMP Solar - Williston': ['GMP VT Solar LLC'],
#  'GMP Solar/Storage-Essex': ['GMP VT Microgrid LLC'],
#  'GMP Solar/Storage-Ferrisburgh': ['GMP VT Microgrid LLC'],
#  'GMP Solar/Storage-Milton': ['GMP VT Microgrid LLC'],
#  'GRE Marshan Solar': ['SoCore 2016 ProjectCo-W1 LLC'],
#  'GSG LLC': ['GSG LLC'],
#  'Galion': ['City of Wadsworth - (OH)',
#   'City of Galion',
#   'City of Hamilton - (OH)',
#   'City of Amherst- (OH)',
#   'City of Bowie - (TX)',
#   'Other',
#   'City of Cuyahoga Falls - (OH)',
#   'City of Dover - (OH)',
#   'City of Painesville',
#   'City of St Marys - (OH)'],
#  'Gallatin #2': ['Dean Machinery'],
#  'Garnet Solar Generation Station I LLC': ['Hanwha Q CELLS USA',
#   'Hanwha PVPLUS, LLC'],
#  'Garnet Wind Energy Center': ['Dutch Energy Corporation'],
#  'Garrell Solar Farm': ['Strata Master Lessee 1, LLC'],
#  'Garrett County - DPU Treatment Plant': ['Dom Solar Lessor I, LP'],
#  'Gaston Memorial Hospital': ['Gaston Memorial Hospital'],
#  'Gastonia, Tulip Drive': ['Gastonia City of'],
#  'Gates Peaker': ['Dittmer, Harold', 'Fresno Power Investors LP'],
#  'Gateway': ['U S Bureau of Reclamation'],
#  'Gavilan District College Solar Project': ['SolarStorage Fund C, LLC'],
#  'Gavin Power, LLC': ['Lightstone Generation LLC'],
#  'Gaviota Oil Plant': ['Whiting Programs Inc',
#   'Sun Offshore Gathering Co',
#   'Harvest Energy Inc',
#   'Capitan Oil Pipeline Co',
#   'Kock Exploration Co LLC',
#   'Freeport McMoRan Oil & Gas',
#   'AMERESCO Delaware Central'],
#  'Genentech Vacaville Meter #1': ['Dom Solar Lessor I, LP'],
#  'Genentech-Oceanside': ['Dom Solar Lessor I, LP'],
#  'General Electric Aircraft Engines': ['AlsoEnergy'],
#  'Genesee Power Station LP': ['CMS Generation Holdings Co',
#   'GPS NEWCO LLC',
#   'Genesee Power Partners LP',
#   'CMS Generation Genesee Co'],
#  'George Neal North': ['IES Utilities, Inc', 'MidAmerican Energy Co'],
#  'George Neal South': ['City of Laurens - (IA)',
#   'Cedar Falls Utilities',
#   'City of Spencer - (IA)',
#   'City of Coon Rapids',
#   'City of Milford - (IA)',
#   'City of Graettinger - (IA)',
#   'Northwest Iowa Power Coop',
#   'MidAmerican Energy Co',
#   'Grundy Center Mun Light & Power',
#   'City of Webster City - (IA)',
#   'Interstate Power and Light Co',
#   'Corn Belt Power Coop',
#   'NorthWestern Energy - (SD)',
#   'City of Algona - (IA)',
#   'Bancroft Municipal Utilities'],
#  'Georgetown': ['Indiana Municipal Power Agency'],
#  'Georgia-Pacific Taylorsville Plywood': ['Georgia-Pacific Monticello LLC',
#   'Georgia-Pacific Chemicals LLC'],
#  'Georgia-Pacific Wauna Mill': ['Western Generation Agency'],
#  'Gibson': ['Indiana Municipal Power Agency',
#   'Duke Energy Indiana, LLC',
#   'Wabash Valley Power Assn, Inc'],
#  'Gila River Power Block 3': ['UNS Electric, Inc', 'Tucson Electric Power Co'],
#  'Gilroy Peaking Energy Center': ['Gilroy Energy Center LLC'],
#  'Glen Ullin Energy Center': ['Great American West Wind, LLC'],
#  'Goat Wind LP': ['NRG Energy, Inc',
#   'Cielo Goat Limited',
#   'Mission Wind Goat Mountain Inc'],
#  'Golden Acorn Casino': ['Foundation CA Fund VII Owner, LLC'],
#  'Golden Renewable Energy, LLC': ['Golden Renewable Energy of Iowa 2, LLC',
#   'Golden Renewable Energy of Iowa 3, LLC',
#   'Golden Renewable Energy of Iowa 1, LLC',
#   'Golden Renewable Energy, LLC'],
#  'Goodhue Solar': ['SoCore 2016 ProjectCo-W1 LLC'],
#  'Goose Lake MN DPC-GM': ['SoCore 2018 ProjectCo-W26 LLC'],
#  'Gopher CSG': ['Gopher CSG 1, LLC'],
#  'Goshen Phase II': ['BP Wind Energy North America Inc',
#   'Leeward Asset Management, LLC'],
#  'Grady Wind Energy Center, LLC': ['Grady Wind Energy Center, LLC'],
#  'Grahamsville': ['City of New York'],
#  'Grand Gulf': ['Cooperative Energy', 'System Energy Resources, Inc'],
#  'Grand Isle Gas Plant / Treating Station': ['Energy XXI Pipeline II, LLC'],
#  'Grand Valley Project Power Plant': ['U S Bureau of Reclamation'],
#  'Grandy PV 1': ['Fresh Air Energy XXXIII, LLC'],
#  'Granite Reliable Power': ['BAIF Granite Holdings LLC',
#   'Freshet Wind Energy LLC'],
#  'Graniteville Enterprise Division': ['Enterprise Mill LLC'],
#  'Granville Solar PV Power Project': ['Southern Turner Renewable Energy'],
#  'Grayling Generating Station': ['Grayling Development Partners',
#   'CMS Generation Holdings Co',
#   'CMS Generation Grayling Co'],
#  'Great Bend - Sunflower': ['Mid-Kansas Electric Company Inc.'],
#  'Great Plains Windpark LLC': ['Noble Environmental Power'],
#  'Green Acres Solar Facility 1': ['OL Elk Grove Trust'],
#  'Green Acres Solar Facility 2': ['OL Elk Grove Trust'],
#  'Green City Recovery, LLC': ['Toyota Motor Manufacturing, Kentucky, Inc.'],
#  'Green Island Hydroelectric Station': ['Green Island Power Authority'],
#  'Green Knight Energy Center': ['Green Knight Economic Development Corpor'],
#  'Green Machine': ['U.S. Government'],
#  'Green Meadows': ['HOW GM LLC'],
#  'Green Pastures Wind I': ['Capital Dynamics'],
#  'Green Pastures Wind II': ['Capital Dynamics'],
#  'Green Power 2': ['Marathon Petroleum Company LP'],
#  'Greenback Energy': ['JDR Holdings LLC', 'Greenback Energy LLC'],
#  'Greene County': ['Alabama Power Co', 'Mississippi Power Co'],
#  'Greene County Meter #1': ['Dom Solar Lessor I, LP'],
#  'Greenup Hydro': ['American Mun Power-Ohio, Inc', 'City of Hamilton - (OH)'],
#  'H Power': ['City and County of Honolulu'],
#  'HEBT Irvine 1': ['Macquarie Capital'],
#  'HEBT Irvine 2': ['Macquarie Capital'],
#  'HEBT WLA 1': ['Macquarie Capital'],
#  'HL Power': ['Greenleaf Power LLC'],
#  'HMP&L Station Two Henderson': ['Henderson City Utility Comm'],
#  'HNL Emergency Power Facility': ['State of Hawaii Department of Transportation, Airport Division'],
#  'HQC Rock River Solar Power Gen Station': ['Hanwha Q CELLS USA',
#   'Hanwha PVPLUS, LLC'],
#  'Hadley Ridge LLC': ['Northern Alternative Energy', 'CHI Energy Inc'],
#  'Halifax County Biomass': ['NOVEC Energy Production'],
#  'Hampden': ['HA MA Solar, LLC'],
#  'Hampshire College': ['Dom Solar Lessor I, LP'],
#  'Hanover Solar, LLC': ['New Energy Solar'],
#  'Happy Hollow CSG': ['Happy Hollow Solar Holdings, LLC'],
#  'Harbor Wind LLC': ['Harbor Wind Tenant LLC', 'Revolution Energy LLC'],
#  'Hardee Power Station': ['Hardee Power Partners Ltd'],
#  'Hardin Hilltop Wind LLC': ['NRG Energy, Inc', 'Other'],
#  'Harpster Wind': ['One Energy Capital LLC', 'Todd A.Stoller Living Trust'],
#  'Harrisburg Facility': ['Lancaster County Solid WR Auth'],
#  'Harrison County Power Project': ['Northeast Texas Elec Coop, Inc',
#   'East Texas Electric Coop, Inc'],
#  'Hastings Solar': ['Hastings Solar, LLC'],
#  'Hatchet Ridge Wind Project': ['Hatchet Ridge Wind LLC'],
#  'Hawaii Cogen': ['Chevron USA Inc'],
#  'Hawkeye Power Partners LLC': ['NextEra Energy Resources'],
#  'Hawkeye Wind Farm': ['RPG Elk/Hawkeye Investco, LLC',
#   'RPMA Wind Holding II'],
#  'Hawks Nest Hydro': ['Brookfield Energy Marketing US LLC'],
#  'Hayden': ['Public Service Co of Colorado',
#   'PacifiCorp',
#   'Salt River Project'],
#  'Haynes Farm': ['Strata Solar Development, LLC', 'CSI Project Holdco, LLC'],
#  'Haywood Solar': ['Silicon Ranch Corporation'],
#  'Hazle Spindle': ['Hazle Spindle LLC'],
#  'Heat Plant 770': ['Honeywell Inc'],
#  'Heat Recovery Coke Facility': ['Primary Energy'],
#  'Heber Geothermal': ['Ormat Nevada Inc'],
#  'Helemano Substation DG': ['Hawthorne Power Systems'],
#  'Henrietta D Energy Storage LLC': ['Henrietta D Energy Storage LLC'],
#  'Henrietta Solar Project': ['SunPower Holding Company', 'Southern Power Co'],
#  'Hermiston Generating Plant': ['Hermiston Generating Co LP', 'PacifiCorp'],
#  'Hesperia': ['DG Solar Lessee LLC'],
#  'Hewlett-Packard (HP) - Andover, MA': ['Dom Solar Lessor I, LP'],
#  'Hidalgo Energy Center': ['Brownsville Public Utilities Board',
#   'Calpine Corp',
#   'Calpine Corp - Hidalgo'],
#  'Hidden View Dairy, LLC': ['T&M Limited Partnership',
#   'T & M Limited Partnership'],
#  'Higginsville Solar Farm': ['MCP-Higginsville, LLC'],
#  'High Shoals PV1': ['Fresh Air Energy XXXII, LLC'],
#  'High Sierra Limited': ['WGP Redwood Holdings, LLC'],
#  'High Winds LLC': ['Florida Power & Light Co'],
#  'Higley': ['BRASCAN Power Corporation'],
#  'Hiilangaay Hydro': ['Alaska Power and Telephone Co', 'Haida Corporation'],
#  'Hill AFB LFG Facility, Bldg #737': ['U.S. Air Force, Hill AFB'],
#  'Hill Top Energy Center, LLC': ['Hill Top MM RH, LP',
#   'Ares EIF Management, LLC'],
#  'Holland Energy Facility': ['Holland Energy LLC'],
#  'Holly': ['Arkansas River Power Authority', 'Town of Holly - (CO)'],
#  'Homer City Generating Station': ['Homer City Holdings LLC', 'HCG GP LLC'],
#  'Homer Street East': ['Renewable Strategies LLC',
#   'JSF Energy, LLC',
#   'Olean Gateway Turnkey LLC',
#   'BQ Energy LLC'],
#  'Homer Street West': ['Renewable Strategies LLC',
#   'JSF Energy, LLC',
#   'Olean Gateway Turnkey LLC',
#   'BQ Energy LLC'],
#  'Honda Torrance': ['American Honda Motor Co., Inc.'],
#  'Hope Creek LLC': ['Northern Alternative Energy', 'Enel North America, Inc.'],
#  'Horn': ['CD US Solar PO 2 LLC'],
#  'Howland Hydro Station': ['Penobscot River Restoration Trust'],
#  'Hudson Falls Hydroelectric Project': ['Hudson Falls, LLC',
#   'Northern Electric Power Co LP',
#   'BPIF LLC'],
#  'Hunter': ['PacifiCorp',
#   'Provo City Corp',
#   'Deseret Generation & Tran Coop',
#   'Utah Associated Mun Power Sys'],
#  'Hurricane Creek Lift Station': ['City of Greenwood'],
#  'Hyland LFGTE Facility': ['Casella Waste Systems'],
#  'Hyperion Treatment Plant CHP Plant': ['City of Los Angeles'],
#  'IBM Southbury': ['IBM'],
#  'IP Springfield Oregon': ['Eugene Water & Electric Board'],
#  'IVC Solar': ['GL IVC Solar, LLC'],
#  'Iatan': ['Kansas City Power & Light Co',
#   'KCP&L Greater Missouri Operations Co',
#   'Empire District Electric Co',
#   'Missouri Jnt Muni.Pwr Elec. Ut. Comm.',
#   'Kansas Electric Power Coop Inc'],
#  'Imperial Solar Energy Center South': ['Tenaska IV South Partners, LLC',
#   'Tenaska CSOLAR South Holdings, LLC',
#   'Tenaska CSOLAR South, LLC'],
#  'Imperial Solar Energy Center West': ['Tenaska CSOLAR West, LLC',
#   'CD Global II CSOLAR, LLC',
#   'Tenaska CSOLAR West Holdings, LLC'],
#  'Imperial Valley Solar Co (IVSC) 2, LLC': ['SunEdison LLC',
#   'Dominion Renewable Energy'],
#  'Independence II Solar Farm': ['MCP-Independence II, LLC'],
#  'Independence Solar Farm': ['MCP-Independence, LLC'],
#  'Independence Steam Electric Station': ['City Water and Light Plant',
#   'City of West Memphis - (AR)',
#   'Conway Corporation',
#   'Arkansas Electric Coop Corp',
#   'City of Osceola - (AR)',
#   'Entergy Mississippi LLC',
#   'Entergy Arkansas LLC',
#   'Entergy Power, LLC',
#   'East Texas Electric Coop, Inc'],
#  'Indian River Generating Station': ['Indian River Power LLC'],
#  'Indian River Plant': ['Orlando Utilities Comm',
#   'Florida Municipal Power Agency',
#   'Kissimmee Utility Authority'],
#  'Indiana Harbor E 5 AC Station': ['Primary Energy'],
#  'Indianapolis Motor Speedway Solar PV': ['Blue Renewable Energy IMS, LLC',
#   'Firstar Development, LLC'],
#  'Indy Solar I, LLC': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'Indy Solar II, LLC': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'Indy Solar III, LLC': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'Ingleside Cogeneration': ['Oxy Cogener Holding Co Inc',
#   'Ingleside Cogeneration LP'],
#  'Innovative Solar 16': ['FLS 2015 Solar G, LLC'],
#  'Innovative Solar 18, LLC': ['FLS 2015 Solar H, LLC'],
#  'Innovative Solar 26, LLC': ['FLS 2015 Solar H, LLC'],
#  'Innovative Solar 31': ['Innovative Solar 31, LLC', 'NES Bank'],
#  'Innovative Solar 44': ['FLS 2015 Solar G, LLC'],
#  'Innovative Solar 63, LLC': ['FLS 2015 Solar H, LLC'],
#  'Intel - Ocotillo Campus Solar': ['Dom Solar Lessor I, LP'],
#  'Intel Folsom': ['Banyan SolarCity Owner 2010 LLC'],
#  'Intel Folsom Phase 3': ['Three Rivers Solar I, LLC'],
#  'Intel Santa Clara': ['Intel'],
#  'Intercession City': ['Duke Energy Florida, LLC', 'Georgia Power Co'],
#  'Intermountain Power Project': ['Intermountain Power Agency'],
#  'International Paper - Orange': ['International Paper Co.'],
#  'Ironwood Wind': ['DEGS Wind 1 LLC', 'Sumitomo Corporation of America'],
#  'Ivanpah 1': ['Solar Partners II LLC'],
#  'Ivanpah 2': ['Solar Partners I LLC'],
#  'Ivanpah 3': ['Solar Partners VIII LLC'],
#  'Iwilei Tank Farm DG': ['Hawthorne Power Systems'],
#  'J C McNeil': ['City of Burlington Electric - (VT)',
#   'Vermont Public Power Supply Authority',
#   'Green Mountain Power Corp'],
#  'J H Campbell': ['Michigan Public Power Agency',
#   'Consumers Energy Co',
#   'Wolverine Power Supply Coop'],
#  'J M Stuart': ['AES Ohio Generation LLC',
#   'Dynegy Energy Services, LLC',
#   'AEP Generation Resources Inc',
#   '126 Grove Solar LLC'],
#  'Jack River LLC': ['Northern Alternative Energy', 'Enel North America, Inc.'],
#  'Jackson Board of Education-Liberty HS': ['Dom Solar Lessor I, LP'],
#  'Jackson Cntr Peaking': ['City of Wadsworth - (OH)',
#   'City of Galion',
#   'City of Hamilton - (OH)',
#   'City of Amherst- (OH)',
#   'Other',
#   'City of Cuyahoga Falls - (OH)',
#   'City of Bowling Green - (OH)',
#   'City of Dover - (OH)',
#   'City of Painesville',
#   'City of St Marys - (OH)'],
#  'James H Miller Jr': ['PowerSouth Energy Cooperative', 'Alabama Power Co'],
# ...
#  'Lakeland Electric Co. (FL) - Aiport II': ['SE Solar Trust VII'],
#  'Lakeland Electric Co. (FL)-Airport 1': ['WF-SunE-XII Solar Statutory Trust'],
#  'Lakota Ridge LLC': ['Edison Mission Energy',
#   'Citi Renewable Investments I LLC'],
#  'Lalamilo Windfarm': ['Hawaiian Electric Co Inc'],
#  'Lamar Plant': ['Arkansas River Power Authority'],
#  'Lancaster Baptist Church': ['Pacific Energy Capital'],
#  'Lancaster County Resource Recovery': ['Lancaster County Solid WR Auth'],
#  'Lancaster Wind Farm Project': ['Lancaster Wind Farm LLC'],
#  'Langley PV1': ['Fresh Air Energy XII LLC'],
#  'Laramie River Station': ['Basin Electric Power Coop',
#   'Lincoln Electric System',
#   'Tri-State G & T Assn, Inc',
#   'Wyoming Municipal Power Agency',
#   'Missouri Basin Muni Power Agny',
#   'Heartland Consumers Power Dist'],
#  'Las Vegas Solar Energy Center': ['Public Service Co of NM'],
#  'Las Virgenes Municipal Water District': ['AU Solar 1 LLC'],
#  'Laurinburg Solar': ['FLS 2015 Solar F'],
#  'Lawrence County Station': ['Wabash Valley Power Assn, Inc'],
#  'Lawrence Creek Solar': ['Lawrence Creek Solar, LLC'],
#  'Lawrenceburg Power, LLC': ['Lightstone Generation LLC'],
#  'Lebanon Solar Farm (MO)': ['MCP-Lebanon, LLC'],
#  'Lee Energy Facility': ['Bruce Power, LLC'],
#  'Leicester One MA Solar LLC': ['SAH Holdings', 'Centaurus Holdings, LLC'],
#  'Lenoir Farm': ['Strata RS Solar Holding Fund LLC'],
#  'Lenoir Farm 2': ['Strata Solar Development, LLC', 'CSI Project Holdco, LLC'],
#  'Liberty HS Solar Project': ['SunTrust Equipment Finance & Leasing Corp'],
#  'Liberty Pole DPC Solar': ['SoCore 2016 ProjectCo-W11 LLC'],
#  'Life Technologies - Pleasanton': ['Life Technologies Corporation'],
#  'Life Technologies Carlsbad': ['Life Technologies Corporation'],
#  'Linden Wind Energy Project': ['Southern California P P A'],
#  'Lindstrom Solar CSG': ['Nordic Solar, LLC'],
#  'Little Bay': ['LB RI Solar, LLC'],
#  'Little River PV 1': ['Fresh Air Energy XXXI, LLC'],
#  'Live Oak Limited': ['WGP Redwood Holdings, LLC'],
#  'Livingston Solar Canopies': ['Key Government Finance, Inc.'],
#  'Llano Estacado Wind Ranch': ['Mitsubishi Heavy Industries America, Inc.'],
#  'Lockheed Martin Sunnyvale': ['Lockheed Martin Corporation'],
#  'Locust Ridge': ['Fortis Capital', 'Iberdrola Renewable Energies USA'],
#  'Logan Generating Company LP': ['Keystone Urban Renewal LP'],
#  'Logans Gap Wind LLC': ['Logans Gap Wind LLC'],
#  'Long Beach Generation LLC': ['NRG Energy, Inc',
#   'Dynegy Inc',
#   'NRG Energy Inc'],
#  'Longview Power Plant': ['Longview Intermediate Holdings C, LLC'],
#  'Lopez Canyon': ['MM Lopez Energy LLC'],
#  'Los Lunas Solar Energy Center': ['Public Service Co of NM'],
#  'Lost Hills/Blackwell': ['First Solar Asset Management', 'Southern Power Co'],
#  'Lost Pines 1 Power Project': ['Lower Colorado River Authority',
#   'GENTEX Power Corp'],
#  'Louisa': ['City of Tipton - (IA)',
#   'Eldridge City Utilities',
#   'Alliant Energy',
#   'Harlan Municipal Utilities - (IA)',
#   'Waverly Municipal Elec Utility',
#   'Central Iowa Power Cooperative',
#   'City of Geneseo - (IL)',
#   'MidAmerican Energy Co'],
#  'Louisiana 1': ['Exxon Mobil Corp'],
#  'Lower Mount Bethel Energy': ['Lower Mount Bethel Project Company LLC'],
#  'Lower Saranac Hydroelectric Facility': ['Lower Saranac Corp',
#   'Twin Saranac Holdings, LLC.',
#   'Enel North America, Inc.'],
#  'Lucky Wind': ['Lucky Wind LLC', 'JDR Holdings LLC'],
#  'Ludington': ['Consumers Energy Co', 'DTE Electric Company'],
#  'Ludlow Landfill': ['GLC-(MA) Ludlow, LLC'],
#  'Luna Energy Facility': ['Tucson Electric Power Co',
#   'Samchully Power & Utilities 1 LLC',
#   'PNMR Development & Management Corp.',
#   'Public Service Co of NM'],
#  'MCRD Parris Island PV': ['MCRD Parris Island / U.S. Marine Corps'],
#  'MEBA': ['MEBA Solar I, LLC'],
#  'MEPI GT Facility': ['Illinois Power Generating Co', 'Kentucky Utilities Co'],
#  'MER Queens': ['KeyBank'],
#  'MF Mesa Lane LLC': ['MS Greenrock, LLC'],
#  'MPC Generating': ['MPC Generating, LLC.'],
#  'Ma': ['CD US Solar PO 2 LLC'],
#  'MacArthur Waste to Energy Facility': ['Islip Resource Recovery Agency'],
#  'Macho Springs': ['Southern Turner Renewable Energy'],
#  'Macon Solar Power Project': ['MCP-Macon, LLC'],
#  "Macy's MD Joppa Solar Project": ['SunPower Commercial Holding Company III, LLC'],
#  'Madera 1 PV': ['GL Madera, LLC'],
#  'Madera Community Hospital': ['GLC - (CA) Madera, LLC'],
#  'Magnolia Power Project': ['Southern California P P A'],
#  'Mahoney Lake Hydroelectric': ['Alaska Power and Telephone Co',
#   'Ketchikan Public Utilities'],
#  'Main Canal Headworks': ['Quincy-Columbia Basin Irr Dist',
#   'South Columbia Basin Irr Dist',
#   'East Columbia Basin Irr Dist'],
#  'Majestic 1 Wind Farm': ['NextEra Energy Resources'],
#  'Malaga Power LLC': ['Malaga Power, LLC'],
#  'Malburg': ['Bicent CA Malburg LLC'],
#  'Mammoth Pacific I': ['Mammoth Pacific LP'],
#  'Mammoth Pacific II': ['Mammoth Pacific LP'],
#  'Manchester Community College East': ['CTGB Solar Mission III LLC'],
#  'Manchester Community College North': ['CTGB Solar Mission III LLC'],
#  'Manning PV 1': ['Fresh Air Energy XX, LLC'],
#  'Manzano Solar': ['Public Service Co of NM'],
#  'Maple Ridge Wind Farm': ['Avangrid Renewables LLC',
#   'EDP Renewables North America LLC',
#   'Madison Windpower LLC'],
#  'March Point Cogeneration': ['Equilon Enterprises LLC'],
#  'Marcus Hook Energy LP': ['Starwood Energy Group Global'],
#  'Marcus Hook Refinery Cogen': ['Starwood Energy Group Global'],
#  'Maricopa West Solar PV, LLC': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'Market Farm': ['Strata Fund 16 LLC'],
#  'Marmas Solar CSG': ['Nordic Solar, LLC'],
#  'Marsh Landing Generating Station': ['Clearway Energy, Inc'],
#  'Marshall Solar Farm (MO)': ['MCP-Marshall, LLC'],
#  'Marshville Farm': ['Strata Solar Development, LLC',
#   'CSI Project Holdco, LLC'],
#  'Martin Creek Farm LLC': ['Strata Master Lessee 1, LLC'],
#  'Martin Lake': ['Luminant Gen Co LLC Fin Holding'],
#  'Maryland Solar': ['8point3 Operating Company LLC'],
#  'Mascoma Hydro': ['Enel North America, Inc.'],
#  'Mashpee Landfill Solar': ['ACE of Cape Cod Solar IV, LLC'],
#  'Maxim': ['Maxim'],
#  'Maywood Photovoltaic Project': ['PNC Energy Capital LLC'],
#  'McCallum Farm': ['Strata Solar Farms, LLC'],
#  'McClain Energy Facility': ['Oklahoma Gas & Electric Co',
#   'Oklahoma Municipal Power Authority'],
#  'McClellan (CA)': ['Sacramenta Power Authority'],
#  'McKay Bay Facility': ['Tampa City of'],
#  'McKee Run': ['City of Dover - (DE)'],
#  'McKenzie Farm': ['Strata Fund 12',
#   'Churchill Hill Stateside Tax Credit Fund II LLC'],
#  'McKittrick Limited': ['WGP Redwood Holdings, LLC'],
#  'McNary Dam Fish Attraction Project': ['Northern Wasco County PUD',
#   'PUD No 1 of Klickitat County'],
#  'Meadow Lake Solar Energy Center': ['Public Service Co of NM'],
#  'Meadow Solar': ['MD MA Solar, LLC'],
#  'Medford DPC Solar': ['SoCore 2016 ProjectCo-W10 LLC'],
#  'Medicine Bow': ['Clipper Windpower Inc'],
#  'Mehoopany Wind Energy LLC': ['BP Wind Energy North America Inc',
#   'Sempra Generation'],
#  'Meldahl Hydroelectric Project': ['American Mun Power-Ohio, Inc',
#   'City of Hamilton - (OH)'],
#  'Mendota Hills, LLC': ['Mendota Hills LLC'],
#  'Merced 1 PV': ['GL Merced 2, LLC'],
#  'Meridian Vineyards': ['Banc of America Leasing & Capital LLC'],
#  'Mesa Wind Power Corp': ['Mesa Wind Power Corporation'],
#  'Methuen Landfill': ['GLC-(MA) Methuen, LLC'],
#  'Metro Wastewater Reclamation District': ['Metropolitan Wastewater Reclam',
#   'ENGIE Denver Metro LLC'],
#  'Miami Fort': ['Duke Energy Ohio Inc'],
#  'Michael Solar': ['SoCore 2016 ProjectCo-W1 LLC'],
#  'Michigan Power LP': ['Osaka Gas USA', 'Rockland Power Partners, LLC'],
#  'Micro Santa Clara': ['Key Equipment Finance'],
#  'Mid-Georgia Cogeneration Facility': ['Mid-Georgia Cogen, LP'],
#  'Mid-Set Cogeneration': ['Chevron USA Inc'],
#  'Middle Daisy': ['Middle Daisy, LLC'],
#  'Middle Falls Hydro': ['Boralex Middle Falls, LLC',
#   'Middle Falls Ltd Partnership'],
#  'Midway Peaking LLC': ['Midway Peaking  LLC'],
#  'Midway Solar - TX': ['174 Power Global Corp.'],
#  'Midway Sunset Cogen': ['San Joaquin Energy Co',
#   'AERA Energy LLC',
#   'Aera Energy LLC'],
#  'Mile Farm': ['Strata Solar Development, LLC', 'CSI Project Holdco, LLC'],
#  'Milford Power LP': ['Starwood Energy Group Global'],
#  'Milhurst Solar': ['TGCOP Operating Hodings I, LLC'],
#  'Mill Pond Solar Farm, LLC': ['Mill Pond Solar Farm, LLC'],
#  'Mill Seat Renewable Energy Facility': ['Monroe County (NY)'],
#  'Millbrook School': ['Three Rivers Solar I, LLC'],
#  'Millstone': ['Dominion Energy Nuclear Conn Inc',
#   'Massachusetts Mun Wholes Electric Co',
#   'Green Mountain Power Corp'],
#  'Milton R Young': ['Square Butte Electrical Cooperative'],
#  'Minnesota River': ['City of Chaska - (MN)'],
#  'Minwind 3-9': ['Minwind Shareholders'],
#  'Miramar': ['NRG Energy, Inc'],
#  'Missouri Center for Waste to Energy': ['PPS Group, LLC'],
#  'Mitchell (WV)': ['Wheeling Power Co'],
#  'Moapa Southern Paiute': ['Moapa Southern Paiute LLC',
#   'Goldman Sachs/General Electric'],
#  'Mocksville Farm': ['NC Renewable Investor 1, LLC'],
#  'Mohave': ['Nevada Power Co',
#   'Los Angeles Department of Water & Power',
#   'Southern California Edison Co',
#   'Salt River Project'],
#  'Moncure Farm LLC': ['Strata Master Lessee 1, LLC'],
#  'Monterey Regional Water Pollution Contro': ['Banyan SolarCity Owner 2010 LLC'],
#  'Montgomery County Oaks LFGE Plant': ['Northeast Maryland W D Auth'],
#  'Montgomery County Resource Recovery': ['Northeast Maryland W D Auth'],
#  'Monticello': ['Luminant Gen Co LLC Fin Holding'],
#  'Montpelier': ['City of Wadsworth - (OH)',
#   'City of Galion',
#   'City of Hamilton - (OH)',
#   'City of Amherst- (OH)',
#   'City of Bowie - (TX)',
#   'Other',
#   'City of Cuyahoga Falls - (OH)',
#   'City of Dover - (OH)',
#   'City of Painesville',
#   'City of St Marys - (OH)'],
#  'Montrose Solar': ['Montrose Solar, LLC'],
#  'Moore Solar Farm': ['Strata Solar Development, LLC',
#   'CSI Project Holdco, LLC'],
#  'Moorings Farm': ['Strata Solar Development, LLC', 'CSI Project Holdco, LLC'],
#  'Morelos del Sol': ['Southern Turner Renewable Energy'],
#  'Morgan City': ['Morgan City - (LA)'],
#  'Morgan Creek': ['Luminant Gen Co LLC Fin Holding',
#   'Luminant Generation Company LLC'],
#  'Morgan Solar Center': ['Enerparc Solar Development, LLC'],
#  'Morin Solar 2013 LLC': ['Morin Solar 2013, LLC'],
#  'Morris Genco LLC': ['Biogas Energy Solutions'],
#  'Mosinee Mill': ['Expera Specialty Solutions'],
#  'Moulton Wind Power': ['Moulton Wind Power Partners, LLC'],
#  'Mount Olive Farm': ['Strata Solar, LLC'],
#  'Mount Tom': ['Mt Tom Generating Company'],
#  'Mountain Home Energy Center': ['MHET Owner Trust-Wells Fargo'],
#  'Mountain View I&2': ['Mountain View Power Prtnrs, LLC'],
#  'Mountain View Solar': ['NextEra Energy Resources'],
#  'Mountain Wind Power II LLC': ['Edison Mission Energy', 'NRG Energy, Inc'],
#  'Mountain Wind Power LLC': ['Edison Mission Energy', 'NRG Energy, Inc'],
#  'Mt Olive Farm 2': ['Strata Solar Farms, LLC'],
#  'Mt Olive Solar 1': ['FLS 2014 Solar D, LLC'],
#  'Mt Poso Cogeneration': ['MacPherson Power Co', 'DTE Energy Services'],
#  'Mt. Hope DPC Solar': ['SoCore 2016 ProjectCo-W5 LLC'],
#  'Mt. Jackson Solar': ['VA Solar, Inc.', 'Virginia Solar LLC'],
#  'Muck Valley Hydroelectric': ['Malacha Hydro Limited Partnership'],
#  'Mulberry Cogeneration Facility': ['Polk Power Partners LP'],
#  'Mulberry Farm LLC': ['SunEdison LLC', 'Dominion Renewable Energy'],
#  'NA 1(Hagerstown)': ['no name'],
#  'NAEA Lakewood LLC': ['Lakewood Cogeneration LP'],
#  'NAEA Ocean Peaking Power LLC': ['NAEA Ocean Peaking Power LLC'],
#  'NAFTA Region Olefins Complex Cogen Fac': ['Total Petrochemicals USA Inc',
#   'BASF Corporation'],
#  'NASA Johnson Space Center CHP': ['NASA Johnson Space Center'],
#  'NCAH Central Utility Plant': ['National Animal Disease Center',
#   'National Veterinary Services Laboratory'],
#  'NIH Cogeneration Facility': ['National Institutes of Health'],
#  'NVSS-II': ['Nevada Valley Solar Solutions II, LLC'],
#  'NWP Indian Mesa Wind Farm': ['Florida Power & Light Co'],
#  'Nalco': ['Naperville Trust'],
#  'Nantucket': ['Other', 'New England Power Company'],
#  'Napoleon Peaking': ['City of Wadsworth - (OH)',
#   'City of Hamilton - (OH)',
#   'Other',
#   'City of Cuyahoga Falls - (OH)',
#   'City of Bowling Green - (OH)',
#   'City of Dover - (OH)',
#   'City of Painesville',
#   'City of St Marys - (OH)'],
#  'Nash 58 Farm': ['Strata Master Lessee 1, LLC'],
#  'Nash 64 Farm': ['Strata Solar Farms, LLC'],
#  'Nassau Energy Corp': ['Engie North America'],
#  'Navajo': ['U S Bureau of Reclamation',
#   'Arizona Public Service Co',
#   'Nevada Power Co',
#   'Tucson Electric Power Co',
#   'Salt River Project',
#   'Los Angeles Department of Water & Power'],
#  'Naval Air Weapons Station China Lake': ['MetLife Capital Credit L.P.'],
#  'Naval Station': ['NRG Energy, Inc'],
#  'Naval Station Energy Facility': ['US Dept of Navy'],
#  'Naval Training Center': ['NRG Energy, Inc'],
#  'Neal Hot Springs Geothermal Project': ['USG Oregon LLC'],
#  'NedPower Mount Storm': ['Dominion Energy Inc', 'Shell Wind Energy Inc.'],
#  'Neenach Solar Center': ['Enerparc Solar Development, LLC'],
#  'Neil Simpson Gas Turbine #2': ['City Of Gillette'],
#  'Nesvold Watertown Solar': ['SoCore 2016 ProjectCo-W1 LLC'],
#  'Nevada Cogen Assoc#1 GarnetVly': ['Bonneville Nevada Corporation',
#   'NSG New Nevada Holdings LLC'],
#  'Nevada Cogen Associates 2 Black Mountain': ['Rockland Power Partners, LLC',
#   'Quantum Utility Generation LLC'],
#  'Neversink': ['City of New York'],
#  'New Auburn DPC Solar': ['SoCore 2016 ProjectCo-W1 LLC'],
#  'New Bern Farm': ['Strata Solar Development, LLC', 'CSI Project Holdco, LLC'],
#  'New Haven Harbor': ['PSEG New Haven LLC'],
#  'New Hogan Power Plant': ['Calaveras County Water Dist'],
#  'New York State Dam Hydro': ['State Dam II, LLC', 'NYSD Ltd Partnership'],
#  'Newark Energy Center': ['Energy Investment Fund'],
#  'Newgulf Cogen': ['Wharton County Elec Coop, Inc', 'GDF Suez NA - Hopewell'],
#  'Nine Mile Point Nuclear Station': ['Exelon Nuclear',
#   'Electricity de France',
#   'Long Island Power Authority'],
#  'Ninnescah Wind Energy, LLC': ['NextEra Energy Operating Services LLC'],
#  'Nitro Solar': ['Holocene Renewable Energy Fund 3, LLC'],
#  'Noble Altona Windpark LLC': ['Noble Environmental Power'],
#  'Noble Bliss Windpark LLC': ['Noble Environmental Power'],
#  'Noble Chateaugay Windpark LLC': ['Noble Environmental Power'],
#  'Noble Clinton Windpark LLC': ['Noble Environmental Power'],
#  'Noble Ellenburg Windpark LLC': ['Noble Environmental Power'],
#  'Noble Wethersfield Windpark LLC': ['Noble Environmental Power'],
#  'Nobles 2 Wind Project': ['Tenaska Nobles 2 Holdings, LLC,',
#   'ALLETE South Wind, LLC'],
#  'NorWest Energy 4, LLC': ['New Energy Solar'],
#  'NorWest Energy 9 LLC': ['New Energy Solar'],
#  'Nordhoff Place': ['MKM Oakdale Solar, LLC'],
#  'North Anna': ['Virginia Electric & Power Co', 'Old Dominion Electric Coop'],
#  'North Chicago Energy Center': ['Amalgamated Bank of Chicago'],
#  'North Island': ['NRG Energy, Inc'],
#  'North Jersey Media Group Solar Facility': ['KDC Solar NJMG LLC'],
#  'North Lake': ['Luminant Gen Co LLC Fin Holding',
#   'Luminant Generation Company LLC'],
#  'North Lancaster Ranch': ['North Lancaster Ranch'],
#  'North Palm Springs 1A': ['North Palm Springs Investments, LLC'],
#  'North Palm Springs 4A': ['North Palm Springs Investments, LLC'],
#  'North Smithfield Solar Power 1': ['Half Moon Ventures, LLC'],
#  'North Star Solar': ['First Solar Asset Management', 'Southern Power Co'],
#  'North Valmy': ['Idaho Power Co', 'Sierra Pacific Power Co'],
#  'NorthPark Solar': ['TGCOP Operating Hodings I, LLC'],
#  'Northern Lights Wind LLC': ['Northern Lights Wind LLC', 'JDR Holdings LLC'],
#  'Norton Landfill Solar': ['Citizens Solar Holdings V, LLC'],
#  'Notrees Windpower': ['DEGS Wind 1 LLC', 'TE Notrees LLC'],
#  'Novel - OYA of Mapleton': ['Novel-OYA Six LLP'],
#  'Novel OYA of Osakis': ['Novel-OYA Two LLP'],
#  'Nunn': ['CD US Solar PO 2 LLC'],
#  'OCI Alamo 4, LLC': ['Consolidated Edison Development Inc.',
#   'Fremont Energy Center'],
#  'OR Solar 2, LLC': ['ET CAP OR HOLDINGS LLC'],
#  'Oak Creek Energy Systems I': ['Terra-Gen Operating Co-Wind'],
#  'Oak Point Cogen': ['Chevron USA Inc'],
#  ...}

# %% [markdown]
# ## Want to deal with multiple owners issue

# %%
multi_owners = merged.merge(owners,how='inner', 
             on=['utility_id','plant_name','generator_id'], 
             indicator=True,
            validate="one_to_many")

# %%
multi_owners['percent_owned'] = pd.to_numeric(multi_owners.percent_owned.str.strip('%'))

# %%
mo_unique = multi_owners.drop_duplicates(['utility_id','plant_state','generator_id'])

# %%
mo_lt100 = mo_unique[mo_unique['percent_owned']<100]

# %%
a1 = mo_unique.technology.value_counts().sort_index()
a1b = mo_lt100.technology.value_counts().sort_index()
a2 = merged.technology.value_counts().sort_index()
a1.divide(a2, fill_value=0).sort_values(ascending=False)
a1b.divide(a2, fill_value=0).sort_values(ascending=False);

# %% [markdown]
# This isn't fruitful... so switching gears

# %%
merged.to_csv(dataDir + 'merged.csv')

# %% [markdown]
# make dictionary of utility names for each street address -- this is important because # entries > # utilities

# %%
utils.street_address.nunique()
# Out:
# 3624

# %%
utils.utility_name.nunique()
# Out:
# 5025

# %%
utils.groupby(['street_address']).utility_name.apply(lambda grp: list(grp.value_counts().index)).to_dict()
# Out:
# {'-16849 102nd Street SE': ['Dakota Magic Casino'],
#  '01 N.E. 7th Street': ['Western Farmers Elec Coop, Inc'],
#  '1 Adelaide Street East': ['Clark Canyon Hydro, LLC', 'Dorena Hydro, LLC'],
#  '1 Armorcast Rd': ['Birdsboro Power LLC'],
#  '1 Ashley Place': ['Ashley Energy LLC'],
#  '1 Atwell Road': ['Bassett Healthcare'],
#  '1 Blanchard RD PO BOX 13190': ['Calpine Corp - Metcalf Energy Center'],
#  '1 Bonnybridge Road': ['International Paper Port Wentworth Mill'],
#  '1 Energy Park Way': ['City of Holland'],
#  '1 Federal Street': ['American Sugar Refining, Inc.'],
#  '1 Gateway Plaza': ['Metropolitan Transportation Authority'],
#  '1 Glen Street': ['Finch Paper LLC'],
#  '1 Gustave L Levy Pl': ['Mount Sinai Hospital'],
#  '1 Hansen Rd PO BOX 266': ['Alexander & Baldwin, Inc.'],
#  '1 Healthy Way': ['South Nassau Communities Hospital'],
#  '1 Hoag Drive': ['Hoag Memorial Presbyterian Hospital'],
#  '1 Horwith Drive': ['EIF Northampton GP, LLC'],
#  '1 Infinite Loop': ['Apple, Inc'],
#  '1 Landmark Sq. Suite 320': ['Green Street Power Partners'],
#  '1 Main Street': ['Town of Stafford, CT'],
#  '1 Metrotech Center': ['Massachusetts Electric Co'],
#  '1 Morgan Drive': ['City of Oberlin - (KS)'],
#  '1 N. Pack Square': ['The Biltmore Company'],
#  '1 New Bond Street': ['Saint - Gobain Abrasives Inc'],
#  '1 New York Times Plz': ['The NY Times Production Facility'],
#  '1 North 2nd Street': ['Sonoco Products Co'],
#  '1 North Main Rd, Po Box 237': ['Town of Otis'],
#  '1 North White Horse Pike': ['Spencer TGC Westminster, LLC'],
#  '1 Organic Way': ['Cashton Greens Wind Farm LLC'],
#  '1 Power Plant Road': ['Sunnyside Cogeneration Assoc'],
#  '1 River Road': ['GE Wind Energy LLC'],
#  '1 Riverside Plaza': ['AEP Generation Resources Inc', 'Ohio Power Co'],
#  '1 Riverside Plaza, 26th Floor': ['Appalachian Power Co',
#   'Kentucky Power Co'],
#  '1 Rockwood Road': ['JLL-One Rockwood Road'],
#  '1 S. Wacker Dr. Ste. 1800': ['Beech Ridge II Wind Energy Center'],
#  '1 Six Flags Boulevard': ['KDC Solar PR1, LLC'],
#  '1 South Dearborn': ['ArcelorMittal USA Inc'],
#  '1 South Jersey Plaza': ['Marina Energy LLC'],
#  '1 St Clair Ave West': ['Wasatch View Solar LLC'],
#  '1 Tech Dr. Suite 220': ['Cimarron Bend Wind Project II, LLC',
#   'Cimarron Bend Wind Project I, LLC'],
#  '1 Tooele Army Depot, Bldg 1510': ['Tooele Army Depot'],
#  '1 University Of Arkansas': ['University Of Arkansas'],
#  '1 Verney Drive': ['Crotched Mt Rehab Ctr Inc'],
#  '1 W. Gillet St.': ['City of Preston'],
#  '10 Atlantic Street': ['Bridgeport Energy LLC'],
#  '10 Browns Road': ['Westtown NY 1, LLC'],
#  '10 East 53rd Street': ['Capital Dynamics'],
#  '10 Highland Avenue': ['Covanta Delaware Valley LP'],
#  '10 Main Street, Suite E': ['GRE 314 East Lyme LLC'],
#  '10 Malcolm X Boulevard': ['BCC Solar III, LLC'],
#  '10 Mcguire Drive': ['McGrath Light & Power Co'],
#  '10 Park Avenue': ['Greater Sandhill I LLC'],
#  '10 Riverview Drive': ['Praxair Inc'],
#  '10 Sherwood Lane': ['Millennium Power Partners LP'],
#  '10 Wagaraw Road': ['Shotco Energy, LLC'],
#  '10 William Street': ['Town of Berlin - (MD)'],
#  '100 Arboretum Drive, Suite 310': ['Wheelabrator Environmental Systems'],
#  '100 Brickstone': ['Whitney Hill Wind Power LLC',
#   'High Lonesome Wind Power, LLC'],
#  '100 Brickstone Sq Suite 300': ['Roadrunner Solar, LLC',
#   'Enel Green Power Diamond Vista Wind Project, LLC',
#   'Thunder Ranch Wind Project, LLC',
#   'Red Dirt Wind Project, LLC'],
#  '100 Brickstone Square': ['Enel Green Power NA, Inc.',
#   'Woods Hill Solar, LLC',
#   'Hilltopper Wind Project, LLC'],
#  '100 Brickstone Square, Suite 3': ['Cranberry Point Energy Storage LLC',
#   'White Cloud Wind Project, LLC',
#   'Rattlesnake Creek Wind Project, LLC'],
#  '100 California': ['North Rosamond Solar, LLC',
#   'Minisink Solar 2 LLC',
#   'Minisink Solar 1 LLC'],
#  '100 California St Suite 400': ['Winona Solar I LLC',
#   'BMP Wind LLC',
#   'Rattlesnake Flat, LLC',
#   'Wabasha Solar LLC'],
#  '100 California Suite 400': ['Mesquite Star LLC'],
#  '100 California, Suite 400': ['CMR Solar, LLC',
#   'NRG MN Community LLC',
#   'Renew Solar ABC Sacramento LLC'],
#  '100 Center Street': ['Domtar LLC'],
#  '100 Central Ave': ['City of Nebraska City'],
#  '100 Central Avenue, Suite 630': ['RTC Properties Inc'],
#  '100 Clinchfield Street': ['Domtar Paper Co LLC Kingsport Mill'],
#  '100 Congress Ave 22nd Floor': ['Texico Wind LP'],
#  '100 Congress Ave.': ['PowerFin ASL 1, LLC'],
#  '100 Congress Avenue, 22nd Floo': ['Lubbock Wind LLC'],
#  '100 Congress, Suite 2000': ['Mariah del Este LLC', 'Mariah del Sur LLC'],
#  '100 Constellation Way': ['Outback Solar, LLC',
#   'Constellation Solar Massachusetts LLC',
#   'Constellation Solar New Jersey II, LLC',
#   'California PV Energy LLC',
#   'Constellation Solar Net Metering LLC',
#   'Constellation Solar Holding, LLC',
#   'Constellation Solar Maryland, LLC',
#   'Denver Airport Solar, LLC',
#   'Constellation Solar Federal LLC',
#   'Constellation Solar Horizons LLC',
#   'Holyoke Solar LLC',
#   'Constellation Solar New Jersey, LLC',
#   'Constellation Solar Arizona LLC',
#   'Constellation Solar Maryland II LLC'],
#  '100 Constellation Way, Suite 1': ['Constellation Solar Georgia, LLC.',
#   'Constellation New Energy Inc.',
#   'Sacramento PV Energy, LLC',
#   'Constellation Solar Arizona 2, LLC',
#   'Mohave Sunrise Solar I, LLC'],
#  '100 Cookstown Road': ['Day Four Solar LLC'],
#  '100 E. Robinson St.': ['City of Lake Crystal - (MN)'],
#  '100 East Erie Street': ['Metro Wtr Recl Dist Grtr Chi'],
#  '100 East Randolph Street': ['Marathon Electric Mfg Corp'],
#  '100 Energy Blvd @ 56th St': ['Covanta Energy of Niagara LP'],
#  '100 Energy Drive': ['Dynegy Fayette Energy Facility'],
#  '100 First Avenue': ['MWRA Charlestown'],
#  '100 Gaston Rd': ['KapStone Kraft Paper Corp'],
#  '100 Global Innovation Circle': ['Lockheed Martin RMS'],
#  '100 Graphic Packaging Intl Way': ['Riverwood Intl USA Inc'],
#  '100 Jensen Rd': ['International Paper Co'],
#  '100 Legacy Park Drive': ['Piedmont Green Power LLC'],
#  '100 Main Street': ['Ahlstrom-Munksjo NA Specialty Solutions, LLC'],
#  '100 Maple Ave': ['Town of Shrewsbury - (MA)'],
#  '100 Marcus Blvd': ['Hawkeye Energy Greenport LLC'],
#  '100 Matsonford Rd': ['Lewiston Solar LLC',
#   'Windsor Solar LLC',
#   'Williamston Solar LLC',
#   'Bethel Solar LLC',
#   'Winton Solar LLC'],
#  '100 Mill Rd': ['Port Townsend Paper Co'],
#  '100 N. Tenth Street10th & Waln': ['NRG Energy Center Paxton LLC'],
#  '100 Newark Way': ['Newark America'],
#  '100 North 2nd Street': ['City of Lamar - (CO)'],
#  '100 North Howard Avenue': ['City of Croswell - (MI)'],
#  '100 Park Ave': ['BASF Corporation'],
#  '100 Progress Place': ['Midland Cogeneration Venture'],
#  '100 Route 206 North': ['KDC Solar PFI LLC'],
#  '100 SCANA Parkway': ['Dominion Energy South Carolina, Inc'],
#  '100 Shore Point Drive': ['Shore Point Solar LLC'],
#  '100 South Railroad Avenue     ': ['ARP-Loyalton Cogen LLC        '],
#  '100 South State St. PO Box 264': ['Renewable World Energies LLC'],
#  '100 State Street': ['Framingham State University'],
#  '100 Summit Lake Dr': ['Consolidated Edison Energy, Inc.'],
#  '100 Summit Lake Drive': ['Consolidated Edison Development Inc.',
#   'Consolidated Edison Solutions Inc'],
#  '100 Supply Rd': ['Georgia-Pacific LLC'],
#  '100 Towers Road': ['Vestas Towers America, Inc'],
#  '100 Tryon Road': ['First Citizens Bank'],
#  '100 W. Old Wilson Bridge Road,': ['Outagamie Clean Energy Project LLC'],
#  '100 West County Rd Y': ['Winnebago County'],
#  '100 West Fourth Street': ['City of Waterloo - (IL)'],
#  '100 West Main Street': ['Haviland Plastic Products Co'],
#  '100 West Mexitli St': ['NextEra Energy Resources Ensign Wind'],
#  '100 West Second Street': ['City of Julesburg - (CO)'],
#  '100 Woods Road': ['Westchester County Medical Center'],
#  '100 World Drive': ['Ralls Wind Farm LLC'],
#  '1000 East Main Street': ['Mount Joy Wire Corp', 'Duke Energy Indiana, LLC'],
#  '1000 GSK Drive': ['GlaxoSmithKline Consumer Healthcare L P'],
#  '1000 Industrial Highway': ['Liberty Electric Power LLC'],
#  '1000 Louisana StreetSuite 5800': ['Sithe/Independence LLC'],
#  '1000 Main Street': ['Petra Nova Power I LLC'],
#  '1000 North Village Avenue': ['Mercy Medical Center'],
#  '1000 W Mount Pleasant Rd': ['Georgia-Pacific Cons Op LLC Port Hudson'],
#  '1000 Western Avenue': ['General Electric Aircraft Engines'],
#  '10000 Ming Ave': ['Aera Energy LLC-Coalinga'],
#  '10001 County Rd 19': ['Cimarron Wind Energy LLC'],
#  '1001 13th Avenue East': ['Tropicana Products Inc'],
#  '1001 Airport Road': ['Chattanooga Metropolitan Airport'],
#  '1001 Carroll Island Road': ['CP Crane Power, LLC'],
#  '1001 Fanin': ['WM Illinois Renewable Energy LLC', 'WM Renewable Energy LLC'],
#  '1001 Pawtucket Blvd': ['Scatter Solar - Mashpee Landfill'],
#  '1002 Adams Parkway': ['Waverly Municipal Elec Utility'],
#  '1002 Harbor Hills Dr': ['Upper Peninsula Power Company'],
#  '1003 Paper Mill Rd': ['Mobile Energy LLC'],
#  '1003 South 5th Street': ['Roquette America'],
#  '100302 Yates Well Road': ['NRG Energy Services'],
#  '1005 Ridge Road': ['Town of Munster'],
#  '1007 Market Street': ['DuPont Sabine River Works'],
#  '10098 Old Ridge Road': ['Doswell Ltd Partnership'],
#  '101 2nd St. Ste. 1250': ['Fresh Air Energy XVIII, LLC'],
#  '101 2nd St., Ste. 1250': ['Fresh Air Energy X, LLC'],
#  '101 Barclay Street': ['The Bank of New York'],
#  '101 Court Street': ['City of Jackson - (MO)'],
#  '101 East Spring Street': ['City of St Marys - (OH)'],
#  '101 Hofstra University': ['Hofstra University'],
#  '101 Lake St South': ['City of Mora - (MN)'],
#  '101 Madison St #100': ['Ameren Missouri'],
#  '101 N Browning Parkway': ['City of Farmington - (NM)'],
#  '101 North 3rd Street': ['American Crystal Sugar Co'],
#  '101 S King Street': ['Riverside Renewable Energy'],
#  '101 S. Hickory': ['City of Ottawa - (KS)'],
#  '101 Second St.': ['Ecoplexus, Inc'],
#  '101 South Main St': ['Village of New Knoxville - (OH)'],
#  '101 Summer Street, 2nd Floor': ['Newfield Solar LLC',
#   'Chester Woods Point Solar, LLC',
#   'Plainfield Solar LLC',
#   'Westminster Renewables, LLC',
#   'Tanglewood Circle Solar 1 LLC',
#   'Griffin Road Solar, LLC',
#   'Hadley 2 Solar, LLC',
#   'Monson Solar, LLC',
#   'Route 14A CDG Solar North and South, LLC',
#   'Ashby Solar, LLC'],
#  '101 W. Washington St. Ste. 140': ['Veolia Energy Kansas City'],
#  '101 West 2nd Street': ['City of Laurel - (NE)'],
#  '101 lst Street SE': ['City of Wells - (MN)'],
#  '1010 Power Plant Drive': ['Steamboat Development Corp'],
#  '1011 North Third Street': ['City of Alexandria - (LA)'],
#  '1015 Briggs Road': ['California Power Holdings LLC'],
#  '1016 Russel Street': ['City of Orangeburg - (SC)'],
#  '102  W Main Street': ['City of McLeansboro - (IL)'],
#  '102 Greenwich Ave, 3rd Floor': ['Altus Power America Management, LLC'],
#  '102 Main St Suite 200': ['Energy Operations Group LLC (MN)'],
#  '102 North U Ave.': ['City of Villisca - (IA)'],
#  '10203 Strang Road': ['LaPorte Power, LLC'],
#  '1024 Central Street': ['Errol Hydroelectric Co LLC',
#   'Granite Reliable Power',
#   'Great Lakes Hydro America LLC',
#   'Pontook Operating LP',
#   'Brookfield Power New England',
#   'Brookfield Black Bear Hydro, LLC'],
#  '10289 102nd Street': ['USS DVL Solar CSG'],
#  '103 Adams Ave.103 Adams Ave.': ['Lewiston City of'],
#  '1031 Bells Branch Rd': ['Soluga Farms 1 LLC'],
#  '10319 S. Pleasants Hwy': ['Pleasants Energy LLC'],
#  '1032 Grandview Drive': ['C-Drop',
#   'Drop 5 Hydro LLC',
#   'Wood Hydro, LLC',
#   'Shavano Falls Hydro LLC ? Shavano Project',
#   'North Gooding Main Hydro LLC',
#   'Dry Creek LLC',
#   'Shavano Falls Hydro LLC - Drop 4 Project',
#   'Turnbull Hydro LLC',
#   'Tiber Montana LLC',
#   'Marsh Valley Development Inc',
#   'Birch Power Co',
#   'Sprague Hydro LLC'],
#  '10323 Lomond Drive': ['South Boston Energy LLC'],
#  '10330 Page Industrial Blvd.': ['StraightUp Solar'],
#  '10350 Scocrates Mine Road': ['Geysers Power Co LLC'],
#  '10350 Socrates Mine Road': ['Calpine Corporation'],
#  '1036 SE DouglasAveCthouseRm306': ['Douglas County'],
#  '104 E 2nd': ['City of Ellinwood - (KS)'],
#  '104 East Riverside St.': ['WestRock Corp'],
#  '104 North 6th Street': ['American Wind Energy Management Corp.'],
#  '104 North 6th Street, 2nd Floo': ['Springfield Project Development LLC'],
#  '104 South Pine Street': ['North Central Power Co Inc'],
#  '104 South Section Avenue': ['Spring Valley Pub Utils Comm'],
#  '104 West South Street': ['City of Arcanum - (OH)'],
#  '1040 Monument St': ['City of Danville - (VA)'],
#  '1040 Spring Street': ['United Therapeutics Corporation'],
#  '10400 Helios Way': ['Topaz Solar Farms LLC'],
#  '1041 Route 202/206': ['CIP II/AR Bridgewater Holdings LLC'],
#  '1042 W Hedding Ste 100': ['IPT SRI Cogeneration Inc'],
#  '1043 Case Ave': ['City of Wrangell - (AK)'],
#  '1043 Road P': ['Abengoa Bioenergy Biomass of Kansas'],
#  '1044 North 115th Street': ['Lincoln Generating Facility LLC',
#   'Crete Energy Venture LLC'],
#  '1046 Forty Oaks': ['Hamilton Wind Energy LLC', 'Norsemen Wind Energy, LLC'],
#  '1046 Wylie Street SE': ['Rowan Solar NC LLC'],
#  '105 Jarvis Street': ['City & Borough of Sitka - (AK)'],
#  '105 NCO Drive': ['158th Fighter Wing'],
#  '105 Smith County Rd. 25': ['Georgia-Pacific Wood Products LLC'],
#  '10500 Buckingham Road': ['Lee County Board-Commissioners'],
#  '1053 100th Ave': ['Capella Community Solar'],
#  '1055 SW Lake Ct': ['Central Oregon Irrigation Dist'],
#  '1055 Westlakes Dr.': ['SS PA II PSU LLC'],
#  '106 Central Street': ['Wellesley College'],
#  '106 East Clay': ['City of Albany - (MO)'],
#  '106 N 8th Street': ['United Water Conservation Dist'],
#  '106 N. 2nd Street': ['City of Sargent - (NE)'],
#  '106 Point Drive North': ['Dunkirk Power LLC'],
#  '106 W. Bourke St.': ['City of Macon - (MO)'],
#  '10600 Nations Ford Road': ['Enerdyne Power Systems Inc'],
#  '1065 Woodman Drive': ['Dayton Power & Light Co'],
#  '1068 Cole Creek Road': ['Duke Energy DEGS Campbell Hill'],
#  '107 Flynn Drive, Suite 100': ['State Auto Insurance, Inc.'],
#  '107 N Kent Street': ['Frederick County Virginia'],
#  '1070 CR 55': ['Chapman Ranch Wind LLC'],
#  '1070 Erie Avenue': ['North American Energy Services'],
#  '1070 Riverside Drive': ['Woodbridge Energy Center'],
#  '10714 South Jordan Gateway': ['Deseret Generation & Tran Coop'],
#  '1073 North Benson Road': ['Fairfield University'],
#  '1075 East 20th Street': ['Sierra Nevada Brewing Co'],
#  '1075 W. Sam Houston Parkway N.': ['Sweeny Cogeneration LP'],
#  '1077 Absecon Boulevard': ['ACB Energy Partners LLC'],
#  '10777 West 700 North': ['Bos Dairy, LLC'],
#  '108 East Main Street': ['City of Casey - (IL)'],
#  '108 National Street': ['Milford Power LLC'],
#  '108 W 8th Street': ['TPW Petersburg LLC'],
#  '108 West Saginaw Street': ['City of St Louis - (MI)'],
#  '10812 Hwy 66 NE': ['Wilton Wind II LLC', 'Ashtabula Wind II LLC'],
#  '1084 205th Street E': ['USS East Hauer Watt Solar CSG'],
#  '10844 Ellis Ave': ['Orange County Sanitation Dist'],
#  '109 N E Second Street': ['City of Fairfield- (IL)'],
#  '109 Second Street': ['City of Monroe City - (MO)'],
#  '10900 Birchwood Dr': ['Birchwood Power Partners LP'],
#  '10900 Euclid Ave': ['Case Western Reserve University'],
#  '11 Beacon Street, Suite 1120': ['Westford Solar Park'],
#  '11 Clearwater Drive': ['Little Rock Wastewater Utility'],
#  '11 East 44th Street, Suite 120': ['Greenbacker Renewable Energy Corporation'],
#  '11 Merrill Industrial Drive': ['Foss Manufacturing Company LLC'],
#  '11 W Bridge Avenue  PO Box 65': ['Delano Municipal Utilities'],
#  '110 12 Ave SW': ['Big Level Wind LLC'],
#  '110 E Seneca Street': ['Alliance NYGT, LLC'],
#  '110 East Seneca Street': ['Sterling Power Partners LP'],
#  '110 Goldthwaite Road': ['Maine Waste to Energy'],
#  '110 Phoenixville Pike, Suite 1': ['SunEast Skyline Solar LLC',
#   'SunEast Hills Solar LLC',
#   'SunEast Clay Solar LLC',
#   'SunEast Dog Corners Solar LLC',
#   'SunEast Watkins Road Solar LLC'],
#  '110 W 7th Street, Suite 2300': ['Targa Pipeline Mid-Continent West OK LLC'],
#  '110 W Main Street': ['City of Sebewaing - (MI)'],
#  '110 West Columbia Street': ['City of Farmington - (MO)'],
#  '110 West First Street': ['City of Madison - (NE)'],
#  '1100 Harbor Blvd': ['AES Redondo Beach LLC'],
#  '1100 Louisiana Street': ['Enbridge'],
#  '1100 Louisiana, Suite 3300': ['Cedar Point LLC'],
#  '1100 Main Street': ['Trenton Municipal Utilities - (MO)'],
#  '1100 N Eastern Ave, Rm 300': ['Los Angeles County'],
#  '1100 North Tower Avenue': ['City of Centralia - (WA)'],
#  '1100 Superior Avenue NE': ['Cleveland Cliffs Inc'],
#  '1100 West 116th Avenue': ['Tri-State G & T Assn, Inc'],
#  '1101 Connectivut Avenue NW': ['Sol Systems'],
#  '1101 County Road 190': ['NRG Energy Inc'],
#  '1101 Market St': ['Philadelphia Water Department'],
#  '11010 65 St NE': ['Caelum Community Solar'],
#  '11011 East Highway 120': ['South San Joaquin Irr District'],
#  '11013 West Broad St.': ['Mead Coated Board Inc'],
#  '11013 West Broad Street': ['WestRock (TX)'],
#  '11021 Brower Rd': ['Vistra Energy Miami Fort'],
#  '1105 Elm Cove': ['Community Renewables, LLC'],
#  '1108 3rd Ave': ['City of Sibley - (IA)'],
#  '1108 Main St #402 Owyhee Plaza': ['Mt. Home Solar 1, LLC'],
#  '1109 Industrial Park Road': ['City of Rock Falls - (IL)'],
#  '111 County Hwy U': ['Whitewater Operating Services LLC'],
#  '111 Duke Street': ['Resolute Forest Products'],
#  '111 East 210 Street': ['Montefiore Medical Center Moses Division'],
#  '111 Hickson Drive': ['Jamison Solar Farm'],
#  '111 Market PlaceSuite 500': ['CER Generation LLC'],
#  '111 No 100 East': ['City of Washington - (UT)'],
#  '111 Ponce De Leon Ave': ['United States Sugar Corp'],
#  '111 Red Bluff Road': ['Pasadena Refining System Inc'],
#  '111 S Chestnut Street': ['City of Lamoni - (IA)'],
#  '111 Speen St': ['Ameresco Butte County LLC'],
#  '111 Speen St., Suite 410': ['Otter River Road Solar LLC'],
#  '111 Speen St.Suite 410': ['AMERESCO Chiquita Canyon LLC',
#   'AMERESCO Stafford LLC',
#   'AMERESCO Jefferson City LLC',
#   'AMERESCO Keller Canyon LLC',
#   'AMERESCO Ox Mountain Energy LLC'],
#  '111 Speen Street': ['Ameresco Forward, LLC',
#   'Ameresco Dallas LLC',
#   'Ameresco San Joaquin, LLC',
#   'Ameresco Vasco Road, LLC',
#   'Ameresco Johnson Canyon LLC'],
#  '111 Speen Street Suite 410': ['Ameresco, Inc - Weston',
#   'Ameresco, Inc - Candlewood',
#   'Ameresco, Inc - Braintree',
#   'Ameresco, Inc - GELD'],
#  '111 Speen Street, Suite 410': ['Ameresco BWC Wading River LLC',
#   'Montevue Lane Solar, LLC',
#   'Ameresco Glendale Road Solar PV LLC'],
#  '111 Speen StreetSuite 410': ['AMERESCO Delaware Central',
#   'AMERESCO Santa Cruz Energy LLC',
#   'AMERESCO Delaware South',
#   'AMERESCO Janesville LLC',
#   'AMERESCO Chicopee Energy LLC'],
#  '111 W Ocean Blvd., Suite 800': ['THUMS Long Beach Company'],
#  '111 W. Jefferson Street': ['Boise Cascade Wood Products LLC'],
#  '111 West Franklin': ['City of Bloomfield - (IA)'],
#  '111 Woodmere Road, Suite 250': ['91MC 8me LLC',
#   '41MB 8me, LLC',
#   '54 KR 8me LLC',
#   '64KT 8me LLC'],
#  '11100 Anderson Street': ['Loma Linda University'],
#  '11101 W 120th Ave, Suite 400': ['West Chicago Battery Storage LLC',
#   'Joliet Battery Storage LLC',
#   'Maverick Creek Wind, LLC'],
#  '11101 W. 120th Avenue': ['Harvest Wind Energy, LLC',
#   'Summit Lake Wind, LLC'],
#  '11101 West 120th Ave': ['Rock County Energy Center, LLC'],
#  '11101 West 120th Avenue': ['Battery Utility of Ohio LLC'],
#  '1111 Airline Hwy 61': ['Gramercy Holdings LLC'],
#  '1111 Amsterdam Ave': ['Mt.Sinai-St.Lukes Rsvlt. Hospital Center'],
#  '1111 Blakely Dam Rd': ['USCE -Vickburg District'],
#  '1111 Hawthorne Lane': ['Chowan Jehu Road Solar, LLC',
#   'Shiloh Hwy 1108 Solar, LLC',
#   'Darlington Solar, LLC',
#   'Sandy Solar, LLC'],
#  '1111 Hawthorne Lane, Suite 201': ['Barnwell Solar, LLC',
#   'Hampton Solar I, LLC',
#   'St. Matthews Solar, LLC',
#   'Odyssey Solar, LLC',
#   'Saluda Solar II, LLC',
#   'Cameron Solar II, LLC',
#   'SP Solar 5, LLC',
#   'HCE Moore I, LLC'],
#  '1111 Hawthorne Ln': ['Lane Solar Farm LLC',
#   'Warrenton Solar I LLC',
#   'Sadiebrook Solar LLC',
#   'Bladenboro Farm 2 LLC',
#   'Quarter Horse Farm LLC',
#   'Atkinson Solar II LLC'],
#  '1111 Hawthorne Ln, Ste 201': ['Woodline Solar, LLC',
#   'Sheep Solar, LLC',
#   'Haley Solar, LLC',
#   'Freedom Solar, LLC',
#   'Novel Solar Three, LLC',
#   'Peony Solar, LLC',
#   'Page Solar Farm, LLC',
#   'Southern Current One, LLC',
#   'Champion Solar, LLC',
#   'SP Solar 6, LLC',
#   'Silverton Solar, LLC',
#   'Swamp Fox Solar, LLC',
#   'Norwest Energy 7, LLC',
#   'SP Solar 8, LLC',
#   'NorWest Energy 14, LLC',
#   'SP Solar 7, LLC',
#   'SP Solar 1, LLC'],
#  '1111 Hawthrone Lane, Suite 201': ['Three Bridge Farm, LLC'],
#  '1111 Saint-Charles Street West': ['Horseshoe Bend Hydroelectric Co'],
#  '1111 Schrock Road, Suite 100': ['American Mun Power-Ohio, Inc'],
#  '1115 BroadwayP O Box 218': ['City of Highland'],
#  '1115 North Tower Road': ['Prairie Lakes Municipal Solid Waste Auth'],
#  '1119 15 501 Hwy South': ['Moore Solar Farm LLC',
#   'Wilson Farm 1 LLC',
#   'Lenoir Farm 2 LLC',
#   'Roxboro Farm LLC',
#   'AM Best Farm',
#   'Rock Farm LLC',
#   'Yanceyville Farm LLC',
#   'Dixon Dairy Road',
#   'Mile Farm LLC',
#   'Haynes Farm LLC',
#   'New Bern Farm LLC',
#   'Marshville Farm LLC',
#   'McCallum Farm LLC',
#   'Mt Olive Farm 2 LLC',
#   'Dibrell Farm LLC',
#   'White Cross Farm LLC',
#   'Bolton Farm LLC',
#   'Two Lines Farm LLC',
#   'Lenoir Farm LLC',
#   'Moorings Farm LLC'],
#  '1119 US 15 501 Hwy South': ['Watts Farm LLC',
#   'Belwood Farm LLC',
#   'Warrenton Farm LLC',
#   'Farrington Solar Farm LLC',
#   'Mocksville Lessee LLC',
#   'Railroad Farm LLC',
#   'Strata Fund 2 Lessee LLC'],
#  '112 East Grand': ['City of Gallatin - (MO)'],
#  '112 Telly Street': ['NRG South CentralOperationsInc',
#   'NRG Sterlington Power LLC'],
#  '112 Turnpike Road, Suite 202': ['Great River Hydro, LLC'],
#  '112 Washington Street': ['Hollingworth & Vose Co Center Falls',
#   'Hollingsworth & Vose Co West Groton'],
#  '112 West Broadway': ['City of Stafford - (KS)'],
#  '112 West Main Street': ['New London Municipal Utilities'],
#  '1120 East Huron Street': ['University of Michigan'],
#  '1120 SW 5th Avenue,  Room 530': ['Portland City of'],
#  '1124 Victory Trail Road': ['Broad River Energy LLC'],
#  '1125 E Morehead St': ['Rhubarb One LLC'],
#  '1125 E Morehead Street, Suite': ['Tamworth Holdings, LLC'],
#  '1125 E. Morehead Street': ['Holstein Holdings, LLC'],
#  '1125 E. Morehead Street Suite': ['McLean Homestead, LLC'],
#  '1125 E. Morehead Street, Suite': ['Shorthorn Holdings, LLC',
#   'Soy Solar LLC',
#   'Quail Holdings, LLC',
#   'Warbler Holdings, LLC',
#   'Howardtown Farm, LLC',
#   'Cotton Solar, LLC',
#   'Friesian Holdings, LLC',
#   'Bradley Farm LLC',
#   'Tanager Holdings, LLC',
#   'Collard Holdings, LLC',
#   'Peanut Solar LLC',
#   'Whitetail Solar LLC'],
#  '1125 Executive Circle, STE 130': ['Sigurd Solar LLC'],
#  '1125 NW Couch , Ste. 700': ['Avangrid Renewables LLC'],
#  '1125 Trenton-Harbourton Road': ['Janssen Pharmaceutical Co'],
#  '11260 Roger Bacon Drive': ['CB&I'],
#  '113 N. 2nd Street': ['Fort Pierce Utilities Authority'],
#  '113 Physical Plant Bldg.': ['Penn State University'],
#  '113 S. Gex': ['City of La Plata - (MO)'],
#  '113 South 4th Street': ['City of Marshall - (MN)'],
#  '1131 South Dee Road': ['Maine Township High School Dist 207'],
#  '1132 Gabbs Valley Road': ['ORNI 37 LLC', 'ORNI 47, LLC'],
#  '11330 Vanstory Drive, Suite 10': ['ReNew Petra Integrators, LLC'],
#  '11385 Wild Meadow Place': ['Summit Water Nexus, Mount Holly, LLC'],
#  '114 N. Broad Street': ['City of Salem - (VA)'],
#  '114 North Broadway': ['City of Sterling - (KS)'],
#  '114 South Del Rosa Ave': ['San Bernardino Comm College Dist'],
#  '11400 Parkside Drive': ['SunCoke Energy, Inc.'],
#  '11401 Bloomfield Ave': ['Metropolitan State Hospital'],
#  '11455 El Camino Real Suite 160': ['Buenos Aires Windpower LLC'],
#  '11455 El Camino Real, Suite 16': ['TG High Prairie Wind, LLC'],
#  '1147 N Daybreak Dr.': ['Homestretch Geothermal LLC'],
#  '115  S Jackson St': ['City of Arcadia - (WI)'],
#  '115 AABC': ['Ptarmigan Res & Engy Inc'],
#  '115 E 4th Street': ['City of St. John - (KS)'],
#  '115 Industrial Drive': ['Duke Energy DEGS North Allegheny'],
#  '115 South Sumner Street': ['City of Oxford - (KS)'],
#  '115 West Main St': ['City of Mt Pleasant - (UT)'],
#  '1150 E. Santa Fe': ['City of Gardner - (KS)'],
#  '1150 N. 3400 E.': ['Fall River Rural Elec Coop Inc'],
#  '1150 Northbrook Dr': ['Gamesa Wind US'],
#  '1150 Northbrook Drive': ['Gamesa Wind US LLC'],
#  '1151 Bannock St': ['SunShare', 'SunShare Management'],
#  '1151 Valley Mall Parkway': ['PUD No 1 of Douglas County'],
#  '1152 Furuby Rd': ['Chisago Community Solar'],
#  '11537 State Route 19A': ['Allegany Generating Station, LLC'],
#  '11543 Lake of Egypt Road': ['Southern Illinois Power Coop'],
#  '1155 Conshohocken Road': ['Covanta Plymouth Renewable Energy L P'],
#  '11550 Ash St, Ste 300': ['Kenyon Energy KS Solar 1 LLC'],
#  '1157 Main Road': ['Washington Island El Coop, Inc'],
#  '116 North Main St USA': ['City of Marceline - (MO)'],
#  '11600 Mexico Farms Road': ['AES WR Ltd Partnership'],
#  '11610 N College Avenue': ['Indiana Municipal Power Agency'],
#  '1166 AVENUE OF THE AMERICAS': ['Willow Spring Solar LLC'],
#  '1166 Ave of the Americas': ['Power County Wind Park North LLC'],
#  '1166 Avenue of the Americans 9': ['DWW Solar ll LLC'],
#  '1166 Avenue of the Americas': ['Marion Solar LLC',
#   'Lamesa Solar II, L.L.C.',
#   'Searchlight Solar LLC',
#   'Willow Spring',
#   'Durbin Creek',
#   'MS Solar 2, LLC',
#   'North Star Solar PV LLC',
#   'Lake County Solar LLC',
#   'Tulare PV II LLC',
#   '63SU 8me, LLC',
#   'Jett Creek',
#   '62SK 8me, LLC',
#   'Keystone Solar, LLC',
#   'Prospector',
#   'D E Shaw & Co., LP',
#   'Power County Wind Park South LLC',
#   'Red Horse 2',
#   'Forbes Street Solar, LLC',
#   'Benson Creek',
#   'Tulare PV I LLC',
#   'Balko Wind LLC',
#   'Kawailoa Wind LLC'],
#  '1166 Avenue of the Americas 9t': ['Cuyama Solar, LLC'],
#  '1166 Avenue of the Americas, 3': ['St. James Solar, LLC'],
#  '1166 Avenue of the Americas, 9': ['Fusion Solar Centre, L.L.C',
#   'Orchard Windfarm, LLC',
#   'Red Horse III',
#   'Portal Ridge Solar, LLC',
#   'Airport Solar LLC',
#   'TPE Alta Luna, LLC',
#   'Rancho Seco Solar, LLC',
#   'DESRI V Mass Solar Holdco, LLC',
#   'Imperial Valley Solar 2, LLC',
#   'Kona Solar, LLC',
#   'Gray Hawk Solar, LLC'],
#  '11661 San Vicente Blvd.': ['PCS Energy, LLC         '],
#  '117 East Third St': ['Coastal Community Action Program'],
#  '117 S Main': ['City of Fayette - (MO)'],
#  '11757 Katy Freeway, Suite 400': ['First Solar Asset Management'],
#  '11765 E Mountain View Ave': ['KES Kingsburg LP'],
#  '1177 West Loop South Ste 900': ['Northeastern Power Co'],
#  '11777 Bay Area Blvd': ['Air Liquide Large Industries U S LP'],
#  '118 Central Ave North': ['New Prague Utilities Comm'],
#  '118 East Main St': ['City of State Center - (IA)'],
#  '1185 N Concord St': ['E&E Enterprises LLC'],
#  '1189 South Fifth Avenue': ['Louisiana Sugar Refining LLC'],
#  '119 E. Front Street': ['City of Stuart - (IA)'],
#  '119 East Michigan Ave.': ['Village of Clinton - (MI)'],
#  '119 South Maple Street': ['Kearsarge Bellingham LLC'],
#  '119 Third Street SW': ['Franklin Heating Station'],
#  '11900 Midlothian Turnpike': ['MSM Solar LLC'],
#  '1193 E Winding Creek Dr., Ste': ['Windland Inc'],
#  '11936 Rosamond Blvd': ['Solar Star California XX, LLC'],
#  '1195 Beal Road': ['Brooks Energy, LLC'],
#  '11970 Grays HWY': ['Moffett Solar 1, LLC'],
#  '1199 Prince Avenue': ['Athens Regional Medical Center'],
#  '12 Mill Brook Road': ['Plainfield Renewable Energy, LLC'],
#  '12 North 7th Avenue': ['Montefiore Mount Vernon Hospital'],
#  '12 S First Street Suite 616': ['Bakersfield 111 LLC'],
#  '120 Armstrong Blvd South City': ['City of St James - (MN)'],
#  '120 Boxelder': ['City of Mulvane - (KS)'],
#  '120 Chiefs Way STE 1 PMB 222': ['Solar Park Gainesville, LLC'],
#  '120 E. 5th  Street': ['Capricorn Ridge Wind LLC'],
#  '120 First Street': ['Village of Swanton - (VT)'],
#  '120 Maplewood Drive': ['Hazleton Generation LLC'],
#  '120 North Ozark': ['City of Girard - (KS)'],
#  '120 Pier S Avenue': ['SERRF Joint Powers Authority'],
#  '120 Tredegar St': ['Moorings Farm 2, LLC',
#   'Pikeville Farm, LLC',
#   'Summit Farms LLC'],
#  '120 Tredegar St.': ['Mustang Solar LLC'],
#  '120 Tredegar Street': ['Dominion Energy Inc',
#   'Virginia Electric & Power Co'],
#  '1200 Arcy Lane': ['Delta Energy Center LLC'],
#  '1200 Discovery Dr.': ['Sentinel Peak Resources California, LLC'],
#  '1200 East California Blvd': ['California Institute-Technology'],
#  '1200 East Colton Ave. P.O. Box': ['University of Redlands'],
#  '1200 East First Avenue': ['Anchorage Municipal Light and Power'],
#  '1200 Main St.': ['KCP&L Greater Missouri Operations Co'],
#  '1200 Main Street': ['Kansas City Power & Light Co'],
#  '1200 N. Mountain': ['University of Arizona'],
#  '1200 North Second Street': ['Bunge North America East LLC'],
#  '1200 Ridgeway Avenue, Suite 21': ['RED-Rochester, LLC'],
#  '1200 Soldiers Field Rd.': ['Kearsarge Granby LLC',
#   'Kearsarge Concord II LLC',
#   'Kearsarge Oppenheim LLC'],
#  '1200 Soldiers Field Road Suite': ['Kearsarge Johnstown 2 LLC',
#   'Kearsarge Johnstown 1 LLC'],
#  '1200 Soldiers Field Road, Suit': ['Kearsarge GB LLC',
#   'Kearsarge Gill LLC',
#   'Kearsarge SKSC2 LLC',
#   'Kearsarge Wilmington LLC',
#   'Kearsarge Uxbridge LLC',
#   'Kearsarge SKSC1 LLC',
#   'Kearsarge Montague LLC'],
#  '1200 Wilson Dr. West': ['QVC Inc'],
#  '1200-10423 101 Street, NW': ['Capital Power Corporation'],
#  '12000 1st Ave.': ['Colorado River Indian Irr Proj'],
#  '12000 BLK Hiram Clarke Road': ['Friendswood Energy Genco, LLC'],
#  '1201 1st Street': ['Cosmo Specialty Fibers'],
#  '1201 Fannin Street': ['NRG Cedar Bayou Development Company LLC',
#   'NRG Texas Power LLC'],
#  '1201 Louisiana Street, Suite 3': ['Pattern Operators LP'],
#  '1201 N. Kinzie Avenue': ['CSL Behring LLC'],
#  '1201 RD 7': ['Caney River Wind Project'],
#  '12011 Sunset Hills Road, Suite': ['Renovo Energy Center'],
#  '1203 North Hobart': ['Midcoast G&P (Oklahoma) LP'],
#  '1205 Bottom St.': ['Victoria WLE, LP'],
#  '1206 First Ave': ['Aurora Energy LLC'],
#  '1207 Long Pond Road': ['Pocono International Raceway Inc'],
#  '1209 Orange St.': ['Gloversville Community Solar LLC'],
#  '121 DeKalb Avenue': ['Brooklyn Hospital Center'],
#  '121 E Front Street': ['Heritage Garden Wind Farm I LLC'],
#  '121 E. Front StSuite 200': ['Heritage Stoney Corners Wind Farm I LLC'],
#  '121 E.Front St': ['Gichi Noodin Wind Farm, LLC'],
#  '121 SW  Salmon Street': ['Portland General Electric Co'],
#  '1212 New York Avenue, N.W., Su': ['Astra Wind LLC'],
#  '1214 Church Street': ['Nashville Electric Service'],
#  '12152 Road 28 1/4': ['Madera-Chowchilla Power Auth'],
#  '1216 Second St  SW': ["St Mary's Hospital"],
#  '1218 Third Avenue Suite 1800': ['William G. Reed Jr'],
#  '122 South Van Rensselaer': ['City of Rensselaer - (IN)'],
#  '1220 Pacific Highway, Bldg 321': ['Department of the Navy'],
#  '12200 Ashcake Rd': ['Belcher Solar LLC'],
#  '1221 Power Drive': ['Rocky Road Power LLC'],
#  '1221 W. Idaho Street': ['Idaho Power Co'],
#  '1222 First Avenue': ['City of San Diego'],
#  '12220 590th Avenue': ['Mapleton Community Solar'],
#  '1225 North State Street': ['Mississippi Baptist Medical'],
#  '1225 Progress Drive': ['Hastings Lock & Dam'],
#  '1226 Port Road': ['Nome Joint Utility Systems'],
#  '1228 North Denver Avenue': ['City of Hastings - (NE)'],
#  '123 Bridge Street': ['City of Piqua - (OH)'],
#  '123 First St SEPO Box 129': ['City of Hopkinton - (IA)'],
#  '123 Main Street': ['New York Power Authority'],
#  '12300 Elm Creek Boulevard': ['Great River Energy'],
#  '12307 S. Florence Ave.': ['Green Country OP Services LLC'],
#  '1231 Main Road P.O. Box 317': ['Covanta Maine LLC'],
#  '1232 Haco DriveP O Box 13307': ['Lansing Board of Water and Light'],
#  '12367 Township Road 215': ['Findlay Wind Farm'],
#  '12385 Township Road 215': ['OEE XIX, LLC',
#   'OEE XXV LLC',
#   'OEE XXX LLC',
#   'OEE XVII, LLC',
#   'OEE XXVI LLC',
#   'OEE XXIII LLC',
#   'OEE XXIV LLC',
#   'OEE XXVIII LLC'],
#  '124 West Court Avenue': ['City of Winterset - (IA)'],
#  '1241 Whitefield Rd': ['Pinetree Power Inc'],
#  '12424 Wilshire Blvd': ['Sunpin Holdings, LLC'],
#  '12424 Wilshire Blvd Suite 660': ['Concord Blue Eagar, LLC'],
#  '125 East Seventh Street': ['Blue Earth Light & Water'],
#  '125 Old Bastrop Rd': ['Bastrop Energy Partners, LP'],
#  '125 Shore Road': ['Casco Bay Energy Co LLC'],
#  '125 West Jefferson Street': ['City of Memphis - (MO)'],
#  '1250 I Street NW Suite 300': ['Grizzly Wind LLC'],
#  '1250 I Street NW, Suite 300': ['Black Bear Wind LLC'],
#  '1250 W. Washington St.': ['Andeavor'],
#  '12500 Baltimore Ave': ['SunE M5 Holdings LLC',
#   'South Street Solar, LLC',
#   'SunE SPS1, LLC',
#   'SunE CPA CDC1 LLC',
#   'SunE WG113 Moreno Valley LLC',
#   'SunE U6 Holdings LLC',
#   'SunE WG45 Woodland LLC',
#   'River Mountains Solar, LLC',
#   'SunE Alamosa1 LLC',
#   'SunE CPA CDC2 LLC'],
#  '12500 Baltimore Ave.': ['SunE SPS5, LLC',
#   'SunE SPS3, LLC',
#   'SunE SPS4, LLC',
#   'SunE GIL1, LLC',
#   'SunE NLB-2, LLC',
#   'SunE NC Progress 1 LLC',
#   'SunE SPS2, LLC',
#   'SunE WF3-ST Holdings, LLC'],
#  '12500 Baltimore Avenue': ['SunE EPE2 LLC',
#   'TerraForm Solar XVII, LLC',
#   'BWC Origination 4, LLC',
#   'REUT Origination, LLC',
#   'SunE M5C Holdings LLC',
#   'Nexamp Treasure Valley Solar, LLC',
#   'SPS Atwell Island LLC',
#   'SunE EPE1 LLC',
#   'Axio Green LLC'],
#  '12500 Baltimore Drive': ['SunE SEM 1, LLC'],
#  '12509 Adkins Road': ['Darby Power, LLC'],
#  '1251 Waterfront Place': ['Innogy Renewables US LLC'],
#  '126 First Street': ['City of McGregor- (IA)'],
#  '126 No Marsall Ave': ['Litchfield Public Utilities'],
#  '126 West St.': ['The Trustees of Smith College'],
#  '1260 Security Road': ['Solar Hagerstown LLC'],
#  '12600 Deerfield Parkway': ['EthosEnergy Power Plant Services'],
#  '1261 Broadway': ['Powergen Development Group, LLC'],
#  '1265 Upsala Road, Ste. 1157': ['Humphrey Realty'],
#  '12695 County Road 32': ['USS King 2 CSG'],
#  '127 South Broadway': ['St. Joseph Hospital (NY)'],
#  '12700 Lake Francis Rd': ['Yuba County Water Agency'],
#  '12780 San Fernando Rd': ['PRC-Desoto Intl Corp./PPG'],
#  '128 N First': ['City of Osborne - (KS)'],
#  '128 Sun Street Suite 100': ['Salinas Valley Solid Waste Authority'],
#  '128 West Second Street': ['City of Salisbury - (MO)'],
#  '1280 Park Center Drive,': ['Watkins Manufacturing Corporation'],
#  '1280 West North Street': ['Energy Center Dover LLC'],
#  '1281 Powerhouse Dr. S.E.': ['CPI USA NC Southport LLC'],
#  '12819 N. Skull Valley Rd.': ['US Magnesium'],
#  '12837 Route 438': ['Seneca Nation'],
#  '129 7th St': ['Pisgah Mountain, LLC'],
#  '129 North School Ave. P.O. Box': ['Boise-Kuna Irrigation District'],
#  '1295 Franklin Boulevard': ['University of Oregon'],
#  '1299 Orleans Drive': ['Bloom Energy'],
#  '12A Titcut St': ['Massachusetts Department of Correction'],
#  '13 Elm Street, Suite 200': ['Fairhaven Wind LLC',
#   'RoxWind LLC',
#   'Scituate Wind LLC'],
#  '13 Pratts Junction Road': ['Anderson Power Products'],
#  '130 Camelot Drive, Suite 2': ['Camelot Wind LLC'],
#  '130 Main Street': ['Aclara Meters LLC'],
#  '130 North Nottawa Street': ['City of Sturgis'],
#  '130 North Washington': ['PUD No 1 of Pend Oreille County'],
#  '130 Oak Creek': ['Oregon State University'],
#  '130 S  Galena Street': ['City of Aspen- (CO)'],
#  '130 Second Ave N W': ['Sleepy Eye Public Utility Comm'],
#  '130 W First  Street': ['City of Stanberry - (MO)'],
#  '1300 13th Street North': ['Corn Belt Power Coop'],
#  '1300 Lakeside Avenue': ['City of Cleveland - (OH)'],
#  '1300 Morris Park Avenue': ['Albert Einstein College of Medicine'],
#  '1300 N Broad St. PO Box 1748': ['Gastonia City of'],
#  '1300 N Northlake Way': ['Ridgeline Energy LLC'],
#  '1300 North 17th Street': ['Power Choice/Pepco Energy Serv'],
#  '1300 South Mopac Expressway': ['New-Indy Ontario LLC'],
#  '13000 Jameson Road': ['Terra-Gen 251 Wind, LLC'],
#  '1301 Broadway': ['City of Lubbock - (TX)'],
#  '1301 McKinney St': ['PAR Petroleum'],
#  '1302 Waugh #896': ['Sky Global Power One Pledgor, LLC'],
#  '1303 East Division': ['City of Barron - (WI)'],
#  '1303 East Herndon': ['Saint Agnes Medical Center'],
#  '1303 S 8th Street': ['Manitowoc Public Utilities'],
#  '1304 South Main Street': ['East Kansas Agri-Energy, LLC'],
#  '13065 Plant Road': ['Major Oak Power, LLC'],
#  '13069 Orono Parkway': ['City of Elk River'],
#  '131 E. 2nd': ['City of Flora - (IL)'],
#  '131 Main Street PO Box 80': ['City of Coggon - (IA)'],
#  '1310 Point St': ['Constellation Solar Rhode Island LLC'],
#  '1310 Point St, 13th Floor': ['JBAB Solar I, LLC.',
#   'California PV Energy 2, LLC'],
#  '1310 Point St. 13th Floor': ['Constellation Solar Georgia 2, LLC'],
#  '1310 Point St., 13th Floor': ['Constellation Solar MC, LLC'],
#  '13113 East Phillips Ave': ['Armadillo Flats Wind Project, LLC'],
#  '13116 Imperial Hwy': ['Golden Springs Development Company LLC'],
#  '1313 South Columbus Ave.': ['PUD No 1 of Klickitat County'],
#  '132 Case Drive': ['Glopak Corporation'],
#  '132 North York Street Suite 3L': ['GlidePath Power Operations LLC'],
#  '132 Peoples Creek Road': ['Cherokee County Cogen Partners LLC'],
#  '132 US Submarine Vet Mem Hwy': ['Covanta Southeastern Connecticut Company'],
#  '13200 Main Street': ['Searles Valley Minerals Operations Inc.'],
#  '1321 Hjartarson Road': ['NaturEner Glacier Wind Energy 1 LLC',
#   'NaturEner Glacier Wind Energy 2 LLC'],
#  '1325 Airmotive Way, Ste. 370': ['X-Elio North America Inc'],
#  '133 Federal Street, Suite 1202': ['Rio Bravo Windpower, LLC'],
#  '133 Peachtree Street NE': ['GP Center Holdings LLC',
#   'Georgia-Pacific Monticello LLC'],
#  '133 South Blair Street': ['Madison Gas & Electric Co'],
#  '1330 Greengate Dr.': ['Rain CII Carbon LLC'],
#  '134 East 40th St': ['Elizabeth Mines Solar 1, LLC'],
#  '134 N Industrial St134 N Indus': ['Pioneer Prairie Wind Farm I, LLC'],
#  '1340 Echelon Pkwy': ['System Energy Resources, Inc'],
#  '1345 Avenue of the Americas': ['Long Ridge Energy Generation LLC'],
#  '1349 River Road': ['Kleen Energy Systems, LLC'],
#  '135 E. 57th St., Fl. 6': ['Sunlight General Solar Fund II, LLC',
#   'Sunlight General Somerset Solar LLC',
#   'RE Cranbury Solar 1, LLC',
#   'Sunlight General Mercer Solar LLC',
#   'Sunlight General Morris Solar LLC'],
#  '135 Humphrey Service Building': ['Cornell Hydro'],
#  '135 Humphreys Service Building': ['Cornell University'],
#  '135 Intervale Rd': ['Simonds Saw LLC'],
#  '135 Main St., 6th Floor': ['First Solar Project Development'],
#  '1350 17th St., Suite 150': ['RIT Henrietta Solar 1, LLC'],
#  '1350 Beardshear Hall': ['Iowa State University'],
#  '1350 Landmark Towers345 Saint': ['St Paul Cogeneration LLC'],
#  '1355 Piccard Drive Suite 300': ['Standard Solar'],
#  '136 Harrison Ave': ['Rockford Generation LLC'],
#  '136 S. Main Street, Ste 600': ['Patua Acquisition Company, LLC'],
#  '136 South Main Street': ['Lightning Dock Geothermal HI-01, LLC'],
#  '1360 19th Hole Drive Suite 200': ['Mendocino Forest Products'],
#  '1360 Post Oak Blvd, Suit 2000': ['GenOn Northeast Management Company',
#   'NRG Wholesale Generation LP',
#   'GenOn California South, LP',
#   'GenOn Canal, LLC',
#   'GenOn REMA, LLC',
#   'GenOn New York, LLC',
#   'GenOn Florida, LP',
#   'GenOn Chalk Point, LLC',
#   'GenOn Mid-Atlantic LLC',
#   'GenOn Power Midwest, LP'],
#  '13612 Midway Road': ['BT Cooke Solar, LLC',
#   'BT Kellam Solar LLC',
#   'BT Coniglio Solar LLC'],
#  '1363 Down River Drive': ['Roseburg LFG Energy LLC'],
#  '13682N  2900 East Road': ['Old Trail Wind Farm LLC',
#   'High Trail Wind Farm LLC'],
#  '137 Newbury St, 4th Floor': ['BWC Salmon Brook, LLC',
#   'BWC French River, LLC'],
#  '13700 Dauphin Island Parkway': ['W&T Offshore Inc'],
#  '1375 Fort Martin Road': ['Longview Power, LLC'],
#  '138 Jackson St.P.O. Box 3': ['City of Brooklyn - (IA)'],
#  '138 West Karcher Road': ['Amalgamated Sugar Co-Nampa'],
#  '1380 San Pablo Ave': ['Phillips 66 Company'],
#  '13800 Biola Avenue': ['Biola University'],
#  '13833 195 Ave SE': ['Spica Community Solar'],
#  '13860 Ballantyne Corporate Pla': ['SEPG Operating Services, LLC Effingham',
#   'SEPG Operating Services, LLC MGC'],
#  '13865 Sunrise Valley Drive': ['WGL Energy Systems, Inc'],
#  '13870 N 570th Ave': ['Bishop Hill Energy II, LLC'],
#  '139 E Fourth St': ['Solar Star North Carolina I LLC',
#   'Duke Energy DEGS Notrees'],
#  '139 E Fourth Street': ['Duke Energy Kentucky Inc', 'Taylorsville Solar LLC'],
#  '139 E. 4th Street': ['RP-Orlando, LLC'],
#  '139 E. Forth St.Mail Drop: EA5': ['TX Solar I LLC'],
#  '139 East 4th St': ['Martins Creek Solar NC, LLC'],
#  '139 East Fourth Street, Mail D': ['CS Murphy Point, LLC',
#   'Murphy Farm Power, LLC'],
#  '1395 County Rd 1A': ['Dynegy Hanging Rock Energy Facility'],
#  '14 North Marshall Ave': ['Springfield Public Utils Comm - (MN)'],
#  '14 Southgate Drive': ['Village of Freeburg - (IL)'],
#  '14-25 Bay 24th Street': ['Jamaica Bay Peaking Facility, LLC'],
#  '140 Broadway, 28th floor': ['Innovative Solar 31, LLC'],
#  '140 South Capital Avenue': ['City of Idaho Falls - (ID)'],
#  '1400 Dinosaur Point  Hwy 152 D': ['International Turbine Res Inc'],
#  '1400 Highway 101 South': ['BMW Manufacturing Co LLC'],
#  '1400 Jack Warner Pkwy NE': ['The Westervelt Co'],
#  '1400 Pacheco Pass Hwy': ['Calpine Gilroy Cogen LP'],
#  '1400 Radio Road': ['Silicon Valley Clean Water'],
#  '1400 Ridgely Street': ['Trigen Inner Harbor East, LLC'],
#  '1400 SE Butler Bridge Road': ['Georgia-Pacific Toledo LLC'],
#  '1400 W Ninth Street': ['Brunswick Cellulose LLC'],
#  '14008 Fruit Farm Rd': ['Orion Community Solar'],
#  '1401 4th St E': ['Antares Community Solar'],
#  '1401 County Line Road': ['Dynegy Kendall Energy LLC'],
#  '1401 Lakeside Dr': ['County of Alameda GSA'],
#  '1401 McKinney Street, Ste 1800': ['Moundsville Power, LLC'],
#  '1401 McKinney Street, Suite 18': ['Navasota Energy Generation Holdings'],
#  '1401 Omni Way': ['APTIM Environmental & Infrastructure'],
#  '1401 S Douglas Rd': ['Frontier El Dorado Refinery LLC'],
#  '1401 Walnut Street Suite 220': ['GR Catalyst One, LLC'],
#  '1401 Walnut Street Suite 420': ['Quinebaug Associates LLC'],
#  '1401 Walnut Street, Suite 420': ['Great Bay Hydro Corp',
#   'Hitchcock Hydro, LLC',
#   'C-S Canal Hydro, LLC'],
#  '1403 New Boston Road': ['Tolland Solar NG LLC'],
#  '1405 Foulk Road, Suite 100': ['LSE Canis Minor LLC', 'LSE Canis Major LLC'],
#  '1409 Iron Road': ['Cloud County Windfarm, LLC'],
#  '141 Cranberry Hwy': ['SEMASS Partnership'],
#  '141 N Glendale Ave': ['City of Glendale - (CA)'],
#  '1410 Kansas Avenue': ['City of Benson - (MN)'],
#  '1410 Red Hat Road': ['Morgan Energy Center LLC'],
#  '1411 Third Street': ['AltaGas Blythe Operations Inc'],
#  '14111 Capital Blvd': ['CenturyLink Regional HQ'],
#  '14120 Ballantyne Corporate Pla': ['Entropy Investment Management, LLC'],
#  '1414 15th Street': ['Nebraska Public Power District'],
#  '1414 Blue Hills Ave': ['Pepperidge Farm, Inc.- Bloomfield'],
#  '1414 Harbour Way': ['Solar Star Arizona II LLC',
#   'Solar Star Arizona III LLC'],
#  '1414 Harbour Way South': ['Solar Star Arizona XIII, LLC',
#   'Solar Star California XLVIII, LLC',
#   'Solar Star California XL, LLC',
#   'White Oak Solar Energy LLC',
#   'Solar Star Colorado II LLC',
#   'Solar Star California XXXI, LLC',
#   'Kern Highschool District Solar,LLC',
#   'Solar Star California LXIII, LLC',
#   'Solar Star California XXXII, LLC',
#   'SunPower Corporation, Systems',
#   'Solar Star New Jersey IV, LLC',
#   'Good Fellow Solar 1 PH1, LLC',
#   "Northstar Macy's Maryland 2015, LLC",
#   'Solar Star California XV, LLC'],
#  '1414 Harboy Way South': ['Solar Star Colorado III, LLC'],
#  '1415 Wyckoff Road': ['NJR Clean Energy Ventures Corporation'],
#  '142 Lower Lyndon St': ['Algonquin Northern Maine'],
#  '1420 Coil Av #C': ['Konoike Pacific'],
#  '1420 US Highway 2016 Suite 120': ['KDC Solar O&M LLC'],
#  '1420 US Highway 206 Suite 120': ['KDC Solar CSCP LLC', 'KDC Solar ASGM LLC'],
#  '1421 Veterans ParkwayPO Box 16': ['Columbus Water Works'],
#  '1422 West Lake Street Suite 30': ['Kimball Wind, LLC'],
#  '1423 CR 131': ['Trent Wind Farm LP'],
#  '1423 Rock Springs Road410-658-': ['Essential Power Rock Springs LLC'],
#  '1424 Bob Barton Road': ['Blind Canyon Aqua Ranch Inc'],
#  '14240 Merchant Energy Way': ['Shady Hills Power Co LLC'],
#  '1425 8th Ave PO Box 400': ['Beaver Falls Municipal Auth'],
#  '1425 Bay 24th Street': ['Bayswater Peaking Facility LLC'],
#  '1425 Corporate Center Drive': ['WPPI Energy'],
#  '1426 E 750 N, Suite 400': ['Central Utah Water Conservancy District'],
#  '1427 Meadow Wood Blvd': ['North Carolina Mun Power Agny #1'],
#  '143 Highway 130P.O. Box 404': ['Pedricktown Cogeneration Company LP'],
#  '143 West Street': ['FirstLight Power Resources Services LLC'],
#  '14302 FNB Parkway': ['Tenaska Pennsylvania Partners, LLC',
#   'CSOLAR IV West LLC',
#   'Tenaska Georgia Partners LP',
#   'Tenaska Alabama B LP',
#   'Tenaska Frontier Partners Ltd',
#   'Tenaska Nobles 2 Power Partners, LLC',
#   'Tenaska Gateway Partners Ltd',
#   'Tenaska Virginia Partners LP',
#   'Kiowa Power Partners LLC',
#   'CSOLAR IV South LLC',
#   'Tenaska Alabama Partners LP'],
#  '14310 Frederick St': ['Riverside County Waste Management Dept'],
#  '1435 Ford Avenue': ['Lafarge Corp'],
#  '1438 Eastland Drive North': ['K-W Co'],
#  '144 Main Street': ['Woodland Pulp LLC'],
#  '1441 Schilling Place ? North B': ['Monterey Cnty Water Res Agency'],
#  '14436 Landfill Road': ['Hernando Energy        '],
#  '1447 S Tryon St': ['Burgaw Solar, LLC'],
#  '1447 S Tryon St, Ste 201': ['Pecan Grove Solar, LLC',
#   '1025 Traveller Solar, LLC',
#   '1047 Little Mountain Solar, LLC',
#   'Ennis Solar, LLC'],
#  '14486 Borax Road': ['U S Borax Inc'],
#  '145 Rosemary Street, Suite E': ['Equity Industrial Turbines'],
#  '145 Town and Country Dr.': ['Contra Costa Generating Station LLC'],
#  '1450 Somerset Avenue': ['Dighton Power, LLC'],
#  '14535 FM 1267': ['Palo Duro Wind'],
#  '14550 N Frank Lloyd Wright': ['Northbrook Carthage LLC'],
#  '14550 N Frank Lloyd Wright Blv': ['Allegheny Hydro LP'],
#  '14550 N Frank Lloyd Wright Ste': ['STS Hydropower, LLC',
#   'Northbrook Carolina Hydro LLC'],
#  '14550 N. Frank Lloyd Wright': ['Northbrook Wisconsin LLC',
#   'EIF Haypress LLC'],
#  '14587 County Road 8 50': ['Weaver Bridgewater Dairy'],
#  '147 Lumber Street': ['Hopkinton MA 1, LLC'],
#  '1470 Riveredge Parkway NW': ['Municipal Electric Authority'],
#  '14700 Downey Avenue': ['Paramount Petroleum Corporation'],
#  '148 E Hail Street': ['City of Bushnell - (IL)'],
#  '14933  416th Ave': ['Burke Wind LLC'],
#  '14933 416th Avenue': ['Day County Wind LLC'],
#  '14950 Cooperative Place, PO Bo': ['SMECO Solar LLC'],
#  '14950 W. Schulte Rd.': ['MRP San Joaquin Energy LLC.'],
#  '14961 Ballou Circle': ['Coram Tehachapi LP'],
#  '1498 West SR 14': ['Hidden View Dairy, LLC'],
#  '1499 Routes 1 & 9 North': ['Covanta Union Operations LLC'],
#  '15 Agawam Avenue': ['NAEA Energy Massachusetts LLC'],
#  '15 East Silver St.': ['Silverstreet Hydro'],
#  '15 Edgewater Road': ['Hull Municipal Light Plant'],
#  '15 Pine Street': ['Palmer Hydroelectric'],
#  '15 West Third Street': ['Atlantic Municipal Utilities'],
#  '150 3rd Ave S, Suite 200': ['Providence Solar Center, LLC'],
#  '150 3rd Ave S, Suite 2000': ['SR Camden, LLC', 'SR Mavericks, LLC'],
#  '150 3rd Ave South': ['SR Enterprise South LLC'],
#  '150 3rd Ave South, Suite 2000': ['SR Innovation, LLC'],
#  '150 3rd Ave. S': ['Hattiesburg Farm, LLC'],
#  '150 3rd Ave. S Suite 200': ['SR Jenkins, LLC'],
#  '150 3rd Ave. S, Ste 2000': ['SR Houston Holdings, LLC',
#   'SR Skylark B, LLC',
#   'Selmer North Solar I, LLC',
#   'SR South Loving, LLC',
#   'Selmer North Solar II, LLC',
#   'SR Millington, LLC',
#   'SR Kersey, LLC'],
#  '150 3rd Ave. S, Ste. 2000': ['SR Hazlehurst, LLC'],
#  '150 3rd Ave. S, Suite 2000': ['SR Clinch'],
#  '150 3rd Avenue South': ['Simon Solar Farm LLC'],
#  '150 Baker Drive': ['WE 90 Technology Drive LLC'],
#  '150 Dorset St.': ['Charlotte Solar LLC'],
#  '150 East Fourth Street, Suite': ['Mark Technologies Corp'],
#  '150 La Terraza Blvd.': ['Oak Creek Energy System Inc II'],
#  '150 Main Street': ['Brookfield White Pine Hydro LLC',
#   'Hydro Kennebec LLC',
#   'Merimil Ltd Partnership',
#   'Brassua Hydroelectric LP'],
#  '150 Mathilda Place': ['SEDC Jersey Gardens Owner LLC',
#   'CF Gainesville Owner One LLC',
#   'CF Jersey Gardens Owner Two LLC'],
#  '150 Mathilda Place Suite 206': ['CF SBC Master Tenant One LLC'],
#  '150 Mathilda Place, Suite 206': ['Clean Focus Renewables, Inc.'],
#  '150 Mathlida Place': ['CF CVEC Owner One LLC'],
#  '150 N. Dairy Ashford': ['Equilon Enterprises LLC d/b/a Shell Oil'],
#  '150 North Michigan': ['Chilocco Wind Farm LLC'],
#  '150 Orford Road': ['Record Hill Wind LLC'],
#  '150 Porter Road': ['Town of Braintree - (MA)'],
#  '150 South Los Robles': ['City of Pasadena - (CA)'],
#  '150 Warrenville RoadMail Code': ['BP America Inc'],
#  '150-C N. Dairy Ashford Rd': ['Shell Wind Energy Inc.'],
# ...
#  '1523 King Street': ['Blacktip Solar, LLC'],
#  '1523 US Route 9 North': ['Cape May County Municipal'],
#  '1524 King Street': ['Bloom Solar, LLC'],
#  '1525 Howe Street': ['S.C. Johnson & Son, Inc.'],
#  '1525 King Street': ['Bond Solar, LLC'],
#  '1525 Miltner Street': ['Cadillac Renewable Energy LLC'],
#  '15250 Blue Mountain Road': ['NGP Blue Mountain I LLC'],
#  '1526 King Street': ['Gary Solar, LLC'],
#  '1527 King Street': ['Goldenrod Solar, LLC'],
#  '1528 3rd Ave': ['City of Rock Island'],
#  '1528 King Street': ['Jessamine Solar, LLC'],
#  '1528 Walnut Street': ['Customized Energy Solutions'],
#  '1530 NC HWY 306 SOUTH': ['PCS Phosphate'],
#  '1531 King Street': ['River Solar, LLC'],
#  '1532 King Street': ['Sapphire Solar, LLC'],
#  '1533 King Street': ['South Solar, LLC'],
#  '1534 King Street': ['Vincent Solar, LLC'],
#  '1535 King Street': ['Watauga Solar, LLC'],
#  '1536 King Street': ['Whitt Solar, LLC'],
#  '15367 Avenue A': ['Solar Star California XIX, LLC'],
#  '1537 King Street': ['Willis Solar, LLC'],
#  '15445 Innovation Dr': ['EDF Renewable Services Inc'],
#  '15445 Innovation Drive': ['Copenhagen Wind Farm, LLC',
#   'Silver Star I Power Partners LLC',
#   'Trinity Hills Wind Farm LLC',
#   'Sherbino II Wind Farm LLC',
#   'EDF Renewable Asset Holdings, Inc.',
#   'Glaciers Edge Wind Project LLC'],
#  '15445 innovation Dr': ['Arrow Canyon Solar LLC'],
#  '1545 US Highway 206': ['KDC Solar RTC LLC'],
#  '1545 US Route 206': ['KDC Solar Bergen 1', 'KDC Solar GRQ LLC'],
#  '15455 Innovation Drive': ['Desert Harvest, LLC', 'Maverick Solar, LLC'],
#  '155 Elmira Loop': ['Starrett City Inc'],
#  '155 Federal Street': ['ACE-Stanton A, LLC',
#   'ACE-Stanton, LLC',
#   'Finger Lakes Solar I, LLC'],
#  '155 Fleet Street': ['Antrim Wind Energy LLC'],
#  '155 Grand Ave': ['Orion Energy Group LLC'],
#  '155 Maple Street': ['ANP Bellingham Energy Company LLC'],
#  '155 N. Wacker Drive, Suite 425': ['Half Moon Ventures, LLC'],
#  '155 North 400 West': ['Utah Associated Mun Power Sys'],
#  '155 W Nationwide Blvd': ['Pavant Solar III LLC'],
#  '155 W Nationwide Suite 400': ['AEP Onsite Partners'],
#  '155 W. Nationwide Suite 400': ['AEP Renewables'],
#  '1555 S Harding Street': ['Eli Lilly and Company'],
#  '15551 Highway 23 South, P.O. B': ['Phillips 66'],
#  '1559 Gifford Rd': ['Elgin Energy Center LLC'],
#  '15615 County Road 53': ['USS Eggo Solar CSG'],
#  '15625 Stafford Avenue': ['City of Industry'],
#  '15696 Energy Rd.': ['Westlake Chemical Natrium Plant'],
#  '157 Church Street': ['GenConn Middletown LLC'],
#  '157 Church StreetPO Box 1564': ['GenConn Devon LLC'],
#  '1575 Sherman Farm Road': ['Ocean State Power Co', 'Ocean State Power II'],
#  '1579 CR 1600': ['Rush Springs Wind Project'],
#  '15801 E First Street': ['MillerCoors Irwindale Brewery'],
#  '15820 Barclay Drive': ['ENERGYneering Solutions, Inc'],
#  '1584 TAMU': ['Texas A&M, Utilities & Energy Services'],
#  '1585 Broadway': ['Carson Solar 1 LLC'],
#  '15921 Highway 301': ['North 301 Solar        '],
#  '1595 W. Longview Ave.': ['Broshco Fabricated Products'],
#  '15968 San Juan Road': ['Sun Harvest Solar, LLC'],
#  '16 Business Park Way': ['Depot Park Solar Farm'],
#  '16 Church Street, PO Box 699': ['SFR Hydro Cor'],
#  '16 Orbit Lane': ['Windsor Machinery Co Inc'],
#  '16 South Golden Street': ['City of Norwich - (CT)'],
#  '16 Squadron Boulevard #106': ['Palmer Solar LLC'],
#  '160 Felgar Street': ['University of Oklahoma'],
#  '160 Greentree Drive Suite 101': ['BWC Origination 18, LLC'],
#  '160 Hood Way': ['HP Hood LLC'],
#  '160 S Hayes Avenue': ['City of Primghar - (IA)'],
#  '1600 County Road 603': ['TX Jumbo Road Wind, LLC'],
#  '1600 Dodge Avenue': ['Evanston Board of Education'],
#  '1600 N Priest Drive': ['AES ES GILBERT, LLC'],
#  '1600 Perdido Street': ['Entergy New Orleans, LLC'],
#  '1600 Walker Street': ['Gregory Power Partners LP'],
#  '1600 West 12th Avenue': ['Denver City & County-Foothills',
#   'Denver City & County of'],
#  '1601 Francis Harris Ln.': ['Hays Energy, LLC'],
#  '1601 West Diehl Road': ['Nalco Co'],
#  '1605 N. Cedar Crest Blvd., Sui': ['EPP Renewable Energy'],
#  '1605 N. Cedar Crest Boulevard,': ['Otay Landfill Gas LLC c/o EPP Service Company, LLC'],
#  '16060 SW 85th Ave': ['Clean Water Services'],
#  '1609 Heritage Commerce Ct.': ['2016 ESA Project Company, LLC'],
#  '16111 Plummer St., Bldg 1 Rm B': ['VA Sepulveda Ambulatory Care Center'],
#  '1615 Braeswood': ['Texas Medical Center Central'],
#  '1615 Poydras St.': ['Cox Operating LLC'],
#  '1615 Stanley Street': ['Central Connecticut State University'],
#  '1626 East Jefferson Street': ['FRIT Solar Inc'],
#  '1628 2nd Ave. SE': ['Novel Energy Solutions'],
#  '163 Acorn Lane': ['Green Mountain Power Corp'],
#  '163 Cedar Street': ['Seneca Power Partners LP'],
#  '1630 23rd Ave  Ste 101': ['Ford Hydro Ltd Partnership'],
#  '1631 211th Street': ["Shane's Wind Machine LLC"],
#  '16313 North Dale Mabry Highway': ['Seminole Electric Cooperative Inc'],
#  '1633 Broadway': ['Paramount Group Inc'],
#  '1633 S Roberts St. Suite A': ['Novel Martin Solar One LLC'],
#  '1634 Locust St.': ['Generate Fremont Digester, LLC.'],
#  '1637 41st St.': ['Antlia Community Solar'],
#  '1639 320th St': ['Junction Hilltop Management LLC'],
#  '164 Harmony Rd': ['Athens Energy, LLC'],
#  '164 W. Magnolia Blvd.': ['City of Burbank Water and Power'],
#  '16400 Mattawoman Drive': ['KMC Thermo, LLC'],
#  '1641 Kains Ave': ['Solvida Energy Group/Blue Oak Energy'],
#  '1644 E 100 Rd': ['Prairie Horizon Agri Energy LLC'],
#  '1645 S 101 E. Ave': ['USCE-Tulsa District'],
#  '16490 Riverside Ave': ['NRG Solar Blythe II LLC'],
#  '165 Barefoot Rd': ['Southbridge Recycling and Disposal Park'],
#  '1650 190th St W': ['Ursa Community Solar'],
#  '1650 Lilly Road': ['Evonik Degussa Corporation'],
#  '1651 West Derby Avenue': ['Auburndale Peaker Energy Center LLC'],
#  '1654 King Street Suite 9': ['MFGR LLC'],
#  '1656 Champlain Avenue': ['Burrstone Energy Center'],
#  '1656 McCarthy Boulevard': ['CoreSite Real Estate 1656 McCarthy, L.P.'],
#  '16617 140th St': ['Leonardo Wind 1 LLC'],
#  '1665 Auen Rd Suite C': ['Pennsylvania Renewable Resources'],
#  '1665 US Hwy 29': ['Spencer Farm, LLC'],
#  '16650 228th Ave SE': ['Bio Energy Washington, LLC'],
#  '1674 Red Brick Rd.': ['Lee County Generating Station'],
#  '168 Division Street': ['Michigan South Central Power Agency'],
#  '168 Worcester Rd': ['Town of Princeton - (MA)'],
#  '16804 427th Ave SE': ['CHI West Inc'],
#  '169 Main Street': ['Woonsocket City of'],
#  '1695 Martin Luther King Drive': ['Walton Bainbridge LLC'],
#  '17 Flagg Hill Road': ['Wind Colebrook South'],
#  '17 High Street': ['Plymouth State University'],
#  '17 South First Street': ['Owyhee Irrigation District'],
#  '17-10 Steinway Street': ['Astoria Energy LLC', 'Astoria Energy II LLC'],
#  '170 N. Radnor Chester Rd ? Sui': ['Laurel Capital Partners'],
#  '170 Power Boulevard': ['PEI Power Corp'],
#  '170 W. 12th Avenue': ['Falls Creek Hydroelectric Project LP'],
#  '170 Williams Street': ['NYP-Lower Manhattan Hospital'],
#  '1700 Eaton Dr': ['City of Grand Haven - (MI)'],
#  '1700 Wade Hampton Boulevard': ['Bob Jones University'],
#  '1700 Washington Avenue': ['E.B. Eddy Paper Inc'],
#  '1701   Cherry Street': ['City of Goodland - (KS)'],
#  '17017 Alpine Road West': ['Tungsten Mountain'],
#  '1701A Spencer Rd': ['City of Denton - (TX)'],
#  '171 Rolling Meadows Road': ['Innovative Solar 47, LLC'],
#  '171 West 4800 South': ['City of Murray - (UT)'],
#  '1710 29th St  #1068': ['Juwi Inc'],
#  '1710 29th Street, Suite 1068': ['Palmer Solar LLC'],
#  '17100 Calle Mariposa Reina': ['Freeport McMoRan Oil & Gas'],
#  '17115 Kenton Drive': ['O2energies, Inc.'],
#  '1716 Lawremce Drive': ['Sunny Templeton, LLC'],
#  '1716 Lawrence Drive': ['Gilbert Solar Facility I, LLC',
#   'Integrys MA Solar, LLC',
#   'Camden Solar Center, LLC',
#   'Solar Star New Jersey VI LLC',
#   'Solar Star California II LLC'],
#  '1717 E Interstate Ave': ['Basin Electric Power Coop'],
#  '1717 Langhorne-Newtown Road': ['Benson Power, LLC.'],
#  '1717 Omaha St.': ['City of Elroy - (WI)'],
#  '1717 West Loop South, Suite 18': ['Avalon Solar Partners II, LLC',
#   'Giffen Solar Park, LLC',
#   'PsomasFMG Lancaster Solar Crest, LLC',
#   'Frontier Solar, LLC',
#   'Sunray Energy 2, LLC',
#   'Five Points Solar Park, LLC',
#   'Sunray Energy 3 LLC',
#   'Wright Solar Park LLC',
#   'AL Solar A, LLC',
#   'Westlands Solar Farms, LLC',
#   'Grand View PV Solar Two, LLC',
#   'Blue Renewable Energy IMS, LLC',
#   'Three Peaks Power LLC',
#   'EE Kettleman California LLC'],
#  '1722 Routh Street, Suite 1300': ['EnLink Midstream Services, LLC'],
#  '173 Alford Street': ['Constellation Mystic Power LLC'],
#  '17300 N. Dallas Parkway Suite': ['Tri Global Energy, LLC'],
#  '17301 CR 97N': ['Blue Summit Storage, LLC', 'Blue Summit Wind LLC'],
#  '17301 Ridgeland Avenue': ['Panduit Corp'],
#  '1731 121st St': ['K-brink Windfarm, LLC'],
#  '1731 Hunterstown Rd': ['Kestrel Acquisition, LLC'],
#  '1732 W. Geneses Street': ['Middlesex Generating Company LLC'],
#  '1739 New Marigold Road': ['Prairie State Generating Co LLC'],
#  '1743 Gallegos Rd': ['Gallegos Wind Farm LLC'],
#  '175 East 200 North': ['City of St George'],
#  '175 East Old Country Rd.': ['National Grid Generation LLC'],
#  '1750 Inland Rd': ['International Paper - Orange'],
#  '1750 Power Plant Rd': ['NRG Homer City Services LLC'],
#  '1750 S. 14th Street, Suite 200': ['Eight Flags Energy LLC'],
#  '1751 Old Columbia Road': ['Cox Interior Inc'],
#  '1754 Alpine NW': ['Bay Windpower LLC'],
#  '1755 East Plumb LaneSuite 155': ['Enel Stillwater LLC'],
#  '17589 Plant Road': ['Bowater Newport Coosa Pines Op'],
#  '176 Mine Lake Court, Suite #10': ['Alpha Value Solar, LLC'],
#  '1760 Greenville Tpke': ['Greenville NY 1, LLC'],
#  '17685 Juniper Path': ['Energy Alternatives Wholesale LLC'],
#  '17702 Bear Mountain Blvd': ['ABEC #3 LLC'],
#  '1780 Hughes Landing, Suite 800': ['Topaz Power Group GP II, LLC'],
#  '1780 Smithfield Way': ['Smithfield Packaged Meats Corp'],
#  '1781 US Route 52': ['Dynegy W H Zimmer'],
#  '1785 WEYERHAEUSER RD': ['International Paper Co. - New Bern Mill'],
#  '1786 E. Kentucky Ave.': ['DTE Energy Services-Woodland'],
#  '179 Lincoln St, Suite 500': ['Sunflower Wind Project'],
#  '179 Lincoln Street': ['First Wind O&M, LLC'],
#  '179 Lincoln Street Suite 500': ['Milford Wind Corridor Stage II LLC'],
#  '17901 Von Karman Avenue': ['Northern Cardinal Solar LLC'],
#  '17901 Von Karman Avenue, Suite': ['BayWa r.e. Solar Projects LLC',
#   'Chestnut Solar LLC'],
#  '18 Kings Highway North': ['Chester Power Partners LLC'],
#  '180 Johnson Street': ['Greenskies'],
#  '180 Montgomery Street, Suite 2': ['Fluvanna Wind Energy 2 LLC'],
#  '1800 Bridgegate St. Suite 102': ['Dutch Energy Corporation',
#   'Garnet Energy Corporation'],
#  '1800 James Street': ['Black Creek Hydro Inc', 'Hydro Sierra Energy, LLC'],
#  '1800 James Street Suite 201': ['Smith Creek Hydro, LLC'],
#  '1800 Larimer St. Suite 1300': ['Foxtail Wind, LLC'],
#  '1800 Larimer Street': ['Public Service Co of Colorado'],
#  '1800 South Street': ['City of Geneva- (IL)'],
#  '1800 West Lake Shore Drive': ['Wells Manufacturing Co'],
#  '1801 Market Street, Suite 2701': ['Viridity Energy Solutions, Inc.',
#   'Stryker 22, L.L.C.',
#   'Plumsted 537 LLC'],
#  '1801 NE 123rd St': ['Minnie Solar LLC',
#   'Audrey Solar LLC',
#   'Milo Solar LLC',
#   'Star Solar LLC',
#   'Sophie Solar LLC',
#   'Amethyst Solar LLC',
#   'Owen Solar LLC'],
#  '1808 I-70 Drive SW': ['Missouri Jnt Muni.Pwr Elec. Ut. Comm.'],
#  '18101 Oakwood Blvd': ['Oakwood Hospital Med Center'],
#  '18111 Nordhoff Street': ['California State University, Northridge'],
#  '1815 Marine Drive': ['McKinley Paper Co. - Washington Mill'],
#  '1819 Woodville Rd': ['Toledo Refining Company'],
#  '1820 Midpark RoadSuite C': ['Ameresco'],
#  '1825 South Grant Street': ['Chuckawalla Solar LLC',
#   'GLT Cloverdale Solar LLC',
#   'Ironwood Solar LLC',
#   'NLH1 Solar LLC'],
#  '183 Raymond Blvd': ['Covanta Essex Company'],
#  '18327 720th Avenue': ['FPL Energy Story Wind LLC'],
#  '1839 Morganton Blvd': ['Bernhardt Furniture Company'],
#  '1840 N 10th Street': ['Temple University'],
#  '18422 Bear Valley Road': ['Victor Valley Community College District'],
#  '185 Charles Lindbergh Blvd': ['Nassau Energy Corp'],
#  '18600 S John Deere Road': ['John Deere Dubuque Works'],
#  '18610-50th Avenue East': ['Frederickson Power LP'],
#  '1866 Hestertown Road': ['NC Renewable Power - Lumberton LLC'],
#  '1870 Miner Circle Drive': ['Missouri University of Science and Technology'],
#  '1875 South West Street': ['City of Tulare Water Pollution Control'],
#  '188 CR 4900': ['Harvest Midstream Co'],
#  '188 M St': ['Covanta Springfield LLC'],
#  '1886 Upper Maple St': ['Frito Lay Incorporated Dayville'],
#  '1898 Highway 99': ['Light Beam Power Co LLC'],
#  '18982 293rd Ave': ['Paynesville Community Solar'],
#  '19 Northern Ave.': ['City of Earlville - (IA)'],
#  '19 Pine Tree Place': ['Caldwell Wastewater Treatment Plant'],
#  '19 S. 7th Street': ['Iowa Lakes Community College'],
#  '19 South Main StreetP O Box 40': ['City of Hillsboro - (ND)'],
#  '190 Greenhorn Road': ['Siskiyou Power Authority'],
#  '190 Route 18 North, Suite 205': ['Middlesex Energy Center LLC'],
#  '190 Tafts Avenue': ['Massachusetts Wtr Rauth-Deer I'],
#  '1900 1st Ave Suite 318': ['Southeast Alaska Power Agency'],
#  '1900 2nd Avenue No': ['City of Lake Worth - (FL)'],
#  '1900 E. Golf Rd. Suite 1030': ['Orange Grove Energy LP'],
#  '1900 East Golf Road': ['Equus Power I, L.P.,',
#   'Shoreham Energy LLC',
#   'Edgewood Energy LLC'],
#  '1900 East Golf Road, Suite 103': ['Jackson Generation, LLC'],
#  '1900 South Ave': ['GL Wind LLC'],
#  '1900 South Avenue': ['GL Dairy Biogas LLC',
#   'Gundersen Lutheran Biogas I LLC'],
#  '1901 Chouteau Avenue': ['Union Electric Co - (MO)'],
#  '1901 Harrison Street, Suite 15': ['Radian Generation'],
#  '1901 Jones Road': ['Paragould Light & Water Comm'],
#  '1901 S 4th St.': ['MRP Generation Holdings, LLC'],
#  '1901 S. Meyers Road,': ['ND Paper LLC'],
#  '1902 6th Avenue East': ['Hibbing Public Utilities Comm'],
#  '1902 River Rd': ['Fortistar Castleton Power'],
#  '19028 County Rd. 28': ['SR Platte'],
#  '1903 W. Michigan': ['Western Michigan University'],
#  '191 Main Street': ['Olsen Power Partners'],
#  '191 Peachtree Street NE Suite': ['Banyan St./GAP 191 Peachtree Owner, LLC'],
#  '1910 Holiday Lane': ['City of West Plains - (MO)'],
#  '19100 Ridgewood Parkway': ['Tesoro Refining and Marketing Co LLC'],
#  '19100 Von KarmanSuite 570': ['Rio Bravo Rocklin'],
#  '1911 River Road': ['Covanta Lancaster Inc'],
#  '19151 15th Avenue': ['NRG Solar Blythe'],
#  '1919 Alliant Energy Center Way': ['Dane County Public Works'],
#  '192 E Main St.': ['White River Hydroelectric'],
#  '192 Raceway Dr': ['SunEnergy1'],
#  '192 Raceway Dr.': ['Ranchland Solar, LLC', 'Williamston Speight Solar, LLC'],
#  '192 Raceway Drive': ['SunEnergy1-Scotland Neck, LLC',
#   'Conetoe Solar, LLC',
#   'Aulander Holloman Solar, LLC',
#   'Sugar Run Solar, LLC',
#   'Albertson Solar LLC',
#   'Choco Solar LLC'],
#  '1920 Dayton Avenue': ['National Centers for Animal Health'],
#  '19200 499th Avenue': ['Poet Biorefining Lake Crystal'],
#  '1921 Hamilton Avenue': ['Cleveland Thermal, LLC'],
#  '1922 State Road': ['Merlin One LLC'],
#  '1923 CR 431': ['NextEra Wolf Ridge LLC'],
#  '19318 Electron Rd. E.': ['Electron Hydro LLC'],
#  '194 West Court Street': ['City of Piggott - (AR)'],
#  '1940 Highway #1 North': ['Placid Refining Co LLC'],
#  '1941 Oak Tree Road STE # 102': ['East Blackland Solar Project 1 LLC'],
#  '19510 Jetton Rd': ['Mayberry Solar LLC'],
#  '1955 West Field Court': ['Boise Packaging & Newsprint LLC'],
#  '1959 Yoder Ave,SW': ['Farmers Electric Coop - (IA)'],
#  '1960 Roberts St': ['Lorin Industries'],
#  '1969 Hart Road': ['Beloit Memorial Hospital'],
#  '19696 Co Rd 9': ['Andromeda Community Solar'],
#  '1970 121st Street': ['Boeve Windfarm LLC'],
#  '1970 E Osceola Road        ': ['Seminole Energy, LLC        '],
#  '19765 13th ave': ['Hanford Renewable Energy LLC'],
#  '1979 Milky Way': ['Galactic Wind', 'Epic Hosting, LLC'],
#  '19797 180th Street': ['Vega Community Solar'],
#  '198 Sakatah Dr': ['Corvus Community Solar'],
#  '198 South 200 West Street': ['City of Bountiful'],
#  '1980 Crompond Road': ['NYP-Hudson Valley Hospital Center'],
#  '1985 County Club Road': ["Farmer's Irrigation District"],
#  ...}
