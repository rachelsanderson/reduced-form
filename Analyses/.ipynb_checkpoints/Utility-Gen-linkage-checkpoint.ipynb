# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 200
plt.rcParams['figure.figsize'] = [15, 10]

# %% [markdown]
# ## Read and fix data

# %%
dataDir = "../../Data for Tax Equity Project/eia_data/eia8602018/"

# %%
utils = pd.read_csv(dataDir + '/utility_2018.csv', header=1)
owners = pd.read_csv(dataDir + 'owner_2018.csv', header=1)

# %%
gen_data = pd.read_csv(dataDir + 'gen_2018.csv')
gen_data.drop(['Unnamed: 0'],axis=1,inplace=True)
gen_data = gen_data[~gen_data['Utility ID'].str.contains('NOTE', na=False)]
gen_data['Utility ID'] = pd.to_numeric(gen_data['Utility ID'])

# %%
utils.columns = utils.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
owners.columns =  owners.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
gen_data.columns = gen_data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
owners.columns =  owners.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
gen_data.set_index('utility_id',inplace=True)

# %%
merged = gen_data.merge(utils, how='left', on='utility_id')

# %%
merged[merged['operator_of_plants_reported_on_form?'].isna()]
# Out:
#        utility_id           utility_name_x  plant_code  \
# 0             195         Alabama Power Co         2.0
# 1             195         Alabama Power Co         3.0
# 2             195         Alabama Power Co         3.0
# 3             195         Alabama Power Co         3.0
# 4             195         Alabama Power Co         3.0
# ...           ...                      ...         ...
# 22112       62777  Burrstone Energy Center     62920.0
# 22113       62777  Burrstone Energy Center     62920.0
# 22114       62777  Burrstone Energy Center     62920.0
# 22115       62777  Burrstone Energy Center     62920.0
# 22117       62764    C2 Starratt Solar LLC     62940.0
#
#                     plant_name state_x      county generator_id  \
# 0                 Bankhead Dam      AL  Tuscaloosa            1
# 1                        Barry      AL      Mobile            1
# 2                        Barry      AL      Mobile            2
# 3                        Barry      AL      Mobile            4
# 4                        Barry      AL      Mobile            5
# ...                        ...     ...         ...          ...
# 22112  Burrstone Energy Center      NY      Oneida         CG-1
# 22113  Burrstone Energy Center      NY      Oneida         CG-2
# 22114  Burrstone Energy Center      NY      Oneida         CG-3
# 22115  Burrstone Energy Center      NY      Oneida         CG-4
# 22117           Starratt Solar      FL       Duval           PV
#
#                                    technology prime_mover unit_code  ...  \
# 0                  Conventional Hydroelectric          HY       NaN  ...
# 1                   Natural Gas Steam Turbine          ST       NaN  ...
# 2                   Natural Gas Steam Turbine          ST       NaN  ...
# 3                     Conventional Steam Coal          ST       NaN  ...
# 4                     Conventional Steam Coal          ST       NaN  ...
# ...                                       ...         ...       ...  ...
# 22112  Natural Gas Internal Combustion Engine          IC       NaN  ...
# 22113  Natural Gas Internal Combustion Engine          IC       NaN  ...
# 22114  Natural Gas Internal Combustion Engine          IC       NaN  ...
# 22115  Natural Gas Internal Combustion Engine          IC       NaN  ...
# 22117                      Solar Photovoltaic          PV       NaN  ...
#
#                 utility_name_y                  street_address          city  \
# 0             Alabama Power Co  P O Box 2641600 North 18th Str    Birmingham
# 1             Alabama Power Co  P O Box 2641600 North 18th Str    Birmingham
# 2             Alabama Power Co  P O Box 2641600 North 18th Str    Birmingham
# 3             Alabama Power Co  P O Box 2641600 North 18th Str    Birmingham
# 4             Alabama Power Co  P O Box 2641600 North 18th Str    Birmingham
# ...                        ...                             ...           ...
# 22112  Burrstone Energy Center           1656 Champlain Avenue  New Hartford
# 22113  Burrstone Energy Center           1656 Champlain Avenue  New Hartford
# 22114  Burrstone Energy Center           1656 Champlain Avenue  New Hartford
# 22115  Burrstone Energy Center           1656 Champlain Avenue  New Hartford
# 22117    C2 Starratt Solar LLC         55 5th Ave., 18th Floor      New York
#
#       state_y    zip owner_of_plants_reported_on_form?  \
# 0          AL  35291                                 Y
# 1          AL  35291                                 Y
# 2          AL  35291                                 Y
# 3          AL  35291                                 Y
# 4          AL  35291                                 Y
# ...       ...    ...                               ...
# 22112      NY  13413                                 Y
# 22113      NY  13413                                 Y
# 22114      NY  13413                                 Y
# 22115      NY  13413                                 Y
# 22117      NY  10003                                 Y
#
#       operator_of_plants_reported_on_form?  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 22112                                  NaN
# 22113                                  NaN
# 22114                                  NaN
# 22115                                  NaN
# 22117                                  NaN
#
#       asset_manager_of_plants_reported_on_form?  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 22112                                       NaN
# 22113                                       NaN
# 22114                                       NaN
# 22115                                       NaN
# 22117                                       NaN
#
#       other_relationships_with_plants_reported_on_form? entity_type
# 0                                                   NaN           I
# 1                                                   NaN           I
# 2                                                   NaN           I
# 3                                                   NaN           I
# 4                                                   NaN           I
# ...                                                 ...         ...
# 22112                                               NaN         COM
# 22113                                               NaN         COM
# 22114                                               NaN         COM
# 22115                                               NaN         COM
# 22117                                               NaN         IND
#
# [17647 rows x 83 columns]

# %%
# Out:
# utility_name
# state
# [None, None]

# %%
utils.columns
# Out:
# Index(['utility_name', 'street_address', 'city', 'state', 'zip',
#        'owner_of_plants_reported_on_form?',
#        'operator_of_plants_reported_on_form?',
#        'asset_manager_of_plants_reported_on_form?',
#        'other_relationships_with_plants_reported_on_form?', 'entity_type'],
#       dtype='object')

# %%
gen_data[gen_data['utility_name'] == 'Tennessee Valley Authority']
# Out:
#                           utility_name  plant_code                 plant_name  \
# utility_id
# 18642       Tennessee Valley Authority        46.0               Browns Ferry
# 18642       Tennessee Valley Authority        46.0               Browns Ferry
# 18642       Tennessee Valley Authority        46.0               Browns Ferry
# 18642       Tennessee Valley Authority        47.0                    Colbert
# 18642       Tennessee Valley Authority        47.0                    Colbert
# ...                                ...         ...                        ...
# 18642       Tennessee Valley Authority     55451.0       Magnolia Power Plant
# 18642       Tennessee Valley Authority     55451.0       Magnolia Power Plant
# 18642       Tennessee Valley Authority     55694.0  Quantum Choctaw Power LLC
# 18642       Tennessee Valley Authority     55694.0  Quantum Choctaw Power LLC
# 18642       Tennessee Valley Authority     55694.0  Quantum Choctaw Power LLC
#
#            state     county generator_id  \
# utility_id
# 18642         AL  Limestone            1
# 18642         AL  Limestone            2
# 18642         AL  Limestone            3
# 18642         AL    Colbert          GT1
# 18642         AL    Colbert          GT2
# ...          ...        ...          ...
# 18642         MS     Benton         STG2
# 18642         MS     Benton         STG3
# 18642         MS    Choctaw          CT1
# 18642         MS    Choctaw          CT2
# 18642         MS    Choctaw          ST1
#
#                                       technology prime_mover unit_code  \
# utility_id
# 18642                                    Nuclear          ST       NaN
# 18642                                    Nuclear          ST       NaN
# 18642                                    Nuclear          ST       NaN
# 18642       Natural Gas Fired Combustion Turbine          GT       NaN
# 18642       Natural Gas Fired Combustion Turbine          GT       NaN
# ...                                          ...         ...       ...
# 18642           Natural Gas Fired Combined Cycle          CA      MCC2
# 18642           Natural Gas Fired Combined Cycle          CA      MCC3
# 18642           Natural Gas Fired Combined Cycle          CT       CC1
# 18642           Natural Gas Fired Combined Cycle          CT       CC1
# 18642           Natural Gas Fired Combined Cycle          CA       CC1
#
#            ownership  ... planned_energy_source_1  \
# utility_id            ...
# 18642              S  ...                     NaN
# 18642              S  ...                     NaN
# 18642              S  ...                     NaN
# 18642              S  ...                     NaN
# 18642              S  ...                     NaN
# ...              ...  ...                     ...
# 18642              S  ...                     NaN
# 18642              S  ...                     NaN
# 18642              S  ...                     NaN
# 18642              S  ...                     NaN
# 18642              S  ...                     NaN
#
#            planned_new_nameplate_capacity_mw planned_repower_month  \
# utility_id
# 18642
# 18642
# 18642
# 18642
# 18642
# ...                                      ...                   ...
# 18642
# 18642
# 18642
# 18642
# 18642
#
#            planned_repower_year other_planned_modifications?  \
# utility_id
# 18642                                                    NaN
# 18642                                                    NaN
# 18642                                                    NaN
# 18642                                                    NaN
# 18642                                                    NaN
# ...                         ...                          ...
# 18642                                                    NaN
# 18642                                                    NaN
# 18642                                                    NaN
# 18642                                                    NaN
# 18642                                                    NaN
#
#            other_modifications_month other_modifications_year multiple_fuels?  \
# utility_id
# 18642                                                                       N
# 18642                                                                       N
# 18642                                                                       N
# 18642                                                                       Y
# 18642                                                                       Y
# ...                              ...                      ...             ...
# 18642                                                                       N
# 18642                                                                       N
# 18642                                                                       N
# 18642                                                                       N
# 18642                                                                       N
#
#            cofire_fuels? switch_between_oil_and_natural_gas?
# utility_id
# 18642                NaN                                 NaN
# 18642                NaN                                 NaN
# 18642                NaN                                 NaN
# 18642                  N                                   Y
# 18642                  N                                   Y
# ...                  ...                                 ...
# 18642                NaN                                 NaN
# 18642                NaN                                 NaN
# 18642                  N                                   N
# 18642                  N                                   N
# 18642                  N                                 NaN
#
# [281 rows x 72 columns]

# %%
utils[utils['utility_name']=='Tennessee Valley Authority']
# Out:
#                           utility_name                  street_address  \
# Utility ID
# 18642       Tennessee Valley Authority  WT 4B-K 400 W Summit Hill Driv
#
#                  city state    zip owner_of_plants_reported_on_form?  \
# Utility ID
# 18642       Knoxville    TN  37902                                 Y
#
#            operator_of_plants_reported_on_form?  \
# Utility ID
# 18642                                       NaN
#
#            asset_manager_of_plants_reported_on_form?  \
# Utility ID
# 18642                                            NaN
#
#            other_relationships_with_plants_reported_on_form? entity_type
# Utility ID
# 18642                                                    NaN           F

# %%
utils.columns
# Out:
# Index(['utility_name', 'street_address', 'city', 'state', 'zip',
#        'owner_of_plants_reported_on_form?',
#        'operator_of_plants_reported_on_form?',
#        'asset_manager_of_plants_reported_on_form?',
#        'other_relationships_with_plants_reported_on_form?', 'entity_type'],
#       dtype='object')

# %%
dfList = [utils, owners,gen_data]
[print(x.shape) for x in dfList]
# Out:
# (5039, 10)
# (4631, 13)
# (22118, 72)
# [None, None, None]

# %%
sum([x in owners.index for x in gen_data.index])
# Out:
# 8151
