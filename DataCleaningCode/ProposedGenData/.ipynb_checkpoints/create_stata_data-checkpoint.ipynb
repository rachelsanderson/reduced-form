# %%
import pandas as pd

# %%
data = pd.ExcelFile('/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/monthly_prices_sales_revenue.xlsx')

# %%
cols[7].split('_')[-1]
# Out:
# 'price'

# %%
df = data.parse(sheetname=data.sheet_names[0], skiprows=0).head(10)

# make a list of the header row and strip up to the 4th letter. This is the location and year information
cols1 = list(df.columns)
cols1 = [str(x).lower() for x in cols1]

# make another list of the first row,this is the age group information
# we need to preserve this information in the column name when we reshape the data 
cols2 = list(df.iloc[0,:])
cols2 = [str(x).lower() for x in cols2]

cols3 = list(df.iloc[1,:])
cols3 = [str(x).lower().replace(" ","_") for x in cols3]

# now join the two lists to make a combined column name which preserves our location, year and age-group information
cols = [x+"_"+y for x,y in zip(cols1,cols2)]
name = ""
for i,x in enumerate(cols):
    
    if "unnamed" in x:
        x = x.split('_')[-1]
        cols[i] = x
        continue
    if "_" in x:
        name = x.split("_")[0]
        print(name)
    if "_" not in x:
        cols[i] = name+"_" + x
cols[0:4] = cols3[0:4]
# Assign new column names to the dataframe
df.columns = cols
# Out:
# hi
# hi
# hi
# hi
# hi
# hi

# %%
df
# Out:
#    year  month  state  data_status residential_revenue          sales  \
# 0   NaN    NaN    NaN          NaN             Revenue          Sales
# 1  Year  Month  State  Data Status    Thousand Dollars  Megawatthours
# 2  1990      1     AK        Final               17477         181752
# 3  1990      1     AL        Final              123332        2070093
# 4  1990      1     AR        Final               72506        1026320
# 5  1990      1     AZ        Final              109332        1396499
# 6  1990      1     CA        Final              597161        6168009
# 7  1990      1     CO        Final               71325        1046805
# 8  1990      1     CT        Final              112085        1189718
# 9  1990      1     DC        Final                9483         168767
#
#    customers      price commercial_revenue          sales  ...  customers  \
# 0  Customers      Price            Revenue          Sales  ...  Customers
# 1      Count  Cents/kWh   Thousand Dollars  Megawatthours  ...      Count
# 2          .       9.62              15818         178259  ...          .
# 3          .       5.96              54495         820415  ...          .
# 4          .       7.06              30966         474988  ...          .
# 5          .       7.83              82694        1081793  ...          .
# 6          .       9.68             508517        6011774  ...          .
# 7          .       6.81              65130        1158963  ...          .
# 8          .       9.42              82881         957848  ...          .
# 9          .       5.62              23529         447252  ...          .
#
#        price     other_revenue          sales  customers      price  \
# 0      Price           Revenue          Sales  Customers      Price
# 1  Cents/kWh  Thousand Dollars  Megawatthours      Count  Cents/kWh
# 2          .              1918          14816          .      12.95
# 3          .              2851          53954          .       5.28
# 4          .              3117          47600          .       6.55
# 5          .              7833         151064          .       5.19
# 6          .             32100         869565          .       3.69
# 7          .              4054          58780          .        6.9
# 8          .              4057          35346          .      11.48
# 9          .              1600          29484          .       5.43
#
#       total_revenue          sales  customers      price
# 0           Revenue          Sales  Customers      Price
# 1  Thousand Dollars  Megawatthours      Count  Cents/kWh
# 2             38848         416438          .       9.33
# 3            268440        5044008          .       5.32
# 4            143635        2331399          .       6.16
# 5            243133        3439153          .       7.07
# 6           1406536       17504013          .       8.04
# 7            164996        2809935          .       5.87
# 8            235023        2671442          .        8.8
# 9             44131         883463          .          5
#
# [10 rows x 28 columns]

# %%
# Import electricity price data (annual)

price_data = pd.read_excel('/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/monthly_prices_sales_revenue.xlsx')
price_data.columns = price_data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# Import generator data (survey of all generators in 2018)

gen_data = pd.read_csv('/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/eia_data/eia8602018/merged_new.csv')
gen_data = gen_data.drop(gen_data.columns[gen_data.columns.str.contains("Unnamed")], axis=1)
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-73-c494850785e4> in <module>
#       1 # Import electricity price data (annual)
#       2
# ----> 3 price_data = pd.read_excel('/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/monthly_prices_sales_revenue.csv')
#       4 price_data.columns = price_data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, verbose, parse_dates, date_parser, thousands, comment, skip_footer, skipfooter, convert_float, mangle_dupe_cols, **kwds)
#     308
#     309     if not isinstance(io, ExcelFile):
# --> 310         io = ExcelFile(io, engine=engine)
#     311     elif engine and engine != io.engine:
#     312         raise ValueError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, io, engine)
#     817         self._io = _stringify_path(io)
#     818
# --> 819         self._reader = self._engines[engine](self._io)
#     820
#     821     def __fspath__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_xlrd.py in __init__(self, filepath_or_buffer)
#      19         err_msg = "Install xlrd >= 1.0.0 for Excel support"
#      20         import_optional_dependency("xlrd", extra=err_msg)
# ---> 21         super().__init__(filepath_or_buffer)
#      22
#      23     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_base.py in __init__(self, filepath_or_buffer)
#     357             self.book = self.load_workbook(filepath_or_buffer)
#     358         elif isinstance(filepath_or_buffer, str):
# --> 359             self.book = self.load_workbook(filepath_or_buffer)
#     360         else:
#     361             raise ValueError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/excel/_xlrd.py in load_workbook(self, filepath_or_buffer)
#      34             return open_workbook(file_contents=data)
#      35         else:
# ---> 36             return open_workbook(filepath_or_buffer)
#      37
#      38     @property
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     155         formatting_info=formatting_info,
#     156         on_demand=on_demand,
# --> 157         ragged_rows=ragged_rows,
#     158     )
#     159     return bk
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xlrd/book.py in open_workbook_xls(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#      90         t1 = perf_counter()
#      91         bk.load_time_stage_1 = t1 - t0
# ---> 92         biff_version = bk.getbof(XL_WORKBOOK_GLOBALS)
#      93         if not biff_version:
#      94             raise XLRDError("Can't determine file's BIFF version")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xlrd/book.py in getbof(self, rqd_stream)
#    1276             bof_error('Expected BOF record; met end of file')
#    1277         if opcode not in bofcodes:
# -> 1278             bof_error('Expected BOF record; found %r' % self.mem[savpos:savpos+8])
#    1279         length = self.get2bytes()
#    1280         if length == MY_EOF:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/xlrd/book.py in bof_error(msg)
#    1270
#    1271         def bof_error(msg):
# -> 1272             raise XLRDError('Unsupported format, or corrupt file: ' + msg)
#    1273         savpos = self._position
#    1274         opcode = self.get2bytes()
#
# XLRDError: Unsupported format, or corrupt file: Expected BOF record; found b'\xef\xbb\xbf,,,,R'

# %%
pd.read_csv('/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/monthly_prices_sales_revenue.csv')
# Out:
#                                               Unnamed: 0 Unnamed: 1  \
# 0                                                    NaN        NaN
# 1                                                   Year      Month
# 2                                                   1990          1
# 3                                                   1990          1
# 4                                                   1990          1
# ...                                                  ...        ...
# 18409                                               2020          1
# 18410                                               2020          1
# 18411                                               2020          1
# 18412                                               2020          1
# 18413  The sector, Other, was collected from 1990-200...        NaN
#
#       Unnamed: 2   Unnamed: 3       RESIDENTIAL     Unnamed: 5 Unnamed: 6  \
# 0            NaN          NaN           Revenue          Sales  Customers
# 1          State  Data Status  Thousand Dollars  Megawatthours      Count
# 2             AK        Final            17,477        181,752          .
# 3             AL        Final           123,332      2,070,093          .
# 4             AR        Final            72,506      1,026,320          .
# ...          ...          ...               ...            ...        ...
# 18409         WA  Preliminary           380,876      4,037,463  3,141,648
# 18410         WI  Preliminary           303,711      2,122,930  2,766,310
# 18411         WV  Preliminary           123,713      1,141,289    859,403
# 18412         WY  Preliminary            32,007        305,050    278,114
# 18413        NaN          NaN               NaN            NaN        NaN
#
#       Unnamed: 7        COMMERCIAL     Unnamed: 9  ... Unnamed: 18  \
# 0          Price           Revenue          Sales  ...   Customers
# 1      Cents/kWh  Thousand Dollars  Megawatthours  ...       Count
# 2           9.62            15,818        178,259  ...           .
# 3           5.96            54,495        820,415  ...           .
# 4           7.06            30,966        474,988  ...           .
# ...          ...               ...            ...  ...         ...
# 18409       9.43           228,884      2,596,890  ...           5
# 18410      14.31           209,448      1,966,289  ...           2
# 18411      10.84            57,706        658,511  ...           0
# 18412      10.49            29,288        320,225  ...           0
# 18413        NaN               NaN            NaN  ...         NaN
#
#       Unnamed: 19             OTHER    Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# 0           Price           Revenue          Sales   Customers       Price
# 1       Cents/kWh  Thousand Dollars  Megawatthours       Count   Cents/kWh
# 2               .             1,918         14,816           .       12.95
# 3               .             2,851         53,954           .        5.28
# 4               .             3,117         47,600           .        6.55
# ...           ...               ...            ...         ...         ...
# 18409        9.56                 .              .           .           .
# 18410       13.97                 .              .           .           .
# 18411        0.00                 .              .           .           .
# 18412        0.00                 .              .           .           .
# 18413         NaN               NaN            NaN         NaN         NaN
#
#                   TOTAL    Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0               Revenue          Sales   Customers       Price
# 1      Thousand Dollars  Megawatthours       Count   Cents/kWh
# 2                38,848        416,438           .        9.33
# 3               268,440      5,044,008           .        5.32
# 4               143,635      2,331,399           .        6.16
# ...                 ...            ...         ...         ...
# 18409           703,273      8,611,835   3,574,790        8.17
# 18410           653,614      5,975,758   3,134,809       10.94
# 18411           255,001      3,045,811   1,016,452        8.37
# 18412           116,883      1,480,941     347,281        7.89
# 18413               NaN            NaN         NaN         NaN
#
# [18414 rows x 28 columns]

# %%
price_data[price_data['industry_sector_category']=="Total Electric Industry"]
# Out:
#       year state industry_sector_category  residential commercial  industrial  \
# 0     2018    AK  Total Electric Industry        21.94      18.58       17.10
# 1     2018    AL  Total Electric Industry        12.18      11.24        6.01
# 2     2018    AR  Total Electric Industry         9.81       7.75        5.64
# 3     2018    AZ  Total Electric Industry        12.77      10.64        6.55
# 4     2018    CA  Total Electric Industry        18.84      16.34       13.20
# ...    ...   ...                      ...          ...        ...         ...
# 5306  1970    WA  Total Electric Industry         1.06       1.10        0.31
# 5307  1970    WI  Total Electric Industry         2.30       2.48        1.42
# 5308  1970    WV  Total Electric Industry         2.19       1.98        0.89
# 5309  1970    WY  Total Electric Industry         2.56       1.80        1.03
# 5310  1970    US  Total Electric Industry         2.22       2.08        0.99
#
#       transportation  other  total
# 0               0.00    NaN  19.36
# 1               0.00    NaN   9.63
# 2              11.35    NaN   7.78
# 3              10.02    NaN  10.85
# 4               8.64    NaN  16.58
# ...              ...    ...    ...
# 5306             NaN    0.0   0.67
# 5307             NaN    0.0   2.04
# 5308             NaN    0.0   1.35
# 5309             NaN    0.0   1.48
# 5310             NaN    0.0   1.68
#
# [2548 rows x 9 columns]
