# %%
import pandas as pd

# %%
gen_data = pd.read_csv("/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/eia_data/eia8602018/gen_2018.csv",
           header = 1)

# %%
# %colorsgen_data
# Out:
#                                               Utility ID  \
# 0                                                    195
# 1                                                    195
# 2                                                    195
# 3                                                    195
# 4                                                    195
# ...                                                  ...
# 22114                                              62777
# 22115                                              62777
# 22116                                              62731
# 22117                                              62764
# 22118  NOTE: Information on planned capacity changes ...
#
#                      Utility Name  Plant Code               Plant Name State  \
# 0                Alabama Power Co         2.0             Bankhead Dam    AL
# 1                Alabama Power Co         3.0                    Barry    AL
# ...
