# %% [markdown]
# ## This code creates a dictionary called final_parent_dict.txt that maps owner/entity/company name to a "parent" owner
# ## The dictionary can be used to analyze other micro datasets

# %%
import pandas as pd
import matplotlib as plt
import re
import json
# %matplotlib inline
dataDir = '/Users/rachelanderson/Dropbox (Princeton)/Data for Tax Equity Project/'
 
with open(dataDir + 'JSONFiles/parent_utility_dict.txt') as outfile:
    parent_dict = json.load(outfile)

# %%
parent_dict = dict((k.lower(), v.lower()) for k,v in parent_dict.items())

# %%
# read in other parent list and merge them
parent_map = {}
subs_data = pd.read_csv(dataDir + 'company_data/good_jobs_subs_data.csv')
subs_data.columns = subs_data.columns.str.lower().str.replace(" ", "_")
subs_data.company = subs_data.company.str.lower()
subs_data.parent_company = subs_data.parent_company.str.lower()

parent_map = dict(zip(subs_data.company, subs_data.parent_company))

# %%
clearway_subs = pd.read_csv(dataDir + 'company_data/clearway_subs.csv', names=['entity_name','','state']).entity_name.str.lower()
for x in clearway_subs:
    parent_map[x] = 'clearway energy'

# %%
parent_map.update(parent_dict)

# %% [markdown]
# ## make master list of utility names from utility dataset, generator dataset, and owners dataset

# %% [markdown]
# ### Read in relevant datasets

# %%
owners = pd.read_csv(dataDir + 'master_company_list_2018/owners2018.csv')
gen_data = pd.read_csv(dataDir + 'master_company_list_2018/gen_2018.csv')
utils = pd.read_csv(dataDir + 'master_company_list_2018/utils_2018.csv')
# Out:
# /Users/rachelanderson/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (16,39,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dfList = [owners, gen_data, utils]

# %%
owners.columns
# Out:
# Index(['Unnamed: 0', 'utility_id', 'utility_name', 'plant_code', 'plant_name',
#        'state', 'generator_id', 'status', 'owner_name', 'owner_street_address',
#        'owner_city', 'owner_state', 'owner_zip', 'ownership_id',
#        'percent_owned', 'perc_owned', 'num_owners', 'idx', 'owner_1',
#        'owner_2', 'owner_3', 'owner_4', 'perc_owner_1', 'perc_owner_2',
#        'perc_owner_3', 'perc_owner_4'],
#       dtype='object')

# %%
owners.rename(columns = {'owner_name':'company_name', 
                         'owner_street_address':'company_address',
                         'owner_state': 'company_state',
                          'owner_city': 'company_city',
                          'owner_zip': 'company_zip',
                           'ownership_id': 'company_id'},inplace=True)
gen_data.rename(columns = {'utility_name':'company_name'}, inplace=True)
utils.rename(columns = {'utility_name':'company_name',
                       'utility_id': 'company_id',
                        'street_address':'company_address',
                         'state':'company_state',
                         'city': 'company_city', 
                          'zip':'company_zip'},inplace=True)

# %%
companies.head(10)
# Out:
#                           company_name                       company_address  \
# 0                     Alabama Power Co     P O Box 2641600 North 18th Street
# 1                 Mississippi Power Co             2992 West Beach Boulevard
# 5                     Georgia Power Co                          P O Box 4545
# 14                     Cleco Power LLC  2030 Donahue Ferry RoadP.O. Box 5000
# 15      Northeast Texas Elec Coop, Inc                      1127 Judson Road
# 16  Oklahoma Municipal Power Authority                          P O Box 1960
# 17      Southwestern Electric Power Co                     212 E. 6th Street
# 18             City of Hastings - (NE)              1228 North Denver Avenue
# 19               City of Nebraska City                       100 Central Ave
# 20       Municipal Energy Agency of NE   PO BOX 951241111 O Street Suite 200
#
#    company_state   company_city company_zip  company_id
# 0             AL     Birmingham       35291         195
# 1             MS       Gulfport       39501       12686
# 5             GA        Atlanta       30302        7140
# 14            LA      Pineville       71361        3265
# 15            TX       Longview       75601       13670
# 16            OK         Edmond       73083       14077
# 17            OK          Tulsa       74119       17698
# 18            NE       Hastings       68902        8245
# 19            NE  Nebraska City       68410       13334
# 20            NE        Lincoln       68509       21352

# %%
# make df with master list of companies (utilities + owners)
companyVals = ['name', 'address','state','city','zip','id']
companyVals = ['company_' + x for x in companyVals]
companies = owners[companyVals].append(utils[companyVals])
# select unique combos
companies.drop_duplicates(inplace=True)

# %%
names = gen_data['company_name'].drop_duplicates()
# I found that no names in gen data are not contained in the other datasets, so I don't merge it in

# %%
def shorten_rd(address):
    '''Completes the road type. I.e. Rd becomes Road, st becomes Street as per Google etc.'''
    address = address.title()
    address = re.sub(r" Street(?=$| [NE(So|S$)(We|W$)])", ' St', address)
    address = re.sub(r" Road(?=$| [NE(So|S$)(We|W$)])", ' Rd', address)
    address = re.sub(r"(?<!The) Avenue(?=$| [NE(So|S$)(We|W$)])", ' Ave', address)
    address = re.sub(r" Close(?=$| [NE(So|S$)(We|W$)])", ' Cl', address)
    address = re.sub(r" Court(?=$| [NE(So|S$)(We|W$)])", ' Ct', address)
    address = re.sub(r"(?<!The) Crescent(?=$| [NE(So|S$)(We|W$)])", ' Cres', address)
    address = re.sub(r" Boulevarde?(?=$| [NE(So|S$)(We|W$)])", ' Blvd', address)
    address = re.sub(r" Drive(?=$| [NE(So|S$)(We|W$)])", ' Dr', address)
    address = re.sub(r" Lane(?=$| [NE(So|S$)(We|W$)])", ' Ln', address)
    address = re.sub(r" Place(?=$| [NE(So|S$)(We|W$)])", ' Pl', address)
    address = re.sub(r" Square(?=$| [NE(So|S$)(We|W$)])", ' Sq', address)
    address = re.sub(r"(?<!The) Parade(?=$| [NE(So|S$)(We|W$)])", ' Pde', address)
    address = re.sub(r" Circuit(?=$| [NE(So|S$)(We|W$)])", ' Cct', address)
    return address

def lengthen_rd(address):
    address = address.title()
    address = re.sub(r" St(?=$| [NE(So|S$)(We|W$)])", " Street", address)
    address = re.sub(r" Rd(?=$| [NE(So|S$)(We|W$)])", " Road", address)
    address = re.sub(r" Ave(?=$| [NE(So|S$)(We|W$)])", " Avenue", address)
    address = re.sub(r" Cl(?=$| [NE(So|S$)(We|W$)])", " Close", address)
    address = re.sub(r" Ct(?=$| [NE(So|S$)(We|W$)])", " Court", address)
    address = re.sub(r" Cres(?=$| [NE(So|S$)(We|W$)])", " Crescent", address)
    address = re.sub(r" Blvd(?=$| [NE(So|S$)(We|W$)])", " Boulevard", address)
    address = re.sub(r" Dr(?=$| [NE(So|S$)(We|W$)])", " Drive", address)
    address = re.sub(r" Ln(?=$| [NE(So|S$)(We|W$)])", " Lane", address)
    address = re.sub(r" Pl(?=$| [NE(So|S$)(We|W$)])", " Place", address)
    address = re.sub(r" Sq(?=$| [NE(So|S$)(We|W$)])", " Square", address)
    address = re.sub(r" Pde(?=$| [NE(So|S$)(We|W$)])", " Parade", address)
    address = re.sub(r" Cct(?=$| [NE(So|S$)(We|W$)])", " Circuit", address)
    return address

def standard_addr(address):
    '''Checks for unit numbers and street addresses and puts them in the standard format''' 
    #print("################################")
    #print("### Address: ", address)
    unit_nums = re.findall(r"(?<=Unit )\w?\d+\w?|(?<=U)\d+\w?|\w?\d+\w?(?=\s*/)", address)
    unit_num = unit_nums[0] if len(unit_nums)==1 else ""
    #print("Unit Number: ", unit_num)
    proc_addr = re.sub(r"Unit \w?\d+\w?/?|U\d+\w?/?|\w?\d+\w?\s*/", "", address)
    proc_addr = re.sub(r"^[,\- ]+|[,\- ]+$", "", proc_addr)
    #print("Unitless address: ", proc_addr)
    type_opts = r"Terrace|Way|Walk|St|Rd|Ave|Cl|Ct|Cres|Blvd|Dr|Ln|Pl|Sq|Pde|Cct"
    road_attrs_pattern = r"(?P<rd_no>\w?\d+(\-\d+)?\w?\s+)(?P<rd_nm>[a-zA-z \d\-]+)\s+(?P<rd_tp>" + type_opts + ")"
    #print("Road Attr Pattern: ", road_attrs_pattern)
    road_attrs = re.search(road_attrs_pattern, proc_addr)
    try:
        road_num = road_attrs.group('rd_no').strip()
    except AttributeError:
        road_num = ""
    #print("Road number: ", road_num)
    try:
        road_name = road_attrs.group('rd_nm').strip()
    except AttributeError:
        road_name = ""
    #print("Road name: ", road_name)
    try:
        road_type = road_attrs.group('rd_tp').strip()
    except AttributeError:
        road_type = ""
    #print("Road type: ", road_type)
    proc_addr = lengthen_rd(re.sub(r"^[,\- ]+|[,\- ]+$", "", re.sub(road_attrs_pattern, "", proc_addr)))
    #print("Leftover: ", proc_addr)

    unit_seg = (unit_num + "/" if unit_num!="" else "") if road_num != "" else ("Unit " + unit_num + ", " if unit_num!="" else "")
    road_seg = ((road_num + " " if road_num!="" else "") + road_name + " " + road_type).strip()
    post_road_seg = " " + proc_addr if proc_addr != "" else ""
    proc_addr = (unit_seg + road_seg) + post_road_seg
    #print("### Processed Address: ", proc_addr)
    return proc_addr

# %%
# clean addresses
companies['raw_address'] = companies['company_address']
companies['company_address'] =companies['raw_address'].apply(lambda x: standard_addr(str(x)))

# first assign company name a common var
companies['name_group'] = companies.groupby('company_name').grouper.group_info[0]

# now assign clean address common var
companies['address_group']=companies.groupby('company_address').grouper.group_info[0]

# %%
companies['company_name'] = companies.company_name.str.lower()

# %%
def apply_parent_dict(df, name, par_dict):
    df['parent_group'] = df[name].str.lower().map(par_dict)
    df['parent_group']=df['parent_group'].fillna(df[name])
    df['parent_group'] = df['parent_group'].apply(lambda x: "duke energy" if "duke energy" in x else x)
    df['parent_group'] = df['parent_group'].apply(lambda x: "nextera energy" if "nextera" in x else x)
    df['parent_group'] = df['parent_group'].apply(lambda x: "nrg energy" if "nrg" in x else x)
    df['parent_group'] = df['parent_group'].apply(lambda x: "solar star" if "solar star" in x else x)
    df['parent_group'] = df['parent_group'].apply(lambda x: "nrg" if "agua caliente solar" in x else x)
    df['parent_group'] = df['parent_group'].apply(lambda x: "nextera energy" if "blythe solar" in x else x)
    df['parent_group'] = df['parent_group'].apply(lambda x: "8me" if "8me" in x.lower() else x)
    df['parent_group'] = df['parent_group'].apply(lambda x: "exelon" if "av solar" in x else x)
    df['parent_group'] = df['parent_group'].apply(lambda x: "exelon" if "exelon" in x else x)
    return(df)

# %%
# now do parent dict... can drop those and deal with remainder

companies = apply_parent_dict(companies, 'company_name', parent_map)

# %%
companies = companies.sort_values('name_group')
name_dict = dict(zip(companies.company_name, companies.name_group))
address_dict = dict(zip(companies.company_name, companies.address_group))
par_dict =  dict(zip(companies.company_name, companies.parent_group))

# %%
def group_two_col(df, col1, col2):
    address_map = {} # is col1
    name_map = {} # is col2 
    group_id = [] # maps to each row in rows
    maximum_group = 0

    
    for  index, row in df.iterrows():

        if address_map.get(row[col1]) is not None:
            group_id.append(address_map[row[col1]]) 
            if name_map.get(row[col2]) is None:
                name_map[row[col2]] = address_map[row[col1]]
            continue

        if name_map.get(row[col2]) is not None:
            group_id.append(name_map[row[col2]])
        
            if address_map.get(row[col1]) is None:
                address_map[row[col1]] = name_map[row[col2]]
            continue
  
  # If we're here no group found, insert new group
        address_map[row[col1]] = maximum_group + 1 # new group id
        name_map[row[col2]] = maximum_group + 1 # new group id

        group_id.append(maximum_group + 1)

        maximum_group += 1
    
    return(group_id)

# %%
companies['id'] = group_two_col(companies,'company_address','company_name')
companies['id'] = group_two_col(companies,'id','parent_group')

# %%
#companies.drop_duplicates(subset='id',keep='first')
# Out:
#                    company_name               company_address company_state  \
# 4964    10 briggs solar ng, llc  267 Water St Reet, 2Nd Floor            RI
# 4899  1025 traveller solar, llc       1447 S Tryon St Ste 201            NC
# 3816        126 grove solar llc            315 Post Road West            CT
# 3673         158th fighter wing                105 NCO Dr Ive            VT
# 4453            1634 solar, llc             1519 King St Reet            SC
# ...                         ...                           ...           ...
# 1519      ziegler power systems    8050 State Highway 101East            MN
# 1522            zion energy llc                 5701 Ninth St            IL
# 2371        zotos international             300 Forge Ave Nue            NY
# 3914        ebay - south jordan     6614 West Crimson View Dr            UT
# 4230                 esvolta lp                 65 Enterprise            CA
#
#           company_city company_zip  company_id                  raw_address  \
# 4964            Warren       02885       62685  267 Water Street, 2nd Floor
# 4899         Charlotte       28203       62139     1447 S Tryon St, Ste 201
# 3816          Westport       06880       60517           315 Post Road West
# 3673  South Burlington       05403       60301                105 NCO Drive
# 4453        Charleston       29405       61541             1519 King Street
# ...                ...         ...         ...                          ...
# 1519          Shakopee       55379       21144   8050 State Highway 101East
# 1522              Zion       60099       21191                5701 Ninth St
# 2371            Geneva       14456       56977             300 Forge Avenue
# 3914      South Jordan       84095       59095    6614 West Crimson View Dr
# 4230       Aliso Viejo       92656       61198                65 Enterprise
#
#       name_group  address_group               parent_group    id
# 4964           0           2984    10 briggs solar ng, llc     1
# 4899           1           2387  1025 traveller solar, llc     2
# 3816           3            647        126 grove solar llc     3
# 3673           4           2040         158th fighter wing     4
# 4453           5           2444            1634 solar, llc     5
# ...          ...            ...                        ...   ...
# 1519        6090           1116      ziegler power systems  3989
# 1522        6091           3614            zion energy llc  3990
# 2371        6092           3049        zotos international  3991
# 3914        6094           3759        ebay - south jordan  3992
# 4230        6096           1018                 esvolta lp  3993
#
# [3993 rows x 11 columns]

# %%
## make company_name --> id  (with parent name) dictionary

# %%
nextera_subs = companies[companies['id']==95].company_name

# %%
for x in nextera_subs:
    final_par_dict[x] = 'nextera energy'

# %% [markdown]
# ### Now save company_name --> parent_company dictionary so I can use with the generator data

# %%
final_par_dict = dict(zip(companies.company_name, companies.parent_group))

# %%
with open(dataDir + 'JSONFiles/final_parent_dict.json','w') as outfile:
    json.dump(final_par_dict,outfile)

# %%
['adelanto solar ii, llc', 'adelanto solar, llc', 'bluebell solar, llc']

# %%
final_par_dict['adelanto solar ii, llc'] = 'nextera energy'
final_par_dict['adelanto solar, llc'] = 'nextera energy'

# %%
companies[companies['id']==95]
# Out:
#                              company_name    company_address company_state  \
# 3197               adelanto solar ii, llc  700 Universe Blvd            FL
# 3196                  adelanto solar, llc  700 Universe Blvd            FL
# 1786       altagas blythe operations inc.  700 Universe Blvd            CA
# 2251               ashtabula wind iii llc  700 Universe Blvd            FL
# 2228                     baldwin wind llc  700 Universe Blvd            ND
# ...                                   ...                ...           ...
# 1476  west texas wind energy partners llc  700 Universe Blvd            FL
# 4950          wheatridge wind energy, llc  700 Universe Blvd            FL
# 3472                 white oak solar, llc  700 Universe Blvd            FL
# 3459                white pine solar, llc  700 Universe Blvd            FL
# 4280      wildcat ranch wind project, llc  700 Universe Blvd            FL
#
#      company_city company_zip  company_id        raw_address  name_group  \
# 3197   Juno Beach       33408       59212  700 Universe Blvd         127
# 3196   Juno Beach       33408       59211  700 Universe Blvd         128
# 1786   Juno Beach       33408       55713  700 Universe Blvd         211
# 2251   Juno Beach       33408       56727  700 Universe Blvd         341
# 2228   Juno Beach       33408       56688  700 Universe Blvd         441
# ...           ...         ...         ...                ...         ...
# 1476   Juno Beach       33408       20424  700 Universe Blvd        5917
# 4950   Juno Beach       33408       62668  700 Universe Blvd        5960
# 3472   Juno Beach       33408       59831  700 Universe Blvd        5971
# 3459   Juno Beach       33408       59803  700 Universe Blvd        5973
# 4280   Juno Beach       33408       61291  700 Universe Blvd        5989
#
#       address_group                         parent_group  id
# 3197           3805               adelanto solar ii, llc  95
# 3196           3805                  adelanto solar, llc  95
# 1786           3805       altagas blythe operations inc.  95
# 2251           3805               ashtabula wind iii llc  95
# 2228           3805                     baldwin wind llc  95
# ...             ...                                  ...  ..
# 1476           3805  west texas wind energy partners llc  95
# 4950           3805          wheatridge wind energy, llc  95
# 3472           3805                 white oak solar, llc  95
# 3459           3805                white pine solar, llc  95
# 4280           3805      wildcat ranch wind project, llc  95
#
# [116 rows x 11 columns]

# %%
final_par_dict['adelanto solar, llc']
# Out:
# 'nextera energy'

# %% [markdown]
# ## hand code nextera

# %%
final_par_dict[]
# Out:
# {'10 briggs solar ng, llc': '10 briggs solar ng, llc',
#  '1025 traveller solar, llc': '1025 traveller solar, llc',
#  '1047 little mountain solar, llc': '1047 little mountain solar, llc',
#  '126 grove solar llc': '126 grove solar llc',
#  '158th fighter wing': '158th fighter wing',
#  '1634 solar, llc': '1634 solar, llc',
#  '174 power global corp.': '174 power global corp.',
#  '180 raritan energy solutions, llc': '180 raritan energy solutions, llc',
#  '1951 hamburg turnpike, llc': '1951 hamburg turnpike, llc',
#  '2016 esa project company, llc': '2016 esa project company, llc',
#  '225dd 8me llc': '8me',
#  '226hc 8me llc': '8me',
#  '231 dixon 74 solar i, llc': '231 dixon 74 solar i, llc',
#  '231rc 8me llc': '8me',
#  '301 chestnut solar ng, llc': '301 chestnut solar ng, llc',
#  '31st street energy llc': '31st street energy llc',
#  '325mk 8me llc': '8me',
#  '33ui 8me llc': '8me',
#  '350 clark solar ng, llc': '350 clark solar ng, llc',
#  '380 middlesex solar llc': '380 middlesex solar llc',
#  '3880 north mission road solar llc': '3880 north mission road solar llc',
#  '41mb 8me, llc': '8me',
#  '433 purchase solar ng, llc': '433 purchase solar ng, llc',
#  '4c acquisition, llc': '4c acquisition, llc',
#  '5 research parkway wallingford llc': '5 research parkway wallingford llc',
#  '500 virginia solar, lp': '500 virginia solar, lp',
#  '510 repp one llc': '510 repp one llc',
#  '54 kr 8me llc': '8me',
#  '62sk 8me, llc': '8me',
#  '63su 8me, llc': '8me',
#  '64kt 8me llc': '8me',
#  '651 chase solar ng llc': '651 chase solar ng llc',
#  '68sf 8me llc': '8me',
#  '69sv 8me llc': '8me',
#  '7x energy, inc.': '7x energy, inc.',
#  '83wi 8me, llc': '8me',
#  '8point3 operating company llc': '8point3 operating company llc',
#  '91mc 8me llc': '8me',
#  'a & n electric coop': 'a & n electric coop',
#  'abec #2 llc': 'abec #2 llc',
#  'abec #3 llc': 'abec #3 llc',
#  'abec #4 llc': 'abec #4 llc',
#  'abec bidart-old river llc': 'abec bidart-old river llc',
#  'ac landfill energy llc': 'ac landfill energy llc',
#  'acb energy partners llc': 'acb energy partners llc',
#  'ace west holdings, llc': 'ace west holdings, llc',
#  'ace of cape cod solar iv, llc': 'ace of cape cod solar iv, llc',
#  'ace-stanton a, llc': 'ace-stanton a, llc',
#  'ace-stanton, llc': 'ace-stanton, llc',
#  'ada carbon solutions (red river), llc': 'ada carbon solutions (red river), llc',
#  'ads renewable energy- wolf creek, llc': 'ads renewable energy- wolf creek, llc',
#  'ae power services llc': 'ae power services llc',
#  'aem wind llc': 'aem wind llc',
#  'aep generating company': 'aep generating company',
#  'aep generation resources inc': 'american electric power',
#  'aep onsite partners': 'aep onsite partners',
#  'aep renewables': 'aep renewables',
#  'aep texas north company': 'aep texas north company',
#  'aera energy llc': 'aera energy llc',
#  'aes alamitos energy, llc': 'aes alamitos energy, llc',
#  'aes alamitos llc': 'aes alamitos llc',
#  'aes distributed energy': 'aes corp.',
#  'aes es alamitos, llc': 'aes es alamitos, llc',
#  'aes es gilbert, llc': 'aes es gilbert, llc',
#  'aes hawaii inc': 'aes hawaii inc',
#  'aes huntington beach energy, llc': 'aes huntington beach energy, llc',
#  'aes huntington beach llc': 'aes huntington beach llc',
#  'aes la fit francisco llc': 'aes la fit francisco llc',
#  'aes la fit sun valley llc': 'aes la fit sun valley llc',
#  'aes lawai solar, llc': 'aes lawai solar, llc',
#  'aes ohio generation llc': 'aes ohio generation llc',
#  'aes redondo beach llc': 'aes redondo beach llc',
#  'aes shady point llc': 'aes shady point llc',
#  'aes tait llc': 'aes tait llc',
#  'aes wr ltd partnership': 'aes wr ltd partnership',
#  'aes wind generation inc': 'aes wind generation inc',
#  'ag energy inc': 'ag energy inc',
#  'ag energy lp': 'ag energy lp',
#  'agc division of apg inc': 'agc division of apg inc',
#  'al cogen inc': 'al cogen inc',
#  'al cogen partner inc.': 'al cogen partner inc.',
#  'al sandersville': 'al sandersville',
#  'al solar a, llc': 'al solar a, llc',
#  'allete south wind, llc': 'allete south wind, llc',
#  'allete, inc.': 'allete, inc.',
#  'alm holding company': 'alm holding company',
#  'am best farm': 'am best farm',
#  'ameresco chicopee energy llc': 'ameresco chicopee energy llc',
#  'ameresco chiquita canyon llc': 'ameresco chiquita canyon llc',
#  'ameresco delaware central': 'ameresco delaware central',
#  'ameresco delaware south': 'ameresco delaware south',
#  'ameresco janesville llc': 'ameresco janesville llc',
#  'ameresco jefferson city llc': 'ameresco jefferson city llc',
#  'ameresco keller canyon llc': 'ameresco keller canyon llc',
#  'ameresco ox mountain energy llc': 'ameresco ox mountain energy llc',
#  'ameresco santa cruz energy llc': 'ameresco santa cruz energy llc',
#  'ameresco stafford llc': 'ameresco stafford llc',
#  'anp bellingham energy company llc': 'anp bellingham energy company llc',
#  'anp blackstone energy company llc': 'anp blackstone energy company llc',
#  'ap north lake i, lp': 'ap north lake i, lp',
#  'aptim environmental & infrastructure': 'aptim environmental & infrastructure',
#  'arco': 'arco',
#  'arco products co-watson': 'arco products co-watson',
#  'are rp bartow, llc': 'are rp bartow, llc',
#  'arp-loyalton cogen llc        ': 'arp-loyalton cogen llc        ',
#  'au solar 1 llc': 'au solar 1 llc',
#  'av solar ranch 1 llc': 'exelon',
#  'avs phase 2 llc': 'avs phase 2 llc',
#  'az solar trust': 'az solar trust',
#  'abbot solar, llc': 'abbot solar, llc',
#  'abengoa bioenergy biomass of kansas': 'abengoa bioenergy biomass of kansas',
#  'acciona energy usa global, llc': 'acciona energy usa global, llc',
#  'acciona solar power': 'acciona solar power',
#  'acciona wind energy usa llc': 'acciona wind energy usa llc',
#  'achilles farm, llc': 'achilles farm, llc',
#  'aclara meters llc': 'aclara meters llc',
#  'acorn i energy storage llc': 'acorn i energy storage llc',
#  'acushnet company': 'acushnet company',
#  'ada cogeneration ltd partnership': 'ada cogeneration ltd partnership',
#  'adams community solar garden iii llc': 'clearway energy',
#  'adams community solar garden llc': 'adams community solar garden llc',
#  'adams electric cooperative': 'adams electric cooperative',
#  'adams farm solar llc': 'adams farm solar llc',
#  'adams nielson solar, llc': 'adams nielson solar, llc',
#  'adams solar, llc': 'adams solar, llc',
#  'adams wind generations llc': 'adams wind generations llc',
#  'adams-columbia electric coop': 'adams-columbia electric coop',
#  'adelanto solar ii, llc': 'adelanto solar ii, llc',
#  'adelanto solar, llc': 'adelanto solar, llc',
#  'adirondack hydro-fourth branch llc': 'adirondack hydro-fourth branch llc',
#  'adkins energy llc': 'adkins energy llc',
#  'adobe systems incorporated': 'adobe systems incorporated',
#  'adrian public utilities comm': 'adrian public utilities comm',
#  'advanced microgrid solutions': 'advanced microgrid solutions',
#  'aegis renewables llc': 'aegis renewables llc',
#  'aeolus wind llc': 'aeolus wind llc',
#  'aera energy llc-coalinga': 'aera energy llc-coalinga',
#  'aera energy llc-san ardo': 'aera energy llc-san ardo',
#  'affordable solar silver city, llc': 'affordable solar silver city, llc',
#  'agpower dcd, llc': 'agpower dcd, llc',
#  'agpower jerome llc': 'agpower jerome llc',
#  'agilitas energy, llc': 'agilitas energy, llc',
#  'agilon energy holdings ii, llc': 'agilon energy holdings ii, llc',
#  'agrirenew': 'agrirenew',
#  'agriwind project, llc': 'agriwind project, llc',
#  'agrilectric power partners ltd': 'agrilectric power partners ltd',
#  'agrium us inc': 'agrium us inc',
#  'agua caliente solar': 'nrg',
#  'ahana renewables, llc': 'ahana renewables, llc',
#  'ahlstrom-munksjo': 'ahlstrom-munksjo',
#  'ahlstrom-munksjo na specialty solutions, llc': 'ahlstrom-munksjo na specialty solutions, llc',
#  'air force civil engineer center': 'air force civil engineer center',
#  'air liquide america corp': 'air liquide america corp',
#  'air liquide large industries u s lp': 'air liquide large industries u s lp',
#  'air liquide large industries u.s. lp': 'air liquide large industries u.s. lp',
#  'air products & chemicals inc': 'air products & chemicals inc',
#  'air products llc': 'air products llc',
#  'aircraft services corp': 'aircraft services corp',
#  'airport solar llc': 'airport solar llc',
#  'akron energy systems llc': 'akron energy systems llc',
#  'aksamit energy development': 'aksamit energy development',
#  'aksamit resource management': 'aksamit resource management',
#  'alabama ledge wind farm llc': 'alabama ledge wind farm llc',
#  'alabama municipal elec authority': 'alabama municipal elec authority',
#  'alabama power co': 'southern company',
#  'alabama river cellulose llc': 'alabama river cellulose llc',
#  'alamosa operating services llc': 'alamosa operating services llc',
#  'alaska electric light&power co': 'alaska electric light&power co',
#  'alaska energy authority': 'alaska energy authority',
#  'alaska environmental power': 'alaska environmental power',
#  'alaska industrial dev&exp auth': 'alaska industrial dev&exp auth',
#  'alaska power and telephone co': 'alaska power and telephone co',
#  'alaska village elec coop, inc': 'alaska village elec coop, inc',
#  'albany engineering corporation': 'albany engineering corporation',
#  'albany green energy, llc': 'albany green energy, llc',
#  'albany medical center': 'albany medical center',
#  'albany solar, llc': 'albany solar, llc',
#  'albert einstein college of medicine': 'albert einstein college of medicine',
#  'albertson solar llc': 'albertson solar llc',
#  'albertville municipal utilities board': 'albertville municipal utilities board',
#  'albuquerque city of': 'albuquerque city of',
#  'alchemy renewable energy': 'alchemy renewable energy',
#  'alcoa world alumina llc': 'alcoa world alumina llc',
#  'alexander & baldwin, inc.': 'alexander & baldwin, inc.',
#  'algonquin northern maine': 'algonquin northern maine',
#  'algonquin power co': 'algonquin power co',
#  'algonquin power sanger llc': 'algonquin power sanger llc',
#  'algonquin windsor locks llc': 'algonquin windsor locks llc',
#  'alice falls hydro, llc': 'alice falls hydro, llc',
#  'all dams generation, llc': 'all dams generation, llc',
#  'allegany generating station, llc': 'allegany generating station, llc',
#  'allegheny electric coop inc': 'allegheny electric coop inc',
#  'allegheny energy supply co llc': 'allegheny energy supply co llc',
#  'allegheny hydro lp': 'allegheny hydro lp',
#  'allegheny ridge wind farm llc': 'allegheny ridge wind farm llc',
#  'allete clean energy': 'allete clean energy',
#  'alliance energy group llc': 'alliance energy group llc',
#  'alliance nygt, llc': 'alliance nygt, llc',
#  'alliant energy': 'alliant energy',
#  'almatis burnside inc.': 'almatis burnside inc.',
#  'aloha solar energy fund i llc': 'aloha solar energy fund i llc',
#  'alpaca energy llc': 'alpaca energy llc',
#  'alpha value solar, llc': 'alpha value solar, llc',
#  'alpine pacific utilities hydro': 'alpine pacific utilities hydro',
#  'alsoenergy': 'alsoenergy',
#  'alstom power, inc. c/o ge renewable energy': 'alstom power, inc. c/o ge renewable energy',
#  'altagas blythe operations inc': 'altagas blythe operations inc',
#  'altagas pomona energy inc.': 'altagas pomona energy inc.',
#  'altagas renewable energy co llc': 'altagas renewable energy co llc',
#  'altagas ripon energy inc.': 'altagas ripon energy inc.',
#  'altagas blythe operations inc.': 'altagas blythe operations inc.',
#  'altair community solar garden, llc': 'altair community solar garden, llc',
#  'alterna springerville  llc': 'alterna springerville  llc',
#  'alternative power development northwest, llc': 'alternative power development northwest, llc',
#  'alterra power corp.': 'alterra power corp.',
#  'altorfer inc.': 'altorfer inc.',
#  'altus power america management, llc': 'altus power america management, llc',
#  'amadeus wind llc': 'amadeus wind llc',
#  'amalgamated bank of chicago': 'amalgamated bank of chicago',
#  'amalgamated sugar co-nampa': 'amalgamated sugar co-nampa',
#  'amana society service co': 'amana society service co',
#  'amazon': 'amazon',
#  'amedee gethrm venture i lp': 'amedee gethrm venture i lp',
#  'ameren illinois': 'ameren illinois',
#  'ameren missouri': 'ameren missouri',
#  'ameresco': 'ameresco',
#  'ameresco bwc wading river llc': 'ameresco bwc wading river llc',
#  'ameresco butte county llc': 'ameresco butte county llc',
#  'ameresco dallas llc': 'ameresco dallas llc',
#  'ameresco federal solutions': 'ameresco federal solutions',
#  'ameresco forward, llc': 'ameresco forward, llc',
#  'ameresco glendale road solar pv llc': 'ameresco glendale road solar pv llc',
#  'ameresco johnson canyon llc': 'ameresco johnson canyon llc',
#  'ameresco lfg i inc': 'ameresco lfg i inc',
#  'ameresco san joaquin, llc': 'ameresco san joaquin, llc',
#  'ameresco select inc': 'ameresco select inc',
#  'ameresco solar acton llc': 'ameresco solar acton llc',
#  'ameresco vasco road, llc': 'ameresco vasco road, llc',
#  'ameresco, inc - braintree': 'ameresco, inc - braintree',
#  'ameresco, inc - candlewood': 'ameresco, inc - candlewood',
#  'ameresco, inc - geld': 'ameresco, inc - geld',
#  'ameresco, inc - weston': 'ameresco, inc - weston',
#  'american bituminous power lp': 'american bituminous power lp',
#  'american crystal sugar co': 'american crystal sugar co',
#  'american falls solar ii, llc': 'american falls solar ii, llc',
#  'american falls solar llc': 'american falls solar llc',
#  'american honda motor co., inc.': 'american honda motor co., inc.',
#  'american hydro power company': 'american hydro power company',
#  'american mun power-ohio, inc': 'american mun power-ohio, inc',
#  'american profol incorporated': 'american profol incorporated',
#  'american sugar refining inc.': 'american sugar refining inc.',
#  'american sugar refining, inc.': 'american sugar refining, inc.',
#  'american wind energy management corp.': 'american wind energy management corp.',
#  'amethyst solar llc': 'amethyst solar llc',
#  'amherst college': 'amherst college',
#  'amity energy, llc': 'amity energy, llc',
#  'ampersand chasm hydro llc': 'ampersand chasm hydro llc',
#  'ampersand chowchilla biomass llc': 'ampersand chowchilla biomass llc',
#  'ampersand collins hydro llc': 'ampersand collins hydro llc',
#  'ampersand gilman hydro lp': 'ampersand gilman hydro lp',
#  'ampersand hollow dam hydro llc': 'ampersand hollow dam hydro llc',
#  'ampersand long falls hydro, llc': 'ampersand long falls hydro, llc',
#  'ampersand moretown hydro llc': 'ampersand moretown hydro llc',
#  'ampersand mount ida hydro llc': 'ampersand mount ida hydro llc',
#  'ampersand tannery island hydro, llc': 'ampersand tannery island hydro, llc',
#  'anaheim public utilities': 'anaheim public utilities',
#  'anchor energy llc': 'anchor energy llc',
#  'anchorage municipal light and power': 'anchorage municipal light and power',
#  'andeavor': 'andeavor',
#  'anderson farm llc': 'anderson farm llc',
#  'anderson power products': 'anderson power products',
#  'anderson wind project, llc': 'anderson wind project, llc',
#  'andromeda community solar': 'andromeda community solar',
#  'angier farm llc': 'angier farm llc',
#  'anheuser-busch inc': 'anheuser-busch inc',
#  'aniak light & power co inc': 'aniak light & power co inc',
#  'annandale solar, llc': 'annandale solar, llc',
#  'annapolis solar park, llc': 'annapolis solar park, llc',
#  'antares community solar': 'antares community solar',
#  'antelope dsr 3 llc': 'antelope dsr 3 llc',
#  'antelope expansion 1b, llc': 'antelope expansion 1b, llc',
#  'antelope expansion 3a, llc': 'antelope expansion 3a, llc',
#  'antelope expansion 3b, llc': 'antelope expansion 3b, llc',
#  'antlia community solar': 'antlia community solar',
#  'antrim wind energy llc': 'antrim wind energy llc',
#  'apex bethel energy center': 'apex bethel energy center',
#  'apex power contracting and consulting': 'apex power contracting and consulting',
#  'apex wind energy holdings, llc': 'apex wind energy holdings, llc',
#  'apollo energy corp': 'apollo energy corp',
#  'appalachian power co': 'appalachian power co',
#  'apple blossom wind, llc': 'apple blossom wind, llc',
#  'apple, inc': 'apple, inc',
#  'appleton coated llc': 'appleton coated llc',
#  'applied energy inc': 'applied energy inc',
#  'appomattox river associates lp': 'appomattox river associates lp',
#  'aqua america inc': 'aqua america inc',
#  'aquamarine westside llc': 'aquamarine westside llc',
#  'aquarius community solar gardens, llc': 'aquarius community solar gardens, llc',
#  'aquenergy systems inc': 'aquenergy systems inc',
#  'aquila community solar gardens, llc': 'aquila community solar gardens, llc',
#  'aragonne wind ii llc': 'aragonne wind ii llc',
#  'aragonne wind llc': 'aragonne wind llc',
#  'arborgate farm, llc': 'arborgate farm, llc',
#  'arbuckle mountain wind farm llc': 'arbuckle mountain wind farm llc',
#  'arcelormittal burns harbor inc': 'arcelormittal burns harbor inc',
#  'arcelormittal cleveland inc': 'arcelormittal cleveland inc',
#  'arcelormittal indiana harbor west': 'arcelormittal indiana harbor west',
#  'arcelormittal usa inc': 'arcelormittal usa inc',
#  'arcelormittal warren inc': 'arcelormittal warren inc',
#  'archer daniels midland co': 'archer daniels midland co',
#  'arcturus community solar garden, llc': 'arcturus community solar garden, llc',
#  'ares eif management, llc': 'ares eif management, llc',
#  'argand energy solutions, llc': 'argand energy solutions, llc',
#  'argo navis community solar': 'argo navis community solar',
#  'argonne national laboratory': 'argonne national laboratory',
#  'argos solar llc': 'argos solar llc',
#  'aries community solar': 'aries community solar',
#  'arizona electric pwr coop inc': 'arizona electric pwr coop inc',
#  'arizona public service co': 'pinnacle west capital',
#  'arizona solar one llc': 'arizona solar one llc',
#  'arizona state university fdm': 'arizona state university fdm',
#  'arkalon ethanol llc': 'arkalon ethanol llc',
#  'arkansas electric coop corp': 'arkansas electric coop corp',
#  'arkansas river power authority': 'arkansas river power authority',
#  'arkwright summit wind farm llc': 'arkwright summit wind farm llc',
#  'arlington valley llc': 'arlington valley llc',
#  'arlington valley solar energy ii llc': 'arlington valley solar energy ii llc',
#  'arlington wind power project llc': 'arlington wind power project llc',
#  'armadillo flats wind project, llc': 'armadillo flats wind project, llc',
#  'armstrong power llc': 'armstrong power llc',
#  'arrow canyon solar llc': 'arrow canyon solar llc',
#  'artemis solar llc': 'artemis solar llc',
#  'arthur kill power llc': 'arthur kill power llc',
#  'ascend performance materials': 'ascend performance materials',
#  'ascend performance materials llc': 'ascend performance materials llc',
#  'ashby solar, llc': 'ashby solar, llc',
#  'ashley energy llc': 'ashley energy llc',
#  'ashley solar (sc)': 'ashley solar (sc)',
#  'ashley solar farm, llc': 'ashley solar farm, llc',
#  'ashtabula wind ii llc': 'ashtabula wind ii llc',
#  'ashtabula wind iii llc': 'ashtabula wind iii llc',
#  'assembly solar, llc': 'assembly solar, llc',
#  'associated electric coop, inc': 'associated electric coop, inc',
#  'astoria energy ii llc': 'astoria energy ii llc',
#  'astoria energy llc': 'astoria energy llc',
#  'astra wind llc': 'astra wind llc',
#  'athens energy, llc': 'athens energy, llc',
#  'athens regional medical center': 'athens regional medical center',
#  'athens-johnston renewables, llc': 'athens-johnston renewables, llc',
#  'atkinson farm, llc': 'atkinson farm, llc',
#  'atkinson solar ii llc': 'atkinson solar ii llc',
#  'atlanta gift mart lp': 'atlanta gift mart lp',
#  'atlantic municipal utilities': 'atlantic municipal utilities',
#  'atlantic power corporation': 'atlantic power corporation',
#  'atlantic solar': 'atlantic solar',
#  'atlantic-vmd revere realty, llc': 'atlantic-vmd revere realty, llc',
#  'atwater solar, llc': 'atwater solar, llc',
#  'atwell solar trust 2012': 'atwell solar trust 2012',
#  'auburn board of public works': 'auburn board of public works',
#  'auburndale peaker energy center llc': 'auburndale peaker energy center llc',
#  'audrey solar llc': 'audrey solar llc',
#  'august wind energy, llc': 'august wind energy, llc',
#  'augusta canal authority': 'augusta canal authority',
#  'augusta solar farm, llc': 'augusta solar farm, llc',
#  'augustus farm, llc': 'augustus farm, llc',
#  'aulander holloman solar, llc': 'aulander holloman solar, llc',
#  'auriga community solar garden, llc': 'auriga community solar garden, llc',
#  'aurora energy llc': 'aurora energy llc',
#  'aurora generation llc': 'aurora generation llc',
#  'austin energy': 'austin energy',
#  'auwahi wind energy llc': 'sempra energy',
#  'avalon hydropower llc': 'avalon hydropower llc',
#  'avalon solar': 'avalon solar',
#  'avalon solar partners ii, llc': 'avalon solar partners ii, llc',
#  'avangrid renewables llc': 'avangrid renewables llc',
#  'avenal solar holdings llc': 'clearway energy',
#  'avidan energy solutions': 'avidan energy solutions',
#  'avista corp': 'avista',
#  'axiall corp': 'axiall corp',
#  'axio green llc': 'axio green llc',
#  'axium us solar holdings llc': 'axium us solar holdings llc',
#  'b & k solar': 'b & k solar',
#  'b braun medical inc': 'b braun medical inc',
#  'b-41 associates': 'b-41 associates',
#  'ba leasing bsc, llc': 'ba leasing bsc, llc',
#  'baif granite holdings llc': 'baif granite holdings llc',
#  'bal green biogas i llc': 'bal green biogas i llc',
#  'basf corp': 'basf corp',
#  'basf corporation': 'basf corporation',
#  'bc landfill energy llc': 'bc landfill energy llc',
#  'bc solar': 'bc solar',
#  'bcc solar iii, llc': 'bcc solar iii, llc',
#  'be ma solar, llc': 'be ma solar, llc',
#  'be minnesota wind holdings llc': 'be minnesota wind holdings llc',
#  'bf atl realty services llc': 'bf atl realty services llc',
#  'bfi waste systems of ga, llc': 'bfi waste systems of ga, llc',
#  'bhe renewables, llc': 'berkshire hathaway',
#  'bher power resources, inc': 'berkshire hathaway',
#  'bif iii holtwood llc': 'bif iii holtwood llc',
#  'bmp wind llc': 'bmp wind llc',
#  'bmw manufacturing co llc': 'bmw manufacturing co llc',
#  'bnb camden solar llc': 'bnb camden solar llc',
#  'bp alternative energy': 'bp alternative energy',
#  'bp america inc': 'bp america inc',
#  'bp hydro associates': 'bp hydro associates',
#  'bp plc': 'bp plc',
#  'bp piney & deep creek llc': 'bp piney & deep creek llc',
#  'bp wind energy north america inc': 'bp wind energy north america inc',
#  'bpif llc': 'bpif llc',
#  'bq energy llc': 'bq energy llc',
#  'brascan power corporation': 'brascan power corporation',
#  'bre nc solar 2, llc': 'bre nc solar 2, llc',
#  'bre nc solar 3, llc': 'bre nc solar 3, llc',
#  'bre nc solar 4, llc': 'bre nc solar 4, llc',
#  'bre partner - bre': 'bre partner - bre',
#  'bt capital': 'bt capital',
#  'bt coniglio solar llc': 'bt coniglio solar llc',
#  'bt cooke solar, llc': 'bt cooke solar, llc',
#  'bt kellam solar llc': 'bt kellam solar llc',
#  'btec turbines lp': 'btec turbines lp',
#  'bwc french river, llc': 'bwc french river, llc',
#  'bwc gibbs brook, llc': 'bwc gibbs brook, llc',
#  'bwc harlow brook, llc': 'bwc harlow brook, llc',
#  'bwc origination 18, llc': 'bwc origination 18, llc',
#  'bwc origination 4, llc': 'bwc origination 4, llc',
#  'bwc pocasset river, llc': 'bwc pocasset river, llc',
#  'bwc salmon brook, llc': 'bwc salmon brook, llc',
#  'bwc stillwater river, llc': 'bwc stillwater river, llc',
#  'bwc swan pond river, llc': 'clearway energy',
#  'bwc wareham river, llc': 'bwc wareham river, llc',
#  'babcock & brown renewable holdings inc': 'babcock & brown renewable holdings inc',
#  'baconton power llc': 'baconton power llc',
#  'badger farm, llc': 'badger farm, llc',
#  'bailey farm llc': 'bailey farm llc',
#  'baker station associates, lp': 'baker station associates, lp',
#  'bakersfield 111 llc': 'bakersfield 111 llc',
#  'bakersfield fuel cell 1, llc': 'bakersfield fuel cell 1, llc',
#  'bakersfield industrial pv 1, llc': 'bakersfield industrial pv 1, llc',
#  'bakersfield pv 1, llc': 'bakersfield pv 1, llc',
#  'bakerstand solar llc': 'bakerstand solar llc',
#  'baldwin wind llc': 'baldwin wind llc',
#  'balko wind llc': 'balko wind llc',
#  'ballston solar llc': 'ballston solar llc',
#  'baltimore church solar, llc': 'baltimore church solar, llc',
#  'banc of america leasing & capital llc': 'banc of america leasing & capital llc',
#  'bancroft municipal utilities': 'bancroft municipal utilities',
#  'bani solar, llc': 'bani solar, llc',
#  'banister hydro lp': 'banister hydro lp',
#  'bank of the west': 'bank of the west',
#  'bankers commercial corporation': 'bankers commercial corporation',
#  'bannock county landfill': 'bannock county landfill',
#  'banyan solarcity owner 2010 llc': 'banyan solarcity owner 2010 llc',
#  'banyan st./gap 191 peachtree owner, llc': 'banyan st./gap 191 peachtree owner, llc',
#  'baptist memorial hospital': 'baptist memorial hospital',
#  'barker solar, llc': 'barker solar, llc',
#  'barnwell solar, llc': 'barnwell solar, llc',
#  'barre energy partners lp': 'barre energy partners lp',
#  'barre solar iii llc': 'barre solar iii llc',
#  'barrick goldstrike mines inc': 'barrick goldstrike mines inc',
#  'barrow utils & elec coop, inc': 'barrow utils & elec coop, inc',
#  'barton solar, llc': 'barton solar, llc',
#  'barton village, inc': 'barton village, inc',
#  'bashaw solar 1, llc': 'clearway energy',
#  'basin creek power services llc': 'basin creek power services llc',
#  'basin electric power coop': 'basin electric power coop',
#  'bassett healthcare': 'bassett healthcare',
#  'bastrop energy partners, lp': 'bastrop energy partners, lp',
#  'battery utility of ohio llc': 'battery utility of ohio llc',
#  'battle solar': 'battle solar',
#  'bay county board-county comm': 'bay county board-county comm',
#  'bay windpower llc': 'bay windpower llc',
#  'baywa r.e wind llc': 'baywa r.e wind llc',
#  'baywa r.e. solar projects llc': 'baywa r.e. solar projects llc',
#  'baywa r.e. usa, llc': 'baywa r.e. usa, llc',
#  'bayles energy llc': 'bayles energy llc',
#  'bayonne energy center llc': 'bayonne energy center llc',
#  'bayonne municipal utilities authority': 'bayonne municipal utilities authority',
#  'bayonne plant holdings, llc': 'bayonne plant holdings, llc',
#  'bayou power llc': 'bayou power llc',
#  'bayshore solar a llc': 'bayshore solar a llc',
#  'bayshore solar b llc': 'bayshore solar b llc',
#  'bayshore solar c llc': 'bayshore solar c llc',
#  'bayswater peaking facility llc': 'bayswater peaking facility llc',
#  'baytown energy center llc': 'baytown energy center llc',
#  'beacon power llc': 'beacon power llc',
#  'bear poplar solar, llc': 'bear poplar solar, llc',
#  'bear swamp power company llc': 'bear swamp power company llc',
#  'bearpond solar center llc': 'bearpond solar center llc',
#  'bearford farm, llc': 'bearford farm, llc',
#  'bearford solar ii, llc': 'bearford solar ii, llc',
#  'bearkat i te partnership llc': 'bearkat i te partnership llc',
#  'bearkat ii te partnership llc': 'bearkat ii te partnership llc',
#  'bearkat te partnership llc': 'bearkat te partnership llc',
#  'beaver city corporation': 'beaver city corporation',
#  'beaver dam energy llc': 'beaver dam energy llc',
#  'beaver falls municipal auth': 'beaver falls municipal auth',
#  'beaver ridge wind llc': 'beaver ridge wind llc',
#  'bed bath & beyond': 'bed bath & beyond',
#  'bedford solar, llc': 'bedford solar, llc',
#  'beebe 1b renewable energy, llc': 'beebe 1b renewable energy, llc',
#  'beebe renewable energy, llc': 'beebe renewable energy, llc',
#  'beech ridge ii wind energy center': 'beech ridge ii wind energy center',
#  'belcher solar llc': 'belcher solar llc',
#  'belchertown renewables, llc': 'belchertown renewables, llc',
#  'bell bay solar farm': 'bell bay solar farm',
#  'bell solar': 'bell solar',
#  'bellefontaine gas producers llc': 'bellefontaine gas producers llc',
#  'beloit memorial hospital': 'beloit memorial hospital',
#  'belwood farm llc': 'belwood farm llc',
#  'bennett creek windfarm llc': 'bennett creek windfarm llc',
#  'benson creek': 'benson creek',
#  'benson power, llc.': 'benson power, llc.',
#  'bentonsun, llc': 'bentonsun, llc',
#  'berkeley cogeneration facility': 'berkeley cogeneration facility',
#  'berkshire power co llc': 'berkshire power co llc',
#  'berkshire wind power cooperative corp': 'berkshire wind power cooperative corp',
#  'berlin station, llc': 'berlin station, llc',
#  'bernhardt furniture company': 'bernhardt furniture company',
#  'berry petroleum co': 'berry petroleum co',
#  'betcher csg llc': 'betcher csg llc',
#  'bethel price solar, llc': 'bethel price solar, llc',
#  'bethel solar llc': 'bethel solar llc',
#  'bethlehem renewable energy llc': 'bethlehem renewable energy llc',
#  'bicent ca malburg llc': 'bicent ca malburg llc',
#  'bicent power': 'bicent power',
#  'big blue river wind farm llc': 'big blue river wind farm llc',
#  'big blue wind farm llc (mn)': 'big blue wind farm llc (mn)',
#  'big creek water works ltd': 'big creek water works ltd',
#  'big fork solar': 'big fork solar',
#  'big lake holdco llc': 'clearway energy',
#  'big level wind llc': 'big level wind llc',
#  'big rivers electric corp': 'big rivers electric corp',
#  'big valley power (bvp) llc': 'big valley power (bvp) llc',
#  'biltmore energy company, llc': 'biltmore energy company, llc',
#  'biltmore natural resources, llc': 'biltmore natural resources, llc',
#  'bio energy washington, llc': 'bio energy washington, llc',
#  'bio-gas technologies ltd': 'bio-gas technologies ltd',
#  'biofuels point loma llc': 'biofuels point loma llc',
#  'biotown ag': 'biotown ag',
#  'biogas energy solutions': 'biogas energy solutions',
#  'biola university': 'biola university',
#  'biomass one lp': 'biomass one lp',
#  'birch power co': 'birch power co',
#  'birch power llc': 'birch power llc',
#  'birch solar': 'birch solar',
#  'birchwood power partners lp': 'birchwood power partners lp',
#  'bird machine solar farm, llc': 'bird machine solar farm, llc',
#  'birdsboro power llc': 'birdsboro power llc',
#  'biscoe owner, llc': 'biscoe owner, llc',
#  'bishop hill energy ii, llc': 'bishop hill energy ii, llc',
#  'bison solar llc': 'bison solar llc',
#  'bisson windfarm llc': 'bisson windfarm llc',
#  'black bear power llc': 'black bear power llc',
#  'black bear wind llc': 'black bear wind llc',
#  'black creek hydro inc': 'black creek hydro inc',
#  'black creek renewable energy llc': 'black creek renewable energy llc',
#  'black hills colorado electric, llc': 'black hills colorado electric, llc',
#  'black hills colorado ipp, llc': 'black hills',
#  'black hills electric generation llc': 'black hills electric generation llc',
#  'black hills power, inc. d/b/a': 'black hills power, inc. d/b/a',
#  'black hills service company llc': 'black hills service company llc',
#  'black hills wyoming inc': 'black hills wyoming inc',
#  'black mountain solar llc': 'black mountain solar llc',
#  'black oak wind, llc': 'black oak wind, llc',
#  'black river generation llc': 'black river generation llc',
#  'black river hydroelectric, llc': 'black river hydroelectric, llc',
#  'blackrock inc.': 'blackrock inc.',
#  'blackstone hydro inc.': 'blackstone hydro inc.',
#  'blackstone wind farm ii llc': 'edp-energias de portugal',
#  'blackstone wind farm llc': 'blackstone wind farm llc',
#  'blacktip solar, llc': 'blacktip solar, llc',
#  'blackville solar farm, llc': 'blackville solar farm, llc',
#  'blackwell wind, llc': 'blackwell wind, llc',
#  'bladenboro farm 2 llc': 'bladenboro farm 2 llc',
#  'blandenboro farm llc': 'blandenboro farm llc',
#  'blazing star 2 llc': 'blazing star 2 llc',
#  'blazing star wind farm, llc': 'blazing star wind farm, llc',
#  'blind canyon aqua ranch inc': 'blind canyon aqua ranch inc',
#  'block island power co': 'block island power co',
#  'bloom energy': 'bloom energy',
#  'bloom energy 2009 ppa': 'bloom energy 2009 ppa',
#  'bloom solar, llc': 'bloom solar, llc',
#  'bloomington solar i': 'bloomington solar i',
#  'blue canyon windpower ii llc': 'blue canyon windpower ii llc',
#  'blue canyon windpower llc': 'blue canyon windpower llc',
#  'blue canyon windpower v llc': 'blue canyon windpower v llc',
#  'blue canyon windpower vi llc': 'blue canyon windpower vi llc',
#  'blue cloud wind energy': 'blue cloud wind energy',
#  'blue earth light & water': 'blue earth light & water',
#  'blue hen wind': 'blue hen wind',
#  'blue heron hydro llc': 'blue heron hydro llc',
#  'blue lake power llc': 'blue lake power llc',
#  'blue marmot ix llc': 'blue marmot ix llc',
#  'blue marmot v llc': 'blue marmot v llc',
#  'blue marmot vi llc': 'blue marmot vi llc',
#  'blue marmot vii llc': 'blue marmot vii llc',
#  'blue marmot viii llc': 'blue marmot viii llc',
#  'blue mountain biogas llc': 'blue mountain biogas llc',
#  'blue renewable energy ims, llc': 'blue renewable energy ims, llc',
#  'blue ridge paper products inc': 'blue ridge paper products inc',
#  'blue summit ii wind, llc': 'blue summit ii wind, llc',
#  'blue summit iii wind, llc': 'blue summit iii wind, llc',
#  'blue summit storage, llc': 'blue summit storage, llc',
#  'blue summit wind llc': 'blue summit wind llc',
#  'blue water renewables inc': 'blue water renewables inc',
#  'bluebell solar, llc': 'bluebell solar, llc',
#  'bluegrove wind, llc': 'bluegrove wind, llc',
#  'bluestem llc': 'bluestem llc',
#  'bluestem wind energy, llc': 'bluestem wind energy, llc',
#  'bluff point wind, llc': 'bluff point wind, llc',
#  'blythe solar 110, llc': 'nextera energy',
#  'blythe solar ii, llc': 'nextera energy',
#  'blythe solar iii, llc': 'nextera energy',
#  'blythe solar iv, llc': 'nextera energy',
#  'board of water electric & communications': 'board of water electric & communications',
#  'bob jones university': 'bob jones university',
#  'boeve windfarm llc': 'boeve windfarm llc',
#  'boise cascade wood products llc': 'boise cascade wood products llc',
#  'boise packaging & newsprint llc': 'boise packaging & newsprint llc',
#  'boise white paper llc': 'boise white paper llc',
#  'boise-kuna irrigation district': 'boise-kuna irrigation district',
#  'bolton farm llc': 'bolton farm llc',
#  'boltonville hydro associates': 'boltonville hydro associates',
#  'bonanza bioenergy llc': 'bonanza bioenergy llc',
#  'bond solar, llc': 'bond solar, llc',
#  'bonneville nevada corporation': 'bonneville nevada corporation',
#  'boott hydropower inc': 'boott hydropower inc',
#  'boralex hydro operations inc': 'boralex hydro operations inc',
#  'boralex middle falls, llc': 'boralex middle falls, llc',
#  'borger energy associates lp': 'borger energy associates lp',
#  'boring solar llc': 'boring solar llc',
#  'borough of chambersburg': 'borough of chambersburg',
#  'borrego solar systems inc': 'borrego solar systems inc',
#  'bos dairy, llc': 'bos dairy, llc',
#  'boston medical center': 'boston medical center',
#  'bostonia wsmr spv llc': 'bostonia wsmr spv llc',
#  'boswell wind project i, llc': 'boswell wind project i, llc',
#  'boswell wind project ii, llc': 'boswell wind project ii, llc',
#  'boswell wind project iii, llc': 'boswell wind project iii, llc',
#  'boswell wind project iv, llc': 'boswell wind project iv, llc',
#  'bottle rock power llc': 'bottle rock power llc',
#  'boulder city of': 'boulder city of',
#  'bowater newport coosa pines op': 'bowater newport coosa pines op',
#  'bowerman power lfg, llc': 'bowerman power lfg, llc',
#  'bowersock mills & power co': 'bowersock mills & power co',
#  'boyce hydro power llc': 'boyce hydro power llc',
#  'bradley farm llc': 'bradley farm llc',
#  'brady power partners': 'brady power partners',
#  'brady wind ii, llc': 'brady wind ii, llc',
#  'brady wind, llc': 'brady wind, llc',
#  'brahms wind, llc': 'brahms wind, llc',
#  'brainerd public utilities': 'brainerd public utilities',
#  'brandon shores llc': 'brandon shores llc',
#  'brassua hydroelectric lp': 'brassua hydroelectric lp',
#  'brazos electric power coop inc': 'brazos electric power coop inc',
#  'brazos sandy creek electric coop inc': 'brazos sandy creek electric coop inc',
#  'brazos valley energy': 'brazos valley energy',
#  'brea generation llc': 'brea generation llc',
#  'brea power ii': 'brea power ii',
#  'brevard energy, llc        ': 'brevard energy, llc        ',
#  'brewster': 'brewster',
#  'briar-hydro associates': 'briar-hydro associates',
#  'brick standard, llc': 'brick standard, llc',
#  'bridge energy llc': 'bridge energy llc',
#  'bridgeport disposal llc': 'bridgeport disposal llc',
#  'bridgeport energy llc': 'bridgeport energy llc',
#  'bridgewater power co lp': 'bridgewater power co lp',
#  'brigham city corporation': 'brigham city corporation',
#  'brigham young univ idaho': 'brigham young univ idaho',
#  'bristol-myers squibb co': 'bristol-myers squibb co',
#  'broad river energy llc': 'broad river energy llc',
#  'broad river solar, llc': 'broad river solar, llc',
#  'broadlands wind farm llc': 'broadlands wind farm llc',
#  'broadridge customer communications': 'broadridge customer communications',
#  'broadridge solar, llc': 'broadridge solar, llc',
#  'broadview energy jn, llc': 'broadview energy jn, llc',
#  'broadview energy kw, llc': 'broadview energy kw, llc',
#  'broken bow wind ii, llc': 'broken bow wind ii, llc',
#  'brook street solar 1, llc': 'clearway energy',
#  'brookfield black bear hydro, llc': 'brookfield black bear hydro, llc',
#  'brookfield energy marketing lp': 'brookfield energy marketing lp',
#  'brookfield energy marketing us llc': 'brookfield energy marketing us llc',
#  'brookfield power new england': 'brookfield power new england',
#  'brookfield renewable energy group': 'brookfield renewable energy group',
#  'brookfield smoky mountain hydropower llc': 'brookfield smoky mountain hydropower llc',
#  'brookfield solar 2013, llc': 'brookfield solar 2013, llc',
#  'brookfield white pine hydro llc': 'brookfield white pine hydro llc',
#  'brooklyn hospital center': 'brooklyn hospital center',
#  'brooklyn navy yard cogen plp': 'brooklyn navy yard cogen plp',
#  'brooks energy, llc': 'brooks energy, llc',
#  'broome energy resources, llc': 'broome energy resources, llc',
#  'broshco fabricated products': 'broshco fabricated products',
#  'brownsville public utilities board': 'brownsville public utilities board',
#  'bruce power, llc': 'bruce power, llc',
#  'brunner island llc': 'brunner island llc',
#  'brunswick cellulose llc': 'brunswick cellulose llc',
#  'buchanan generation, llc': 'buchanan generation, llc',
#  'buckeye florida ltd partners': 'buckeye florida ltd partners',
#  'buckeye power, inc': 'buckeye power, inc',
#  'bucknell university': 'bucknell university',
#  'bucksport generation llc': 'bucksport generation llc',
#  'buckthorn westex, llc': 'clearway energy',
#  'buckthorn wind project, llc': 'buckthorn wind project, llc',
#  'buena vista biomass llc': 'buena vista biomass llc',
#  'buena vista energy llc': 'buena vista energy llc',
#  'buenos aires windpower llc': 'buenos aires windpower llc',
#  'buffalo center wind llc': 'buffalo center wind llc',
#  'buffalo dunes wind project llc': 'buffalo dunes wind project llc',
#  'bull creek wind llc': 'iberdrola',
#  'bulldog energy airport llc': 'bulldog energy airport llc',
#  'bulldog wind energy, llc': 'bulldog wind energy, llc',
#  'bullock road solar 1, llc': 'clearway energy',
#  'bunge north america east llc': 'bunge north america east llc',
#  'bunn level farm, llc': 'bunn level farm, llc',
#  'burgaw solar, llc': 'burgaw solar, llc',
#  'burke wind llc': 'burke wind llc',
#  'burney biomass power llc': 'burney biomass power llc',
#  'burrows paper corp': 'burrows paper corp',
#  'burrstone energy center': 'burrstone energy center',
#  'butler ridge wind energy center': 'butler ridge wind energy center',
#  'butte-glenn community college district': 'butte-glenn community college district',
#  'butter solar, llc': 'butter solar, llc',
#  'byers wind, llc': 'byers wind, llc',
#  'c&h sugar company inc': 'c&h sugar company inc',
#  'c-drop': 'c-drop',
#  'c-s canal hydro, llc': 'c-s canal hydro, llc',
#  'c2 starratt solar llc': 'c2 starratt solar llc',
#  'c4gt, llc': 'c4gt, llc',
#  'ca odevi llc': 'ca odevi llc',
#  'cb&i': 'cb&i',
#  'cbc alternative energy, llc': 'cbc alternative energy, llc',
#  'cbs broadcasting, inc.': 'cbs broadcasting, inc.',
#  'cbs television city': 'cbs television city',
#  'cc polymers llc': 'cc polymers llc',
#  'ccc hastings renewable energy, llc': 'ccc hastings renewable energy, llc',
#  'ccc solar holdings llc': 'ccc solar holdings llc',
#  'cci roseton llc': 'cci roseton llc',
#  'cd arevon usa, inc.': 'cd arevon usa, inc.',
#  'cd global ii csolar, llc': 'cd global ii csolar, llc',
#  'cd global solar holdings, llc': 'cd global solar holdings, llc',
#  'cd us solar mt 2 llc': 'cd us solar mt 2 llc',
#  'cd us solar mt1 llc': 'cd us solar mt1 llc',
#  'cd us solar mt3, llc': 'cd us solar mt3, llc',
#  'cd us solar po 2 llc': 'cd us solar po 2 llc',
#  'cd us solar po 3, llc': 'cd us solar po 3, llc',
#  'ce generation': 'ce generation',
#  'ce obsidian energy llc': 'ce obsidian energy llc',
#  'cen juncos solar llc': 'cen juncos solar llc',
#  'cer colorado bend energy partners lp': 'cer colorado bend energy partners lp',
#  'cer generation llc': 'cer generation llc',
#  'cer quail run energy partners lp': 'cer quail run energy partners lp',
#  'ces placerita inc': 'ces placerita inc',
#  'cf cvec owner one llc': 'cf cvec owner one llc',
#  'cf gainesville owner one llc': 'cf gainesville owner one llc',
#  'cf industries nitrogen llc': 'cf industries nitrogen llc',
#  'cf jersey gardens owner two llc': 'cf jersey gardens owner two llc',
#  'cf novel solar gardens eleven llc': 'cf novel solar gardens eleven llc',
#  'cf novel solar gardens two llc': 'cf novel solar gardens two llc',
#  'cf sbc master tenant one llc': 'cf sbc master tenant one llc',
#  'cfw solar x llc': 'cfw solar x llc',
#  'cg windfarm llc': 'cg windfarm llc',
#  'ch4 biogas llc': 'ch4 biogas llc',
#  'chi energy inc': 'chi energy inc',
#  'chi operations inc': 'chi operations inc',
#  'chi west inc': 'chi west inc',
#  'chi-west inc': 'chi-west inc',
#  'ci iii vk i te partnership llc': 'ci iii vk i te partnership llc',
#  'cii carbon llc': 'cii carbon llc',
#  'cii wood power inc': 'cii wood power inc',
#  'cip ii/ar bridgewater holdings llc': 'cip ii/ar bridgewater holdings llc',
#  'citgo petroleum corp': 'citgo petroleum corp',
#  'cmd carson gp llc': 'cmd carson gp llc',
#  'cmd carson llc': 'cmd carson llc',
#  'cmr solar, llc': 'clearway energy',
#  'cms generation filer city inc': 'cms generation filer city inc',
#  'cms generation genesee co': 'cms generation genesee co',
#  'cms generation grayling co': 'cms generation grayling co',
#  'cms generation holdings co': 'cms generation holdings co',
#  'cms generation mi power llc': 'cms generation mi power llc',
#  'cms generation operating co ii': 'cms generation operating co ii',
#  'cms generation operating llc': 'cms generation operating llc',
#  'consol energy inc': 'consol energy inc',
#  'cot/division of water reclamation': 'cot/division of water reclamation',
#  'cp crane power, llc': 'cp crane power, llc',
#  'cpi usa nc roxboro llc': 'cpi usa nc roxboro llc',
#  'cpi usa nc southport llc': 'cpi usa nc southport llc',
#  'cpkelco u s inc': 'cpkelco u s inc',
#  'cpv fairview, llc': 'cpv fairview, llc',
#  'cpv keenan ii renewable energy co llc': 'cpv keenan ii renewable energy co llc',
#  'cpv maryland llc': 'cpv maryland llc',
#  'cpv sentinel llc': 'cpv sentinel llc',
#  'cpv towantic, llc': 'cpv towantic, llc',
#  'cpv valley, llc': 'cpv valley, llc',
#  'cr clearing, llc': 'cr clearing, llc',
#  'cre-avalon arizona llc': 'cre-avalon arizona llc',
#  'cre-sunray california llc delaware': 'cre-sunray california llc delaware',
#  'cre-sunray energy 3 california llc delaware': 'cre-sunray energy 3 california llc delaware',
#  'cre-three peaks utah llc': 'cre-three peaks utah llc',
#  'cropp cooperative': 'cropp cooperative',
#  'cs murphy point, llc': 'duke energy',
#  'csi project holdco, llc': 'csi project holdco, llc',
#  'csl behring llc': 'csl behring llc',
#  'csolar iv south llc': 'csolar iv south llc',
#  'csolar iv west llc': 'csolar iv west llc',
#  'csuci site authority': 'csuci site authority',
#  'ctgb solar mission iii llc': 'ctgb solar mission iii llc',
#  'ctv marketing group': 'ctv marketing group',
#  'cu solar llc': 'cu solar llc',
#  'cxa la paloma llc': 'cxa la paloma llc',
#  'cadillac renewable energy llc': 'cadillac renewable energy llc',
#  'caelum community solar': 'caelum community solar',
#  'caithness energy': 'caithness energy',
#  'caithness long island, llc': 'caithness energy',
#  'caithness shepherds flat llc': 'caithness shepherds flat llc',
#  'caithness vg wind llc': 'caithness vg wind llc',
#  'calenergy operating corporation': 'calenergy operating corporation',
#  'calpers': 'calpers',
#  'calpeak power - border llc': 'calpeak power - border llc',
#  'calpeak power - enterprise llc': 'calpeak power - enterprise llc',
#  'calpeak power - panoche llc': 'calpeak power - panoche llc',
#  'calpeak power - vaca dixon llc': 'calpeak power - vaca dixon llc',
#  'calrenew-1 llc': 'calrenew-1 llc',
#  'calwind resources inc': 'calwind resources inc',
#  'calaveras county water dist': 'calaveras county water dist',
#  'caldwell wastewater treatment plant': 'caldwell wastewater treatment plant',
#  'calhoun power co llc': 'calhoun power co llc',
#  'california dept of corrections': 'california dept of corrections',
#  'california dept. of water resources': 'california dept. of water resources',
#  'california ethanol power, llc': 'california ethanol power, llc',
#  'california flats solar 130, llc': 'california flats solar 130, llc',
#  'california holdings delano 2 llc': 'california holdings delano 2 llc',
#  'california holdings delano llc': 'california holdings delano llc',
#  'california institute-technology': 'california institute-technology',
#  'california pv energy 2, llc': 'california pv energy 2, llc',
#  'california pv energy llc': 'california pv energy llc',
#  'california power holdings llc': 'california power holdings llc',
#  'california resources elk hills llc': 'california resources elk hills llc',
#  'california state university at fullerton': 'california state university at fullerton',
#  'california state university, northridge': 'california state university, northridge',
#  'calleguas mun water district': 'calleguas mun water district',
#  'calpeak operating services, llc': 'calpeak operating services, llc',
#  'calpine -rockgen energy': 'calpine -rockgen energy',
#  'calpine bethlehem llc': 'calpine bethlehem llc',
#  'calpine bosque energy center llc': 'calpine bosque energy center llc',
#  'calpine central lp': 'calpine central lp',
#  'calpine corp': 'calpine',
#  'calpine corp - hidalgo': 'calpine corp - hidalgo',
#  'calpine corp - metcalf energy center': 'calpine corp - metcalf energy center',
#  'calpine corp - pastoria energy center': 'calpine corp - pastoria energy center',
#  'calpine corp-king city': 'calpine corp-king city',
#  'calpine corp-magic valley': 'calpine corp-magic valley',
#  'calpine corp-sutter': 'calpine corp-sutter',
#  'calpine corp-yuba city': 'calpine corp-yuba city',
#  'calpine corporation': 'calpine',
#  'calpine eastern corp': 'calpine eastern corp',
#  'calpine fore river energy center, llc': 'calpine fore river energy center, llc',
#  'calpine gilroy cogen lp': 'calpine gilroy cogen lp',
#  'calpine king city cogen llc': 'calpine king city cogen llc',
#  'calpine mid-atlantic generation llc': 'calpine mid-atlantic generation llc',
#  'calpine mid-merit llc': 'calpine mid-merit llc',
#  'calpine new jersey generation llc': 'calpine new jersey generation llc',
#  'calpine vineland solar llc': 'calpine vineland solar llc',
#  'cambria cogen co': 'cambria cogen co',
#  'camden plant holdings, l.l.c.': 'camden plant holdings, l.l.c.',
#  'camden solar center, llc': 'camden solar center, llc',
#  'camelot wind llc': 'camelot wind llc',
#  'cameron ridge llc': 'cameron ridge llc',
#  'cameron solar ii, llc': 'cameron solar ii, llc',
#  'cameron solar, llc': 'cameron solar, llc',
#  'cameron wind 1 llc': 'cameron wind 1 llc',
#  'camino energy llc': 'camino energy llc',
#  'canadian hills wind llc': 'canadian hills wind llc',
#  'caney river wind project': 'caney river wind project',
#  'canopus community solar garden, llc': 'canopus community solar garden, llc',
#  'canton mountain wind llc': 'canton mountain wind llc',
#  'cape may county municipal': 'cape may county municipal',
#  'capella community solar': 'capella community solar',
#  'capital dynamics': 'capital dynamics',
#  'capital power corporation': 'capital power corporation',
#  'capitan oil pipeline co': 'capitan oil pipeline co',
#  'capitol broadcasting company inc': 'capitol broadcasting company inc',
#  'capitol district energy center': 'capitol district energy center',
#  'capricorn ridge wind llc': 'capricorn ridge wind llc',
#  'capricornus community solar garden, llc': 'capricornus community solar garden, llc',
#  'caprock solar 1, llc': 'caprock solar 1, llc',
#  'caprock solar 2, llc': 'caprock solar 2, llc',
#  'caprock wind llc': 'caprock wind llc',
#  'cardinal operating company': 'cardinal operating company',
#  'cargill inc': 'cargill inc',
#  'cargill inc north america sweetners': 'cargill inc north america sweetners',
#  'cargill salt hersey': 'cargill salt hersey',
#  'carina community solar': 'carina community solar',
#  'carleton college': 'carleton college',
#  'carlisle area school district': 'carlisle area school district',
#  'carlsbad energy center llc': 'carlsbad energy center llc',
#  'carolina poultry power': 'carolina poultry power',
#  'carolina solar energy llc': 'carolina solar energy llc',
#  'carousel wind farm, llc': 'carousel wind farm, llc',
#  'carr street generating sta lp': 'carr street generating sta lp',
#  'carroll county energy llc': 'carroll county energy llc',
#  'carrollton board of public wks': 'carrollton board of public wks',
#  'carson cogeneration co': 'carson cogeneration co',
#  'carson solar 1 llc': 'carson solar 1 llc',
#  'carstensen wind llc': 'carstensen wind llc',
#  'carthage energy llc': 'carthage energy llc',
#  'carver ma 2, llc': 'carver ma 2, llc',
#  'carville energy llc': 'carville energy llc',
#  'cary oil company': 'cary oil company',
#  'casa mesa wind, llc': 'casa mesa wind, llc',
#  'cascade municipal utilities': 'cascade municipal utilities',
#  'cascade solar llc': 'cascade solar llc',
#  'casco bay energy co llc': 'casco bay energy co llc',
#  'case western reserve university': 'case western reserve university',
#  'casella waste systems': 'casella waste systems',
#  'cashton greens wind farm llc': 'cashton greens wind farm llc',
#  'cassia gulch wind park, llc': 'cassia gulch wind park, llc',
#  'cassia wind farm, llc': 'cassia wind farm, llc',
#  'cassiopeia community solar garden, llc': 'cassiopeia community solar garden, llc',
#  'castalia solar llc': 'castalia solar llc',
#  'castle rock cooling': 'castle rock cooling',
#  'castleman power development llc': 'castleman power development llc',
#  'castleton energy center': 'castleton energy center',
#  'catawba county': 'catawba county',
#  'catawba solar llc': 'catawba solar llc',
#  'caterpillar financial services': 'caterpillar financial services',
#  'caterpillar inc': 'caterpillar inc',
#  'cayuga operating company, llc': 'cayuga operating company, llc',
#  'cedar bluff wind, llc': 'cedar bluff wind, llc',
#  'cedar creek wind energy llc': 'cedar creek wind energy llc',
#  'cedar falls solar farm, llc': 'cedar falls solar farm, llc',
#  'cedar falls utilities': 'cedar falls utilities',
#  'cedar point llc': 'cedar point llc',
#  'cedarville solar iii, llc': 'cedarville solar iii, llc',
#  'cedarville solar phase ii, llc': 'cedarville solar phase ii, llc',
#  'celanese acetate corp': 'celanese acetate corp',
#  'celanese acetate llc': 'celanese acetate llc',
#  'celina solar project #1, llc': 'celina solar project #1, llc',
#  'centaurus community solar': 'centaurus community solar',
#  'centaurus holdings, llc': 'centaurus holdings, llc',
#  'centinela solar energy llc': 'centinela solar energy llc',
#  'central antelope dry ranch c llc': 'central antelope dry ranch c llc',
#  'central arizona water conservation dist': 'central arizona water conservation dist',
#  'central ca fuel cell 2, llc': 'central ca fuel cell 2, llc',
#  'central connecticut state university': 'central connecticut state university',
#  'central contra costa sanitary district': 'central contra costa sanitary district',
#  'central electric power': 'central electric power',
#  'central hudson gas & elec corp': 'central hudson gas & elec corp',
#  'central iowa power cooperative': 'central iowa power cooperative',
#  'central michigan university': 'central michigan university',
#  'central nebraska pub p&i dist': 'central nebraska pub p&i dist',
#  'central oregon irrigation dist': 'central oregon irrigation dist',
#  'central rivers power ma, llc': 'central rivers power ma, llc',
#  'central rivers power nh, llc': 'central rivers power nh, llc',
#  'central utah water conservancy district': 'central utah water conservancy district',
#  'central valley ag power llc': 'central valley ag power llc',
#  'central valley financing auth': 'central valley financing auth',
#  'central wisconsin elec coop': 'central wisconsin elec coop',
#  'centurylink regional hq': 'centurylink regional hq',
#  'chadbourn farm llc': 'chadbourn farm llc',
#  'chaffey community college district': 'chaffey community college district',
#  'chalmette refining llc': 'chalmette refining llc',
#  'chambers cogeneration lp': 'chambers cogeneration lp',
#  'chambersburg energy, llc': 'chambersburg energy, llc',
#  'champepadan wind power partners, llc': 'champepadan wind power partners, llc',
#  'champion solar, llc': 'champion solar, llc',
#  'changeup solar, llc': 'changeup solar, llc',
#  'channel energy center llc': 'channel energy center llc',
#  'chapman ranch wind llc': 'chapman ranch wind llc',
#  'chapman solar': 'chapman solar',
#  'charlotte solar llc': 'charlotte solar llc',
#  'charlton solar i, llc': 'charlton solar i, llc',
#  'chattanooga metropolitan airport': 'chattanooga metropolitan airport',
#  'chauncey farm': 'chauncey farm',
#  'chautauqua county': 'chautauqua county',
#  'chaves solar llc': 'chaves solar llc',
#  'cherokee county cogen partners llc': 'cherokee county cogen partners llc',
#  'cherokee falls hydroelectric project, llc': 'cherokee falls hydroelectric project, llc',
#  'chester ny 1, llc': 'chester ny 1, llc',
#  'chester power partners llc': 'chester power partners llc',
#  'chester woods point solar, llc': 'chester woods point solar, llc',
#  'chestnut solar llc': 'chestnut solar llc',
#  'chevelle wind iowa llc': 'chevelle wind iowa llc',
#  'chevron oronite co llc': 'chevron oronite co llc',
#  'chevron products company-richmond': 'chevron products company-richmond',
#  'chevron technology ventures': 'chevron technology ventures',
#  'chevron usa': 'chevron usa',
#  'chevron usa inc': 'chevron usa inc',
#  'chevron usa inc-el segundo': 'chevron usa inc-el segundo',
#  'cheyenne light fuel & power d/b/a black hills energy': 'cheyenne light fuel & power d/b/a black hills energy',
#  'chief conemaugh power llc': 'chief conemaugh power llc',
#  'chief keystone power llc': 'chief keystone power llc',
#  'childress solar park llc': 'childress solar park llc',
#  'chillicothe municipal utils': 'chillicothe municipal utils',
#  'chilocco wind farm llc': 'chilocco wind farm llc',
#  'chisago community solar': 'chisago community solar',
#  'chisago holdco llc': 'clearway energy',
#  'chisago solar, llc': 'chisago solar, llc',
#  'chisholm view wind project': 'chisholm view wind project',
#  'chittenden county solar partners llc': 'chittenden county solar partners llc',
#  'choco solar llc': 'choco solar llc',
#  ...}
