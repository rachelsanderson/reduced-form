# %%
import json

# %%
newColNames = {}
newColNames['utility_name'] = ['utilname','utility_name','utility name']
newColNames['utility_id'] = ['utilcode', 'utility id', 'utility_id']
newColNames['plant_name'] = ['plntname', 'plant_name', 'plant name']
newColNames['plant_code'] = ['plntcode', 'plant_code', 'plant code']
#Plant state
newColNames['plant_state'] = ['state']
newColNames['plant_county'] = ['county']
newColNames['generator_id'] = ['gencode', 'generator id', 'generator_id']
#values are "S=Single ownership; J= Joint ownership; W=Wholly owned by an other entity"
newColNames['ownership'] = ['ownership', 'owner']
newColNames['status'] = ['status', 'proposed_status']
# TODO: NEED TO CODE PRIME MOVER SEPARATELY -- make list per generator
newColNames['prime_mover'] = [ 'prime mover', 'prime_mover', 'primemover']
newColNames['duct_burners']=['duct burners', 'duct_burners']
newColNames['nameplate_cap'] = ['nameplate', 'nameplate capacity (mw)', 'proposed_nameplate']
# TODO: NEED TO CODE ENERGY SOURCES SEPARATELY -- make list per generator
newColNames['energy_source'] = ['energy source', 'energy_source','proposed_energy_source']
newColNames['unit_code'] = [ 'unit code', 'unit_code' ]
newColNames['cogen'] = ['cogenerator', 'proposed_cogenerator']
#solid fuel gasification system?
newColNames['sfg_system'] = ['sfg_system', 'solid fuel gasification system', 'solid fuel gasification system?','proposed_sfg_system'] 

#Indicates that the generator uses carbon capture technology
newColNames['carbon_capture'] = ['carbon capture technology?', 'carboncapture', 'carbon capture technology']
# original effective month on which the generator was scheduled to start operation
newColNames['scheduled_start_month'] = ['org_month', 'effective_month', 'effective month']
newColNames['scheduled_start_year'] = ['org_year', 'effective_year', 'effective year']
# most recently updated effective month on which the generator is scheduled to start operation
newColNames['curr_sceheduled_month'] = ['current_month','current month']
newColNames['curr_scheduled_year'] = ['current_year', 'current year']
newColNames['num_wind_turbines'] = ['turbines', 'proposed_turbines']

#summer capacity in MW, estimate by respondent
newColNames['summer_cap_resp'] = ['summer_capability', 'summer_capacity', 'summer capacity (mw)', 'proposed_summer_capability']
#winter capacity in MW, estimate by respondent
newColNames['winter_cap_resp'] = ['winter_capacity','winter_capability', 'winter capacity (mw)', 'proposed_winter_capability']
#"EIA estimate of summer capacity - Megawatts"
newColNames['summer_cap_eia'] = ['summer_estimated_capability','summer_estimated_capacity']
newColNames['winter_cap_eia'] = ['winter_estimated_capability','winter_estimated_capacity']

# Indicates whether the combustion system that will power each proposed generator expects to have the regulatory permits necessary to fuel switch
newColNames['multiple_fuels'] = ['multiple_fuels', 'operating_switch', 'multiple fuels', 'multiple fuels?']
#Indicates that the generator uses pulverized coal technology
newColNames['pulverized_coal']= ['pulverized_coal', 'pulverized coal technology', 'pulverized coal technology?']
#Indicates that the generator uses fluidized bed technology
newColNames['fluidized_bed'] = ['fluidized_bed', 'fluidized bed technology', 'fluidized bed technology?']
#Indicates that the generator uses subcritical technology
newColNames['subcritical'] = ['subcritical', 'subcritical technology', 'subcritical technology?']
#Indicates that the generator uses supercritical technology
newColNames['supercritical'] = ['supercritical', 'supercritical technology', 'supercritical technology?']
#Indicates that the generator uses ultra-supercritical technology
newColNames['ultrasupercritical'] = ['ultrasupercritical', 'ultrasupercritical technology','ultrasupercritical technology?']
#The code representing the first, second, third or fourth start-up and flame stabilization energy source used by the combustion unit(s) associated with this generator
newColNames['startup_source'] = ['startup_source', 'startup source'] 

newColNames['distributed_gen'] =['proposed_distgenerator']
#Plant-level sector name, designated by the primary purpose, regulatory status and plant-level combined heat and power status
#Values are:  Commercial; Electric Utility; Industrial; Non-Combined Heat and Power Independent Power Producer (IPP); Combined Heat and Power (IPP CHP)
##NEED TO CODE SEPARATELY
newColNames['sector_name'] = ['sector_name', 'sector name']
newColNames['sector_val'] = ['sector', 'sector_number']
#Plant-level sector number, designated by the primary purpose, regulatory status and plant-level combined heat and power status
#2011 : values are "1 = Electric Utility 2 = Independent Power Producer, Non-Combined Heat and Power 3 = Independent Power Producer, Combined Heat and Power 4 = Commercial, Non-Combined Heat and Power 5 = Commercial, Combined Heat and Power 6 = Industrial, Non-Combined Heat and Power 7 = Industrial, Combined Heat and Power"

#Can this generator operate while bypassing the heat recovery steam generator?
newColNames['bypass_heat_recovery'] = ['can bypass heat recovery steam generator?']

# The designation used to identify the price node in RTO/ISO Locational Marginal Price reports
newColNames['lmp_node']=['rto/iso lmp node designation']

#The designation used to report ths specific location of the wholesale sales transactions to FERC for the Electric Quarterly Report
newColNames['lmp_node_ferc']=['rto/iso location designation for reporting wholesale sales data to ferc']

#The nameplate power factor of the generator
newColNames['nameplate_power'] = ['nameplate power factor']

#Indicates whether the generator is associated with a combined heat and power system
newColNames['chp'] = ['associated with combined heat and power system']

#Indicates whether the generator was previously reported as indefinitely postponed or canceled
newColNames['previously_canceled'] =['previously canceled']

#Number of wind turbines, inverters, or hydrokinetic buoys  
newColNames['num_turbines_inverters_buoys'] = ['turbines','turbines, inverters, or hydrokinetic buoys','turbines or hydrokinetic buoys', 'proposed_turbines']

#Indicates whether the generator uses stoker technology
newColNames['stoker_tech'] = ['stoker technology?']

#Indicates whether the generator uses other combustion technologies
newColNames['other_combustion_tech'] = ['other combustion technology?']

#Indicates whether the generator switch between oil and natural gas
newColNames['switch_oil_ng'] = ['switch between oil and natural gas?']

#Can the generator co-fire fuels?
newColNames['cofire_fuels'] = [ 'cofire fuels?']

#High level description of the technology used by the generator to produce electricity
newColNames['technology'] = ['technology']

newColNames['transportation'] = [ 'proposed_transportation']

# %%
### save dictionary of column converter

with open('../Tax Equity Code/Clean Data/eia_proposed_gen_col_dict.json', 'w') as outfile:
    json.dump(newColNames, outfile)
